# %% [markdown]
# V1 (02 11 2025): Translated from R to Python and added the visualizations for goals B to D
#
#
# V2 (04 01 2025): Loop system implemented
#
# V2.5 (04 02 2025): Loops system tweaks. Removed openpyxl as it was corrupting files and replaced it with xlwings

# %%
#!pip install numpy pandas scipy matplotlib xlwings

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import subprocess
import xlwings as xw
import time

# %%
# -- Variable Setup -- ##

#Monte Carlo Trials
n_trials = 10**5

#Case Study Profile Selection
Profile = "P1" #Either P1 or P2

#Excel worksheets
excel_returns = "Returns"
excel_volatilities = "Volatilities"
excel_correlation = "Correlation"
excel_gbi = "GBI Allocations P1" if Profile == "P1" else "GBI Allocations P2"
excel_gbi_goals = "GBI Goals P1" if Profile == "P1" else "GBI Goals P2"

# %% [markdown]
# # Define Functions
# This section defines the functions used for calculating portfolio volatility, expected return,
# goal achievement probability, and the objective (failure probability) to minimize.

# %%
def sd_f(weight_vector, covar_table):
    covar_vector = np.zeros(len(weight_vector))
    for z in range(len(weight_vector)):
        covar_vector[z] = np.sum(weight_vector * covar_table[:, z])
    return np.sqrt(np.sum(weight_vector * covar_vector))

# %%
def mean_f(weight_vector, return_vector):
    return np.sum(weight_vector * return_vector)

# %%
"""def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    # goal_vector is [value ratio, funding requirement, time horizon]
    required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
    if goal_allocation * pool >= goal_vector[1]:
        return 1
    else:
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)

""" #Made new version below that takes into account cases where the goal is too unreachable and writes down when that happens

def phi_f(goal_vector, goal_allocation, pool, mean, sd, year=None, goal_name=None):
    denominator = pool * goal_allocation
    if denominator <= 0:
        if year and goal_name:
            infeasible_goals_log.append((year, goal_name, "Zero allocation or pool"))
        return 0

    required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1

    if required_return > 1:
        if year and goal_name:
            infeasible_goals_log.append((year, goal_name, f"Required return > 100% ({required_return:.2%})"))
        return 0

    if denominator >= goal_vector[1]:
        return 1

    return 1 - norm.cdf(required_return, loc=mean, scale=sd)

# %%
def optim_function(weights):
    # Uses the current global variables: goal_vector, allocation, pool, return_vector, covar_table
    return 1 - phi_f(
        goal_vector,
        allocation,
        pool,
        mean_f(weights, return_vector),
        sd_f(weights, covar_table)
    )

# %%
def constraint_function(weights):
    # For SciPy equality constraints, we require constraint_function(weights) == 0.
    return np.sum(weights) - 1

# %%
def mvu_f(weights):
    # mvu_f is defined for mean-variance optimization (not used below).
    return -(mean_f(weights, return_vector) - 0.5 * gamma * sd_f(weights, covariances)**2)

# %%
def r_req_f(goal_vector, goal_allocation, pool):
    return (goal_vector[1] / (goal_allocation * pool))**(1 / goal_vector[2]) - 1

# %%
def get_goal_data(master_excel_path, plan=Profile):
    """
    Returns a DataFrame of the specified goal table (P1 or P2).
    P1 => B2:F5
    P2 => B7:F10
    """
    if plan == "P1":
        skip = 1  # start reading at row 2
    elif plan == "P2":
        skip = 6  # start reading at row 7
    else:
        raise ValueError("Plan not recognized. Use 'P1' or 'P2'.")

    df_goals = pd.read_excel(master_excel_path,sheet_name="Goals",skiprows=skip,nrows=4,usecols="B:F",header=0)
    # First column is "Goal Info", so make that the index
    df_goals.set_index(df_goals.columns[0], inplace=True)
    return df_goals

# %% [markdown]
# # Load & Parse Data

# %%
## -- Repo Root and Folders -- ##

# Get repo root and set folders
root = subprocess.run(["git", "rev-parse", "--show-toplevel"], capture_output=True, text=True).stdout.strip()
data_folder = os.path.join(root, "GBI Optimisation", "data")
output_folder = os.path.join(root, "GBI Optimisation")

# Get excel file and sheets
master_excel_path = os.path.join(data_folder, "Master.xlsx")

df_returns = pd.read_excel(master_excel_path, sheet_name=excel_returns)
df_vols = pd.read_excel(master_excel_path, sheet_name=excel_volatilities)

df_returns.set_index(df_returns.columns[0], inplace=True)
df_vols.set_index(df_vols.columns[0], inplace=True)

df_corr = pd.read_excel(master_excel_path, sheet_name=excel_correlation)
df_corr.set_index(df_corr.columns[0], inplace=True)

# %%
infeasible_goals_log = [] #Added for the new phi_f definition

while True:
    ## -- Loop Table -- ##
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop",usecols="B:F",skiprows=1,header=0)
    # Find Last looped year and select the next one
    # Filter only rows where LoopStatus is N
    pending_rows = table_loop_df[table_loop_df["LoopStatus"] == "N"]

    # If we find any rows, get the row with the lowest Year
    if pending_rows.empty:
        print("All loops completed")
        break


    chosen_row = pending_rows.loc[pending_rows["Year"].idxmin()]
    loop_year = chosen_row["Year"]
    loop_number = chosen_row["N"]
    loop_age1 = chosen_row["AgeP1"]
    loop_age2 = chosen_row["AgeP2"]

    print(loop_year, loop_number, loop_age1, loop_age2)

    # - Wealth - #

    # Retrieve Wealth value for selected profile and year from "Wealth" sheet
    df_wealth = pd.read_excel(master_excel_path, sheet_name="Wealth")
    df_wealth.set_index(df_wealth.columns[0], inplace=True)  # Set P1/P2 as index

    # Use profile and loop_year to get the correct pool value
    try:
        pool = df_wealth.loc[Profile, str(loop_year)]
    except KeyError:
        raise KeyError(f"Wealth data for profile '{Profile}' in year {loop_year} not found.")

    capital_market_expectations_raw = {}
    for asset in df_returns.index:
        expected_return = df_returns.loc[asset, str(loop_year)]
        volatility = df_vols.loc[asset, 'volatility']
        capital_market_expectations_raw[asset] = {
            'Return Forecast': expected_return,
            'Volatility Forecast': volatility
        }

    capital_market_expectations_raw = pd.DataFrame.from_dict(capital_market_expectations_raw, orient='index')

    capital_market_expectations_raw = capital_market_expectations_raw.reset_index()
    capital_market_expectations_raw.rename(columns={'index': 'Unnamed: 0'}, inplace=True)

    # Rearrange columns to match your old format (optional):
    capital_market_expectations_raw = capital_market_expectations_raw[['Unnamed: 0', 'Return Forecast', 'Volatility Forecast']]

    goal_data_raw = get_goal_data(master_excel_path, plan="P1")

    # - Dynamic time horizon based on current year - #

    # Step 1: Get Starting Year (minimum year in Loop sheet)
    starting_year = table_loop_df["Year"].min()

    # Step 2: Compute Goal Years = starting_year + time_horizon
    goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
    goal_years = starting_year + goal_horizons

    # Step 3: Recalculate Time Horizons = goal_years - current loop_year
    adjusted_horizons = goal_years - loop_year

    # Step 4: Replace the "Time Horizon" row in goal_data_raw
    goal_data_raw.loc["Time Horizon"] = adjusted_horizons

    # Optional: print to confirm
    print("Starting Year:", starting_year)
    print("Current Year:", loop_year)
    print("Goal Years:", goal_years.to_dict())
    print("Adjusted Horizons:", adjusted_horizons.to_dict())

    # Record number of potential investments and goals
    num_assets = capital_market_expectations_raw.shape[0]
    num_goals = goal_data_raw.shape[1]

    # Create vector of expected returns
    return_vector = capital_market_expectations_raw["Return Forecast"].to_numpy()

    # Get the correlations as a numeric DataFrame (just a num_assets × num_assets block)
    correlations = df_corr.iloc[:num_assets, :num_assets].astype(float)

    # Build the covariance matrix: stdev_i * stdev_j * correlation_ij
    stdevs = capital_market_expectations_raw["Volatility Forecast"].to_numpy()
    covariances = np.zeros((num_assets, num_assets))
    for i in range(num_assets):
        for j in range(num_assets):
            covariances[i, j] = stdevs[i] * stdevs[j] * correlations.iloc[i, j]

    goal_A = goal_data_raw["GOAL A"].values
    goal_B = goal_data_raw["GOAL B"].values
    goal_C = goal_data_raw["GOAL C"].values
    goal_D = goal_data_raw["GOAL D"].values

    # - Optimal Goal Allocation - #


    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    # Set SLSQP options to be more stringent, mimicking solnp's behavior.
    slsqp_opts = {
        'ftol': 1e-12,     # function tolerance
        'eps': 1e-12,      # finite-difference step size for gradient estimation
        'maxiter': 10000,  # maximum iterations
        'disp': False     # do not display convergence messages
    }

    for i, alloc in enumerate(goal_allocation):
        allocation = alloc      # Global variable used in optim_function
        covar_table = covariances

        # Goal A Optimization
        goal_vector = goal_A   # Global variable used in optim_function
        if goal_A[1] <= pool * allocation:
            optimal_weights_A[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_A[i, :] = result.x

        # Goal B Optimization
        goal_vector = goal_B
        if goal_B[1] <= pool * allocation:
            optimal_weights_B[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_B[i, :] = result.x

        # Goal C Optimization
        goal_vector = goal_C
        if goal_C[1] <= pool * allocation:
            optimal_weights_C[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_C[i, :] = result.x

        # Goal D Optimization
        goal_vector = goal_D
        if goal_D[1] <= pool * allocation:
            optimal_weights_D[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_D[i, :] = result.x

    # Calculate the best probability (phi) for each allocation level for every goal
    phi_A = np.zeros(len(goal_allocation))
    phi_B = np.zeros(len(goal_allocation))
    phi_C = np.zeros(len(goal_allocation))
    phi_D = np.zeros(len(goal_allocation))

    for i, alloc in enumerate(goal_allocation):
        phi_A[i] = phi_f(goal_A, alloc, pool,
                         mean_f(optimal_weights_A[i, :], return_vector),
                         sd_f(optimal_weights_A[i, :], covariances), year=loop_year, goal_name="Goal A")
        phi_B[i] = phi_f(goal_B, alloc, pool,
                         mean_f(optimal_weights_B[i, :], return_vector),
                         sd_f(optimal_weights_B[i, :], covariances), year=loop_year, goal_name="Goal B")
        phi_C[i] = phi_f(goal_C, alloc, pool,
                         mean_f(optimal_weights_C[i, :], return_vector),
                         sd_f(optimal_weights_C[i, :], covariances), year=loop_year, goal_name="Goal C")
        phi_D[i] = phi_f(goal_D, alloc, pool,
                         mean_f(optimal_weights_D[i, :], return_vector),
                         sd_f(optimal_weights_D[i, :], covariances), year=loop_year, goal_name="Goal D")

    # Simulate goal weights: each row is a simulated allocation (in percentages)
    sim_goal_weights = np.random.multinomial(100, [1/num_goals]*num_goals, size=n_trials) #this one sums to 100 so its good
    for i in range(n_trials):
        rand_vector = np.random.uniform(0, 1, num_goals)
        normalizer = np.sum(rand_vector)
        # Compute rounded percentages and enforce a minimum of 1
        percents = np.round((rand_vector / normalizer) * 100, 0)
        sim_goal_weights[i, :] = np.maximum(percents, 1)


    # Calculate utility for each simulated portfolio.
    # Note: subtract 1 from simulated weights for 0-indexing.
    utility = (
        goal_A[0] * phi_A[sim_goal_weights[:, 0] - 1] +
        goal_A[0] * goal_B[0] * phi_B[sim_goal_weights[:, 1] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * phi_C[sim_goal_weights[:, 2] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * goal_D[0] * phi_D[sim_goal_weights[:, 3] - 1]
    )

    # Find the index of the portfolio with the highest utility
    index = np.argmax(utility)
    optimal_goal_weights = sim_goal_weights[index, :]

    # - Optimal Subportfolio Allocation - #

    # Retrieve optimal subportfolio allocations
    optimal_subportfolios = np.zeros((num_goals, num_assets))
    goals = ["A", "B", "C", "D"]

    # For each goal, use the simulated percentage to select the corresponding row
    # from the optimal weights matrix (adjust for zero-indexing)
    for i in range(num_goals):
        optimal_subportfolios[i, :] = eval(f"optimal_weights_{goals[i]}")[optimal_goal_weights[i] - 1, :]

    # Compute the optimal aggregate investment portfolio.
    optimal_aggregate_portfolio = (optimal_goal_weights / 100) @ optimal_subportfolios

    #Define asset names
    asset_names = capital_market_expectations_raw.iloc[:, 0].astype(str).tolist()

    # - Storing and exporting results - #

    # Create a DataFrame for the aggregate portfolio.
    # First calculate unrounded percentages
    raw_alloc = optimal_aggregate_portfolio * 100

    # Normalize to force sum = 100 after rounding
    normalized_alloc = raw_alloc / raw_alloc.sum() * 100
    normalized_goal_alloc = optimal_goal_weights / np.sum(optimal_goal_weights) * 100

    # Create a DataFrame for the across-goal allocation.
    df_across_goal = pd.DataFrame({
        "Goal": goals,
        "Allocation (%)": np.round(normalized_goal_alloc, 2) # Keep raw percentages
    })

    # Round after normalization
    df_aggregate = pd.DataFrame({
        "Asset": asset_names,
        "Weight": optimal_aggregate_portfolio,
        "Allocation (%)": np.round(normalized_alloc, 2)
    })

    print("Optimal Across-Goal Allocation:")
    print(df_across_goal.to_string(index=False))

    print("\nOptimal Aggregate Investment Allocation:")
    print(df_aggregate.to_string(index=False))

    # -- Safer Excel launch --
    app = xw.App(visible=False)
    app.display_alerts = False
    app.screen_updating = False

    time.sleep(1)

    # Open workbook
    wb = app.books.open(master_excel_path)
    ws = wb.sheets[excel_gbi]

    # Get header values from row 1 (columns B to AY ~= cols 2 to 51)
    header_values = [ws.cells(1, col).value for col in range(2, 53)]

    try:
        year_col = header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in worksheet headers.")

    # Write weights
    for i, asset in enumerate(asset_names):
        allocation = float(np.round(normalized_alloc[i], 2)) / 100
        cell = ws.cells(i + 2, year_col)
        cell.value = allocation
        cell.number_format = '0.00%'  # display as percentage

    # -- Export Goal Weights to Excel -- #

    # Re-access the sheet after workbook is open
    ws_goals = wb.sheets[excel_gbi_goals]

    # Read header values from row 1 (columns B to AY ≈ cols 2 to 52)
    goal_header_values = [ws_goals.cells(1, col).value for col in range(2, 53)]

    try:
        goal_year_col = goal_header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in goal worksheet headers.")

    # Write each across-goal allocation to the appropriate row
    for i, allocation in enumerate(df_across_goal["Allocation (%)"]):
        value = float(np.round(allocation / 100, 6))  # convert to decimal
        row = i + 2  # assuming goal names are in rows starting at 2
        cell = ws_goals.cells(row, goal_year_col)
        cell.value = value
        cell.number_format = '0.00%'  # display as percentage

    # -- Modify Loop Check -- #
    print("Starting loop status check...")

    ws_loop = wb.sheets["Loop"]
    print("Accessed 'Loop' worksheet.")

    # Read data range again (columns B to F)
    last_row = ws_loop.cells.last_cell.row
    print(f"Last cell row: {last_row}")

    loop_data = ws_loop.range("B2:F" + str(last_row)).value
    print(f"Loaded loop data. Total rows read: {len(loop_data)}")

    # Find and update the matching year with LoopStatus 'N'
    found = False
    for i, row in enumerate(loop_data):
        year = row[1]
        status = row[4]
        print(f"Row {i+2}: Year = {year}, Status = {status}")
        if year == loop_year and status == 'N':
            print(f"Match found at row {i+2}. Updating status to 'Y'.")
            ws_loop.cells(i + 2, 6).value = 'Y'  # Column F is column 6
            found = True
            break

    if not found:
        print(f"No matching row found for year {loop_year} with status 'N'.")
    else:
        print("Status updated successfully.")

    wb.save()
    wb.close()
    app.quit()
    time.sleep(1)
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop", usecols="B:F", skiprows=1, header=0)
# Out:
# 2025 1 25 40
# Starting Year: 2025
# Current Year: 2025
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2055, 'GOAL C': 2029, 'GOAL D': 2043}
# Adjusted Horizons: {'GOAL A': 10, 'GOAL B': 30, 'GOAL C': 4, 'GOAL D': 18}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             1.0
#    B            89.0
#    C             4.0
#    D             6.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.043319            4.33
#         Developed Markets - Equities 0.142556           14.26
# Emerging Markets State - Obligations 0.000196            0.02
#       High Yield Bonds - Obligations 0.335000           33.50
# Investment Grade Bonds - Obligations 0.334839           33.48
#    Government ZC Bonds - Obligations 0.144090           14.41
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = N
# Match found at row 3. Updating status to 'Y'.
# Status updated successfully.
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2055, 'GOAL C': 2029, 'GOAL D': 2043}
# Adjusted Horizons: {'GOAL A': 9, 'GOAL B': 29, 'GOAL C': 3, 'GOAL D': 17}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.99
#    B           96.04
#    C            0.99
#    D            1.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.385381           38.16
#         Developed Markets - Equities 0.002631            0.26
# Emerging Markets State - Obligations 0.009750            0.97
#       High Yield Bonds - Obligations 0.013271            1.31
# Investment Grade Bonds - Obligations 0.587227           58.14
#    Government ZC Bonds - Obligations 0.011740            1.16
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = N
# Match found at row 4. Updating status to 'Y'.
# Status updated successfully.
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2055, 'GOAL C': 2029, 'GOAL D': 2043}
# Adjusted Horizons: {'GOAL A': 8, 'GOAL B': 28, 'GOAL C': 2, 'GOAL D': 16}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            2.97
#    B           93.07
#    C            0.99
#    D            2.97
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.954593           94.51
#         Developed Markets - Equities 0.014581            1.44
# Emerging Markets State - Obligations 0.006051            0.60
#       High Yield Bonds - Obligations 0.014909            1.48
# Investment Grade Bonds - Obligations 0.010520            1.04
#    Government ZC Bonds - Obligations 0.009346            0.93
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = N
# Match found at row 5. Updating status to 'Y'.
# Status updated successfully.
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2055, 'GOAL C': 2029, 'GOAL D': 2043}
# Adjusted Horizons: {'GOAL A': 7, 'GOAL B': 27, 'GOAL C': 1, 'GOAL D': 15}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             3.0
#    B            94.0
#    C             2.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.013921            1.39
#         Developed Markets - Equities 0.942028           94.20
# Emerging Markets State - Obligations 0.007862            0.79
#       High Yield Bonds - Obligations 0.006517            0.65
# Investment Grade Bonds - Obligations 0.015565            1.56
#    Government ZC Bonds - Obligations 0.014108            1.41
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = N
# Match found at row 6. Updating status to 'Y'.
# Status updated successfully.
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2055, 'GOAL C': 2029, 'GOAL D': 2043}
# Adjusted Horizons: {'GOAL A': 6, 'GOAL B': 26, 'GOAL C': 0, 'GOAL D': 14}
# C:\Users\admin\AppData\Local\Temp\ipykernel_6848\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            1.98
#    B           96.04
#    C            0.99
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.970792           96.12
#         Developed Markets - Equities 0.006404            0.63
# Emerging Markets State - Obligations 0.008097            0.80
#       High Yield Bonds - Obligations 0.009131            0.90
# Investment Grade Bonds - Obligations 0.001028            0.10
#    Government ZC Bonds - Obligations 0.014548            1.44
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = N
# Match found at row 7. Updating status to 'Y'.
# Status updated successfully.
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2055, 'GOAL C': 2029, 'GOAL D': 2043}
# Adjusted Horizons: {'GOAL A': 5, 'GOAL B': 25, 'GOAL C': -1, 'GOAL D': 13}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.98
#    B           29.41
#    C            0.98
#    D           68.63
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 1.003498           98.38
#         Developed Markets - Equities 0.004425            0.43
# Emerging Markets State - Obligations 0.002517            0.25
#       High Yield Bonds - Obligations 0.004110            0.40
# Investment Grade Bonds - Obligations 0.004840            0.47
#    Government ZC Bonds - Obligations 0.000609            0.06
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = N
# Match found at row 8. Updating status to 'Y'.
# Status updated successfully.
# 2031 7 31 46
# Starting Year: 2025
# Current Year: 2031
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2055, 'GOAL C': 2029, 'GOAL D': 2043}
# Adjusted Horizons: {'GOAL A': 4, 'GOAL B': 24, 'GOAL C': -2, 'GOAL D': 12}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             1.0
#    B            93.0
#    C             4.0
#    D             2.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.943577           94.36
#         Developed Markets - Equities 0.015315            1.53
# Emerging Markets State - Obligations 0.008557            0.86
#       High Yield Bonds - Obligations 0.008225            0.82
# Investment Grade Bonds - Obligations 0.011097            1.11
#    Government ZC Bonds - Obligations 0.013230            1.32
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = N
# Match found at row 9. Updating status to 'Y'.
# Status updated successfully.
# 2032 8 32 47
# Starting Year: 2025
# Current Year: 2032
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2055, 'GOAL C': 2029, 'GOAL D': 2043}
# Adjusted Horizons: {'GOAL A': 3, 'GOAL B': 23, 'GOAL C': -3, 'GOAL D': 11}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            4.95
#    B           93.07
#    C            0.99
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.946311           93.69
#         Developed Markets - Equities 0.009144            0.91
# Emerging Markets State - Obligations 0.017070            1.69
#       High Yield Bonds - Obligations 0.013736            1.36
# Investment Grade Bonds - Obligations 0.000631            0.06
#    Government ZC Bonds - Obligations 0.023108            2.29
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = N
# Match found at row 10. Updating status to 'Y'.
# Status updated successfully.
# All loops completed

# %%
if infeasible_goals_log:
    print("\n⚠️ Infeasible goal scenarios encountered:")
    for year, goal, reason in infeasible_goals_log:
        print(f" - Year {year}, Goal {goal}: {reason}")

    # Optional: write to CSV
    pd.DataFrame(infeasible_goals_log, columns=["Year", "Goal", "Reason"]).to_csv(
        os.path.join(output_folder, "infeasible_goals_log.csv"), index=False)
else:
    print("\n✅ No infeasible goals encountered.")
# Out:
# ⚠️ Infeasible goal scenarios encountered:
#  - Year 2025, Goal Goal A: Required return > 100% (150.67%)
#  - Year 2025, Goal Goal C: Required return > 100% (506.75%)
#  - Year 2025, Goal Goal A: Required return > 100% (133.88%)
#  - Year 2025, Goal Goal C: Required return > 100% (410.21%)
#  - Year 2025, Goal Goal A: Required return > 100% (124.59%)
#  - Year 2025, Goal Goal C: Required return > 100% (361.03%)
#  - Year 2025, Goal Goal A: Required return > 100% (118.22%)
#  - Year 2025, Goal Goal C: Required return > 100% (329.04%)
#  - Year 2025, Goal Goal A: Required return > 100% (113.41%)
#  - Year 2025, Goal Goal C: Required return > 100% (305.76%)
#  - Year 2025, Goal Goal A: Required return > 100% (109.55%)
#  - Year 2025, Goal Goal C: Required return > 100% (287.68%)
#  - Year 2025, Goal Goal A: Required return > 100% (106.35%)
#  - Year 2025, Goal Goal C: Required return > 100% (273.02%)
#  - Year 2025, Goal Goal A: Required return > 100% (103.61%)
#  - Year 2025, Goal Goal C: Required return > 100% (260.77%)
#  - Year 2025, Goal Goal A: Required return > 100% (101.22%)
#  - Year 2025, Goal Goal C: Required return > 100% (250.31%)
#  - Year 2025, Goal Goal C: Required return > 100% (241.20%)
#  - Year 2025, Goal Goal C: Required return > 100% (233.17%)
#  - Year 2025, Goal Goal C: Required return > 100% (226.00%)
#  - Year 2025, Goal Goal C: Required return > 100% (219.54%)
#  - Year 2025, Goal Goal C: Required return > 100% (213.67%)
#  - Year 2025, Goal Goal C: Required return > 100% (208.31%)
#  - Year 2025, Goal Goal C: Required return > 100% (203.37%)
#  - Year 2025, Goal Goal C: Required return > 100% (198.81%)
#  - Year 2025, Goal Goal C: Required return > 100% (194.57%)
#  - Year 2025, Goal Goal C: Required return > 100% (190.62%)
#  - Year 2025, Goal Goal C: Required return > 100% (186.91%)
#  - Year 2025, Goal Goal C: Required return > 100% (183.44%)
#  - Year 2025, Goal Goal C: Required return > 100% (180.16%)
#  - Year 2025, Goal Goal C: Required return > 100% (177.06%)
#  - Year 2025, Goal Goal C: Required return > 100% (174.13%)
#  - Year 2025, Goal Goal C: Required return > 100% (171.35%)
#  - Year 2025, Goal Goal C: Required return > 100% (168.70%)
#  - Year 2025, Goal Goal C: Required return > 100% (166.18%)
#  - Year 2025, Goal Goal C: Required return > 100% (163.77%)
#  - Year 2025, Goal Goal C: Required return > 100% (161.46%)
#  - Year 2025, Goal Goal C: Required return > 100% (159.26%)
#  - Year 2025, Goal Goal C: Required return > 100% (157.14%)
#  - Year 2025, Goal Goal C: Required return > 100% (155.11%)
#  - Year 2025, Goal Goal C: Required return > 100% (153.15%)
#  - Year 2025, Goal Goal C: Required return > 100% (151.27%)
#  - Year 2025, Goal Goal C: Required return > 100% (149.45%)
#  - Year 2025, Goal Goal C: Required return > 100% (147.70%)
#  - Year 2025, Goal Goal C: Required return > 100% (146.01%)
#  - Year 2025, Goal Goal C: Required return > 100% (144.38%)
#  - Year 2025, Goal Goal C: Required return > 100% (142.80%)
#  - Year 2025, Goal Goal C: Required return > 100% (141.26%)
#  - Year 2025, Goal Goal C: Required return > 100% (139.78%)
#  - Year 2025, Goal Goal C: Required return > 100% (138.34%)
#  - Year 2025, Goal Goal C: Required return > 100% (136.94%)
#  - Year 2025, Goal Goal C: Required return > 100% (135.58%)
#  - Year 2025, Goal Goal C: Required return > 100% (134.26%)
#  - Year 2025, Goal Goal C: Required return > 100% (132.98%)
#  - Year 2025, Goal Goal C: Required return > 100% (131.73%)
#  - Year 2025, Goal Goal C: Required return > 100% (130.51%)
#  - Year 2025, Goal Goal C: Required return > 100% (129.33%)
#  - Year 2025, Goal Goal C: Required return > 100% (128.17%)
#  - Year 2025, Goal Goal C: Required return > 100% (127.05%)
#  - Year 2025, Goal Goal C: Required return > 100% (125.95%)
#  - Year 2025, Goal Goal C: Required return > 100% (124.87%)
#  - Year 2025, Goal Goal C: Required return > 100% (123.83%)
#  - Year 2025, Goal Goal C: Required return > 100% (122.80%)
#  - Year 2025, Goal Goal C: Required return > 100% (121.80%)
#  - Year 2025, Goal Goal C: Required return > 100% (120.82%)
#  - Year 2025, Goal Goal C: Required return > 100% (119.86%)
#  - Year 2025, Goal Goal C: Required return > 100% (118.93%)
#  - Year 2025, Goal Goal C: Required return > 100% (118.01%)
#  - Year 2025, Goal Goal C: Required return > 100% (117.11%)
#  - Year 2025, Goal Goal C: Required return > 100% (116.23%)
#  - Year 2025, Goal Goal C: Required return > 100% (115.36%)
#  - Year 2025, Goal Goal C: Required return > 100% (114.52%)
#  - Year 2025, Goal Goal C: Required return > 100% (113.69%)
#  - Year 2025, Goal Goal C: Required return > 100% (112.87%)
#  - Year 2025, Goal Goal C: Required return > 100% (112.08%)
#  - Year 2025, Goal Goal C: Required return > 100% (111.29%)
#  - Year 2025, Goal Goal C: Required return > 100% (110.52%)
#  - Year 2025, Goal Goal C: Required return > 100% (109.77%)
#  - Year 2025, Goal Goal C: Required return > 100% (109.02%)
#  - Year 2025, Goal Goal C: Required return > 100% (108.29%)
#  - Year 2025, Goal Goal C: Required return > 100% (107.58%)
#  - Year 2025, Goal Goal C: Required return > 100% (106.87%)
#  - Year 2025, Goal Goal C: Required return > 100% (106.18%)
#  - Year 2025, Goal Goal C: Required return > 100% (105.50%)
#  - Year 2025, Goal Goal C: Required return > 100% (104.83%)
#  - Year 2025, Goal Goal C: Required return > 100% (104.17%)
#  - Year 2025, Goal Goal C: Required return > 100% (103.52%)
#  - Year 2025, Goal Goal C: Required return > 100% (102.88%)
#  - Year 2025, Goal Goal C: Required return > 100% (102.25%)
#  - Year 2025, Goal Goal C: Required return > 100% (101.63%)
#  - Year 2025, Goal Goal C: Required return > 100% (101.02%)
#  - Year 2025, Goal Goal C: Required return > 100% (100.42%)
#  - Year 2026, Goal Goal A: Required return > 100% (156.90%)
#  - Year 2026, Goal Goal C: Required return > 100% (776.89%)
#  - Year 2026, Goal Goal A: Required return > 100% (137.86%)
#  - Year 2026, Goal Goal C: Required return > 100% (595.99%)
#  - Year 2026, Goal Goal A: Required return > 100% (127.38%)
#  - Year 2026, Goal Goal C: Required return > 100% (508.00%)
#  - Year 2026, Goal Goal A: Required return > 100% (120.22%)
#  - Year 2026, Goal Goal C: Required return > 100% (452.41%)
#  - Year 2026, Goal Goal A: Required return > 100% (114.83%)
#  - Year 2026, Goal Goal C: Required return > 100% (412.81%)
#  - Year 2026, Goal Goal A: Required return > 100% (110.52%)
#  - Year 2026, Goal Goal C: Required return > 100% (382.57%)
#  - Year 2026, Goal Goal A: Required return > 100% (106.95%)
#  - Year 2026, Goal Goal C: Required return > 100% (358.40%)
#  - Year 2026, Goal Goal A: Required return > 100% (103.90%)
#  - Year 2026, Goal Goal C: Required return > 100% (338.45%)
#  - Year 2026, Goal Goal A: Required return > 100% (101.25%)
#  - Year 2026, Goal Goal C: Required return > 100% (321.57%)
#  - Year 2026, Goal Goal C: Required return > 100% (307.02%)
#  - Year 2026, Goal Goal C: Required return > 100% (294.29%)
#  - Year 2026, Goal Goal C: Required return > 100% (283.02%)
#  - Year 2026, Goal Goal C: Required return > 100% (272.93%)
#  - Year 2026, Goal Goal C: Required return > 100% (263.83%)
#  - Year 2026, Goal Goal C: Required return > 100% (255.56%)
#  - Year 2026, Goal Goal C: Required return > 100% (248.00%)
#  - Year 2026, Goal Goal C: Required return > 100% (241.03%)
#  - Year 2026, Goal Goal C: Required return > 100% (234.60%)
#  - Year 2026, Goal Goal C: Required return > 100% (228.62%)
#  - Year 2026, Goal Goal C: Required return > 100% (223.05%)
#  - Year 2026, Goal Goal C: Required return > 100% (217.84%)
#  - Year 2026, Goal Goal C: Required return > 100% (212.95%)
#  - Year 2026, Goal Goal C: Required return > 100% (208.35%)
#  - Year 2026, Goal Goal C: Required return > 100% (204.00%)
#  - Year 2026, Goal Goal C: Required return > 100% (199.89%)
#  - Year 2026, Goal Goal C: Required return > 100% (196.00%)
#  - Year 2026, Goal Goal C: Required return > 100% (192.30%)
#  - Year 2026, Goal Goal C: Required return > 100% (188.78%)
#  - Year 2026, Goal Goal C: Required return > 100% (185.42%)
#  - Year 2026, Goal Goal C: Required return > 100% (182.21%)
#  - Year 2026, Goal Goal C: Required return > 100% (179.14%)
#  - Year 2026, Goal Goal C: Required return > 100% (176.20%)
#  - Year 2026, Goal Goal C: Required return > 100% (173.39%)
#  - Year 2026, Goal Goal C: Required return > 100% (170.68%)
#  - Year 2026, Goal Goal C: Required return > 100% (168.08%)
#  - Year 2026, Goal Goal C: Required return > 100% (165.57%)
#  - Year 2026, Goal Goal C: Required return > 100% (163.16%)
#  - Year 2026, Goal Goal C: Required return > 100% (160.83%)
#  - Year 2026, Goal Goal C: Required return > 100% (158.58%)
#  - Year 2026, Goal Goal C: Required return > 100% (156.40%)
#  - Year 2026, Goal Goal C: Required return > 100% (154.30%)
#  - Year 2026, Goal Goal C: Required return > 100% (152.27%)
#  - Year 2026, Goal Goal C: Required return > 100% (150.30%)
#  - Year 2026, Goal Goal C: Required return > 100% (148.39%)
#  - Year 2026, Goal Goal C: Required return > 100% (146.53%)
#  - Year 2026, Goal Goal C: Required return > 100% (144.73%)
#  - Year 2026, Goal Goal C: Required return > 100% (142.99%)
#  - Year 2026, Goal Goal C: Required return > 100% (141.29%)
#  - Year 2026, Goal Goal C: Required return > 100% (139.63%)
#  - Year 2026, Goal Goal C: Required return > 100% (138.03%)
#  - Year 2026, Goal Goal C: Required return > 100% (136.46%)
#  - Year 2026, Goal Goal C: Required return > 100% (134.93%)
#  - Year 2026, Goal Goal C: Required return > 100% (133.45%)
#  - Year 2026, Goal Goal C: Required return > 100% (132.00%)
#  - Year 2026, Goal Goal C: Required return > 100% (130.58%)
#  - Year 2026, Goal Goal C: Required return > 100% (129.20%)
#  - Year 2026, Goal Goal C: Required return > 100% (127.85%)
#  - Year 2026, Goal Goal C: Required return > 100% (126.54%)
#  - Year 2026, Goal Goal C: Required return > 100% (125.25%)
#  - Year 2026, Goal Goal C: Required return > 100% (123.99%)
#  - Year 2026, Goal Goal C: Required return > 100% (122.76%)
#  - Year 2026, Goal Goal C: Required return > 100% (121.56%)
#  - Year 2026, Goal Goal C: Required return > 100% (120.38%)
#  - Year 2026, Goal Goal C: Required return > 100% (119.22%)
#  - Year 2026, Goal Goal C: Required return > 100% (118.09%)
#  - Year 2026, Goal Goal C: Required return > 100% (116.99%)
#  - Year 2026, Goal Goal C: Required return > 100% (115.90%)
#  - Year 2026, Goal Goal C: Required return > 100% (114.84%)
#  - Year 2026, Goal Goal C: Required return > 100% (113.79%)
#  - Year 2026, Goal Goal C: Required return > 100% (112.77%)
#  - Year 2026, Goal Goal C: Required return > 100% (111.77%)
#  - Year 2026, Goal Goal C: Required return > 100% (110.78%)
#  - Year 2026, Goal Goal C: Required return > 100% (109.82%)
#  - Year 2026, Goal Goal C: Required return > 100% (108.87%)
#  - Year 2026, Goal Goal C: Required return > 100% (107.93%)
#  - Year 2026, Goal Goal C: Required return > 100% (107.02%)
#  - Year 2026, Goal Goal C: Required return > 100% (106.12%)
#  - Year 2026, Goal Goal C: Required return > 100% (105.23%)
#  - Year 2026, Goal Goal C: Required return > 100% (104.36%)
#  - Year 2026, Goal Goal C: Required return > 100% (103.51%)
#  - Year 2026, Goal Goal C: Required return > 100% (102.67%)
#  - Year 2026, Goal Goal C: Required return > 100% (101.84%)
#  - Year 2026, Goal Goal C: Required return > 100% (101.03%)
#  - Year 2026, Goal Goal C: Required return > 100% (100.23%)
#  - Year 2027, Goal Goal A: Required return > 100% (173.48%)
#  - Year 2027, Goal Goal C: Required return > 100% (1980.51%)
#  - Year 2027, Goal Goal A: Required return > 100% (150.78%)
#  - Year 2027, Goal Goal C: Required return > 100% (1371.14%)
#  - Year 2027, Goal Goal A: Required return > 100% (138.38%)
#  - Year 2027, Goal Goal C: Required return > 100% (1101.18%)
#  - Year 2027, Goal Goal A: Required return > 100% (129.96%)
#  - Year 2027, Goal Goal C: Required return > 100% (940.25%)
#  - Year 2027, Goal Goal A: Required return > 100% (123.64%)
#  - Year 2027, Goal Goal C: Required return > 100% (830.43%)
#  - Year 2027, Goal Goal A: Required return > 100% (118.60%)
#  - Year 2027, Goal Goal C: Required return > 100% (749.36%)
#  - Year 2027, Goal Goal A: Required return > 100% (114.43%)
#  - Year 2027, Goal Goal C: Required return > 100% (686.36%)
#  - Year 2027, Goal Goal A: Required return > 100% (110.88%)
#  - Year 2027, Goal Goal C: Required return > 100% (635.57%)
#  - Year 2027, Goal Goal A: Required return > 100% (107.80%)
#  - Year 2027, Goal Goal C: Required return > 100% (593.50%)
#  - Year 2027, Goal Goal A: Required return > 100% (105.08%)
#  - Year 2027, Goal Goal C: Required return > 100% (557.91%)
#  - Year 2027, Goal Goal A: Required return > 100% (102.65%)
#  - Year 2027, Goal Goal C: Required return > 100% (527.30%)
#  - Year 2027, Goal Goal A: Required return > 100% (100.46%)
#  - Year 2027, Goal Goal C: Required return > 100% (500.59%)
#  - Year 2027, Goal Goal C: Required return > 100% (477.03%)
#  - Year 2027, Goal Goal C: Required return > 100% (456.04%)
#  - Year 2027, Goal Goal C: Required return > 100% (437.18%)
#  - Year 2027, Goal Goal C: Required return > 100% (420.13%)
#  - Year 2027, Goal Goal C: Required return > 100% (404.60%)
#  - Year 2027, Goal Goal C: Required return > 100% (390.38%)
#  - Year 2027, Goal Goal C: Required return > 100% (377.30%)
#  - Year 2027, Goal Goal C: Required return > 100% (365.22%)
#  - Year 2027, Goal Goal C: Required return > 100% (354.00%)
#  - Year 2027, Goal Goal C: Required return > 100% (343.57%)
#  - Year 2027, Goal Goal C: Required return > 100% (333.82%)
#  - Year 2027, Goal Goal C: Required return > 100% (324.68%)
#  - Year 2027, Goal Goal C: Required return > 100% (316.10%)
#  - Year 2027, Goal Goal C: Required return > 100% (308.02%)
#  - Year 2027, Goal Goal C: Required return > 100% (300.39%)
#  - Year 2027, Goal Goal C: Required return > 100% (293.18%)
#  - Year 2027, Goal Goal C: Required return > 100% (286.34%)
#  - Year 2027, Goal Goal C: Required return > 100% (279.85%)
#  - Year 2027, Goal Goal C: Required return > 100% (273.67%)
#  - Year 2027, Goal Goal C: Required return > 100% (267.79%)
#  - Year 2027, Goal Goal C: Required return > 100% (262.17%)
#  - Year 2027, Goal Goal C: Required return > 100% (256.80%)
#  - Year 2027, Goal Goal C: Required return > 100% (251.67%)
#  - Year 2027, Goal Goal C: Required return > 100% (246.75%)
#  - Year 2027, Goal Goal C: Required return > 100% (242.03%)
#  - Year 2027, Goal Goal C: Required return > 100% (237.50%)
#  - Year 2027, Goal Goal C: Required return > 100% (233.15%)
#  - Year 2027, Goal Goal C: Required return > 100% (228.96%)
#  - Year 2027, Goal Goal C: Required return > 100% (224.92%)
#  - Year 2027, Goal Goal C: Required return > 100% (221.03%)
#  - Year 2027, Goal Goal C: Required return > 100% (217.27%)
#  - Year 2027, Goal Goal C: Required return > 100% (213.65%)
#  - Year 2027, Goal Goal C: Required return > 100% (210.14%)
#  - Year 2027, Goal Goal C: Required return > 100% (206.75%)
#  - Year 2027, Goal Goal C: Required return > 100% (203.47%)
#  - Year 2027, Goal Goal C: Required return > 100% (200.30%)
#  - Year 2027, Goal Goal C: Required return > 100% (197.22%)
#  - Year 2027, Goal Goal C: Required return > 100% (194.23%)
#  - Year 2027, Goal Goal C: Required return > 100% (191.33%)
#  - Year 2027, Goal Goal C: Required return > 100% (188.51%)
#  - Year 2027, Goal Goal C: Required return > 100% (185.78%)
#  - Year 2027, Goal Goal C: Required return > 100% (183.12%)
#  - Year 2027, Goal Goal C: Required return > 100% (180.54%)
#  - Year 2027, Goal Goal C: Required return > 100% (178.02%)
#  - Year 2027, Goal Goal C: Required return > 100% (175.57%)
#  - Year 2027, Goal Goal C: Required return > 100% (173.18%)
#  - Year 2027, Goal Goal C: Required return > 100% (170.86%)
#  - Year 2027, Goal Goal C: Required return > 100% (168.59%)
#  - Year 2027, Goal Goal C: Required return > 100% (166.38%)
#  - Year 2027, Goal Goal C: Required return > 100% (164.22%)
#  - Year 2027, Goal Goal C: Required return > 100% (162.12%)
#  - Year 2027, Goal Goal C: Required return > 100% (160.06%)
#  - Year 2027, Goal Goal C: Required return > 100% (158.06%)
#  - Year 2027, Goal Goal C: Required return > 100% (156.09%)
#  - Year 2027, Goal Goal C: Required return > 100% (154.17%)
#  - Year 2027, Goal Goal C: Required return > 100% (152.30%)
#  - Year 2027, Goal Goal C: Required return > 100% (150.46%)
#  - Year 2027, Goal Goal C: Required return > 100% (148.67%)
#  - Year 2027, Goal Goal C: Required return > 100% (146.91%)
#  - Year 2027, Goal Goal C: Required return > 100% (145.19%)
#  - Year 2027, Goal Goal C: Required return > 100% (143.50%)
#  - Year 2027, Goal Goal C: Required return > 100% (141.85%)
#  - Year 2027, Goal Goal C: Required return > 100% (140.24%)
#  - Year 2027, Goal Goal C: Required return > 100% (138.65%)
#  - Year 2027, Goal Goal C: Required return > 100% (137.10%)
#  - Year 2027, Goal Goal C: Required return > 100% (135.57%)
#  - Year 2027, Goal Goal C: Required return > 100% (134.08%)
#  - Year 2027, Goal Goal C: Required return > 100% (132.61%)
#  - Year 2027, Goal Goal C: Required return > 100% (131.17%)
#  - Year 2027, Goal Goal C: Required return > 100% (129.75%)
#  - Year 2027, Goal Goal C: Required return > 100% (128.37%)
#  - Year 2027, Goal Goal C: Required return > 100% (127.00%)
#  - Year 2027, Goal Goal C: Required return > 100% (125.66%)
#  - Year 2027, Goal Goal C: Required return > 100% (124.35%)
#  - Year 2027, Goal Goal C: Required return > 100% (123.05%)
#  - Year 2027, Goal Goal C: Required return > 100% (121.78%)
#  - Year 2027, Goal Goal C: Required return > 100% (120.53%)
#  - Year 2027, Goal Goal C: Required return > 100% (119.30%)
#  - Year 2027, Goal Goal C: Required return > 100% (118.10%)
#  - Year 2027, Goal Goal C: Required return > 100% (116.91%)
#  - Year 2027, Goal Goal C: Required return > 100% (115.74%)
#  - Year 2027, Goal Goal C: Required return > 100% (114.59%)
#  - Year 2027, Goal Goal C: Required return > 100% (113.46%)
#  - Year 2027, Goal Goal C: Required return > 100% (112.34%)
#  - Year 2027, Goal Goal C: Required return > 100% (111.24%)
#  - Year 2027, Goal Goal C: Required return > 100% (110.16%)
#  - Year 2027, Goal Goal C: Required return > 100% (109.10%)
#  - Year 2027, Goal Goal C: Required return > 100% (108.05%)
#  - Year 2028, Goal Goal A: Required return > 100% (202.12%)
#  - Year 2028, Goal Goal C: Required return > 100% (31689.08%)
#  - Year 2028, Goal Goal A: Required return > 100% (173.64%)
#  - Year 2028, Goal Goal C: Required return > 100% (15794.54%)
#  - Year 2028, Goal Goal A: Required return > 100% (158.24%)
#  - Year 2028, Goal Goal C: Required return > 100% (10496.36%)
#  - Year 2028, Goal Goal A: Required return > 100% (147.84%)
#  - Year 2028, Goal Goal C: Required return > 100% (7847.27%)
#  - Year 2028, Goal Goal A: Required return > 100% (140.07%)
#  - Year 2028, Goal Goal C: Required return > 100% (6257.82%)
#  - Year 2028, Goal Goal A: Required return > 100% (133.89%)
#  - Year 2028, Goal Goal C: Required return > 100% (5198.18%)
#  - Year 2028, Goal Goal A: Required return > 100% (128.80%)
#  - Year 2028, Goal Goal C: Required return > 100% (4441.30%)
#  - Year 2028, Goal Goal A: Required return > 100% (124.48%)
#  - Year 2028, Goal Goal C: Required return > 100% (3873.64%)
#  - Year 2028, Goal Goal A: Required return > 100% (120.73%)
#  - Year 2028, Goal Goal C: Required return > 100% (3432.12%)
#  - Year 2028, Goal Goal A: Required return > 100% (117.43%)
#  - Year 2028, Goal Goal C: Required return > 100% (3078.91%)
#  - Year 2028, Goal Goal A: Required return > 100% (114.49%)
#  - Year 2028, Goal Goal C: Required return > 100% (2789.92%)
#  - Year 2028, Goal Goal A: Required return > 100% (111.84%)
#  - Year 2028, Goal Goal C: Required return > 100% (2549.09%)
#  - Year 2028, Goal Goal A: Required return > 100% (109.43%)
#  - Year 2028, Goal Goal C: Required return > 100% (2345.31%)
#  - Year 2028, Goal Goal A: Required return > 100% (107.23%)
#  - Year 2028, Goal Goal C: Required return > 100% (2170.65%)
#  - Year 2028, Goal Goal A: Required return > 100% (105.20%)
#  - Year 2028, Goal Goal C: Required return > 100% (2019.27%)
#  - Year 2028, Goal Goal A: Required return > 100% (103.31%)
#  - Year 2028, Goal Goal C: Required return > 100% (1886.82%)
#  - Year 2028, Goal Goal A: Required return > 100% (101.56%)
#  - Year 2028, Goal Goal C: Required return > 100% (1769.95%)
#  - Year 2028, Goal Goal C: Required return > 100% (1666.06%)
#  - Year 2028, Goal Goal C: Required return > 100% (1573.11%)
#  - Year 2028, Goal Goal C: Required return > 100% (1489.45%)
#  - Year 2028, Goal Goal C: Required return > 100% (1413.77%)
#  - Year 2028, Goal Goal C: Required return > 100% (1344.96%)
#  - Year 2028, Goal Goal C: Required return > 100% (1282.13%)
#  - Year 2028, Goal Goal C: Required return > 100% (1224.55%)
#  - Year 2028, Goal Goal C: Required return > 100% (1171.56%)
#  - Year 2028, Goal Goal C: Required return > 100% (1122.66%)
#  - Year 2028, Goal Goal C: Required return > 100% (1077.37%)
#  - Year 2028, Goal Goal C: Required return > 100% (1035.32%)
#  - Year 2028, Goal Goal C: Required return > 100% (996.18%)
#  - Year 2028, Goal Goal C: Required return > 100% (959.64%)
#  - Year 2028, Goal Goal C: Required return > 100% (925.45%)
#  - Year 2028, Goal Goal C: Required return > 100% (893.41%)
#  - Year 2028, Goal Goal C: Required return > 100% (863.31%)
#  - Year 2028, Goal Goal C: Required return > 100% (834.97%)
#  - Year 2028, Goal Goal C: Required return > 100% (808.26%)
#  - Year 2028, Goal Goal C: Required return > 100% (783.03%)
#  - Year 2028, Goal Goal C: Required return > 100% (759.16%)
#  - Year 2028, Goal Goal C: Required return > 100% (736.55%)
#  - Year 2028, Goal Goal C: Required return > 100% (715.10%)
#  - Year 2028, Goal Goal C: Required return > 100% (694.73%)
#  - Year 2028, Goal Goal C: Required return > 100% (675.34%)
#  - Year 2028, Goal Goal C: Required return > 100% (656.88%)
#  - Year 2028, Goal Goal C: Required return > 100% (639.28%)
#  - Year 2028, Goal Goal C: Required return > 100% (622.48%)
#  - Year 2028, Goal Goal C: Required return > 100% (606.42%)
#  - Year 2028, Goal Goal C: Required return > 100% (591.07%)
#  - Year 2028, Goal Goal C: Required return > 100% (576.36%)
#  - Year 2028, Goal Goal C: Required return > 100% (562.27%)
#  - Year 2028, Goal Goal C: Required return > 100% (548.76%)
#  - Year 2028, Goal Goal C: Required return > 100% (535.78%)
#  - Year 2028, Goal Goal C: Required return > 100% (523.32%)
#  - Year 2028, Goal Goal C: Required return > 100% (511.33%)
#  - Year 2028, Goal Goal C: Required return > 100% (499.79%)
#  - Year 2028, Goal Goal C: Required return > 100% (488.69%)
#  - Year 2028, Goal Goal C: Required return > 100% (477.98%)
#  - Year 2028, Goal Goal C: Required return > 100% (467.66%)
#  - Year 2028, Goal Goal C: Required return > 100% (457.70%)
#  - Year 2028, Goal Goal C: Required return > 100% (448.09%)
#  - Year 2028, Goal Goal C: Required return > 100% (438.80%)
#  - Year 2028, Goal Goal C: Required return > 100% (429.82%)
#  - Year 2028, Goal Goal C: Required return > 100% (421.13%)
#  - Year 2028, Goal Goal C: Required return > 100% (412.73%)
#  - Year 2028, Goal Goal C: Required return > 100% (404.59%)
#  - Year 2028, Goal Goal C: Required return > 100% (396.70%)
#  - Year 2028, Goal Goal C: Required return > 100% (389.06%)
#  - Year 2028, Goal Goal C: Required return > 100% (381.65%)
#  - Year 2028, Goal Goal C: Required return > 100% (374.46%)
#  - Year 2028, Goal Goal C: Required return > 100% (367.49%)
#  - Year 2028, Goal Goal C: Required return > 100% (360.71%)
#  - Year 2028, Goal Goal C: Required return > 100% (354.13%)
#  - Year 2028, Goal Goal C: Required return > 100% (347.73%)
#  - Year 2028, Goal Goal C: Required return > 100% (341.52%)
#  - Year 2028, Goal Goal C: Required return > 100% (335.47%)
#  - Year 2028, Goal Goal C: Required return > 100% (329.58%)
#  - Year 2028, Goal Goal C: Required return > 100% (323.85%)
#  - Year 2028, Goal Goal C: Required return > 100% (318.28%)
#  - Year 2028, Goal Goal C: Required return > 100% (312.85%)
#  - Year 2028, Goal Goal C: Required return > 100% (307.55%)
#  - Year 2028, Goal Goal C: Required return > 100% (302.39%)
#  - Year 2028, Goal Goal C: Required return > 100% (297.36%)
#  - Year 2028, Goal Goal C: Required return > 100% (292.46%)
#  - Year 2028, Goal Goal C: Required return > 100% (287.67%)
#  - Year 2028, Goal Goal C: Required return > 100% (283.00%)
#  - Year 2028, Goal Goal C: Required return > 100% (278.44%)
#  - Year 2028, Goal Goal C: Required return > 100% (273.99%)
#  - Year 2028, Goal Goal C: Required return > 100% (269.64%)
#  - Year 2028, Goal Goal C: Required return > 100% (265.39%)
#  - Year 2028, Goal Goal C: Required return > 100% (261.24%)
#  - Year 2028, Goal Goal C: Required return > 100% (257.18%)
#  - Year 2028, Goal Goal C: Required return > 100% (253.21%)
#  - Year 2028, Goal Goal C: Required return > 100% (249.33%)
#  - Year 2028, Goal Goal C: Required return > 100% (245.53%)
#  - Year 2028, Goal Goal C: Required return > 100% (241.82%)
#  - Year 2028, Goal Goal C: Required return > 100% (238.18%)
#  - Year 2028, Goal Goal C: Required return > 100% (234.62%)
#  - Year 2028, Goal Goal C: Required return > 100% (231.14%)
#  - Year 2028, Goal Goal C: Required return > 100% (227.72%)
#  - Year 2028, Goal Goal C: Required return > 100% (224.38%)
#  - Year 2028, Goal Goal C: Required return > 100% (221.10%)
#  - Year 2028, Goal Goal C: Required return > 100% (217.89%)
#  - Year 2029, Goal Goal A: Required return > 100% (249.15%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (211.06%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (190.73%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (177.12%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (167.00%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (159.01%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (152.44%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (146.89%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (142.09%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (137.87%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (134.12%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (130.75%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (127.70%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (124.90%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (122.33%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (119.95%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (117.74%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (115.68%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (113.74%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (111.92%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (110.21%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (108.58%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (107.04%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (105.58%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (104.18%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (102.85%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (101.58%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal A: Required return > 100% (100.36%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2029, Goal Goal C: Required return > 100% (inf%)
#  - Year 2030, Goal Goal A: Required return > 100% (331.32%)
#  - Year 2030, Goal Goal A: Required return > 100% (275.49%)
#  - Year 2030, Goal Goal A: Required return > 100% (246.24%)
#  - Year 2030, Goal Goal A: Required return > 100% (226.88%)
#  - Year 2030, Goal Goal A: Required return > 100% (212.61%)
#  - Year 2030, Goal Goal A: Required return > 100% (201.42%)
#  - Year 2030, Goal Goal A: Required return > 100% (192.27%)
#  - Year 2030, Goal Goal A: Required return > 100% (184.56%)
#  - Year 2030, Goal Goal A: Required return > 100% (177.94%)
#  - Year 2030, Goal Goal A: Required return > 100% (172.14%)
#  - Year 2030, Goal Goal A: Required return > 100% (167.01%)
#  - Year 2030, Goal Goal A: Required return > 100% (162.40%)
#  - Year 2030, Goal Goal A: Required return > 100% (158.23%)
#  - Year 2030, Goal Goal A: Required return > 100% (154.43%)
#  - Year 2030, Goal Goal A: Required return > 100% (150.95%)
#  - Year 2030, Goal Goal A: Required return > 100% (147.73%)
#  - Year 2030, Goal Goal A: Required return > 100% (144.74%)
#  - Year 2030, Goal Goal A: Required return > 100% (141.96%)
#  - Year 2030, Goal Goal A: Required return > 100% (139.36%)
#  - Year 2030, Goal Goal A: Required return > 100% (136.92%)
#  - Year 2030, Goal Goal A: Required return > 100% (134.61%)
#  - Year 2030, Goal Goal A: Required return > 100% (132.44%)
#  - Year 2030, Goal Goal A: Required return > 100% (130.38%)
#  - Year 2030, Goal Goal A: Required return > 100% (128.43%)
#  - Year 2030, Goal Goal A: Required return > 100% (126.57%)
#  - Year 2030, Goal Goal A: Required return > 100% (124.80%)
#  - Year 2030, Goal Goal A: Required return > 100% (123.11%)
#  - Year 2030, Goal Goal A: Required return > 100% (121.50%)
#  - Year 2030, Goal Goal A: Required return > 100% (119.95%)
#  - Year 2030, Goal Goal A: Required return > 100% (118.46%)
#  - Year 2030, Goal Goal A: Required return > 100% (117.03%)
#  - Year 2030, Goal Goal A: Required return > 100% (115.66%)
#  - Year 2030, Goal Goal A: Required return > 100% (114.34%)
#  - Year 2030, Goal Goal A: Required return > 100% (113.06%)
#  - Year 2030, Goal Goal A: Required return > 100% (111.83%)
#  - Year 2030, Goal Goal A: Required return > 100% (110.64%)
#  - Year 2030, Goal Goal A: Required return > 100% (109.49%)
#  - Year 2030, Goal Goal A: Required return > 100% (108.37%)
#  - Year 2030, Goal Goal A: Required return > 100% (107.29%)
#  - Year 2030, Goal Goal A: Required return > 100% (106.25%)
#  - Year 2030, Goal Goal A: Required return > 100% (105.23%)
#  - Year 2030, Goal Goal A: Required return > 100% (104.24%)
#  - Year 2030, Goal Goal A: Required return > 100% (103.28%)
#  - Year 2030, Goal Goal A: Required return > 100% (102.35%)
#  - Year 2030, Goal Goal A: Required return > 100% (101.44%)
#  - Year 2030, Goal Goal A: Required return > 100% (100.56%)
#  - Year 2031, Goal Goal A: Required return > 100% (494.46%)
#  - Year 2031, Goal Goal A: Required return > 100% (399.88%)
#  - Year 2031, Goal Goal A: Required return > 100% (351.69%)
#  - Year 2031, Goal Goal A: Required return > 100% (320.35%)
#  - Year 2031, Goal Goal A: Required return > 100% (297.54%)
#  - Year 2031, Goal Goal A: Required return > 100% (279.83%)
#  - Year 2031, Goal Goal A: Required return > 100% (265.47%)
#  - Year 2031, Goal Goal A: Required return > 100% (253.47%)
#  - Year 2031, Goal Goal A: Required return > 100% (243.21%)
#  - Year 2031, Goal Goal A: Required return > 100% (234.29%)
#  - Year 2031, Goal Goal A: Required return > 100% (226.42%)
#  - Year 2031, Goal Goal A: Required return > 100% (219.39%)
#  - Year 2031, Goal Goal A: Required return > 100% (213.07%)
#  - Year 2031, Goal Goal A: Required return > 100% (207.32%)
#  - Year 2031, Goal Goal A: Required return > 100% (202.06%)
#  - Year 2031, Goal Goal A: Required return > 100% (197.23%)
#  - Year 2031, Goal Goal A: Required return > 100% (192.76%)
#  - Year 2031, Goal Goal A: Required return > 100% (188.60%)
#  - Year 2031, Goal Goal A: Required return > 100% (184.73%)
#  - Year 2031, Goal Goal A: Required return > 100% (181.10%)
#  - Year 2031, Goal Goal A: Required return > 100% (177.69%)
#  - Year 2031, Goal Goal A: Required return > 100% (174.48%)
#  - Year 2031, Goal Goal A: Required return > 100% (171.45%)
#  - Year 2031, Goal Goal A: Required return > 100% (168.58%)
#  - Year 2031, Goal Goal A: Required return > 100% (165.85%)
#  - Year 2031, Goal Goal A: Required return > 100% (163.26%)
#  - Year 2031, Goal Goal A: Required return > 100% (160.78%)
#  - Year 2031, Goal Goal A: Required return > 100% (158.42%)
#  - Year 2031, Goal Goal A: Required return > 100% (156.17%)
#  - Year 2031, Goal Goal A: Required return > 100% (154.00%)
#  - Year 2031, Goal Goal A: Required return > 100% (151.93%)
#  - Year 2031, Goal Goal A: Required return > 100% (149.94%)
#  - Year 2031, Goal Goal A: Required return > 100% (148.02%)
#  - Year 2031, Goal Goal A: Required return > 100% (146.18%)
#  - Year 2031, Goal Goal A: Required return > 100% (144.40%)
#  - Year 2031, Goal Goal A: Required return > 100% (142.69%)
#  - Year 2031, Goal Goal A: Required return > 100% (141.03%)
#  - Year 2031, Goal Goal A: Required return > 100% (139.43%)
#  - Year 2031, Goal Goal A: Required return > 100% (137.88%)
#  - Year 2031, Goal Goal A: Required return > 100% (136.38%)
#  - Year 2031, Goal Goal A: Required return > 100% (134.92%)
#  - Year 2031, Goal Goal A: Required return > 100% (133.51%)
#  - Year 2031, Goal Goal A: Required return > 100% (132.14%)
#  - Year 2031, Goal Goal A: Required return > 100% (130.81%)
#  - Year 2031, Goal Goal A: Required return > 100% (129.52%)
#  - Year 2031, Goal Goal A: Required return > 100% (128.26%)
#  - Year 2031, Goal Goal A: Required return > 100% (127.04%)
#  - Year 2031, Goal Goal A: Required return > 100% (125.85%)
#  - Year 2031, Goal Goal A: Required return > 100% (124.68%)
#  - Year 2031, Goal Goal A: Required return > 100% (123.55%)
#  - Year 2031, Goal Goal A: Required return > 100% (122.45%)
#  - Year 2031, Goal Goal A: Required return > 100% (121.37%)
#  - Year 2031, Goal Goal A: Required return > 100% (120.32%)
#  - Year 2031, Goal Goal A: Required return > 100% (119.29%)
#  - Year 2031, Goal Goal A: Required return > 100% (118.29%)
#  - Year 2031, Goal Goal A: Required return > 100% (117.31%)
#  - Year 2031, Goal Goal A: Required return > 100% (116.35%)
#  - Year 2031, Goal Goal A: Required return > 100% (115.41%)
#  - Year 2031, Goal Goal A: Required return > 100% (114.49%)
#  - Year 2031, Goal Goal A: Required return > 100% (113.59%)
#  - Year 2031, Goal Goal A: Required return > 100% (112.71%)
#  - Year 2031, Goal Goal A: Required return > 100% (111.85%)
#  - Year 2031, Goal Goal A: Required return > 100% (111.00%)
#  - Year 2031, Goal Goal A: Required return > 100% (110.17%)
#  - Year 2031, Goal Goal A: Required return > 100% (109.36%)
#  - Year 2031, Goal Goal A: Required return > 100% (108.56%)
#  - Year 2031, Goal Goal A: Required return > 100% (107.78%)
#  - Year 2031, Goal Goal A: Required return > 100% (107.01%)
#  - Year 2031, Goal Goal A: Required return > 100% (106.26%)
#  - Year 2031, Goal Goal A: Required return > 100% (105.52%)
#  - Year 2031, Goal Goal A: Required return > 100% (104.79%)
#  - Year 2031, Goal Goal A: Required return > 100% (104.07%)
#  - Year 2031, Goal Goal A: Required return > 100% (103.37%)
#  - Year 2031, Goal Goal A: Required return > 100% (102.68%)
#  - Year 2031, Goal Goal A: Required return > 100% (102.00%)
#  - Year 2031, Goal Goal A: Required return > 100% (101.33%)
#  - Year 2031, Goal Goal A: Required return > 100% (100.68%)
#  - Year 2031, Goal Goal A: Required return > 100% (100.03%)
#  - Year 2032, Goal Goal A: Required return > 100% (923.40%)
#  - Year 2032, Goal Goal A: Required return > 100% (712.27%)
#  - Year 2032, Goal Goal A: Required return > 100% (609.58%)
#  - Year 2032, Goal Goal A: Required return > 100% (544.70%)
#  - Year 2032, Goal Goal A: Required return > 100% (498.49%)
#  - Year 2032, Goal Goal A: Required return > 100% (463.20%)
#  - Year 2032, Goal Goal A: Required return > 100% (434.99%)
#  - Year 2032, Goal Goal A: Required return > 100% (411.70%)
#  - Year 2032, Goal Goal A: Required return > 100% (392.00%)
#  - Year 2032, Goal Goal A: Required return > 100% (375.02%)
#  - Year 2032, Goal Goal A: Required return > 100% (360.16%)
#  - Year 2032, Goal Goal A: Required return > 100% (347.01%)
#  - Year 2032, Goal Goal A: Required return > 100% (335.24%)
#  - Year 2032, Goal Goal A: Required return > 100% (324.62%)
#  - Year 2032, Goal Goal A: Required return > 100% (314.97%)
#  - Year 2032, Goal Goal A: Required return > 100% (306.13%)
#  - Year 2032, Goal Goal A: Required return > 100% (298.01%)
#  - Year 2032, Goal Goal A: Required return > 100% (290.50%)
#  - Year 2032, Goal Goal A: Required return > 100% (283.52%)
#  - Year 2032, Goal Goal A: Required return > 100% (277.02%)
#  - Year 2032, Goal Goal A: Required return > 100% (270.94%)
#  - Year 2032, Goal Goal A: Required return > 100% (265.23%)
#  - Year 2032, Goal Goal A: Required return > 100% (259.86%)
#  - Year 2032, Goal Goal A: Required return > 100% (254.79%)
#  - Year 2032, Goal Goal A: Required return > 100% (250.00%)
#  - Year 2032, Goal Goal A: Required return > 100% (245.45%)
#  - Year 2032, Goal Goal A: Required return > 100% (241.13%)
#  - Year 2032, Goal Goal A: Required return > 100% (237.02%)
#  - Year 2032, Goal Goal A: Required return > 100% (233.10%)
#  - Year 2032, Goal Goal A: Required return > 100% (229.36%)
#  - Year 2032, Goal Goal A: Required return > 100% (225.78%)
#  - Year 2032, Goal Goal A: Required return > 100% (222.35%)
#  - Year 2032, Goal Goal A: Required return > 100% (219.06%)
#  - Year 2032, Goal Goal A: Required return > 100% (215.90%)
#  - Year 2032, Goal Goal A: Required return > 100% (212.86%)
#  - Year 2032, Goal Goal A: Required return > 100% (209.94%)
#  - Year 2032, Goal Goal A: Required return > 100% (207.12%)
#  - Year 2032, Goal Goal A: Required return > 100% (204.40%)
#  - Year 2032, Goal Goal A: Required return > 100% (201.78%)
#  - Year 2032, Goal Goal A: Required return > 100% (199.24%)
#  - Year 2032, Goal Goal A: Required return > 100% (196.79%)
#  - Year 2032, Goal Goal A: Required return > 100% (194.42%)
#  - Year 2032, Goal Goal A: Required return > 100% (192.12%)
#  - Year 2032, Goal Goal A: Required return > 100% (189.89%)
#  - Year 2032, Goal Goal A: Required return > 100% (187.72%)
#  - Year 2032, Goal Goal A: Required return > 100% (185.62%)
#  - Year 2032, Goal Goal A: Required return > 100% (183.58%)
#  - Year 2032, Goal Goal A: Required return > 100% (181.60%)
#  - Year 2032, Goal Goal A: Required return > 100% (179.67%)
#  - Year 2032, Goal Goal A: Required return > 100% (177.79%)
#  - Year 2032, Goal Goal A: Required return > 100% (175.96%)
#  - Year 2032, Goal Goal A: Required return > 100% (174.18%)
#  - Year 2032, Goal Goal A: Required return > 100% (172.45%)
#  - Year 2032, Goal Goal A: Required return > 100% (170.76%)
#  - Year 2032, Goal Goal A: Required return > 100% (169.11%)
#  - Year 2032, Goal Goal A: Required return > 100% (167.49%)
#  - Year 2032, Goal Goal A: Required return > 100% (165.92%)
#  - Year 2032, Goal Goal A: Required return > 100% (164.38%)
#  - Year 2032, Goal Goal A: Required return > 100% (162.88%)
#  - Year 2032, Goal Goal A: Required return > 100% (161.41%)
#  - Year 2032, Goal Goal A: Required return > 100% (159.98%)
#  - Year 2032, Goal Goal A: Required return > 100% (158.57%)
#  - Year 2032, Goal Goal A: Required return > 100% (157.20%)
#  - Year 2032, Goal Goal A: Required return > 100% (155.85%)
#  - Year 2032, Goal Goal A: Required return > 100% (154.53%)
#  - Year 2032, Goal Goal A: Required return > 100% (153.24%)
#  - Year 2032, Goal Goal A: Required return > 100% (151.97%)
#  - Year 2032, Goal Goal A: Required return > 100% (150.73%)
#  - Year 2032, Goal Goal A: Required return > 100% (149.51%)
#  - Year 2032, Goal Goal A: Required return > 100% (148.32%)
#  - Year 2032, Goal Goal A: Required return > 100% (147.15%)
#  - Year 2032, Goal Goal A: Required return > 100% (146.00%)
#  - Year 2032, Goal Goal A: Required return > 100% (144.87%)
#  - Year 2032, Goal Goal A: Required return > 100% (143.76%)
#  - Year 2032, Goal Goal A: Required return > 100% (142.67%)
#  - Year 2032, Goal Goal A: Required return > 100% (141.60%)
#  - Year 2032, Goal Goal A: Required return > 100% (140.55%)
#  - Year 2032, Goal Goal A: Required return > 100% (139.52%)
#  - Year 2032, Goal Goal A: Required return > 100% (138.51%)
#  - Year 2032, Goal Goal A: Required return > 100% (137.51%)
#  - Year 2032, Goal Goal A: Required return > 100% (136.53%)
#  - Year 2032, Goal Goal A: Required return > 100% (135.56%)
#  - Year 2032, Goal Goal A: Required return > 100% (134.61%)
#  - Year 2032, Goal Goal A: Required return > 100% (133.68%)
#  - Year 2032, Goal Goal A: Required return > 100% (132.76%)
#  - Year 2032, Goal Goal A: Required return > 100% (131.85%)
#  - Year 2032, Goal Goal A: Required return > 100% (130.96%)
#  - Year 2032, Goal Goal A: Required return > 100% (130.08%)
#  - Year 2032, Goal Goal A: Required return > 100% (129.22%)
#  - Year 2032, Goal Goal A: Required return > 100% (128.36%)
#  - Year 2032, Goal Goal A: Required return > 100% (127.53%)
#  - Year 2032, Goal Goal A: Required return > 100% (126.70%)
#  - Year 2032, Goal Goal A: Required return > 100% (125.88%)
#  - Year 2032, Goal Goal A: Required return > 100% (125.08%)
#  - Year 2032, Goal Goal A: Required return > 100% (124.29%)
#  - Year 2032, Goal Goal A: Required return > 100% (123.50%)
#  - Year 2032, Goal Goal A: Required return > 100% (122.73%)
#  - Year 2032, Goal Goal A: Required return > 100% (121.97%)
#  - Year 2032, Goal Goal A: Required return > 100% (121.22%)
#  - Year 2032, Goal Goal A: Required return > 100% (120.48%)
