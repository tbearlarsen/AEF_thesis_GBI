# %% [markdown]
# V1 (02 11 2025): Translated from R to Python and added the visualizations for goals B to D
#
#
# V2 (04 01 2025): Loop system implemented
#
# V2.5 (04 02 2025): Loops system tweaks. Removed openpyxl as it was corrupting files and replaced it with xlwings

# %%
#!pip install numpy pandas scipy matplotlib xlwings

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import subprocess
import xlwings as xw
import time

# %%
# -- Variable Setup -- ##

#Monte Carlo Trials
n_trials = 10**5

#Case Study Profile Selection
Profile = "P1" #Either P1 or P2

#Excel worksheets
excel_returns = "Returns"
excel_volatilities = "Volatilities"
excel_correlation = "Correlation"
excel_gbi = "GBI Allocations P1" if Profile == "P1" else "GBI Allocations P2"
excel_gbi_goals = "GBI Goals P1" if Profile == "P1" else "GBI Goals P2"

# %% [markdown]
# # Define Functions
# This section defines the functions used for calculating portfolio volatility, expected return,
# goal achievement probability, and the objective (failure probability) to minimize.

# %%
def sd_f(weight_vector, covar_table):
    covar_vector = np.zeros(len(weight_vector))
    for z in range(len(weight_vector)):
        covar_vector[z] = np.sum(weight_vector * covar_table[:, z])
    return np.sqrt(np.sum(weight_vector * covar_vector))

# %%
def mean_f(weight_vector, return_vector):
    return np.sum(weight_vector * return_vector)

# %%
"""def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    # goal_vector is [value ratio, funding requirement, time horizon]
    required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
    if goal_allocation * pool >= goal_vector[1]:
        return 1
    else:
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)

""" #Made new version below that takes into account cases where the goal is too unreachable and writes down when that happens

def phi_f(goal_vector, goal_allocation, pool, mean, sd, year=None, goal_name=None):
    denominator = pool * goal_allocation
    if denominator <= 0:
        if year and goal_name:
            infeasible_goals_log.append((year, goal_name, "Zero allocation or pool"))
        return 0

    required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1

    if required_return > 1:
        if year and goal_name:
            infeasible_goals_log.append((year, goal_name, f"Required return > 100% ({required_return:.2%})"))
        return 0

    if denominator >= goal_vector[1]:
        return 1

    return 1 - norm.cdf(required_return, loc=mean, scale=sd)

# %%
def optim_function(weights):
    # Uses the current global variables: goal_vector, allocation, pool, return_vector, covar_table
    return 1 - phi_f(
        goal_vector,
        allocation,
        pool,
        mean_f(weights, return_vector),
        sd_f(weights, covar_table)
    )

# %%
def constraint_function(weights):
    # For SciPy equality constraints, we require constraint_function(weights) == 0.
    return np.sum(weights) - 1

# %%
def mvu_f(weights):
    # mvu_f is defined for mean-variance optimization (not used below).
    return -(mean_f(weights, return_vector) - 0.5 * gamma * sd_f(weights, covariances)**2)

# %%
def r_req_f(goal_vector, goal_allocation, pool):
    return (goal_vector[1] / (goal_allocation * pool))**(1 / goal_vector[2]) - 1

# %%
def get_goal_data(master_excel_path, plan=Profile):
    """
    Returns a DataFrame of the specified goal table (P1 or P2).
    P1 => B2:F5
    P2 => B7:F10
    """
    if plan == "P1":
        skip = 1  # start reading at row 2
    elif plan == "P2":
        skip = 6  # start reading at row 7
    else:
        raise ValueError("Plan not recognized. Use 'P1' or 'P2'.")

    df_goals = pd.read_excel(master_excel_path,sheet_name="Goals",skiprows=skip,nrows=4,usecols="B:F",header=0)
    # First column is "Goal Info", so make that the index
    df_goals.set_index(df_goals.columns[0], inplace=True)
    return df_goals

# %% [markdown]
# # Load & Parse Data

# %%
## -- Repo Root and Folders -- ##

# Get repo root and set folders
root = subprocess.run(["git", "rev-parse", "--show-toplevel"], capture_output=True, text=True).stdout.strip()
data_folder = os.path.join(root, "GBI Optimisation", "data")
output_folder = os.path.join(root, "GBI Optimisation")

# Get excel file and sheets
master_excel_path = os.path.join(data_folder, "Master.xlsx")

df_returns = pd.read_excel(master_excel_path, sheet_name=excel_returns)
df_vols = pd.read_excel(master_excel_path, sheet_name=excel_volatilities)

df_returns.set_index(df_returns.columns[0], inplace=True)
df_vols.set_index(df_vols.columns[0], inplace=True)

df_corr = pd.read_excel(master_excel_path, sheet_name=excel_correlation)
df_corr.set_index(df_corr.columns[0], inplace=True)

# %%
infeasible_goals_log = [] #Added for the new phi_f definition


while True:
    ## -- Loop Table -- ##
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop",usecols="B:F",skiprows=1,header=0)
    # Find Last looped year and select the next one
    # Filter only rows where LoopStatus is N
    pending_rows = table_loop_df[table_loop_df["LoopStatus"] == "N"]

    # If we find any rows, get the row with the lowest Year
    if pending_rows.empty:
        print("All loops completed")
        break


    chosen_row = pending_rows.loc[pending_rows["Year"].idxmin()]
    loop_year = chosen_row["Year"]
    loop_number = chosen_row["N"]
    loop_age1 = chosen_row["AgeP1"]
    loop_age2 = chosen_row["AgeP2"]

    print(loop_year, loop_number, loop_age1, loop_age2)

    # - Wealth - #

    # Retrieve Wealth value for selected profile and year from "Wealth" sheet
    df_wealth = pd.read_excel(master_excel_path, sheet_name="Wealth")
    df_wealth.set_index(df_wealth.columns[0], inplace=True)  # Set P1/P2 as index

    # Use profile and loop_year to get the correct pool value
    try:
        pool = df_wealth.loc[Profile, str(loop_year)]
    except KeyError:
        raise KeyError(f"Wealth data for profile '{Profile}' in year {loop_year} not found.")

    capital_market_expectations_raw = {}
    for asset in df_returns.index:
        expected_return = df_returns.loc[asset, str(loop_year)]
        volatility = df_vols.loc[asset, 'volatility']
        capital_market_expectations_raw[asset] = {
            'Return Forecast': expected_return,
            'Volatility Forecast': volatility
        }

    capital_market_expectations_raw = pd.DataFrame.from_dict(capital_market_expectations_raw, orient='index')

    capital_market_expectations_raw = capital_market_expectations_raw.reset_index()
    capital_market_expectations_raw.rename(columns={'index': 'Unnamed: 0'}, inplace=True)

    # Rearrange columns to match your old format (optional):
    capital_market_expectations_raw = capital_market_expectations_raw[['Unnamed: 0', 'Return Forecast', 'Volatility Forecast']]

    goal_data_raw = get_goal_data(master_excel_path, plan="P1")

    # - Dynamic time horizon based on current year - #

    # Step 1: Get Starting Year (minimum year in Loop sheet)
    starting_year = table_loop_df["Year"].min()

    # Step 2: Compute Goal Years = starting_year + time_horizon
    goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
    goal_years = starting_year + goal_horizons

    # Step 3: Recalculate Time Horizons = goal_years - current loop_year
    adjusted_horizons = goal_years - loop_year

    # Step 4: Replace the "Time Horizon" row in goal_data_raw
    goal_data_raw.loc["Time Horizon"] = adjusted_horizons

    goals = ["A", "B", "C", "D"]
    active_goal_mask = np.array([adjusted_horizons[f"GOAL {g}"] > 0 for g in goals])

    # Optional: print to confirm
    print("Starting Year:", starting_year)
    print("Current Year:", loop_year)
    print("Goal Years:", goal_years.to_dict())
    print("Adjusted Horizons:", adjusted_horizons.to_dict())

    # Record number of potential investments and goals
    num_assets = capital_market_expectations_raw.shape[0]
    num_goals = goal_data_raw.shape[1]

    # Create vector of expected returns
    return_vector = capital_market_expectations_raw["Return Forecast"].to_numpy()

    # Get the correlations as a numeric DataFrame (just a num_assets × num_assets block)
    correlations = df_corr.iloc[:num_assets, :num_assets].astype(float)

    # Build the covariance matrix: stdev_i * stdev_j * correlation_ij
    stdevs = capital_market_expectations_raw["Volatility Forecast"].to_numpy()
    covariances = np.zeros((num_assets, num_assets))
    for i in range(num_assets):
        for j in range(num_assets):
            covariances[i, j] = stdevs[i] * stdevs[j] * correlations.iloc[i, j]

    goal_A = goal_data_raw["GOAL A"].values
    goal_B = goal_data_raw["GOAL B"].values
    goal_C = goal_data_raw["GOAL C"].values
    goal_D = goal_data_raw["GOAL D"].values

    # - Optimal Goal Allocation - #


    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    # Set SLSQP options to be more stringent, mimicking solnp's behavior.
    slsqp_opts = {
        'ftol': 1e-12,     # function tolerance
        'eps': 1e-12,      # finite-difference step size for gradient estimation
        'maxiter': 10000,  # maximum iterations
        'disp': False     # do not display convergence messages
    }

    for i, alloc in enumerate(goal_allocation):
        allocation = alloc      # Global variable used in optim_function
        covar_table = covariances

        # Goal A Optimization
        goal_vector = goal_A   # Global variable used in optim_function
        if goal_A[1] <= pool * allocation:
            optimal_weights_A[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_A[i, :] = result.x

        # Goal B Optimization
        goal_vector = goal_B
        if goal_B[1] <= pool * allocation:
            optimal_weights_B[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_B[i, :] = result.x

        # Goal C Optimization
        goal_vector = goal_C
        if goal_C[1] <= pool * allocation:
            optimal_weights_C[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_C[i, :] = result.x

        # Goal D Optimization
        goal_vector = goal_D
        if goal_D[1] <= pool * allocation:
            optimal_weights_D[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_D[i, :] = result.x

    # Calculate the best probability (phi) for each allocation level for every goal
    phi_A = np.zeros(len(goal_allocation))
    phi_B = np.zeros(len(goal_allocation))
    phi_C = np.zeros(len(goal_allocation))
    phi_D = np.zeros(len(goal_allocation))

    for i, alloc in enumerate(goal_allocation):
        phi_A[i] = phi_f(goal_A, alloc, pool,
                         mean_f(optimal_weights_A[i, :], return_vector),
                         sd_f(optimal_weights_A[i, :], covariances), year=loop_year, goal_name="Goal A")
        phi_B[i] = phi_f(goal_B, alloc, pool,
                         mean_f(optimal_weights_B[i, :], return_vector),
                         sd_f(optimal_weights_B[i, :], covariances), year=loop_year, goal_name="Goal B")
        phi_C[i] = phi_f(goal_C, alloc, pool,
                         mean_f(optimal_weights_C[i, :], return_vector),
                         sd_f(optimal_weights_C[i, :], covariances), year=loop_year, goal_name="Goal C")
        phi_D[i] = phi_f(goal_D, alloc, pool,
                         mean_f(optimal_weights_D[i, :], return_vector),
                         sd_f(optimal_weights_D[i, :], covariances), year=loop_year, goal_name="Goal D")

    # Simulate goal weights: each row is a simulated allocation (in percentages)
    sim_goal_weights = np.random.multinomial(100, [1/num_goals]*num_goals, size=n_trials) #this one sums to 100 so its good
    for i in range(n_trials):
        rand_vector = np.random.uniform(0, 1, num_goals)
        normalizer = np.sum(rand_vector)
        percents = np.round((rand_vector / normalizer) * 100, 0)

        # Only enforce floor for active goals
        floor_applied = np.where(active_goal_mask, np.maximum(percents, 1), percents)
        sim_goal_weights[i, :] = floor_applied


    # Calculate utility for each simulated portfolio.
    # Note: subtract 1 from simulated weights for 0-indexing.
    utility = (
        goal_A[0] * phi_A[sim_goal_weights[:, 0] - 1] +
        goal_A[0] * goal_B[0] * phi_B[sim_goal_weights[:, 1] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * phi_C[sim_goal_weights[:, 2] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * goal_D[0] * phi_D[sim_goal_weights[:, 3] - 1]
    )

    # Find the index of the portfolio with the highest utility
    index = np.argmax(utility)
    optimal_goal_weights = sim_goal_weights[index, :]

    # - Optimal Subportfolio Allocation - #

    # Retrieve optimal subportfolio allocations
    optimal_subportfolios = np.zeros((num_goals, num_assets))

    # For each goal, use the simulated percentage to select the corresponding row
    # from the optimal weights matrix (adjust for zero-indexing)
    for i in range(num_goals):
        optimal_subportfolios[i, :] = eval(f"optimal_weights_{goals[i]}")[optimal_goal_weights[i] - 1, :]

    # Compute the optimal aggregate investment portfolio.
    optimal_aggregate_portfolio = (optimal_goal_weights / 100) @ optimal_subportfolios

    #Define asset names
    asset_names = capital_market_expectations_raw.iloc[:, 0].astype(str).tolist()

    # - Storing and exporting results - #

    # Create a DataFrame for the aggregate portfolio.
    # First calculate unrounded percentages
    raw_alloc = optimal_aggregate_portfolio * 100

    # Normalize to force sum = 100 after rounding
    normalized_alloc = raw_alloc / raw_alloc.sum() * 100
    normalized_goal_alloc = np.zeros_like(optimal_goal_weights, dtype=float)
    active_sum = np.sum(optimal_goal_weights[active_goal_mask])
    normalized_goal_alloc[active_goal_mask] = (optimal_goal_weights[active_goal_mask] / active_sum) * 100

    # Create a DataFrame for the across-goal allocation.
    df_across_goal = pd.DataFrame({
        "Goal": goals,
        "Allocation (%)": np.round(normalized_goal_alloc, 2) # Keep raw percentages
    })

    # Round after normalization
    df_aggregate = pd.DataFrame({
        "Asset": asset_names,
        "Weight": optimal_aggregate_portfolio,
        "Allocation (%)": np.round(normalized_alloc, 2)
    })

    print("Optimal Across-Goal Allocation:")
    print(df_across_goal.to_string(index=False))

    print("\nOptimal Aggregate Investment Allocation:")
    print(df_aggregate.to_string(index=False))

    # -- Safer Excel launch --
    app = xw.App(visible=False)
    app.display_alerts = False
    app.screen_updating = False

    time.sleep(1)

    # Open workbook
    wb = app.books.open(master_excel_path)
    ws = wb.sheets[excel_gbi]

    # Get header values from row 1 (columns B to AY ~= cols 2 to 51)
    header_values = [ws.cells(1, col).value for col in range(2, 53)]

    try:
        year_col = header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in worksheet headers.")

    # Write weights
    for i, asset in enumerate(asset_names):
        allocation = float(np.round(normalized_alloc[i], 2)) / 100
        cell = ws.cells(i + 2, year_col)
        cell.value = allocation
        cell.number_format = '0.00%'  # display as percentage

    # -- Export Goal Weights to Excel -- #

    # Re-access the sheet after workbook is open
    ws_goals = wb.sheets[excel_gbi_goals]

    # Read header values from row 1 (columns B to AY ≈ cols 2 to 52)
    goal_header_values = [ws_goals.cells(1, col).value for col in range(2, 53)]

    try:
        goal_year_col = goal_header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in goal worksheet headers.")

    # Write each across-goal allocation to the appropriate row
    for i, allocation in enumerate(df_across_goal["Allocation (%)"]):
        value = float(np.round(allocation / 100, 6))  # convert to decimal
        row = i + 2  # assuming goal names are in rows starting at 2
        cell = ws_goals.cells(row, goal_year_col)
        cell.value = value
        cell.number_format = '0.00%'  # display as percentage

    # -- Modify Loop Check -- #
    print("Starting loop status check...")

    ws_loop = wb.sheets["Loop"]
    print("Accessed 'Loop' worksheet.")

    # Read data range again (columns B to F)
    last_row = ws_loop.cells.last_cell.row
    print(f"Last cell row: {last_row}")

    loop_data = ws_loop.range("B2:F" + str(last_row)).value
    print(f"Loaded loop data. Total rows read: {len(loop_data)}")

    # Find and update the matching year with LoopStatus 'N'
    found = False
    for i, row in enumerate(loop_data):
        year = row[1]
        status = row[4]
        print(f"Row {i+2}: Year = {year}, Status = {status}")
        if year == loop_year and status == 'N':
            print(f"Match found at row {i+2}. Updating status to 'Y'.")
            ws_loop.cells(i + 2, 6).value = 'Y'  # Column F is column 6
            found = True
            break

    if not found:
        print(f"No matching row found for year {loop_year} with status 'N'.")
    else:
        print("Status updated successfully.")

    wb.save()
    wb.close()
    app.quit()
    time.sleep(1)
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop", usecols="B:F", skiprows=1, header=0)
# Out:
# 2025 1 25 40
# Starting Year: 2025
# Current Year: 2025
# Goal Years: {'GOAL A': 2028, 'GOAL B': 2055, 'GOAL C': 2027, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 3, 'GOAL B': 30, 'GOAL C': 2, 'GOAL D': 35}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.99
#    B           59.41
#    C           38.61
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.003933            0.39
#         Developed Markets - Equities 0.002535            0.25
# Emerging Markets State - Obligations 0.004162            0.41
#       High Yield Bonds - Obligations 0.001588            0.16
# Investment Grade Bonds - Obligations 0.004241            0.42
#    Government ZC Bonds - Obligations 0.993540           98.37
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = N
# Match found at row 3. Updating status to 'Y'.
# Status updated successfully.
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2028, 'GOAL B': 2055, 'GOAL C': 2027, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 2, 'GOAL B': 29, 'GOAL C': 1, 'GOAL D': 34}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            1.01
#    B            9.09
#    C           18.18
#    D           71.72
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.352939           35.65
#         Developed Markets - Equities 0.000975            0.10
# Emerging Markets State - Obligations 0.004889            0.49
#       High Yield Bonds - Obligations 0.000915            0.09
# Investment Grade Bonds - Obligations 0.624906           63.12
#    Government ZC Bonds - Obligations 0.005377            0.54
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = N
# Match found at row 4. Updating status to 'Y'.
# Status updated successfully.
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2028, 'GOAL B': 2055, 'GOAL C': 2027, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 1, 'GOAL B': 28, 'GOAL C': 0, 'GOAL D': 33}
# C:\Users\admin\AppData\Local\Temp\ipykernel_19344\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             1.0
#    B            31.0
#    C             0.0
#    D            68.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.869802           86.98
#         Developed Markets - Equities 0.000793            0.08
# Emerging Markets State - Obligations 0.002809            0.28
#       High Yield Bonds - Obligations 0.002930            0.29
# Investment Grade Bonds - Obligations 0.000194            0.02
#    Government ZC Bonds - Obligations 0.123472           12.35
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = N
# Match found at row 5. Updating status to 'Y'.
# Status updated successfully.
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2028, 'GOAL B': 2055, 'GOAL C': 2027, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 0, 'GOAL B': 27, 'GOAL C': -1, 'GOAL D': 32}
# C:\Users\admin\AppData\Local\Temp\ipykernel_19344\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B           35.71
#    C            0.00
#    D           64.29
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.000710            0.07
#         Developed Markets - Equities 0.636046           63.60
# Emerging Markets State - Obligations 0.005038            0.50
#       High Yield Bonds - Obligations 0.003690            0.37
# Investment Grade Bonds - Obligations 0.003758            0.38
#    Government ZC Bonds - Obligations 0.350758           35.08
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = N
# Match found at row 6. Updating status to 'Y'.
# Status updated successfully.
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2028, 'GOAL B': 2055, 'GOAL C': 2027, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -1, 'GOAL B': 26, 'GOAL C': -2, 'GOAL D': 31}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B           12.24
#    C            0.00
#    D           87.76
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.980959           98.10
#         Developed Markets - Equities 0.000164            0.02
# Emerging Markets State - Obligations 0.006310            0.63
#       High Yield Bonds - Obligations 0.005701            0.57
# Investment Grade Bonds - Obligations 0.002809            0.28
#    Government ZC Bonds - Obligations 0.004059            0.41
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = N
# Match found at row 7. Updating status to 'Y'.
# Status updated successfully.
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2028, 'GOAL B': 2055, 'GOAL C': 2027, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -2, 'GOAL B': 25, 'GOAL C': -3, 'GOAL D': 30}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B           15.46
#    C            0.00
#    D           84.54
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.742512           74.25
#         Developed Markets - Equities 0.224273           22.43
# Emerging Markets State - Obligations 0.004853            0.49
#       High Yield Bonds - Obligations 0.005515            0.55
# Investment Grade Bonds - Obligations 0.017556            1.76
#    Government ZC Bonds - Obligations 0.005291            0.53
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = N
# Match found at row 8. Updating status to 'Y'.
# Status updated successfully.
# All loops completed

# %%
if infeasible_goals_log:
    print("\n⚠️ Infeasible goal scenarios encountered:")
    for year, goal, reason in infeasible_goals_log:
        print(f" - Year {year}, Goal {goal}: {reason}")

    # Optional: write to CSV
    pd.DataFrame(infeasible_goals_log, columns=["Year", "Goal", "Reason"]).to_csv(
        os.path.join(output_folder, "infeasible_goals_log.csv"), index=False)
else:
    print("\n✅ No infeasible goals encountered.")
# Out:
# ⚠️ Infeasible goal scenarios encountered:
#  - Year 2025, Goal Goal A: Required return > 100% (812.50%)
#  - Year 2025, Goal Goal C: Required return > 100% (516.36%)
#  - Year 2025, Goal Goal A: Required return > 100% (624.25%)
#  - Year 2025, Goal Goal C: Required return > 100% (335.83%)
#  - Year 2025, Goal Goal A: Required return > 100% (532.69%)
#  - Year 2025, Goal Goal C: Required return > 100% (255.86%)
#  - Year 2025, Goal Goal A: Required return > 100% (474.84%)
#  - Year 2025, Goal Goal C: Required return > 100% (208.18%)
#  - Year 2025, Goal Goal A: Required return > 100% (433.63%)
#  - Year 2025, Goal Goal C: Required return > 100% (175.65%)
#  - Year 2025, Goal Goal A: Required return > 100% (402.17%)
#  - Year 2025, Goal Goal C: Required return > 100% (151.63%)
#  - Year 2025, Goal Goal A: Required return > 100% (377.02%)
#  - Year 2025, Goal Goal C: Required return > 100% (132.96%)
#  - Year 2025, Goal Goal A: Required return > 100% (356.25%)
#  - Year 2025, Goal Goal C: Required return > 100% (117.92%)
#  - Year 2025, Goal Goal A: Required return > 100% (338.69%)
#  - Year 2025, Goal Goal C: Required return > 100% (105.45%)
#  - Year 2025, Goal Goal A: Required return > 100% (323.55%)
#  - Year 2025, Goal Goal A: Required return > 100% (310.30%)
#  - Year 2025, Goal Goal A: Required return > 100% (298.57%)
#  - Year 2025, Goal Goal A: Required return > 100% (288.08%)
#  - Year 2025, Goal Goal A: Required return > 100% (278.61%)
#  - Year 2025, Goal Goal A: Required return > 100% (270.00%)
#  - Year 2025, Goal Goal A: Required return > 100% (262.13%)
#  - Year 2025, Goal Goal A: Required return > 100% (254.88%)
#  - Year 2025, Goal Goal A: Required return > 100% (248.18%)
#  - Year 2025, Goal Goal A: Required return > 100% (241.97%)
#  - Year 2025, Goal Goal A: Required return > 100% (236.17%)
#  - Year 2025, Goal Goal A: Required return > 100% (230.75%)
#  - Year 2025, Goal Goal A: Required return > 100% (225.66%)
#  - Year 2025, Goal Goal A: Required return > 100% (220.87%)
#  - Year 2025, Goal Goal A: Required return > 100% (216.35%)
#  - Year 2025, Goal Goal A: Required return > 100% (212.07%)
#  - Year 2025, Goal Goal A: Required return > 100% (208.02%)
#  - Year 2025, Goal Goal A: Required return > 100% (204.17%)
#  - Year 2025, Goal Goal A: Required return > 100% (200.50%)
#  - Year 2025, Goal Goal A: Required return > 100% (197.01%)
#  - Year 2025, Goal Goal A: Required return > 100% (193.67%)
#  - Year 2025, Goal Goal A: Required return > 100% (190.48%)
#  - Year 2025, Goal Goal A: Required return > 100% (187.42%)
#  - Year 2025, Goal Goal A: Required return > 100% (184.49%)
#  - Year 2025, Goal Goal A: Required return > 100% (181.67%)
#  - Year 2025, Goal Goal A: Required return > 100% (178.96%)
#  - Year 2025, Goal Goal A: Required return > 100% (176.35%)
#  - Year 2025, Goal Goal A: Required return > 100% (173.84%)
#  - Year 2025, Goal Goal A: Required return > 100% (171.42%)
#  - Year 2025, Goal Goal A: Required return > 100% (169.08%)
#  - Year 2025, Goal Goal A: Required return > 100% (166.82%)
#  - Year 2025, Goal Goal A: Required return > 100% (164.63%)
#  - Year 2025, Goal Goal A: Required return > 100% (162.51%)
#  - Year 2025, Goal Goal A: Required return > 100% (160.46%)
#  - Year 2025, Goal Goal A: Required return > 100% (158.47%)
#  - Year 2025, Goal Goal A: Required return > 100% (156.54%)
#  - Year 2025, Goal Goal A: Required return > 100% (154.67%)
#  - Year 2025, Goal Goal A: Required return > 100% (152.85%)
#  - Year 2025, Goal Goal A: Required return > 100% (151.08%)
#  - Year 2025, Goal Goal A: Required return > 100% (149.36%)
#  - Year 2025, Goal Goal A: Required return > 100% (147.69%)
#  - Year 2025, Goal Goal A: Required return > 100% (146.06%)
#  - Year 2025, Goal Goal A: Required return > 100% (144.47%)
#  - Year 2025, Goal Goal A: Required return > 100% (142.93%)
#  - Year 2025, Goal Goal A: Required return > 100% (141.42%)
#  - Year 2025, Goal Goal A: Required return > 100% (139.95%)
#  - Year 2025, Goal Goal A: Required return > 100% (138.51%)
#  - Year 2025, Goal Goal A: Required return > 100% (137.11%)
#  - Year 2025, Goal Goal A: Required return > 100% (135.74%)
#  - Year 2025, Goal Goal A: Required return > 100% (134.40%)
#  - Year 2025, Goal Goal A: Required return > 100% (133.09%)
#  - Year 2025, Goal Goal A: Required return > 100% (131.81%)
#  - Year 2025, Goal Goal A: Required return > 100% (130.55%)
#  - Year 2025, Goal Goal A: Required return > 100% (129.33%)
#  - Year 2025, Goal Goal A: Required return > 100% (128.13%)
#  - Year 2025, Goal Goal A: Required return > 100% (126.95%)
#  - Year 2025, Goal Goal A: Required return > 100% (125.80%)
#  - Year 2025, Goal Goal A: Required return > 100% (124.67%)
#  - Year 2025, Goal Goal A: Required return > 100% (123.56%)
#  - Year 2025, Goal Goal A: Required return > 100% (122.48%)
#  - Year 2025, Goal Goal A: Required return > 100% (121.41%)
#  - Year 2025, Goal Goal A: Required return > 100% (120.37%)
#  - Year 2025, Goal Goal A: Required return > 100% (119.34%)
#  - Year 2025, Goal Goal A: Required return > 100% (118.34%)
#  - Year 2025, Goal Goal A: Required return > 100% (117.35%)
#  - Year 2025, Goal Goal A: Required return > 100% (116.38%)
#  - Year 2025, Goal Goal A: Required return > 100% (115.42%)
#  - Year 2025, Goal Goal A: Required return > 100% (114.49%)
#  - Year 2025, Goal Goal A: Required return > 100% (113.57%)
#  - Year 2025, Goal Goal A: Required return > 100% (112.66%)
#  - Year 2025, Goal Goal A: Required return > 100% (111.77%)
#  - Year 2025, Goal Goal A: Required return > 100% (110.90%)
#  - Year 2025, Goal Goal A: Required return > 100% (110.04%)
#  - Year 2025, Goal Goal A: Required return > 100% (109.19%)
#  - Year 2025, Goal Goal A: Required return > 100% (108.36%)
#  - Year 2025, Goal Goal A: Required return > 100% (107.54%)
#  - Year 2025, Goal Goal A: Required return > 100% (106.73%)
#  - Year 2025, Goal Goal A: Required return > 100% (105.93%)
#  - Year 2025, Goal Goal A: Required return > 100% (105.15%)
#  - Year 2025, Goal Goal A: Required return > 100% (104.38%)
#  - Year 2025, Goal Goal A: Required return > 100% (103.62%)
#  - Year 2025, Goal Goal A: Required return > 100% (102.87%)
#  - Year 2025, Goal Goal A: Required return > 100% (102.13%)
#  - Year 2025, Goal Goal A: Required return > 100% (101.41%)
#  - Year 2025, Goal Goal A: Required return > 100% (100.69%)
#  - Year 2026, Goal Goal A: Required return > 100% (1844.25%)
#  - Year 2026, Goal Goal C: Required return > 100% (1790.06%)
#  - Year 2026, Goal Goal A: Required return > 100% (1274.79%)
#  - Year 2026, Goal Goal C: Required return > 100% (845.03%)
#  - Year 2026, Goal Goal A: Required return > 100% (1022.51%)
#  - Year 2026, Goal Goal C: Required return > 100% (530.02%)
#  - Year 2026, Goal Goal A: Required return > 100% (872.13%)
#  - Year 2026, Goal Goal C: Required return > 100% (372.51%)
#  - Year 2026, Goal Goal A: Required return > 100% (769.50%)
#  - Year 2026, Goal Goal C: Required return > 100% (278.01%)
#  - Year 2026, Goal Goal A: Required return > 100% (693.74%)
#  - Year 2026, Goal Goal C: Required return > 100% (215.01%)
#  - Year 2026, Goal Goal A: Required return > 100% (634.86%)
#  - Year 2026, Goal Goal C: Required return > 100% (170.01%)
#  - Year 2026, Goal Goal A: Required return > 100% (587.40%)
#  - Year 2026, Goal Goal C: Required return > 100% (136.26%)
#  - Year 2026, Goal Goal A: Required return > 100% (548.08%)
#  - Year 2026, Goal Goal C: Required return > 100% (110.01%)
#  - Year 2026, Goal Goal A: Required return > 100% (514.83%)
#  - Year 2026, Goal Goal A: Required return > 100% (486.21%)
#  - Year 2026, Goal Goal A: Required return > 100% (461.26%)
#  - Year 2026, Goal Goal A: Required return > 100% (439.24%)
#  - Year 2026, Goal Goal A: Required return > 100% (419.62%)
#  - Year 2026, Goal Goal A: Required return > 100% (402.00%)
#  - Year 2026, Goal Goal A: Required return > 100% (386.06%)
#  - Year 2026, Goal Goal A: Required return > 100% (371.55%)
#  - Year 2026, Goal Goal A: Required return > 100% (358.26%)
#  - Year 2026, Goal Goal A: Required return > 100% (346.04%)
#  - Year 2026, Goal Goal A: Required return > 100% (334.75%)
#  - Year 2026, Goal Goal A: Required return > 100% (324.27%)
#  - Year 2026, Goal Goal A: Required return > 100% (314.52%)
#  - Year 2026, Goal Goal A: Required return > 100% (305.40%)
#  - Year 2026, Goal Goal A: Required return > 100% (296.87%)
#  - Year 2026, Goal Goal A: Required return > 100% (288.85%)
#  - Year 2026, Goal Goal A: Required return > 100% (281.30%)
#  - Year 2026, Goal Goal A: Required return > 100% (274.17%)
#  - Year 2026, Goal Goal A: Required return > 100% (267.43%)
#  - Year 2026, Goal Goal A: Required return > 100% (261.04%)
#  - Year 2026, Goal Goal A: Required return > 100% (254.97%)
#  - Year 2026, Goal Goal A: Required return > 100% (249.20%)
#  - Year 2026, Goal Goal A: Required return > 100% (243.70%)
#  - Year 2026, Goal Goal A: Required return > 100% (238.45%)
#  - Year 2026, Goal Goal A: Required return > 100% (233.44%)
#  - Year 2026, Goal Goal A: Required return > 100% (228.64%)
#  - Year 2026, Goal Goal A: Required return > 100% (224.04%)
#  - Year 2026, Goal Goal A: Required return > 100% (219.63%)
#  - Year 2026, Goal Goal A: Required return > 100% (215.40%)
#  - Year 2026, Goal Goal A: Required return > 100% (211.33%)
#  - Year 2026, Goal Goal A: Required return > 100% (207.41%)
#  - Year 2026, Goal Goal A: Required return > 100% (203.64%)
#  - Year 2026, Goal Goal A: Required return > 100% (200.00%)
#  - Year 2026, Goal Goal A: Required return > 100% (196.50%)
#  - Year 2026, Goal Goal A: Required return > 100% (193.11%)
#  - Year 2026, Goal Goal A: Required return > 100% (189.83%)
#  - Year 2026, Goal Goal A: Required return > 100% (186.66%)
#  - Year 2026, Goal Goal A: Required return > 100% (183.60%)
#  - Year 2026, Goal Goal A: Required return > 100% (180.63%)
#  - Year 2026, Goal Goal A: Required return > 100% (177.75%)
#  - Year 2026, Goal Goal A: Required return > 100% (174.96%)
#  - Year 2026, Goal Goal A: Required return > 100% (172.25%)
#  - Year 2026, Goal Goal A: Required return > 100% (169.62%)
#  - Year 2026, Goal Goal A: Required return > 100% (167.06%)
#  - Year 2026, Goal Goal A: Required return > 100% (164.58%)
#  - Year 2026, Goal Goal A: Required return > 100% (162.16%)
#  - Year 2026, Goal Goal A: Required return > 100% (159.81%)
#  - Year 2026, Goal Goal A: Required return > 100% (157.52%)
#  - Year 2026, Goal Goal A: Required return > 100% (155.29%)
#  - Year 2026, Goal Goal A: Required return > 100% (153.12%)
#  - Year 2026, Goal Goal A: Required return > 100% (151.00%)
#  - Year 2026, Goal Goal A: Required return > 100% (148.94%)
#  - Year 2026, Goal Goal A: Required return > 100% (146.92%)
#  - Year 2026, Goal Goal A: Required return > 100% (144.95%)
#  - Year 2026, Goal Goal A: Required return > 100% (143.03%)
#  - Year 2026, Goal Goal A: Required return > 100% (141.15%)
#  - Year 2026, Goal Goal A: Required return > 100% (139.32%)
#  - Year 2026, Goal Goal A: Required return > 100% (137.53%)
#  - Year 2026, Goal Goal A: Required return > 100% (135.78%)
#  - Year 2026, Goal Goal A: Required return > 100% (134.06%)
#  - Year 2026, Goal Goal A: Required return > 100% (132.38%)
#  - Year 2026, Goal Goal A: Required return > 100% (130.74%)
#  - Year 2026, Goal Goal A: Required return > 100% (129.13%)
#  - Year 2026, Goal Goal A: Required return > 100% (127.56%)
#  - Year 2026, Goal Goal A: Required return > 100% (126.01%)
#  - Year 2026, Goal Goal A: Required return > 100% (124.50%)
#  - Year 2026, Goal Goal A: Required return > 100% (123.02%)
#  - Year 2026, Goal Goal A: Required return > 100% (121.57%)
#  - Year 2026, Goal Goal A: Required return > 100% (120.14%)
#  - Year 2026, Goal Goal A: Required return > 100% (118.75%)
#  - Year 2026, Goal Goal A: Required return > 100% (117.37%)
#  - Year 2026, Goal Goal A: Required return > 100% (116.03%)
#  - Year 2026, Goal Goal A: Required return > 100% (114.71%)
#  - Year 2026, Goal Goal A: Required return > 100% (113.41%)
#  - Year 2026, Goal Goal A: Required return > 100% (112.14%)
#  - Year 2026, Goal Goal A: Required return > 100% (110.88%)
#  - Year 2026, Goal Goal A: Required return > 100% (109.65%)
#  - Year 2026, Goal Goal A: Required return > 100% (108.45%)
#  - Year 2026, Goal Goal A: Required return > 100% (107.26%)
#  - Year 2026, Goal Goal A: Required return > 100% (106.09%)
#  - Year 2026, Goal Goal A: Required return > 100% (104.94%)
#  - Year 2026, Goal Goal A: Required return > 100% (103.81%)
#  - Year 2026, Goal Goal A: Required return > 100% (102.70%)
#  - Year 2026, Goal Goal A: Required return > 100% (101.61%)
#  - Year 2026, Goal Goal A: Required return > 100% (100.53%)
#  - Year 2027, Goal Goal A: Required return > 100% (24166.34%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (12033.17%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (7988.78%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (5966.58%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (4753.27%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (3944.39%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (3366.62%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (2933.29%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (2596.26%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (2326.63%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (2106.03%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (1922.19%)
#  - Year 2027, Goal Goal C: Required return > 100% (inf%)
#  - Year 2027, Goal Goal A: Required return > 100% (1766.64%)
#  - Year 2027, Goal Goal A: Required return > 100% (1633.31%)
#  - Year 2027, Goal Goal A: Required return > 100% (1517.76%)
#  - Year 2027, Goal Goal A: Required return > 100% (1416.65%)
#  - Year 2027, Goal Goal A: Required return > 100% (1327.43%)
#  - Year 2027, Goal Goal A: Required return > 100% (1248.13%)
#  - Year 2027, Goal Goal A: Required return > 100% (1177.18%)
#  - Year 2027, Goal Goal A: Required return > 100% (1113.32%)
#  - Year 2027, Goal Goal A: Required return > 100% (1055.54%)
#  - Year 2027, Goal Goal A: Required return > 100% (1003.02%)
#  - Year 2027, Goal Goal A: Required return > 100% (955.06%)
#  - Year 2027, Goal Goal A: Required return > 100% (911.10%)
#  - Year 2027, Goal Goal A: Required return > 100% (870.65%)
#  - Year 2027, Goal Goal A: Required return > 100% (833.32%)
#  - Year 2027, Goal Goal A: Required return > 100% (798.75%)
#  - Year 2027, Goal Goal A: Required return > 100% (766.65%)
#  - Year 2027, Goal Goal A: Required return > 100% (736.77%)
#  - Year 2027, Goal Goal A: Required return > 100% (708.88%)
#  - Year 2027, Goal Goal A: Required return > 100% (682.79%)
#  - Year 2027, Goal Goal A: Required return > 100% (658.32%)
#  - Year 2027, Goal Goal A: Required return > 100% (635.34%)
#  - Year 2027, Goal Goal A: Required return > 100% (613.72%)
#  - Year 2027, Goal Goal A: Required return > 100% (593.32%)
#  - Year 2027, Goal Goal A: Required return > 100% (574.06%)
#  - Year 2027, Goal Goal A: Required return > 100% (555.85%)
#  - Year 2027, Goal Goal A: Required return > 100% (538.59%)
#  - Year 2027, Goal Goal A: Required return > 100% (522.21%)
#  - Year 2027, Goal Goal A: Required return > 100% (506.66%)
#  - Year 2027, Goal Goal A: Required return > 100% (491.86%)
#  - Year 2027, Goal Goal A: Required return > 100% (477.77%)
#  - Year 2027, Goal Goal A: Required return > 100% (464.33%)
#  - Year 2027, Goal Goal A: Required return > 100% (451.51%)
#  - Year 2027, Goal Goal A: Required return > 100% (439.25%)
#  - Year 2027, Goal Goal A: Required return > 100% (427.53%)
#  - Year 2027, Goal Goal A: Required return > 100% (416.31%)
#  - Year 2027, Goal Goal A: Required return > 100% (405.55%)
#  - Year 2027, Goal Goal A: Required return > 100% (395.23%)
#  - Year 2027, Goal Goal A: Required return > 100% (385.33%)
#  - Year 2027, Goal Goal A: Required return > 100% (375.81%)
#  - Year 2027, Goal Goal A: Required return > 100% (366.66%)
#  - Year 2027, Goal Goal A: Required return > 100% (357.86%)
#  - Year 2027, Goal Goal A: Required return > 100% (349.38%)
#  - Year 2027, Goal Goal A: Required return > 100% (341.21%)
#  - Year 2027, Goal Goal A: Required return > 100% (333.33%)
#  - Year 2027, Goal Goal A: Required return > 100% (325.73%)
#  - Year 2027, Goal Goal A: Required return > 100% (318.39%)
#  - Year 2027, Goal Goal A: Required return > 100% (311.29%)
#  - Year 2027, Goal Goal A: Required return > 100% (304.44%)
#  - Year 2027, Goal Goal A: Required return > 100% (297.81%)
#  - Year 2027, Goal Goal A: Required return > 100% (291.39%)
#  - Year 2027, Goal Goal A: Required return > 100% (285.18%)
#  - Year 2027, Goal Goal A: Required return > 100% (279.16%)
#  - Year 2027, Goal Goal A: Required return > 100% (273.33%)
#  - Year 2027, Goal Goal A: Required return > 100% (267.67%)
#  - Year 2027, Goal Goal A: Required return > 100% (262.18%)
#  - Year 2027, Goal Goal A: Required return > 100% (256.86%)
#  - Year 2027, Goal Goal A: Required return > 100% (251.69%)
#  - Year 2027, Goal Goal A: Required return > 100% (246.66%)
#  - Year 2027, Goal Goal A: Required return > 100% (241.78%)
#  - Year 2027, Goal Goal A: Required return > 100% (237.03%)
#  - Year 2027, Goal Goal A: Required return > 100% (232.42%)
#  - Year 2027, Goal Goal A: Required return > 100% (227.92%)
#  - Year 2027, Goal Goal A: Required return > 100% (223.55%)
#  - Year 2027, Goal Goal A: Required return > 100% (219.29%)
#  - Year 2027, Goal Goal A: Required return > 100% (215.15%)
#  - Year 2027, Goal Goal A: Required return > 100% (211.11%)
#  - Year 2027, Goal Goal A: Required return > 100% (207.17%)
#  - Year 2027, Goal Goal A: Required return > 100% (203.33%)
#  - Year 2027, Goal Goal A: Required return > 100% (199.58%)
#  - Year 2027, Goal Goal A: Required return > 100% (195.93%)
#  - Year 2027, Goal Goal A: Required return > 100% (192.37%)
#  - Year 2027, Goal Goal A: Required return > 100% (188.88%)
#  - Year 2027, Goal Goal A: Required return > 100% (185.49%)
#  - Year 2027, Goal Goal A: Required return > 100% (182.17%)
#  - Year 2027, Goal Goal A: Required return > 100% (178.92%)
#  - Year 2027, Goal Goal A: Required return > 100% (175.75%)
#  - Year 2027, Goal Goal A: Required return > 100% (172.66%)
#  - Year 2027, Goal Goal A: Required return > 100% (169.63%)
#  - Year 2027, Goal Goal A: Required return > 100% (166.66%)
#  - Year 2027, Goal Goal A: Required return > 100% (163.76%)
#  - Year 2027, Goal Goal A: Required return > 100% (160.93%)
#  - Year 2027, Goal Goal A: Required return > 100% (158.15%)
#  - Year 2027, Goal Goal A: Required return > 100% (155.44%)
#  - Year 2027, Goal Goal A: Required return > 100% (152.77%)
#  - Year 2027, Goal Goal A: Required return > 100% (150.17%)
#  - Year 2027, Goal Goal A: Required return > 100% (147.62%)
#  - Year 2027, Goal Goal A: Required return > 100% (145.11%)
#  - Year 2027, Goal Goal A: Required return > 100% (142.66%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (102.00%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (113.23%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (124.45%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (135.67%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (146.89%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (158.12%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (169.34%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (180.56%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (191.78%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (203.00%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (214.23%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (225.45%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (236.67%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (247.89%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (259.12%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (270.34%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (281.56%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (292.78%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (304.01%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (315.23%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (326.45%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (337.67%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (348.90%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (360.12%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (371.34%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (382.56%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (393.79%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (405.01%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (416.23%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (427.45%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (438.68%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (449.90%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (461.12%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (472.34%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (483.57%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (494.79%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (506.01%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (517.23%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (528.45%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (539.68%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (550.90%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (562.12%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (573.34%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (584.57%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (595.79%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (607.01%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (618.23%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (629.46%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (640.68%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (651.90%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (663.12%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (674.35%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (685.57%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (696.79%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (708.01%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (719.24%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (730.46%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (741.68%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (752.90%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (764.13%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (775.35%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (786.57%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (797.79%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (809.01%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (820.24%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (831.46%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (842.68%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (853.90%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (865.13%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (876.35%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (887.57%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (898.79%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (910.02%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (921.24%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (932.46%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (943.68%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (954.91%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (966.13%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (977.35%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (988.57%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (999.80%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (1011.02%)
#  - Year 2028, Goal Goal A: Required return > 100% (inf%)
#  - Year 2028, Goal Goal C: Required return > 100% (1022.24%)
#  - Year 2029, Goal Goal C: Required return > 100% (103.16%)
#  - Year 2029, Goal Goal C: Required return > 100% (106.64%)
#  - Year 2029, Goal Goal C: Required return > 100% (110.05%)
#  - Year 2029, Goal Goal C: Required return > 100% (113.41%)
#  - Year 2029, Goal Goal C: Required return > 100% (116.72%)
#  - Year 2029, Goal Goal C: Required return > 100% (119.98%)
#  - Year 2029, Goal Goal C: Required return > 100% (123.19%)
#  - Year 2029, Goal Goal C: Required return > 100% (126.36%)
#  - Year 2029, Goal Goal C: Required return > 100% (129.48%)
#  - Year 2029, Goal Goal C: Required return > 100% (132.56%)
#  - Year 2029, Goal Goal C: Required return > 100% (135.60%)
#  - Year 2029, Goal Goal C: Required return > 100% (138.60%)
#  - Year 2029, Goal Goal C: Required return > 100% (141.57%)
#  - Year 2029, Goal Goal C: Required return > 100% (144.49%)
#  - Year 2029, Goal Goal C: Required return > 100% (147.39%)
#  - Year 2029, Goal Goal C: Required return > 100% (150.25%)
#  - Year 2029, Goal Goal C: Required return > 100% (153.08%)
#  - Year 2029, Goal Goal C: Required return > 100% (155.87%)
#  - Year 2029, Goal Goal C: Required return > 100% (158.64%)
#  - Year 2029, Goal Goal C: Required return > 100% (161.38%)
#  - Year 2029, Goal Goal C: Required return > 100% (164.08%)
#  - Year 2029, Goal Goal C: Required return > 100% (166.77%)
#  - Year 2029, Goal Goal C: Required return > 100% (169.42%)
#  - Year 2029, Goal Goal C: Required return > 100% (172.05%)
#  - Year 2029, Goal Goal C: Required return > 100% (174.65%)
#  - Year 2029, Goal Goal C: Required return > 100% (177.23%)
#  - Year 2029, Goal Goal C: Required return > 100% (179.79%)
#  - Year 2029, Goal Goal C: Required return > 100% (182.32%)
#  - Year 2029, Goal Goal C: Required return > 100% (184.83%)
#  - Year 2029, Goal Goal C: Required return > 100% (187.32%)
#  - Year 2029, Goal Goal C: Required return > 100% (189.78%)
#  - Year 2029, Goal Goal C: Required return > 100% (192.23%)
#  - Year 2029, Goal Goal C: Required return > 100% (194.65%)
#  - Year 2029, Goal Goal C: Required return > 100% (197.06%)
#  - Year 2029, Goal Goal C: Required return > 100% (199.44%)
#  - Year 2029, Goal Goal C: Required return > 100% (201.81%)
#  - Year 2029, Goal Goal C: Required return > 100% (204.16%)
#  - Year 2029, Goal Goal C: Required return > 100% (206.49%)
#  - Year 2029, Goal Goal C: Required return > 100% (208.80%)
#  - Year 2029, Goal Goal C: Required return > 100% (211.10%)
#  - Year 2029, Goal Goal C: Required return > 100% (213.38%)
#  - Year 2029, Goal Goal C: Required return > 100% (215.64%)
#  - Year 2029, Goal Goal C: Required return > 100% (217.89%)
#  - Year 2029, Goal Goal C: Required return > 100% (220.12%)
#  - Year 2029, Goal Goal C: Required return > 100% (222.33%)
#  - Year 2029, Goal Goal C: Required return > 100% (224.53%)
#  - Year 2029, Goal Goal C: Required return > 100% (226.72%)
#  - Year 2029, Goal Goal C: Required return > 100% (228.89%)
#  - Year 2029, Goal Goal C: Required return > 100% (231.05%)
#  - Year 2029, Goal Goal C: Required return > 100% (233.19%)
#  - Year 2029, Goal Goal C: Required return > 100% (235.32%)
#  - Year 2029, Goal Goal C: Required return > 100% (237.43%)
#  - Year 2029, Goal Goal C: Required return > 100% (239.54%)
#  - Year 2029, Goal Goal C: Required return > 100% (241.63%)
#  - Year 2029, Goal Goal C: Required return > 100% (243.70%)
#  - Year 2029, Goal Goal C: Required return > 100% (245.77%)
#  - Year 2029, Goal Goal C: Required return > 100% (247.82%)
#  - Year 2029, Goal Goal C: Required return > 100% (249.86%)
#  - Year 2029, Goal Goal C: Required return > 100% (251.89%)
#  - Year 2029, Goal Goal C: Required return > 100% (253.90%)
#  - Year 2029, Goal Goal C: Required return > 100% (255.91%)
#  - Year 2029, Goal Goal C: Required return > 100% (257.90%)
#  - Year 2029, Goal Goal C: Required return > 100% (259.89%)
#  - Year 2029, Goal Goal C: Required return > 100% (261.86%)
#  - Year 2029, Goal Goal C: Required return > 100% (263.82%)
#  - Year 2029, Goal Goal C: Required return > 100% (265.77%)
#  - Year 2029, Goal Goal C: Required return > 100% (267.71%)
#  - Year 2029, Goal Goal C: Required return > 100% (269.64%)
#  - Year 2029, Goal Goal C: Required return > 100% (271.56%)
#  - Year 2029, Goal Goal C: Required return > 100% (273.47%)
#  - Year 2029, Goal Goal C: Required return > 100% (275.37%)
#  - Year 2029, Goal Goal C: Required return > 100% (277.26%)
#  - Year 2030, Goal Goal C: Required return > 100% (100.98%)
#  - Year 2030, Goal Goal C: Required return > 100% (102.40%)
#  - Year 2030, Goal Goal C: Required return > 100% (103.79%)
#  - Year 2030, Goal Goal C: Required return > 100% (105.17%)
#  - Year 2030, Goal Goal C: Required return > 100% (106.53%)
#  - Year 2030, Goal Goal C: Required return > 100% (107.87%)
#  - Year 2030, Goal Goal C: Required return > 100% (109.19%)
#  - Year 2030, Goal Goal C: Required return > 100% (110.50%)
#  - Year 2030, Goal Goal C: Required return > 100% (111.79%)
#  - Year 2030, Goal Goal C: Required return > 100% (113.07%)
#  - Year 2030, Goal Goal C: Required return > 100% (114.33%)
#  - Year 2030, Goal Goal C: Required return > 100% (115.58%)
#  - Year 2030, Goal Goal C: Required return > 100% (116.81%)
#  - Year 2030, Goal Goal C: Required return > 100% (118.03%)
#  - Year 2030, Goal Goal C: Required return > 100% (119.23%)
#  - Year 2030, Goal Goal C: Required return > 100% (120.42%)
#  - Year 2030, Goal Goal C: Required return > 100% (121.60%)
#  - Year 2030, Goal Goal C: Required return > 100% (122.77%)
#  - Year 2030, Goal Goal C: Required return > 100% (123.92%)
#  - Year 2030, Goal Goal C: Required return > 100% (125.06%)
#  - Year 2030, Goal Goal C: Required return > 100% (126.19%)
#  - Year 2030, Goal Goal C: Required return > 100% (127.31%)
#  - Year 2030, Goal Goal C: Required return > 100% (128.42%)
#  - Year 2030, Goal Goal C: Required return > 100% (129.52%)
#  - Year 2030, Goal Goal C: Required return > 100% (130.61%)
#  - Year 2030, Goal Goal C: Required return > 100% (131.69%)
#  - Year 2030, Goal Goal C: Required return > 100% (132.75%)
#  - Year 2030, Goal Goal C: Required return > 100% (133.81%)
#  - Year 2030, Goal Goal C: Required return > 100% (134.86%)
#  - Year 2030, Goal Goal C: Required return > 100% (135.90%)
#  - Year 2030, Goal Goal C: Required return > 100% (136.93%)
#  - Year 2030, Goal Goal C: Required return > 100% (137.95%)
#  - Year 2030, Goal Goal C: Required return > 100% (138.96%)
#  - Year 2030, Goal Goal C: Required return > 100% (139.97%)
#  - Year 2030, Goal Goal C: Required return > 100% (140.96%)
#  - Year 2030, Goal Goal C: Required return > 100% (141.95%)
#  - Year 2030, Goal Goal C: Required return > 100% (142.93%)
#  - Year 2030, Goal Goal C: Required return > 100% (143.90%)
#  - Year 2030, Goal Goal C: Required return > 100% (144.87%)
#  - Year 2030, Goal Goal C: Required return > 100% (145.82%)
#  - Year 2030, Goal Goal C: Required return > 100% (146.77%)
#  - Year 2030, Goal Goal C: Required return > 100% (147.71%)
#  - Year 2030, Goal Goal C: Required return > 100% (148.65%)
#  - Year 2030, Goal Goal C: Required return > 100% (149.58%)
#  - Year 2030, Goal Goal C: Required return > 100% (150.50%)
#  - Year 2030, Goal Goal C: Required return > 100% (151.41%)
#  - Year 2030, Goal Goal C: Required return > 100% (152.32%)
#  - Year 2030, Goal Goal C: Required return > 100% (153.22%)
#  - Year 2030, Goal Goal C: Required return > 100% (154.12%)
#  - Year 2030, Goal Goal C: Required return > 100% (155.00%)
#  - Year 2030, Goal Goal C: Required return > 100% (155.89%)
#  - Year 2030, Goal Goal C: Required return > 100% (156.76%)
#  - Year 2030, Goal Goal C: Required return > 100% (157.63%)
#  - Year 2030, Goal Goal C: Required return > 100% (158.50%)
