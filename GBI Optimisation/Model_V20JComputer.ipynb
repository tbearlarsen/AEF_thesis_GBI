# %% [markdown]
# V1 (02 11 2025): Translated from R to Python and added the visualizations for goals B to D
#
#
# V2 (04 01 2025): Loop system implemented
#
# V2.5 (04 02 2025): Loops system tweaks. Removed openpyxl as it was corrupting files and replaced it with xlwings
#
# V3 & V4 finalize the loop except for the tax and asset channel
#
# V 5,6,7 add tax shenanigans. V7C added the fully functioning inflow and outflow of wealth with the returns and taxes in it.
#
# V8 modifies the aktiesparekonto pool so that it is increased when taxes are payed.
#
# V9 substracts from the wealth pool the amount for the goals reached. It does not just substract the full amount of the goal, but rather the % from the allocation of the year prior to the goal being handed.
#
# V10 Corrects returns to be inflation adjusted
#
# V11 Opportunity cost calculation to redeem goal
#
# V12 FinalWealth works without excel
#
# V13 Loop check works without excel
#
# V 14 to 17 have handled the removal of excel dependency and the Montecarlo setup
#
# V 18 onwards continues with improving the reporting aspect of the loops.

# %%
#!pip install numpy pandas scipy matplotlib xlwings openpyxl

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import subprocess

# %%
# -- Variable Setup -- ##

#Monte Carlo Trials
n_trials = 10**5

# -V10 - Static Inflation
inflation_rate = 0.02  # 2%
#Case Study Profile Selection
Profile = "P1" #Either P1 or P2

#Excel worksheets - Master
excel_returns = "Returns"
excel_volatilities = "Volatilities"
excel_correlation = "Correlation"
excel_income = "Salary"
excel_real_returns = "Real Returns"

#Excel worksheets - Montecarlo Returns
excel_obligations_zc = "Government ZC Bonds - Obli"
excel_obligations_igb = "Investment Grade Bonds - Obli"
excel_obligations_hyb = "High Yield Bonds - Obli"
excel_obligations_ems = "Emerging Markets State - Obli"
excel_equities_dm = "Developed Markets - Equities"
excel_equities_em = "Emerging Markets - Equities"

# Define path range (inclusive of start, exclusive of end)
start_path = 0
end_path = 2  # e.g., will simulate paths 100 to 199

# %% [markdown]
# # Define Functions
# This section defines the functions used for calculating portfolio volatility, expected return,
# goal achievement probability, and the objective (failure probability) to minimize.

# %%
def sd_f(weight_vector, covar_table):
    covar_vector = np.zeros(len(weight_vector))
    for z in range(len(weight_vector)):
        covar_vector[z] = np.sum(weight_vector * covar_table[:, z])
    return np.sqrt(np.sum(weight_vector * covar_vector))

# %%
def mean_f(weight_vector, return_vector):
    return np.sum(weight_vector * return_vector)

# %%
"""
Disabled because due to the dynamic model some phis are nan instead of 0
def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    # goal_vector is [value ratio, funding requirement, time horizon]
    required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
    if goal_allocation * pool >= goal_vector[1]:
        return 1
    else:
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)"""

def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    try:
        if goal_allocation <= 0 or pool <= 0 or goal_vector[2] <= 0 or sd <= 0:
            return 0  # invalid case
        required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
        if goal_allocation * pool >= goal_vector[1]:
            return 1
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)
    except:
        return 0  # fallback for any numerical error

# %%
def optim_function(weights):
    # Uses the current global variables: goal_vector, allocation, pool, return_vector, covar_table
    return 1 - phi_f(
        goal_vector,
        allocation,
        pool,
        mean_f(weights, return_vector),
        sd_f(weights, covar_table)
    )

# %%
def constraint_function(weights):
    # For SciPy equality constraints, we require constraint_function(weights) == 0.
        return np.sum(weights) - 1

# %%
def mvu_f(weights):
    # mvu_f is defined for mean-variance optimization (not used below).
    return -(mean_f(weights, return_vector) - 0.5 * gamma * sd_f(weights, covariances)**2)

# %%
def r_req_f(goal_vector, goal_allocation, pool):
    return (goal_vector[1] / (goal_allocation * pool))**(1 / goal_vector[2]) - 1

# %%
def get_goal_data(master_excel_path, plan=Profile):
    """
    Returns a DataFrame of the specified goal table (P1 or P2).
    P1 => B2:F5
    P2 => B7:F10
    """
    if plan == "P1":
        skip = 1  # start reading at row 2
    elif plan == "P2":
        skip = 6  # start reading at row 7
    else:
        raise ValueError("Plan not recognized. Use 'P1' or 'P2'.")

    df_goals = pd.read_excel(master_excel_path,sheet_name="Goals",skiprows=skip,nrows=4,usecols="B:F",header=0)
    # First column is "Goal Info", so make that the index
    df_goals.set_index(df_goals.columns[0], inplace=True)
    return df_goals

# %% [markdown]
# # Load & Parse Data

# %%
## -- Repo Root and Folders -- ##

# Get repo root and set folders
root = subprocess.run(["git", "rev-parse", "--show-toplevel"], capture_output=True, text=True).stdout.strip()
data_folder = os.path.join(root, "GBI Optimisation", "data")
# Define dynamic output folder based on path range
output_folder_name = f"outputs_path_{start_path}_to_{end_path}"
output_folder = os.path.join(root, "GBI Optimisation", output_folder_name)

# Create the folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Get excel file and sheets
master_excel_path = os.path.join(data_folder, "Master.xlsx")
montecarlo_excel_path = os.path.join(data_folder, "Montecarlo Returns.xlsx")


df_returns = pd.read_excel(master_excel_path, sheet_name=excel_returns)
df_vols = pd.read_excel(master_excel_path, sheet_name=excel_volatilities)

df_returns.set_index(df_returns.columns[0], inplace=True)
df_vols.set_index(df_vols.columns[0], inplace=True)

df_corr = pd.read_excel(master_excel_path, sheet_name=excel_correlation)
df_corr.set_index(df_corr.columns[0], inplace=True)

df_real_returns = pd.read_excel(master_excel_path, sheet_name=excel_real_returns)
df_real_returns.set_index(df_real_returns.columns[0], inplace=True)

#Montecarlo Excel File DFs
df_zc = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_zc)
df_igb = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_igb)
df_hyb = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_hyb)
df_ems = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_ems)
df_dm = pd.read_excel(montecarlo_excel_path, sheet_name=excel_equities_dm)
df_em = pd.read_excel(montecarlo_excel_path, sheet_name=excel_equities_em)

# %%
sheet_map = {
    "Government ZC Bonds - Obligations": df_zc,
    "Investment Grade Bonds - Obligations": df_igb,
    "High Yield Bonds - Obligations": df_hyb,
    "Emerging Markets State - Obligations": df_ems,
    "Developed Markets - Equities": df_dm,
    "Emerging Markets - Equities": df_em,
}

# Stack into a long format with asset label and path number
all_paths = []

for sheet_name, df in sheet_map.items():
    df = df.drop(columns=df.columns[0])  # Drop the unnamed column
    df["Asset"] = sheet_name
    df["Path"] = range(len(df))
    all_paths.append(df)

df_montecarlo_returns = pd.concat(all_paths, ignore_index=True)
df_montecarlo_returns = df_montecarlo_returns.set_index(["Asset", "Path"])  # Multi-index for looping per asset/path

# %%
print(df_montecarlo_returns)
# Out:
#                                             2025      2026      2027  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.000007  0.032520  0.031400
#                                   1    -0.032011 -0.016466  0.022058
#                                   2     0.059478 -0.041409  0.112298
#                                   3     0.018892  0.022836 -0.041172
#                                   4     0.036280  0.026994 -0.043246
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9995 -0.195809  0.147981 -0.255507
#                                   9996  0.272002  0.197929  0.019133
#                                   9997  0.123811 -0.076521  0.304091
#                                   9998 -0.000032  0.025178 -0.137352
#                                   9999 -0.264516  0.200983  0.212296
#
#                                             2028      2029      2030  \
# Asset                             Path
# Government ZC Bonds - Obligations 0     0.084478  0.049271  0.000944
#                                   1    -0.022606  0.029971  0.129354
#                                   2    -0.022153  0.058938 -0.057467
#                                   3     0.043495  0.067872  0.081891
#                                   4     0.087760  0.012542  0.016454
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9995  0.116068  0.259879  0.301469
#                                   9996  0.308058 -0.158233 -0.025175
#                                   9997  0.348244  0.012878 -0.041964
#                                   9998 -0.071918  0.284494 -0.023585
#                                   9999  0.479749  0.346665  0.229773
#
#                                             2031      2032      2033  \
# Asset                             Path
# Government ZC Bonds - Obligations 0     0.029205 -0.059361 -0.024902
#                                   1     0.039348 -0.075178  0.027823
#                                   2    -0.007297  0.044033 -0.095266
#                                   3    -0.011422 -0.032769 -0.057947
#                                   4     0.019284 -0.024468 -0.085010
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9995  0.135570 -0.010909  0.396562
#                                   9996  0.432799  0.334607 -0.064113
#                                   9997  0.456502  0.161741  0.797180
#                                   9998  0.293742 -0.168514  0.208062
#                                   9999 -0.044745 -0.125317  0.070469
#
#                                             2034  ...      2066      2067  \
# Asset                             Path            ...
# Government ZC Bonds - Obligations 0    -0.044924  ... -0.044940 -0.067034
#                                   1    -0.000004  ...  0.044008 -0.032297
#                                   2     0.070355  ... -0.049671 -0.027272
#                                   3     0.050958  ...  0.094294 -0.009810
#                                   4     0.100474  ... -0.080258  0.054006
# ...                                          ...  ...       ...       ...
# Emerging Markets - Equities       9995  0.592109  ...  0.019935  0.157335
#                                   9996 -0.020769  ...  0.240310  0.049975
#                                   9997  0.064672  ...  0.188076  0.185146
#                                   9998 -0.079955  ...  0.377140 -0.100160
#                                   9999  0.162238  ...  0.364832 -0.100723
#
#                                             2068      2069      2070  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.005422 -0.018352  0.088154
#                                   1    -0.044900 -0.048844 -0.016176
#                                   2    -0.094621 -0.016504  0.065108
#                                   3     0.049919  0.021916 -0.024192
#                                   4     0.053771  0.049364 -0.064463
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9995  0.362955 -0.033361 -0.323189
#                                   9996  0.277965  0.014838  0.204011
#                                   9997  0.471738 -0.157125  0.006551
#                                   9998  0.110597 -0.234932 -0.168143
#                                   9999  0.098638  0.157942 -0.302259
#
#                                             2071      2072      2073  \
# Asset                             Path
# Government ZC Bonds - Obligations 0     0.043110  0.066915  0.005376
#                                   1     0.107332 -0.005704 -0.083704
#                                   2     0.043573  0.119018  0.029971
#                                   3    -0.094172 -0.033086  0.054652
#                                   4    -0.073501  0.062877 -0.025275
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9995  0.369606 -0.092357  0.038923
#                                   9996  0.224297  0.377593 -0.080649
#                                   9997  0.103836 -0.103930 -0.300631
#                                   9998  0.021186  0.188827  0.215730
#                                   9999 -0.016392 -0.103447  0.345458
#
#                                             2074  2075
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.009182   NaN
#                                   1     0.010094   NaN
#                                   2    -0.115711   NaN
#                                   3     0.041892   NaN
#                                   4    -0.038259   NaN
# ...                                          ...   ...
# Emerging Markets - Equities       9995 -0.065768   NaN
#                                   9996  0.047737   NaN
#                                   9997  0.065117   NaN
#                                   9998 -0.120336   NaN
#                                   9999  0.173459   NaN
#
# [60000 rows x 51 columns]

# %%
print(df_real_returns)
# Out:
#                                        2025   2026   2027   2028   2029  \
# Unnamed: 0
# Emerging Markets - Equities           0.001  0.001  0.001  0.001  0.001
# Developed Markets - Equities          0.001  0.001  0.001  0.001  0.001
# Emerging Markets State - Obligations  0.001  0.001  0.001  0.001  0.001
# High Yield Bonds - Obligations        0.001  0.001  0.001  0.001  0.001
# Investment Grade Bonds - Obligations  0.001  0.001  0.001  0.001  0.001
# Government ZC Bonds - Obligations     0.001  0.001  0.001  0.001  0.001
#
#                                        2030   2031   2032   2033   2034  ...  \
# Unnamed: 0                                                               ...
# Emerging Markets - Equities           0.001  0.001  0.001  0.001  0.001  ...
# Developed Markets - Equities          0.001  0.001  0.001  0.001  0.001  ...
# Emerging Markets State - Obligations  0.001  0.001  0.001  0.001  0.001  ...
# High Yield Bonds - Obligations        0.001  0.001  0.001  0.001  0.001  ...
# Investment Grade Bonds - Obligations  0.001  0.001  0.001  0.001  0.001  ...
# Government ZC Bonds - Obligations     0.001  0.001  0.001  0.001  0.001  ...
#
#                                       2066  2067  2068  2069  2070  2071  \
# Unnamed: 0
# Emerging Markets - Equities           0.04  0.04  0.04  0.04  0.04  0.04
# Developed Markets - Equities          0.04  0.04  0.04  0.04  0.04  0.04
# Emerging Markets State - Obligations  0.04  0.04  0.04  0.04  0.04  0.04
# High Yield Bonds - Obligations        0.04  0.04  0.04  0.04  0.04  0.04
# Investment Grade Bonds - Obligations  0.04  0.04  0.04  0.04  0.04  0.04
# Government ZC Bonds - Obligations     0.04  0.04  0.04  0.04  0.04  0.04
#
#                                       2072  2073  2074  2075
# Unnamed: 0
# Emerging Markets - Equities           0.04  0.04  0.04  0.04
# Developed Markets - Equities          0.04  0.04  0.04  0.04
# Emerging Markets State - Obligations  0.04  0.04  0.04  0.04
# High Yield Bonds - Obligations        0.04  0.04  0.04  0.04
# Investment Grade Bonds - Obligations  0.04  0.04  0.04  0.04
# Government ZC Bonds - Obligations     0.04  0.04  0.04  0.04
#
# [6 rows x 51 columns]

# %%
# - NEW V8 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #

# Initial cap in 2025
initial_ask_cap = 166200
growth_rate = 0.1265  # 12.65% annual increase
aktiesparekonto_used_total = 0

# %%
# V 13 - Year Loop table
# -- Replaces Excel loop sheet with in-code structure -- #
start_year = 2025
end_year = 2075
N_max = end_year - start_year + 1

age_p1_start = 25
age_p2_start = 40

loop_df = pd.DataFrame({
    "N": range(1, N_max + 1),
    "Year": list(range(start_year, end_year + 1)),
    "AgeP1": [age_p1_start + i for i in range(N_max)],
    "AgeP2": [age_p2_start + i for i in range(N_max)],
    "LoopStatus": ['N'] * N_max
})

# %%
# V14 - Load salary data for all years
df_salary = pd.read_excel(master_excel_path, sheet_name=excel_income)
df_salary.set_index(df_salary.columns[0], inplace=True)

# %%
path_results = {}
goal_reached = {g: [] for g in ["A", "B", "C", "D"]}

master_asset_log = []
master_final_wealth = []
master_goal_weights = []
master_aggregate_portfolio = []
master_goal_optimal_weights = {g: [] for g in ["A", "B", "C", "D"]}



for path_id in range(start_path, end_path):
    loop_df["LoopStatus"] = "N"
    asset_level_log = []  # NEW: Log each asset's return pre- and post-tax by account
    #V12 moved finalwealth to python
    final_wealth_tracker = {}

    #V15 goal info stored in python instead of excel
    goal_weights_tracker = []  # Stores goal weights for each year
    aggregate_portfolio_tracker = []  # Stores aggregate portfolio for each year

    # V15: Store all optimal weight matrices by year
    goal_optimal_weights_A = {}
    goal_optimal_weights_B = {}
    goal_optimal_weights_C = {}
    goal_optimal_weights_D = {}
    print(f"🧪 Running simulation for path {path_id}")

    while True:
        pending_rows = loop_df[loop_df["LoopStatus"] == "N"]

        # If we find any rows, get the row with the lowest Year
        if pending_rows.empty:
            print("All loops completed")
            break

        chosen_row = pending_rows.loc[pending_rows["Year"].idxmin()]
        loop_year = chosen_row["Year"]
        loop_number = chosen_row["N"]
        loop_age1 = chosen_row["AgeP1"]
        loop_age2 = chosen_row["AgeP2"]

        print(loop_year, loop_number, loop_age1, loop_age2)

        # - Wealth - #

        # Get salary for current year
        salary = df_salary.loc[Profile, str(loop_year)]

        # - Dynamic time horizon based on current year - #

        # Step 1: Get Starting Year (minimum year in Loop sheet)
        starting_year = start_year
        prev_year = str(loop_year - 1)

        # If first loop year, no previous wealth exists
        if loop_year == starting_year:
            prev_wealth = 0
            pool = salary
        else:
            try:
                prev_wealth = final_wealth_tracker[int(prev_year)]
            except KeyError:
                raise KeyError(f"Previous wealth not found for {Profile} in {prev_year}")
            pool = salary + prev_wealth

        capital_market_expectations_raw = {}
        for asset in df_returns.index:
            expected_return = df_returns.loc[asset, str(loop_year)]
            volatility = df_vols.loc[asset, 'volatility']
            capital_market_expectations_raw[asset] = {
                'Return Forecast': expected_return,
                'Volatility Forecast': volatility
            }

        capital_market_expectations_raw = pd.DataFrame.from_dict(capital_market_expectations_raw, orient='index')

        capital_market_expectations_raw = capital_market_expectations_raw.reset_index()
        capital_market_expectations_raw.rename(columns={'index': 'Unnamed: 0'}, inplace=True)

        # Rearrange columns to match your old format (optional):
        capital_market_expectations_raw = capital_market_expectations_raw[
            ['Unnamed: 0', 'Return Forecast', 'Volatility Forecast']]

        goal_data_raw = get_goal_data(master_excel_path, plan="P1")

        # - Dynamic time horizon based on current year - #

        # Step 2: Compute Goal Years = starting_year + time_horizon
        goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
        goal_years = starting_year + goal_horizons

        # Step 3: Recalculate Time Horizons = goal_years - current loop_year
        adjusted_horizons = goal_years - loop_year

        # Step 4: Replace the "Time Horizon" row in goal_data_raw
        goal_data_raw.loc["Time Horizon"] = adjusted_horizons

        # - V8 - Dynamically compute ASK cap per year
        aktiesparekonto_cap = initial_ask_cap * ((1 + growth_rate) ** (loop_year - starting_year))

        goals = ["A", "B", "C", "D"]
        active_goal_mask = np.array([adjusted_horizons[f"GOAL {g}"] > 0 for g in goals])

        # Optional: print to confirm
        print("Starting Year:", starting_year)
        print("Current Year:", loop_year)
        print("Goal Years:", goal_years.to_dict())
        print("Adjusted Horizons:", adjusted_horizons.to_dict())

        # Record number of potential investments and goals
        num_assets = capital_market_expectations_raw.shape[0]
        num_goals = goal_data_raw.shape[1]

        # Create vector of expected returns
        return_vector = (capital_market_expectations_raw["Return Forecast"] - inflation_rate).to_numpy()

        # Get the correlations as a numeric DataFrame (just a num_assets × num_assets block)
        correlations = df_corr.iloc[:num_assets, :num_assets].astype(float)

        # Build the covariance matrix: stdev_i * stdev_j * correlation_ij
        stdevs = capital_market_expectations_raw["Volatility Forecast"].to_numpy()
        covariances = np.zeros((num_assets, num_assets))
        for i in range(num_assets):
            for j in range(num_assets):
                covariances[i, j] = stdevs[i] * stdevs[j] * correlations.iloc[i, j]

        goal_A = goal_data_raw["GOAL A"].values
        goal_B = goal_data_raw["GOAL B"].values
        goal_C = goal_data_raw["GOAL C"].values
        goal_D = goal_data_raw["GOAL D"].values

        # - Optimal Goal Allocation - #

        goal_allocation = np.arange(0.01, 1.01, 0.01)

        # Starting weights (random initialization normalized to sum to 1)
        starting_weights = np.random.uniform(0, 1, num_assets)
        starting_weights /= np.sum(starting_weights)

        # Initialize matrices to store the optimal weights for each goal
        optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
        optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
        optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
        optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

        goal_allocation = np.arange(0.01, 1.01, 0.01)

        # Set SLSQP options to be more stringent, mimicking solnp's behavior.
        slsqp_opts = {
            'ftol': 1e-12,  # function tolerance
            'eps': 1e-12,  # finite-difference step size for gradient estimation
            'maxiter': 10000,  # maximum iterations
            'disp': False  # do not display convergence messages
        }

        for i, alloc in enumerate(goal_allocation):
            allocation = alloc  # Global variable used in optim_function
            covar_table = covariances

            # Goal A Optimization
            goal_vector = goal_A  # Global variable used in optim_function
            if goal_A[1] <= pool * allocation:
                optimal_weights_A[i, :] = [0] * (num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_A[i, :] = result.x

            # Goal B Optimization
            goal_vector = goal_B
            if goal_B[1] <= pool * allocation:
                optimal_weights_B[i, :] = [0] * (num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_B[i, :] = result.x

            # Goal C Optimization
            goal_vector = goal_C
            if goal_C[1] <= pool * allocation:
                optimal_weights_C[i, :] = [0] * (num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_C[i, :] = result.x

            # Goal D Optimization
            goal_vector = goal_D
            if goal_D[1] <= pool * allocation:
                optimal_weights_D[i, :] = [0] * (num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_D[i, :] = result.x

        goal_optimal_weights_A[loop_year] = optimal_weights_A
        goal_optimal_weights_B[loop_year] = optimal_weights_B
        goal_optimal_weights_C[loop_year] = optimal_weights_C
        goal_optimal_weights_D[loop_year] = optimal_weights_D

        # Calculate the best probability (phi) for each allocation level for every goal
        phi_A = np.zeros(len(goal_allocation))
        phi_B = np.zeros(len(goal_allocation))
        phi_C = np.zeros(len(goal_allocation))
        phi_D = np.zeros(len(goal_allocation))

        for i, alloc in enumerate(goal_allocation):
            phi_A[i] = phi_f(goal_A, alloc, pool,
                             mean_f(optimal_weights_A[i, :], return_vector),
                             sd_f(optimal_weights_A[i, :], covariances))
            phi_B[i] = phi_f(goal_B, alloc, pool,
                             mean_f(optimal_weights_B[i, :], return_vector),
                             sd_f(optimal_weights_B[i, :], covariances))
            phi_C[i] = phi_f(goal_C, alloc, pool,
                             mean_f(optimal_weights_C[i, :], return_vector),
                             sd_f(optimal_weights_C[i, :], covariances))
            phi_D[i] = phi_f(goal_D, alloc, pool,
                             mean_f(optimal_weights_D[i, :], return_vector),
                             sd_f(optimal_weights_D[i, :], covariances))

        # Simulate goal weights: each row is a simulated allocation (in percentages)
        sim_goal_weights = np.random.multinomial(100, [1 / num_goals] * num_goals,
                                                 size=n_trials)  #this one sums to 100 so its good
        for i in range(n_trials):
            rand_vector = np.random.uniform(0, 1, num_goals)
            normalizer = np.sum(rand_vector)
            percents = np.round((rand_vector / normalizer) * 100, 0)

            # Only enforce floor for active goals
            floor_applied = np.where(active_goal_mask, np.maximum(percents, 1), percents)
            sim_goal_weights[i, :] = floor_applied

        # Calculate utility for each simulated portfolio.
        # Note: subtract 1 from simulated weights for 0-indexing.
        utility = (
                goal_A[0] * phi_A[sim_goal_weights[:, 0] - 1] +
                goal_A[0] * goal_B[0] * phi_B[sim_goal_weights[:, 1] - 1] +
                goal_A[0] * goal_B[0] * goal_C[0] * phi_C[sim_goal_weights[:, 2] - 1] +
                goal_A[0] * goal_B[0] * goal_C[0] * goal_D[0] * phi_D[sim_goal_weights[:, 3] - 1]
        )

        # Find the index of the portfolio with the highest utility
        index = np.argmax(utility)
        optimal_goal_weights = sim_goal_weights[index, :]

        # - Optimal Subportfolio Allocation - #

        # Retrieve optimal subportfolio allocations
        optimal_subportfolios = np.zeros((num_goals, num_assets))

        # For each goal, use the simulated percentage to select the corresponding row
        # from the optimal weights matrix (adjust for zero-indexing)
        for i in range(num_goals):
            optimal_subportfolios[i, :] = eval(f"optimal_weights_{goals[i]}")[optimal_goal_weights[i] - 1, :]

        # Compute the optimal aggregate investment portfolio.
        optimal_aggregate_portfolio = (optimal_goal_weights / 100) @ optimal_subportfolios

        #Define asset names
        asset_names = capital_market_expectations_raw.iloc[:, 0].astype(str).tolist()

        # - Storing and exporting results - #

        # Create a DataFrame for the aggregate portfolio.
        # First calculate unrounded percentages
        raw_alloc = optimal_aggregate_portfolio * 100

        # Normalize to force sum = 100 after rounding
        normalized_alloc = raw_alloc / raw_alloc.sum() * 100
        normalized_goal_alloc = np.zeros_like(optimal_goal_weights, dtype=float)
        active_sum = np.sum(optimal_goal_weights[active_goal_mask])
        normalized_goal_alloc[active_goal_mask] = (optimal_goal_weights[active_goal_mask] / active_sum) * 100

        normalized_weights = normalized_alloc / 100  # convert back to decimal weights

        # Create a DataFrame for the across-goal allocation.
        df_across_goal = pd.DataFrame({
            "Goal": goals,
            "Allocation (%)": np.round(normalized_goal_alloc, 2)  # Keep raw percentages
        })

        # Round after normalization
        df_aggregate = pd.DataFrame({
            "Asset": asset_names,
            "Weight": normalized_weights,
            "Invested Amt (DKK)": normalized_weights * pool,
            "Allocation (%)": np.round(normalized_alloc, 2)  # keep for display only
        })

        # - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #
        # --- NEW: Exact and Proportional ASK Logic ---
        account_allocations = []
        equity_rows = []
        non_equity_rows = []

        # First pass: split equity and non-equity rows
        for i, row in df_aggregate.iterrows():
            asset_name = row["Asset"]
            invested = row["Invested Amt (DKK)"]
            weight = row["Weight"]

            row_dict = {
                "Year": loop_year,
                "Asset": asset_name,
                "Invested": invested,
                "Weight": weight,
                "ASK (DKK)": 0,
                "Normal (DKK)": 0,
            }

            if "Equities" in asset_name:
                equity_rows.append(row_dict)
            else:
                row_dict["Normal (DKK)"] = invested
                non_equity_rows.append(row_dict)

        # Determine total equity to allocate proportionally if ASK cap remains
        total_equity = sum(row["Invested"] for row in equity_rows)
        remaining_ask_cap = max(0, aktiesparekonto_cap - aktiesparekonto_used_total)
        ask_fraction = min(1, remaining_ask_cap / total_equity) if total_equity > 0 else 0

        # Apply proportional ASK allocation to equities
        for row in equity_rows:
            ask_part = row["Invested"] * ask_fraction
            normal_part = row["Invested"] - ask_part
            row["ASK (DKK)"] = round(ask_part, 2)
            row["Normal (DKK)"] = round(normal_part, 2)
            aktiesparekonto_used_total += ask_part

        # Combine and finalize
        account_allocations = equity_rows + non_equity_rows

        df_accounts = pd.DataFrame(account_allocations)
        print(f"[DEBUG] Final weight sum: {sum(row['Weight'] for row in account_allocations):.10f}")
        # - V5 END - #

        # - NEW V6 CONTENT REGARDING GAINS & TAXES - #

        share_income_normal = 0  # for progressive tax
        tax_ask = 0  # Track ASK tax separately

        # Update portfolio and compute gains
        for row in account_allocations:
            asset = row["Asset"]
            ask = row["ASK (DKK)"]
            normal = row["Normal (DKK)"]
            weight = row["Weight"]
            expected_return_nominal = df_montecarlo_returns.loc[(asset, path_id), str(loop_year)]
            expected_return_inflation_adj = expected_return_nominal - inflation_rate

            # V7C -LOG ASSET RETURNS BY ACCOUNT
            if ask > 0:
                new_val = ask * (1 + expected_return_inflation_adj)
                gain = new_val - ask
                tax = 0.17 * gain
                asset_level_log.append({
                    "Year": loop_year,
                    "Account": "ASK",
                    "Asset": asset,
                    "Invested": ask,
                    "Weight": ask / pool,
                    "Return (Nominal)": expected_return_nominal,
                    "Inflation Rate": inflation_rate,
                    "Return (Inflation Adjusted)": expected_return_inflation_adj,
                    "Gross Gain": gain,
                    "Tax": tax,
                    "Net Gain": gain - tax,
                    "End Value": ask + gain - tax,
                    "TOTAL ASK Cap (DKK)": aktiesparekonto_cap
                })

            if normal > 0:
                new_val = normal * (1 + expected_return_inflation_adj)
                gain = new_val - normal
                share_income_normal += gain
                asset_level_log.append({
                    "Year": loop_year,
                    "Account": "NORMAL",
                    "Asset": asset,
                    "Invested": normal,
                    "Weight": normal / pool,
                    "Return (Nominal)": expected_return_nominal,
                    "Inflation Rate": inflation_rate,
                    "Return (Inflation Adjusted)": expected_return_inflation_adj,
                    "Gross Gain": gain,
                    "Tax": None,  # progressive tax logged later
                    "Net Gain": None,
                    "End Value": None,
                    "TOTAL ASK Cap (DKK)": aktiesparekonto_cap
                })

                #V7C END

        # Tax on Normal Account (progressive)
        cap = 67500
        if share_income_normal <= cap:
            tax_normal = 0.27 * share_income_normal
        else:
            tax_normal = 0.27 * cap + 0.42 * (share_income_normal - cap)

        # Distribute tax proportionally across NORMAL assets
        normal_log_rows = [
            row for row in asset_level_log
            if "Account" in row and row["Account"] == "NORMAL" and row["Year"] == loop_year
        ]

        total_normal_gain = sum(row["Gross Gain"] for row in normal_log_rows)

        print(f"[DEBUG] Year: {loop_year}")
        print(f"[DEBUG] Gross Gains (Normal account): {share_income_normal:.2f}")
        print(f"[DEBUG] Tax Calculated (Normal account): {tax_normal:.2f}")

        for row in normal_log_rows:
            if total_normal_gain > 0:
                share = row["Gross Gain"] / total_normal_gain
                tax = share * tax_normal
            else:
                tax = 0

            row["Tax"] = tax
            row["Net Gain"] = row["Gross Gain"] - tax
            row["End Value"] = row["Invested"] + row["Net Gain"]

        total_gains_normal = share_income_normal - tax_normal

        print("Optimal Across-Goal Allocation:")
        print(df_across_goal.to_string(index=False))

        print("\nOptimal Aggregate Investment Allocation:")
        print(df_aggregate.to_string(index=False))

        print("\nUtility:")
        print(utility)

        print("\nProbability of Achieving Each Goal at Optimal Allocation:")
        print(f"Goal A: {phi_A[optimal_goal_weights[0] - 1]:.4f}")
        print(f"Goal B: {phi_B[optimal_goal_weights[1] - 1]:.4f}")
        print(f"Goal C: {phi_C[optimal_goal_weights[2] - 1]:.4f}")
        print(f"Goal D: {phi_D[optimal_goal_weights[3] - 1]:.4f}")

        # -- V15 Goal weights -- #

        # Store current year's across-goal allocation
        goal_weights_tracker.append({
            "Year": loop_year,
            **{f"Goal {goals[i]} (%)": normalized_goal_alloc[i] for i in range(num_goals)}
        })

        # Store current year's aggregate portfolio
        for i in range(num_assets):
            aggregate_portfolio_tracker.append({
                "Year": loop_year,
                "Asset": asset_names[i],
                "Weight": normalized_weights[i],
                "Allocation (%)": np.round(normalized_alloc[i], 2),
                "Invested Amt (DKK)": normalized_weights[i] * pool
            })

        # -- V13 - Modify Loop Check -- #
        print("Starting loop status check (in-memory)...")

        # Show up to 10 rows (adjust as needed) of the current loop status
        preview_rows = loop_df.tail(10)
        for i, row in preview_rows.iterrows():
            print(f"Row {i + 2}: Year = {row['Year']}, Status = {row['LoopStatus']}")

        # Update the current year's loop status
        loop_df.loc[loop_df["Year"] == loop_year, "LoopStatus"] = "Y"
        print(f"✅ LoopStatus updated to 'Y' for Year {loop_year}")

        this_year_rows = [row for row in asset_level_log if row["Year"] == loop_year]
        end_value_sum = sum(row["End Value"] for row in this_year_rows)

        # - V9 END -
        # --- V11: Opportunity Cost Check for Goal Redemption --- #
        for idx, g in enumerate(goals):
            horizon = adjusted_horizons[f"GOAL {g}"]
            if horizon == 1:
                goal_vec   = goal_data_raw[f"GOAL {g}"].values.copy()
                goal_value = goal_vec[1]

                # ---------- FIX: define allocs & allocated_value up-front ----------
                allocs           = [normalized_goal_alloc[i] / 100 for i in range(num_goals)]
                allocated_value  = allocs[idx] * end_value_sum        # ← was missing
                redeemed_amount  = 0
                redemption_status = "FALSE"
                # ------------------------------------------------------------------

                # Step 1: Prepare inputs
                phi_array   = [None] * num_goals
                goal_ratios = [goal_data_raw[f"GOAL {goals[i]}"].values[0]
                               for i in range(num_goals)]

                # Step 2: Case 1 - Keep goal (phi = 0 for this goal)
                for j in range(num_goals):
                    if j == idx:
                        phi_array[j] = 0
                    else:
                        phi_array[j] = phi_f(
                            goal_data_raw[f"GOAL {goals[j]}"].values,
                            allocs[j],
                            pool,
                            mean_f(optimal_subportfolios[j], return_vector),
                            sd_f(optimal_subportfolios[j], covariances)
                        )

                utility_keep = (
                        goal_ratios[0] * phi_array[0] +
                        goal_ratios[0] * goal_ratios[1] * phi_array[1] +
                        goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * phi_array[2] +
                        goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * goal_ratios[3] * phi_array[3]
                )

                # Step 3: Case 2 - Redeem goal (phi = 1, pool reduced)
                pool_reduced = pool - goal_value
                for j in range(num_goals):
                    if j == idx:
                        phi_array[j] = 1
                    else:
                        phi_array[j] = phi_f(
                            goal_data_raw[f"GOAL {goals[j]}"].values,
                            allocs[j],
                            pool_reduced,
                            mean_f(optimal_subportfolios[j], return_vector),
                            sd_f(optimal_subportfolios[j], covariances)
                        )

                utility_redeem = (
                        goal_ratios[0] * phi_array[0] +
                        goal_ratios[0] * goal_ratios[1] * phi_array[1] +
                        goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * phi_array[2] +
                        goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * goal_ratios[3] * phi_array[3]
                )

                # Step 4: Compare & apply
                utility_diff = utility_redeem - utility_keep
                redeem       = utility_diff > 0

                if redeem:
                    redeemed_amount   = min(goal_value, allocated_value)
                    end_value_sum    -= redeemed_amount
                    redemption_status = "TRUE" if redeemed_amount >= goal_value else "PARTIAL"

                goal_reached[g].append({
                    "path_id": path_id,
                    "year":   loop_year,
                    "status": redemption_status,
                    "redeemed_amount": redeemed_amount,
                    "goal_value": goal_value
                })

                asset_level_log.append({
                    "Year": loop_year,
                    "Goal": f"GOAL {g}",
                    "Redeemed Amount": redeemed_amount,
                    "Allocated Value": allocated_value,   # ← always defined now
                    "Goal Value": goal_value,
                    "Utility (Keep)":   utility_keep,
                    "Utility (Redeem)": utility_redeem,
                    "Utility Δ":        utility_diff,
                    "Redeemed": redemption_status
                })

        final_wealth_tracker[loop_year] = end_value_sum

        print(f"\n--- Year {loop_year} Summary ---")
        print(f"Income (Salary): {salary:.2f}")
        if loop_year != starting_year:
            print(f"Previous Wealth Carried: {prev_wealth:.2f}")
        print(f"Post-Tax Wealth (New Final Wealth): {pool:.2f}")
        print("------------------------------\n")


    # Export asset-level log
    df_log = pd.DataFrame(asset_level_log)
    df_log["Path_ID"] = path_id
    master_asset_log.append(df_log)

    # Export final wealth
    df_wealth = pd.DataFrame.from_dict(final_wealth_tracker, orient='index', columns=['Final Wealth'])
    df_wealth["Path_ID"] = path_id
    master_final_wealth.append(df_wealth.reset_index().rename(columns={"index": "Year"}))

    # Export goal weights
    df_goal_weights = pd.DataFrame(goal_weights_tracker)
    df_goal_weights["Path_ID"] = path_id
    master_goal_weights.append(df_goal_weights)

    # Export aggregate portfolio
    df_aggregate = pd.DataFrame(aggregate_portfolio_tracker)
    df_aggregate["Path_ID"] = path_id
    master_aggregate_portfolio.append(df_aggregate)

    # Export optimal weights for each goal
    for goal_letter, matrix_dict in zip(
            ["A", "B", "C", "D"],
            [goal_optimal_weights_A, goal_optimal_weights_B, goal_optimal_weights_C, goal_optimal_weights_D]
    ):
        for year, mat in matrix_dict.items():
            df = pd.DataFrame(mat)
            df.insert(0, "Path_ID", path_id)
            df.insert(1, "Year", year)
            df.insert(2, "Allocation Level", np.arange(0.01, 1.01, 0.01))
            master_goal_optimal_weights[goal_letter].append(df)
# Out:
# 🧪 Running simulation for path 0
# 2025 1 25 40
# Starting Year: 2025
# Current Year: 2025
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 50, 'GOAL B': 5, 'GOAL C': 20, 'GOAL D': 30}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2025
# [DEBUG] Gross Gains (Normal account): 0.00
# [DEBUG] Tax Calculated (Normal account): 0.00
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             9.0
#    B            47.0
#    C            33.0
#    D            11.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.216673                 0.0           21.67
#         Developed Markets - Equities 0.030926                 0.0            3.09
# Emerging Markets State - Obligations 0.262538                 0.0           26.25
#       High Yield Bonds - Obligations 0.055501                 0.0            5.55
# Investment Grade Bonds - Obligations 0.187060                 0.0           18.71
#    Government ZC Bonds - Obligations 0.247303                 0.0           24.73
#
# Utility:
# [0. 0. 0. ... 0. 0. 0.]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2025
#
# --- Year 2025 Summary ---
# Income (Salary): 0.00
# Post-Tax Wealth (New Final Wealth): 0.00
# ------------------------------
#
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 49, 'GOAL B': 4, 'GOAL C': 19, 'GOAL D': 29}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2026
# [DEBUG] Gross Gains (Normal account): 15.32
# [DEBUG] Tax Calculated (Normal account): 4.14
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           47.52
#    B            0.99
#    C           50.50
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.984447        27120.158770           98.44
#         Developed Markets - Equities 0.003968          109.311988            0.40
# Emerging Markets State - Obligations 0.003643          100.355085            0.36
#       High Yield Bonds - Obligations 0.000828           22.811615            0.08
# Investment Grade Bonds - Obligations 0.003096           85.290629            0.31
#    Government ZC Bonds - Obligations 0.004018          110.691992            0.40
#
# Utility:
# [0.28134678 0.39228075 0.18842273 ... 0.37293176 0.4153719  0.37611569]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3562
# Goal B: 0.0000
# Goal C: 0.3802
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2026
#
# --- Year 2026 Summary ---
# Income (Salary): 27548.62
# Previous Wealth Carried: 0.00
# Post-Tax Wealth (New Final Wealth): 27548.62
# ------------------------------
#
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 48, 'GOAL B': 3, 'GOAL C': 18, 'GOAL D': 28}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2027
# [DEBUG] Gross Gains (Normal account): 61.33
# [DEBUG] Tax Calculated (Normal account): 16.56
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           49.50
#    B            0.99
#    C           48.51
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.985119        54895.894593           98.51
#         Developed Markets - Equities 0.005525          307.909022            0.55
# Emerging Markets State - Obligations 0.002073          115.509476            0.21
#       High Yield Bonds - Obligations 0.000760           42.335012            0.08
# Investment Grade Bonds - Obligations 0.005099          284.142154            0.51
#    Government ZC Bonds - Obligations 0.001424           79.364814            0.14
#
# Utility:
# [0.45130602 0.52828162 0.47895683 ... 0.27158588 0.3789726  0.34902114]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4222
# Goal B: 0.0000
# Goal C: 0.5381
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2027
#
# --- Year 2027 Summary ---
# Income (Salary): 27845.19
# Previous Wealth Carried: 27879.96
# Post-Tax Wealth (New Final Wealth): 55725.16
# ------------------------------
#
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 47, 'GOAL B': 2, 'GOAL C': 17, 'GOAL D': 27}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2028
# [DEBUG] Gross Gains (Normal account): 4720.83
# [DEBUG] Tax Calculated (Normal account): 1274.62
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           25.49
#    B            0.98
#    C           72.55
#    D            0.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.258407        26353.248160           25.84
#         Developed Markets - Equities 0.004974          507.263193            0.50
# Emerging Markets State - Obligations 0.005833          594.883731            0.58
#       High Yield Bonds - Obligations 0.001345          137.214711            0.13
# Investment Grade Bonds - Obligations 0.003362          342.863666            0.34
#    Government ZC Bonds - Obligations 0.726079        74048.040550           72.61
#
# Utility:
# [0.57643695 0.58378042 0.63089154 ... 0.52908258 0.62262822 0.68059744]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4089
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2028
#
# --- Year 2028 Summary ---
# Income (Salary): 29269.36
# Previous Wealth Carried: 72714.15
# Post-Tax Wealth (New Final Wealth): 101983.51
# ------------------------------
#
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 46, 'GOAL B': 1, 'GOAL C': 16, 'GOAL D': 26}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2029
# [DEBUG] Gross Gains (Normal account): 2151.37
# [DEBUG] Tax Calculated (Normal account): 580.87
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            43.0
#    B             1.0
#    C            55.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.438083        58387.510480           43.81
#         Developed Markets - Equities 0.004880          650.433180            0.49
# Emerging Markets State - Obligations 0.000335           44.686398            0.03
#       High Yield Bonds - Obligations 0.001798          239.686311            0.18
# Investment Grade Bonds - Obligations 0.001939          258.468373            0.19
#    Government ZC Bonds - Obligations 0.552963        73698.645756           55.30
#
# Utility:
# [0.7079366  0.67595587 0.62381013 ... 0.38929165 0.72580746 0.52106488]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4830
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2029
#
# --- Year 2029 Summary ---
# Income (Salary): 29582.08
# Previous Wealth Carried: 103697.35
# Post-Tax Wealth (New Final Wealth): 133279.43
# ------------------------------
#
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 45, 'GOAL B': 0, 'GOAL C': 15, 'GOAL D': 25}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2030
# [DEBUG] Gross Gains (Normal account): -1088.48
# [DEBUG] Tax Calculated (Normal account): -293.89
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            52.0
#    B             0.0
#    C            47.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.521086        82620.011062           52.11
#         Developed Markets - Equities 0.000171           27.089313            0.02
# Emerging Markets State - Obligations 0.007116         1128.336227            0.71
#       High Yield Bonds - Obligations 0.002899          459.635840            0.29
# Investment Grade Bonds - Obligations 0.000483           76.574832            0.05
#    Government ZC Bonds - Obligations 0.468245        74241.967796           46.82
#
# Utility:
# [0.60702104 0.51954177 0.70630704 ... 0.51785446 0.63838851 0.60337653]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5157
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2030
#
# --- Year 2030 Summary ---
# Income (Salary): 29897.42
# Previous Wealth Carried: 128656.20
# Post-Tax Wealth (New Final Wealth): 158553.62
# ------------------------------
#
# 2031 7 31 46
# Starting Year: 2025
# Current Year: 2031
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 44, 'GOAL B': -1, 'GOAL C': 14, 'GOAL D': 24}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2031
# [DEBUG] Gross Gains (Normal account): -1995.89
# [DEBUG] Tax Calculated (Normal account): -538.89
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           62.24
#    B            0.00
#    C           36.73
#    D            1.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.616449       129988.514885           61.64
#         Developed Markets - Equities 0.003693          778.629281            0.37
# Emerging Markets State - Obligations 0.001537          324.137328            0.15
#       High Yield Bonds - Obligations 0.003643          768.283865            0.36
# Investment Grade Bonds - Obligations 0.005690         1199.779183            0.57
#    Government ZC Bonds - Obligations 0.368988        77807.335095           36.90
#
# Utility:
# [0.7739925  0.6068104  0.80057576 ... 0.85433157 0.85051754 0.79919194]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5584
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2031
#
# --- Year 2031 Summary ---
# Income (Salary): 32088.85
# Previous Wealth Carried: 178777.83
# Post-Tax Wealth (New Final Wealth): 210866.68
# ------------------------------
#
# 2032 8 32 47
# Starting Year: 2025
# Current Year: 2032
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 43, 'GOAL B': -2, 'GOAL C': 13, 'GOAL D': 23}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2032
# [DEBUG] Gross Gains (Normal account): 3082.73
# [DEBUG] Tax Calculated (Normal account): 832.34
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            68.0
#    B             0.0
#    C            31.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.676639       159775.775063           67.66
#         Developed Markets - Equities 0.004200          991.823217            0.42
# Emerging Markets State - Obligations 0.001714          404.665527            0.17
#       High Yield Bonds - Obligations 0.004482         1058.338807            0.45
# Investment Grade Bonds - Obligations 0.002156          509.100625            0.22
#    Government ZC Bonds - Obligations 0.310809        73391.865441           31.08
#
# Utility:
# [0.74284314 0.72015781 0.66137467 ... 0.43951712 0.51499295 0.5291502 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5776
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2032
#
# --- Year 2032 Summary ---
# Income (Salary): 32427.30
# Previous Wealth Carried: 203704.27
# Post-Tax Wealth (New Final Wealth): 236131.57
# ------------------------------
#
# 2033 9 33 48
# Starting Year: 2025
# Current Year: 2033
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 42, 'GOAL B': -3, 'GOAL C': 12, 'GOAL D': 22}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2033
# [DEBUG] Gross Gains (Normal account): 50033.39
# [DEBUG] Tax Calculated (Normal account): 13509.02
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           71.43
#    B            0.00
#    C           27.55
#    D            1.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.705722       193244.490565           70.57
#         Developed Markets - Equities 0.007248         1984.587131            0.72
# Emerging Markets State - Obligations 0.000670          183.579573            0.07
#       High Yield Bonds - Obligations 0.008143         2229.633346            0.81
# Investment Grade Bonds - Obligations 0.002846          779.408137            0.28
#    Government ZC Bonds - Obligations 0.275371        75403.679435           27.54
#
# Utility:
# [0.74826686 0.72083395 0.55956395 ... 0.65796328 0.83581427 0.76974882]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5923
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2033
#
# --- Year 2033 Summary ---
# Income (Salary): 32768.66
# Previous Wealth Carried: 241056.72
# Post-Tax Wealth (New Final Wealth): 273825.38
# ------------------------------
#
# 2034 10 34 49
# Starting Year: 2025
# Current Year: 2034
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 41, 'GOAL B': -4, 'GOAL C': 11, 'GOAL D': 21}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2034
# [DEBUG] Gross Gains (Normal account): 51465.27
# [DEBUG] Tax Calculated (Normal account): 13895.62
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           74.75
#    B            0.00
#    C           22.22
#    D            3.03
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.750887       269727.001870           75.09
#         Developed Markets - Equities 0.000901          323.598684            0.09
# Emerging Markets State - Obligations 0.006463         2321.555540            0.65
#       High Yield Bonds - Obligations 0.008011         2877.690729            0.80
# Investment Grade Bonds - Obligations 0.003549         1274.969487            0.35
#    Government ZC Bonds - Obligations 0.230188        82686.257340           23.02
#
# Utility:
# [0.76738808 0.5894536  0.7103364  ... 0.88115772 0.75957226 0.7128067 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.6245
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2034
#
# --- Year 2034 Summary ---
# Income (Salary): 34429.79
# Previous Wealth Carried: 324781.29
# Post-Tax Wealth (New Final Wealth): 359211.07
# ------------------------------
#
# 2035 11 35 50
# Starting Year: 2025
# Current Year: 2035
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 40, 'GOAL B': -5, 'GOAL C': 10, 'GOAL D': 20}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2035
# [DEBUG] Gross Gains (Normal account): 2024.51
# [DEBUG] Tax Calculated (Normal account): 546.62
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            80.0
#    B             0.0
#    C            19.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.201422        89306.409312           20.14
#         Developed Markets - Equities 0.593895       263321.319671           59.39
# Emerging Markets State - Obligations 0.003948         1750.497937            0.39
#       High Yield Bonds - Obligations 0.002771         1228.572713            0.28
# Investment Grade Bonds - Obligations 0.006190         2744.529003            0.62
#    Government ZC Bonds - Obligations 0.191774        85028.933577           19.18
#
# Utility:
# [0.82125801 0.8414742  0.81027898 ... 0.67573026 0.65288749 0.68505322]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5752
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2035
#
# --- Year 2035 Summary ---
# Income (Salary): 34790.27
# Previous Wealth Carried: 408589.99
# Post-Tax Wealth (New Final Wealth): 443380.26
# ------------------------------
#
# 2036 12 36 51
# Starting Year: 2025
# Current Year: 2036
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 39, 'GOAL B': -6, 'GOAL C': 9, 'GOAL D': 19}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2036
# [DEBUG] Gross Gains (Normal account): 23244.39
# [DEBUG] Tax Calculated (Normal account): 6275.98
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           81.82
#    B            0.00
#    C           16.16
#    D            2.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.212757       102332.183832           21.28
#         Developed Markets - Equities 0.610941       293850.600837           61.09
# Emerging Markets State - Obligations 0.005343         2570.066351            0.53
#       High Yield Bonds - Obligations 0.003466         1667.003136            0.35
# Investment Grade Bonds - Obligations 0.001573          756.560125            0.16
#    Government ZC Bonds - Obligations 0.165920        79804.133505           16.59
#
# Utility:
# [0.86390232 0.57678139 0.78663738 ... 0.79567419 0.78840081 0.83264979]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5849
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2036
#
# --- Year 2036 Summary ---
# Income (Salary): 35153.92
# Previous Wealth Carried: 445826.63
# Post-Tax Wealth (New Final Wealth): 480980.55
# ------------------------------
#
# 2037 13 37 52
# Starting Year: 2025
# Current Year: 2037
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 38, 'GOAL B': -7, 'GOAL C': 8, 'GOAL D': 18}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2037
# [DEBUG] Gross Gains (Normal account): 771.86
# [DEBUG] Tax Calculated (Normal account): 208.40
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           81.82
#    B            0.00
#    C           17.17
#    D            1.01
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.205834       110511.762711           20.58
#         Developed Markets - Equities 0.606109       325418.957692           60.61
# Emerging Markets State - Obligations 0.007329         3934.958852            0.73
#       High Yield Bonds - Obligations 0.001796          964.291472            0.18
# Investment Grade Bonds - Obligations 0.004669         2507.017249            0.47
#    Government ZC Bonds - Obligations 0.174263        93561.282520           17.43
#
# Utility:
# [0.89408631 0.84420494 0.50517955 ... 0.7758901  0.57380096 0.49818266]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5977
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2037
#
# --- Year 2037 Summary ---
# Income (Salary): 35520.78
# Previous Wealth Carried: 501377.49
# Post-Tax Wealth (New Final Wealth): 536898.27
# ------------------------------
#
# 2038 14 38 53
# Starting Year: 2025
# Current Year: 2038
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 37, 'GOAL B': -8, 'GOAL C': 7, 'GOAL D': 17}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2038
# [DEBUG] Gross Gains (Normal account): -22839.06
# [DEBUG] Tax Calculated (Normal account): -6166.55
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           84.85
#    B            0.00
#    C           13.13
#    D            2.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.217783       125408.232528           21.78
#         Developed Markets - Equities 0.626663       360857.582266           62.67
# Emerging Markets State - Obligations 0.010314         5939.321556            1.03
#       High Yield Bonds - Obligations 0.009588         5521.128423            0.96
# Investment Grade Bonds - Obligations 0.000984          566.413369            0.10
#    Government ZC Bonds - Obligations 0.134669        77547.712906           13.47
#
# Utility:
# [0.71551242 0.54291759 0.80356737 ... 0.65040215 0.89657592 0.54346086]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.6104
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2038
#
# --- Year 2038 Summary ---
# Income (Salary): 37315.42
# Previous Wealth Carried: 538524.97
# Post-Tax Wealth (New Final Wealth): 575840.39
# ------------------------------
#
# 2039 15 39 54
# Starting Year: 2025
# Current Year: 2039
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 36, 'GOAL B': -9, 'GOAL C': 6, 'GOAL D': 16}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2039
# [DEBUG] Gross Gains (Normal account): 44069.02
# [DEBUG] Tax Calculated (Normal account): 11898.64
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           83.84
#    B            0.00
#    C           14.14
#    D            2.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.216497       126902.050407           21.65
#         Developed Markets - Equities 0.629371       368912.910570           62.94
# Emerging Markets State - Obligations 0.004901         2872.618820            0.49
#       High Yield Bonds - Obligations 0.003289         1927.967825            0.33
# Investment Grade Bonds - Obligations 0.003205         1878.374814            0.32
#    Government ZC Bonds - Obligations 0.142738        83667.545378           14.27
#
# Utility:
# [0.83769754 0.86650998 0.46748576 ... 0.82473285 0.60723081 0.77422028]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.6075
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2039
#
# --- Year 2039 Summary ---
# Income (Salary): 37703.05
# Previous Wealth Carried: 548458.41
# Post-Tax Wealth (New Final Wealth): 586161.47
# ------------------------------
#
# 2040 16 40 55
# Starting Year: 2025
# Current Year: 2040
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 35, 'GOAL B': -10, 'GOAL C': 5, 'GOAL D': 15}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2040
# [DEBUG] Gross Gains (Normal account): -123747.50
# [DEBUG] Tax Calculated (Normal account): -33411.82
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            86.0
#    B             0.0
#    C            12.0
#    D             2.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.219594       146179.801356           21.96
#         Developed Markets - Equities 0.644501       429032.505196           64.45
# Emerging Markets State - Obligations 0.003930         2615.927189            0.39
#       High Yield Bonds - Obligations 0.003314         2206.094218            0.33
# Investment Grade Bonds - Obligations 0.003704         2465.820000            0.37
#    Government ZC Bonds - Obligations 0.124957        83181.798207           12.50
#
# Utility:
# [0.70760957 0.76861852 0.74344267 ... 0.89601244 0.71026657 0.84410326]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.6302
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2040
#
# --- Year 2040 Summary ---
# Income (Salary): 38094.16
# Previous Wealth Carried: 627587.78
# Post-Tax Wealth (New Final Wealth): 665681.95
# ------------------------------
#
# 2041 17 41 56
# Starting Year: 2025
# Current Year: 2041
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 34, 'GOAL B': -11, 'GOAL C': 4, 'GOAL D': 14}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2041
# [DEBUG] Gross Gains (Normal account): 68329.13
# [DEBUG] Tax Calculated (Normal account): 18573.23
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            85.0
#    B             0.0
#    C            14.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.217596       121219.235660           21.76
#         Developed Markets - Equities 0.635070       353787.777425           63.51
# Emerging Markets State - Obligations 0.002473         1377.410549            0.25
#       High Yield Bonds - Obligations 0.000725          404.123275            0.07
# Investment Grade Bonds - Obligations 0.003194         1779.106861            0.32
#    Government ZC Bonds - Obligations 0.140942        78516.624085           14.09
#
# Utility:
# [0.74524815 0.45893048 0.61927901 ... 0.70603285 0.49786247 0.38145165]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5944
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2041
#
# --- Year 2041 Summary ---
# Income (Salary): 38488.78
# Previous Wealth Carried: 518595.50
# Post-Tax Wealth (New Final Wealth): 557084.28
# ------------------------------
#
# 2042 18 42 57
# Starting Year: 2025
# Current Year: 2042
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 33, 'GOAL B': -12, 'GOAL C': 3, 'GOAL D': 13}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2042
# [DEBUG] Gross Gains (Normal account): -13118.27
# [DEBUG] Tax Calculated (Normal account): -3541.93
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           83.84
#    B            0.00
#    C           15.15
#    D            1.01
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.216400       144331.960618           21.64
#         Developed Markets - Equities 0.615967       410829.432519           61.60
# Emerging Markets State - Obligations 0.003471         2315.181304            0.35
#       High Yield Bonds - Obligations 0.000377          251.549845            0.04
# Investment Grade Bonds - Obligations 0.008214         5478.368000            0.82
#    Government ZC Bonds - Obligations 0.155571       103760.410841           15.56
#
# Utility:
# [0.49503608 0.72460345 0.80615636 ... 0.86022536 0.81010123 0.87846041]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.6174
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2042
#
# --- Year 2042 Summary ---
# Income (Salary): 40428.05
# Previous Wealth Carried: 626538.86
# Post-Tax Wealth (New Final Wealth): 666966.90
# ------------------------------
#
# 2043 19 43 58
# Starting Year: 2025
# Current Year: 2043
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 32, 'GOAL B': -13, 'GOAL C': 2, 'GOAL D': 12}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2043
# [DEBUG] Gross Gains (Normal account): 145939.63
# [DEBUG] Tax Calculated (Normal account): 51169.64
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           85.57
#    B            0.00
#    C           12.37
#    D            2.06
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.217770       150948.601018           21.78
#         Developed Markets - Equities 0.636156       440955.729796           63.62
# Emerging Markets State - Obligations 0.006599         4573.914602            0.66
#       High Yield Bonds - Obligations 0.002114         1465.350136            0.21
# Investment Grade Bonds - Obligations 0.015642        10842.378628            1.56
#    Government ZC Bonds - Obligations 0.121719        84370.223128           12.17
#
# Utility:
# [0.77793746 0.42239337 0.84717481 ... 0.78431585 0.50858616 0.82775218]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.6202
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2043
#
# --- Year 2043 Summary ---
# Income (Salary): 40845.24
# Previous Wealth Carried: 652310.96
# Post-Tax Wealth (New Final Wealth): 693156.20
# ------------------------------
#
# 2044 20 44 59
# Starting Year: 2025
# Current Year: 2044
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 31, 'GOAL B': -14, 'GOAL C': 1, 'GOAL D': 11}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2044
# [DEBUG] Gross Gains (Normal account): 111128.27
# [DEBUG] Tax Calculated (Normal account): 36548.87
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           86.73
#    B            0.00
#    C           12.24
#    D            1.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.221088       193241.369079           22.11
#         Developed Markets - Equities 0.640996       560260.144178           64.10
# Emerging Markets State - Obligations 0.009429         8240.945201            0.94
#       High Yield Bonds - Obligations 0.003403         2973.949379            0.34
# Investment Grade Bonds - Obligations 0.001876         1639.937139            0.19
#    Government ZC Bonds - Obligations 0.123208       107689.686415           12.32
#
# Utility:
# [0.62975461 0.79013306 0.55636689 ... 0.9605988  0.501603   0.89358551]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.6626
# Goal B: 0.0000
# Goal C: 1.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2044
#
# --- Year 2044 Summary ---
# Income (Salary): 41266.22
# Previous Wealth Carried: 832779.81
# Post-Tax Wealth (New Final Wealth): 874046.03
# ------------------------------
#
# 2045 21 45 60
# Starting Year: 2025
# Current Year: 2045
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 30, 'GOAL B': -15, 'GOAL C': 0, 'GOAL D': 10}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2045
# [DEBUG] Gross Gains (Normal account): -15450.02
# [DEBUG] Tax Calculated (Normal account): -4171.50
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           97.96
#    B            0.00
#    C            0.00
#    D            2.04
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.208555       197534.794024           20.86
#         Developed Markets - Equities 0.447688       424030.738971           44.77
# Emerging Markets State - Obligations 0.010698        10132.249596            1.07
#       High Yield Bonds - Obligations 0.000515          488.103503            0.05
# Investment Grade Bonds - Obligations 0.013433        12723.549700            1.34
#    Government ZC Bonds - Obligations 0.319111       302248.333704           31.91
#
# Utility:
# [0.29901829 0.49402198 0.40776656 ... 0.58875266 0.37208658 0.48632157]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.6991
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2045
#
# --- Year 2045 Summary ---
# Income (Salary): 41691.05
# Previous Wealth Carried: 905466.72
# Post-Tax Wealth (New Final Wealth): 947157.77
# ------------------------------
#
# 2046 22 46 61
# Starting Year: 2025
# Current Year: 2046
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 29, 'GOAL B': -16, 'GOAL C': -1, 'GOAL D': 9}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2046
# [DEBUG] Gross Gains (Normal account): 8477.03
# [DEBUG] Tax Calculated (Normal account): 2288.80
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           97.98
#    B            0.00
#    C            0.00
#    D            2.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.196201       192903.683229           19.62
#         Developed Markets - Equities 0.381030       374625.510526           38.10
# Emerging Markets State - Obligations 0.003884         3818.368614            0.39
#       High Yield Bonds - Obligations 0.006629         6517.986560            0.66
# Investment Grade Bonds - Obligations 0.007105         6985.097141            0.71
#    Government ZC Bonds - Obligations 0.405151       398341.444641           40.52
#
# Utility:
# [0.55857765 0.43321983 0.47442481 ... 0.53167169 0.41487222 0.52848732]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.7094
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2046
#
# --- Year 2046 Summary ---
# Income (Salary): 43415.44
# Previous Wealth Carried: 939776.65
# Post-Tax Wealth (New Final Wealth): 983192.09
# ------------------------------
#
# 2047 23 47 62
# Starting Year: 2025
# Current Year: 2047
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 28, 'GOAL B': -17, 'GOAL C': -2, 'GOAL D': 8}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2047
# [DEBUG] Gross Gains (Normal account): -609.90
# [DEBUG] Tax Calculated (Normal account): -164.67
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           95.88
#    B            0.00
#    C            0.00
#    D            4.12
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.186124       193543.558393           18.61
#         Developed Markets - Equities 0.350918       364905.982389           35.09
# Emerging Markets State - Obligations 0.026144        27186.426042            2.61
#       High Yield Bonds - Obligations 0.024515        25492.357927            2.45
# Investment Grade Bonds - Obligations 0.004454         4632.030235            0.45
#    Government ZC Bonds - Obligations 0.407844       424101.301791           40.78
#
# Utility:
# [0.39065297 0.47366064 0.33363912 ... 0.47004924 0.29180891 0.4667121 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.7114
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2047
#
# --- Year 2047 Summary ---
# Income (Salary): 43760.55
# Previous Wealth Carried: 996101.11
# Post-Tax Wealth (New Final Wealth): 1039861.66
# ------------------------------
#
# 2048 24 48 63
# Starting Year: 2025
# Current Year: 2048
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 27, 'GOAL B': -18, 'GOAL C': -3, 'GOAL D': 7}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2048
# [DEBUG] Gross Gains (Normal account): -21368.86
# [DEBUG] Tax Calculated (Normal account): -5769.59
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           93.81
#    B            0.00
#    C            0.00
#    D            6.19
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.198810       216002.956660           19.88
#         Developed Markets - Equities 0.336911       366046.942868           33.69
# Emerging Markets State - Obligations 0.001506         1636.195401            0.15
#       High Yield Bonds - Obligations 0.004439         4822.847029            0.44
# Investment Grade Bonds - Obligations 0.010588        11503.802580            1.06
#    Government ZC Bonds - Obligations 0.447747       486468.461803           44.77
#
# Utility:
# [0.56416399 0.41140697 0.08885277 ... 0.04931972 0.49880903 0.30351398]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.7160
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2048
#
# --- Year 2048 Summary ---
# Income (Salary): 44108.76
# Previous Wealth Carried: 1042372.44
# Post-Tax Wealth (New Final Wealth): 1086481.21
# ------------------------------
#
# 2049 25 49 64
# Starting Year: 2025
# Current Year: 2049
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 26, 'GOAL B': -19, 'GOAL C': -4, 'GOAL D': 6}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2049
# [DEBUG] Gross Gains (Normal account): 82323.03
# [DEBUG] Tax Calculated (Normal account): 24450.67
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           98.94
#    B            0.00
#    C            0.00
#    D            1.06
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.189919       209811.601760           18.99
#         Developed Markets - Equities 0.292313       322930.217115           29.23
# Emerging Markets State - Obligations 0.015912        17578.420033            1.59
#       High Yield Bonds - Obligations 0.006967         7697.056185            0.70
# Investment Grade Bonds - Obligations 0.010407        11497.227813            1.04
#    Government ZC Bonds - Obligations 0.484482       535227.101524           48.45
#
# Utility:
# [0.56207545 0.55175974 0.45008521 ... 0.51740061 0.51110794 0.42015222]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.7264
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2049
#
# --- Year 2049 Summary ---
# Income (Salary): 44460.12
# Previous Wealth Carried: 1060281.51
# Post-Tax Wealth (New Final Wealth): 1104741.62
# ------------------------------
#
# 2050 26 50 65
# Starting Year: 2025
# Current Year: 2050
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 25, 'GOAL B': -20, 'GOAL C': -5, 'GOAL D': 5}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2050
# [DEBUG] Gross Gains (Normal account): -1821.49
# [DEBUG] Tax Calculated (Normal account): -491.80
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           98.92
#    B            0.00
#    C            0.00
#    D            1.08
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.187674       230187.364080           18.77
#         Developed Markets - Equities 0.207173       254103.048966           20.72
# Emerging Markets State - Obligations 0.003163         3879.905015            0.32
#       High Yield Bonds - Obligations 0.011412        13997.000575            1.14
# ...
#    Government ZC Bonds - Obligations 0.707641        1.456571e+06           70.76
#
# Utility:
# [1.         0.46248899 0.         ... 0.24575635 0.02338546 0.32250735]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2067
#
# --- Year 2067 Summary ---
# Income (Salary): 52993.96
# Previous Wealth Carried: 2005354.93
# Post-Tax Wealth (New Final Wealth): 2058348.89
# ------------------------------
#
# 2068 44 68 83
# Starting Year: 2025
# Current Year: 2068
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 7, 'GOAL B': -38, 'GOAL C': -23, 'GOAL D': -13}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2068
# [DEBUG] Gross Gains (Normal account): -129469.69
# [DEBUG] Tax Calculated (Normal account): -34956.82
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.014498        3.142312e+04            1.45
#         Developed Markets - Equities 0.005669        1.228789e+04            0.57
# Emerging Markets State - Obligations 0.022006        4.769659e+04            2.20
#       High Yield Bonds - Obligations 0.012038        2.609265e+04            1.20
# Investment Grade Bonds - Obligations 0.008437        1.828660e+04            0.84
#    Government ZC Bonds - Obligations 0.937352        2.031677e+06           93.74
#
# Utility:
# [2.41234967e-01 1.99285785e-01 9.54791801e-15 ... 2.83652433e-01
#  4.63749942e-01 4.99288805e-01]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2068
#
# --- Year 2068 Summary ---
# Income (Salary): 53428.85
# Previous Wealth Carried: 2114035.42
# Post-Tax Wealth (New Final Wealth): 2167464.27
# ------------------------------
#
# 2069 45 69 84
# Starting Year: 2025
# Current Year: 2069
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 6, 'GOAL B': -39, 'GOAL C': -24, 'GOAL D': -14}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2069
# [DEBUG] Gross Gains (Normal account): -81579.17
# [DEBUG] Tax Calculated (Normal account): -22026.38
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.076106        1.552129e+05            7.61
#         Developed Markets - Equities 0.022375        4.563324e+04            2.24
# Emerging Markets State - Obligations 0.031324        6.388299e+04            3.13
#       High Yield Bonds - Obligations 0.069834        1.424223e+05            6.98
# Investment Grade Bonds - Obligations 0.002902        5.918597e+03            0.29
#    Government ZC Bonds - Obligations 0.797458        1.626359e+06           79.75
#
# Utility:
# [5.35800155e-02 9.53174695e-02 7.39345853e-01 ... 5.14097078e-01
#  1.90143670e-06 2.27348043e-01]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2069
#
# --- Year 2069 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 2039429.48
# Post-Tax Wealth (New Final Wealth): 2039429.48
# ------------------------------
#
# 2070 46 70 85
# Starting Year: 2025
# Current Year: 2070
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 5, 'GOAL B': -40, 'GOAL C': -25, 'GOAL D': -15}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2070
# [DEBUG] Gross Gains (Normal account): -60077.10
# [DEBUG] Tax Calculated (Normal account): -16220.82
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.011888        2.445755e+04            1.19
#         Developed Markets - Equities 0.064115        1.319079e+05            6.41
# Emerging Markets State - Obligations 0.085770        1.764600e+05            8.58
#       High Yield Bonds - Obligations 0.088360        1.817882e+05            8.84
# Investment Grade Bonds - Obligations 0.025877        5.323898e+04            2.59
#    Government ZC Bonds - Obligations 0.723989        1.489503e+06           72.40
#
# Utility:
# [0.01364268 0.41419535 0.14094499 ... 0.32048065 0.04770703 0.27316071]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2070
#
# --- Year 2070 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 2057355.92
# Post-Tax Wealth (New Final Wealth): 2057355.92
# ------------------------------
#
# 2071 47 71 86
# Starting Year: 2025
# Current Year: 2071
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 4, 'GOAL B': -41, 'GOAL C': -26, 'GOAL D': -16}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2071
# [DEBUG] Gross Gains (Normal account): 141080.16
# [DEBUG] Tax Calculated (Normal account): 49128.67
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.048971        9.769227e+04            4.90
#         Developed Markets - Equities 0.081725        1.630340e+05            8.17
# Emerging Markets State - Obligations 0.008816        1.758780e+04            0.88
#       High Yield Bonds - Obligations 0.016784        3.348183e+04            1.68
# Investment Grade Bonds - Obligations 0.083604        1.667825e+05            8.36
#    Government ZC Bonds - Obligations 0.760100        1.516330e+06           76.01
#
# Utility:
# [1.59667205e-01 1.38169661e-01 6.08003164e-08 ... 4.22849734e-02
#  0.00000000e+00 9.94952918e-02]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2071
#
# --- Year 2071 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 1994908.60
# Post-Tax Wealth (New Final Wealth): 1994908.60
# ------------------------------
#
# 2072 48 72 87
# Starting Year: 2025
# Current Year: 2072
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 3, 'GOAL B': -42, 'GOAL C': -27, 'GOAL D': -17}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2072
# [DEBUG] Gross Gains (Normal account): -14787.22
# [DEBUG] Tax Calculated (Normal account): -3992.55
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.058590        1.239386e+05            5.86
#         Developed Markets - Equities 0.130873        2.768447e+05           13.09
# Emerging Markets State - Obligations 0.152277        3.221215e+05           15.23
#       High Yield Bonds - Obligations 0.038755        8.198044e+04            3.88
# Investment Grade Bonds - Obligations 0.014711        3.111935e+04            1.47
#    Government ZC Bonds - Obligations 0.604794        1.279359e+06           60.48
#
# Utility:
# [0.00000000e+00 6.66133815e-16 0.00000000e+00 ... 0.00000000e+00
#  0.00000000e+00 1.34608391e-07]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2072
#
# --- Year 2072 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 2115363.35
# Post-Tax Wealth (New Final Wealth): 2115363.35
# ------------------------------
#
# 2073 49 73 88
# Starting Year: 2025
# Current Year: 2073
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 2, 'GOAL B': -43, 'GOAL C': -28, 'GOAL D': -18}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2073
# [DEBUG] Gross Gains (Normal account): -200689.77
# [DEBUG] Tax Calculated (Normal account): -54186.24
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.037785        8.050660e+04            3.78
#         Developed Markets - Equities 0.091907        1.958206e+05            9.19
# Emerging Markets State - Obligations 0.057875        1.233111e+05            5.79
#       High Yield Bonds - Obligations 0.057303        1.220912e+05            5.73
# Investment Grade Bonds - Obligations 0.020426        4.351947e+04            2.04
#    Government ZC Bonds - Obligations 0.734705        1.565393e+06           73.47
#
# Utility:
# [0.         0.         0.         ... 0.09642732 0.         0.        ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = Y
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2073
#
# --- Year 2073 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 2130641.97
# Post-Tax Wealth (New Final Wealth): 2130641.97
# ------------------------------
#
# 2074 50 74 89
# Starting Year: 2025
# Current Year: 2074
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 1, 'GOAL B': -44, 'GOAL C': -29, 'GOAL D': -19}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2074
# [DEBUG] Gross Gains (Normal account): -2588.26
# [DEBUG] Tax Calculated (Normal account): -698.83
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.024971        4.802337e+04            2.50
#         Developed Markets - Equities 0.049615        9.541909e+04            4.96
# Emerging Markets State - Obligations 0.007845        1.508726e+04            0.78
#       High Yield Bonds - Obligations 0.068173        1.311084e+05            6.82
# Investment Grade Bonds - Obligations 0.012117        2.330386e+04            1.21
#    Government ZC Bonds - Obligations 0.837278        1.610233e+06           83.73
#
# Utility:
# [0. 0. 0. ... 0. 0. 0.]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = Y
# Row 50: Year = 2073, Status = Y
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2074
#
# --- Year 2074 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 1923174.66
# Post-Tax Wealth (New Final Wealth): 1923174.66
# ------------------------------
#
# 2075 51 75 90
# Starting Year: 2025
# Current Year: 2075
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2045, 'GOAL D': 2055}
# Adjusted Horizons: {'GOAL A': 0, 'GOAL B': -45, 'GOAL C': -30, 'GOAL D': -20}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2075
# [DEBUG] Gross Gains (Normal account): nan
# [DEBUG] Tax Calculated (Normal account): nan
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.128098        98103.253935           12.81
#         Developed Markets - Equities 0.191416       146594.994434           19.14
# Emerging Markets State - Obligations 0.175639       134512.352775           17.56
#       High Yield Bonds - Obligations 0.178913       137019.566865           17.89
# Investment Grade Bonds - Obligations 0.063579        48692.067015            6.36
#    Government ZC Bonds - Obligations 0.262355       200923.168493           26.24
#
# Utility:
# [0. 0. 0. ... 0. 0. 0.]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = Y
# Row 50: Year = 2073, Status = Y
# Row 51: Year = 2074, Status = Y
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2075
#
# --- Year 2075 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 765845.40
# Post-Tax Wealth (New Final Wealth): 765845.40
# ------------------------------
#
# All loops completed

# %%
# After all paths simulated

pd.concat(master_asset_log, ignore_index=True).to_csv(os.path.join(output_folder, "master_asset_returns_log.csv"),
                                                      index=False)
pd.concat(master_final_wealth, ignore_index=True).to_csv(os.path.join(output_folder, "master_final_wealth_by_year.csv"),
                                                         index=False)
pd.concat(master_goal_weights, ignore_index=True).to_csv(os.path.join(output_folder, "master_goal_weights_by_year.csv"),
                                                         index=False)
pd.concat(master_aggregate_portfolio, ignore_index=True).to_csv(
    os.path.join(output_folder, "master_aggregate_portfolio_by_year.csv"), index=False)

for goal_letter in ["A", "B", "C", "D"]:
    pd.concat(master_goal_optimal_weights[goal_letter], ignore_index=True).to_csv(
        os.path.join(output_folder, f"master_optimal_weights_goal_{goal_letter}.csv"),
        index=False
    )

# %%
# V17 - Store if goal was reached or not
records = []
for g in ["A", "B", "C", "D"]:
    for entry in goal_reached[g]:
        records.append({
            "Goal": g,
            "Path_ID": entry["path_id"],
            "Year": entry["year"],
            "Status": entry["status"],
            "Redeemed Amount (DKK)": entry["redeemed_amount"],
            "Goal Value (DKK)": entry["goal_value"]
        })

df_goal_redemptions = pd.DataFrame(records)

# Save full detailed redemption log
df_goal_redemptions.to_csv(os.path.join(output_folder, "goal_redemption_details.csv"), index=False)
print("\n✅ Redemption details exported successfully!")

# Build quick success/failure summary
df_goal_redemptions["Success"] = df_goal_redemptions["Status"] == "TRUE"
summary = df_goal_redemptions.groupby("Goal")["Success"].agg(["sum", "count"])
summary.rename(columns={"sum": "Successes", "count": "Total"}, inplace=True)
summary["Failures"] = summary["Total"] - summary["Successes"]
summary = summary[["Successes", "Failures"]]

print("\n--- Goal Success/Failure Distribution ---")
print(summary)

# Save only the summary
summary.to_csv(os.path.join(output_folder, "goal_success_summary.csv"))

print(df_montecarlo_returns)
# Out:
# ✅ Redemption details exported successfully!
#
# --- Goal Success/Failure Distribution ---
#       Successes  Failures
# Goal
# A             2         0
# B             0         2
# C             2         0
# D             0         2
#                                             2025      2026      2027  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.000007  0.032520  0.031400
#                                   1    -0.032011 -0.016466  0.022058
#                                   2     0.059478 -0.041409  0.112298
#                                   3     0.018892  0.022836 -0.041172
#                                   4     0.036280  0.026994 -0.043246
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9995 -0.195809  0.147981 -0.255507
#                                   9996  0.272002  0.197929  0.019133
#                                   9997  0.123811 -0.076521  0.304091
#                                   9998 -0.000032  0.025178 -0.137352
#                                   9999 -0.264516  0.200983  0.212296
#
#                                             2028      2029      2030  \
# Asset                             Path
# Government ZC Bonds - Obligations 0     0.084478  0.049271  0.000944
#                                   1    -0.022606  0.029971  0.129354
#                                   2    -0.022153  0.058938 -0.057467
#                                   3     0.043495  0.067872  0.081891
#                                   4     0.087760  0.012542  0.016454
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9995  0.116068  0.259879  0.301469
#                                   9996  0.308058 -0.158233 -0.025175
#                                   9997  0.348244  0.012878 -0.041964
#                                   9998 -0.071918  0.284494 -0.023585
#                                   9999  0.479749  0.346665  0.229773
#
#                                             2031      2032      2033  \
# Asset                             Path
# Government ZC Bonds - Obligations 0     0.029205 -0.059361 -0.024902
#                                   1     0.039348 -0.075178  0.027823
#                                   2    -0.007297  0.044033 -0.095266
#                                   3    -0.011422 -0.032769 -0.057947
#                                   4     0.019284 -0.024468 -0.085010
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9995  0.135570 -0.010909  0.396562
#                                   9996  0.432799  0.334607 -0.064113
#                                   9997  0.456502  0.161741  0.797180
#                                   9998  0.293742 -0.168514  0.208062
#                                   9999 -0.044745 -0.125317  0.070469
#
#                                             2034  ...      2066      2067  \
# Asset                             Path            ...
# Government ZC Bonds - Obligations 0    -0.044924  ... -0.044940 -0.067034
#                                   1    -0.000004  ...  0.044008 -0.032297
#                                   2     0.070355  ... -0.049671 -0.027272
#                                   3     0.050958  ...  0.094294 -0.009810
#                                   4     0.100474  ... -0.080258  0.054006
# ...                                          ...  ...       ...       ...
# Emerging Markets - Equities       9995  0.592109  ...  0.019935  0.157335
#                                   9996 -0.020769  ...  0.240310  0.049975
#                                   9997  0.064672  ...  0.188076  0.185146
#                                   9998 -0.079955  ...  0.377140 -0.100160
#                                   9999  0.162238  ...  0.364832 -0.100723
#
#                                             2068      2069      2070  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.005422 -0.018352  0.088154
#                                   1    -0.044900 -0.048844 -0.016176
#                                   2    -0.094621 -0.016504  0.065108
#                                   3     0.049919  0.021916 -0.024192
#                                   4     0.053771  0.049364 -0.064463
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9995  0.362955 -0.033361 -0.323189
#                                   9996  0.277965  0.014838  0.204011
#                                   9997  0.471738 -0.157125  0.006551
#                                   9998  0.110597 -0.234932 -0.168143
#                                   9999  0.098638  0.157942 -0.302259
#
#                                             2071      2072      2073  \
# Asset                             Path
# Government ZC Bonds - Obligations 0     0.043110  0.066915  0.005376
#                                   1     0.107332 -0.005704 -0.083704
#                                   2     0.043573  0.119018  0.029971
#                                   3    -0.094172 -0.033086  0.054652
#                                   4    -0.073501  0.062877 -0.025275
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9995  0.369606 -0.092357  0.038923
#                                   9996  0.224297  0.377593 -0.080649
#                                   9997  0.103836 -0.103930 -0.300631
#                                   9998  0.021186  0.188827  0.215730
#                                   9999 -0.016392 -0.103447  0.345458
#
#                                             2074  2075
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.009182   NaN
#                                   1     0.010094   NaN
#                                   2    -0.115711   NaN
#                                   3     0.041892   NaN
#                                   4    -0.038259   NaN
# ...                                          ...   ...
# Emerging Markets - Equities       9995 -0.065768   NaN
#                                   9996  0.047737   NaN
#                                   9997  0.065117   NaN
#                                   9998 -0.120336   NaN
#                                   9999  0.173459   NaN
#
# [60000 rows x 51 columns]
