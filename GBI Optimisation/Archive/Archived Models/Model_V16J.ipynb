# %% [markdown]
# V1 (02 11 2025): Translated from R to Python and added the visualizations for goals B to D
#
#
# V2 (04 01 2025): Loop system implemented
#
# V2.5 (04 02 2025): Loops system tweaks. Removed openpyxl as it was corrupting files and replaced it with xlwings
#
# V3 & V4 finalize the loop except for the tax and asset channel
#
# V 5,6,7 add tax shenanigans. V7C added the fully functioning inflow and outflow of wealth with the returns and taxes in it.
#
# V8 modifies the aktiesparekonto pool so that it is increased when taxes are payed.
#
# V9 substracts from the wealth pool the amount for the goals reached. It does not just substract the full amount of the goal, but rather the % from the allocation of the year prior to the goal being handed.
#
# V10 Corrects returns to be inflation adjusted
#
# V11 Opportunity cost calculation to redeem goal
#
# V12 FinalWealth works without excel
#
# V13 Loop check works without excel

# %%
#!pip install numpy pandas scipy matplotlib xlwings

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import subprocess

# %%
# -- Variable Setup -- ##

#Monte Carlo Trials
n_trials = 10**5

# -V10 - Static Inflation
inflation_rate = 0.02  # 2%
#Case Study Profile Selection
Profile = "P1" #Either P1 or P2

#Excel worksheets
excel_returns = "Returns"
excel_volatilities = "Volatilities"
excel_correlation = "Correlation"
excel_income = "Salary"

# %% [markdown]
# # Define Functions
# This section defines the functions used for calculating portfolio volatility, expected return,
# goal achievement probability, and the objective (failure probability) to minimize.

# %%
def sd_f(weight_vector, covar_table):
    covar_vector = np.zeros(len(weight_vector))
    for z in range(len(weight_vector)):
        covar_vector[z] = np.sum(weight_vector * covar_table[:, z])
    return np.sqrt(np.sum(weight_vector * covar_vector))

# %%
def mean_f(weight_vector, return_vector):
    return np.sum(weight_vector * return_vector)

# %%
def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    # goal_vector is [value ratio, funding requirement, time horizon]
    required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
    if goal_allocation * pool >= goal_vector[1]:
        return 1
    else:
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)

# %%
def optim_function(weights):
    # Uses the current global variables: goal_vector, allocation, pool, return_vector, covar_table
    return 1 - phi_f(
        goal_vector,
        allocation,
        pool,
        mean_f(weights, return_vector),
        sd_f(weights, covar_table)
    )

# %%
def constraint_function(weights):
    # For SciPy equality constraints, we require constraint_function(weights) == 0.
        return np.sum(weights) - 1

# %%
def mvu_f(weights):
    # mvu_f is defined for mean-variance optimization (not used below).
    return -(mean_f(weights, return_vector) - 0.5 * gamma * sd_f(weights, covariances)**2)

# %%
def r_req_f(goal_vector, goal_allocation, pool):
    return (goal_vector[1] / (goal_allocation * pool))**(1 / goal_vector[2]) - 1

# %%
# V 11 Utility Loss function for cashing out goal
def net_utility_change_from_goal_funding(
    goal_value_ratio,
    goal_required,
    portfolio_value,
    future_goals,
    future_goal_weights,
    return_vector,
    covariances
):
    # Portfolio value *after* cashing out the current goal
    portfolio_after = portfolio_value - goal_required

    # Utility loss from hitting future goals with reduced capital
    future_utility_loss = 0
    phi_details = []

    for i, goal in enumerate(future_goals):
        alloc = future_goal_weights[i]
        mean = mean_f(alloc, return_vector)
        sd = sd_f(alloc, covariances)

        phi_with = phi_f(goal, 1, portfolio_after, mean, sd)
        phi_without = phi_f(goal, 1, portfolio_value, mean, sd)
        value_weight = goal[0]

        future_utility_loss += value_weight * (phi_without - phi_with)
        phi_details.append((phi_without, phi_with))

    # Utility gain from achieving current goal
    utility_gain_now = value_now_nested * 1  # goal fully achieved if funded

    # Net effect on utility
    net_utility_change = utility_gain_now - future_utility_loss

    return net_utility_change, future_utility_loss, phi_details

# %%
# V11

def nested_value_ratio(goal_index, goal_value_list):
    ratio = 1.0
    for i in range(goal_index + 1):
        ratio *= goal_value_list[i]
    return ratio

# %%
def get_goal_data(master_excel_path, plan=Profile):
    """
    Returns a DataFrame of the specified goal table (P1 or P2).
    P1 => B2:F5
    P2 => B7:F10
    """
    if plan == "P1":
        skip = 1  # start reading at row 2
    elif plan == "P2":
        skip = 6  # start reading at row 7
    else:
        raise ValueError("Plan not recognized. Use 'P1' or 'P2'.")

    df_goals = pd.read_excel(master_excel_path,sheet_name="Goals",skiprows=skip,nrows=4,usecols="B:F",header=0)
    # First column is "Goal Info", so make that the index
    df_goals.set_index(df_goals.columns[0], inplace=True)
    return df_goals

# %% [markdown]
# # Load & Parse Data

# %%
## -- Repo Root and Folders -- ##

# Get repo root and set folders
root = subprocess.run(["git", "rev-parse", "--show-toplevel"], capture_output=True, text=True).stdout.strip()
data_folder = os.path.join(root, "GBI Optimisation", "data")
output_folder = os.path.join(root, "GBI Optimisation")

# Get excel file and sheets
master_excel_path = os.path.join(data_folder, "Master.xlsx")

df_returns = pd.read_excel(master_excel_path, sheet_name=excel_returns)
df_vols = pd.read_excel(master_excel_path, sheet_name=excel_volatilities)

df_returns.set_index(df_returns.columns[0], inplace=True)
df_vols.set_index(df_vols.columns[0], inplace=True)

df_corr = pd.read_excel(master_excel_path, sheet_name=excel_correlation)
df_corr.set_index(df_corr.columns[0], inplace=True)

# %%
# - NEW V8 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #

# Initial cap in 2025
initial_ask_cap = 166200
growth_rate = 0.1265  # 12.65% annual increase
aktiesparekonto_used_total = 0

#V12 moved finalwealth to python
final_wealth_tracker = {}

#V15 goal info stored in python instead of excel
goal_weights_tracker = []          # Stores goal weights for each year
aggregate_portfolio_tracker = []   # Stores aggregate portfolio for each year

# V15: Store all optimal weight matrices by year
goal_optimal_weights_A = {}
goal_optimal_weights_B = {}
goal_optimal_weights_C = {}
goal_optimal_weights_D = {}

# %%
# V 13 - Year Loop table
# -- Replaces Excel loop sheet with in-code structure -- #
start_year = 2025
end_year = 2075
N_max = end_year - start_year + 1

age_p1_start = 25
age_p2_start = 40

loop_df = pd.DataFrame({
    "N": range(1, N_max + 1),
    "Year": list(range(start_year, end_year + 1)),
    "AgeP1": [age_p1_start + i for i in range(N_max)],
    "AgeP2": [age_p2_start + i for i in range(N_max)],
    "LoopStatus": ['N'] * N_max
})

# %%
asset_level_log = []  # NEW: Log each asset's return pre- and post-tax by account

while True:
    pending_rows = loop_df[loop_df["LoopStatus"] == "N"]

    # If we find any rows, get the row with the lowest Year
    if pending_rows.empty:
        print("All loops completed")
        break


    chosen_row = pending_rows.loc[pending_rows["Year"].idxmin()]
    loop_year = chosen_row["Year"]
    loop_number = chosen_row["N"]
    loop_age1 = chosen_row["AgeP1"]
    loop_age2 = chosen_row["AgeP2"]

    print(loop_year, loop_number, loop_age1, loop_age2)

    # - Wealth - #

    # Get salary for current year
    salary = df_salary.loc[Profile, str(loop_year)]


    # - Dynamic time horizon based on current year - #

    # Step 1: Get Starting Year (minimum year in Loop sheet)
    starting_year = start_year
    prev_year = str(loop_year - 1)

    # If first loop year, no previous wealth exists
    if loop_year == starting_year:
        prev_wealth = 0
        pool = salary
    else:
        try:
            prev_wealth = final_wealth_tracker[int(prev_year)]
        except KeyError:
            raise KeyError(f"Previous wealth not found for {Profile} in {prev_year}")
        pool = salary + prev_wealth

    capital_market_expectations_raw = {}
    for asset in df_returns.index:
        expected_return = df_returns.loc[asset, str(loop_year)]
        volatility = df_vols.loc[asset, 'volatility']
        capital_market_expectations_raw[asset] = {
            'Return Forecast': expected_return,
            'Volatility Forecast': volatility
        }

    capital_market_expectations_raw = pd.DataFrame.from_dict(capital_market_expectations_raw, orient='index')

    capital_market_expectations_raw = capital_market_expectations_raw.reset_index()
    capital_market_expectations_raw.rename(columns={'index': 'Unnamed: 0'}, inplace=True)

    # Rearrange columns to match your old format (optional):
    capital_market_expectations_raw = capital_market_expectations_raw[['Unnamed: 0', 'Return Forecast', 'Volatility Forecast']]

    goal_data_raw = get_goal_data(master_excel_path, plan="P1")

    # - Dynamic time horizon based on current year - #


    # Step 2: Compute Goal Years = starting_year + time_horizon
    goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
    goal_years = starting_year + goal_horizons

    # Step 3: Recalculate Time Horizons = goal_years - current loop_year
    adjusted_horizons = goal_years - loop_year

    # Step 4: Replace the "Time Horizon" row in goal_data_raw
    goal_data_raw.loc["Time Horizon"] = adjusted_horizons

    # - V8 - Dynamically compute ASK cap per year
    aktiesparekonto_cap = initial_ask_cap * ((1 + growth_rate) ** (loop_year - starting_year))

    goals = ["A", "B", "C", "D"]
    active_goal_mask = np.array([adjusted_horizons[f"GOAL {g}"] > 0 for g in goals])

    # Optional: print to confirm
    print("Starting Year:", starting_year)
    print("Current Year:", loop_year)
    print("Goal Years:", goal_years.to_dict())
    print("Adjusted Horizons:", adjusted_horizons.to_dict())



    # Record number of potential investments and goals
    num_assets = capital_market_expectations_raw.shape[0]
    num_goals = goal_data_raw.shape[1]

    # Create vector of expected returns
    return_vector = (capital_market_expectations_raw["Return Forecast"] - inflation_rate).to_numpy()

    # Get the correlations as a numeric DataFrame (just a num_assets × num_assets block)
    correlations = df_corr.iloc[:num_assets, :num_assets].astype(float)

    # Build the covariance matrix: stdev_i * stdev_j * correlation_ij
    stdevs = capital_market_expectations_raw["Volatility Forecast"].to_numpy()
    covariances = np.zeros((num_assets, num_assets))
    for i in range(num_assets):
        for j in range(num_assets):
            covariances[i, j] = stdevs[i] * stdevs[j] * correlations.iloc[i, j]

    goal_A = goal_data_raw["GOAL A"].values
    goal_B = goal_data_raw["GOAL B"].values
    goal_C = goal_data_raw["GOAL C"].values
    goal_D = goal_data_raw["GOAL D"].values

    # - Optimal Goal Allocation - #


    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Set SLSQP options to be more stringent, mimicking solnp's behavior.
    slsqp_opts = {
        'ftol': 1e-12,     # function tolerance
        'eps': 1e-12,      # finite-difference step size for gradient estimation
        'maxiter': 10000,  # maximum iterations
        'disp': False     # do not display convergence messages
    }

    for i, alloc in enumerate(goal_allocation):
        allocation = alloc      # Global variable used in optim_function
        covar_table = covariances

        # Goal A Optimization
        goal_vector = goal_A   # Global variable used in optim_function
        if goal_A[1] <= pool * allocation:
            optimal_weights_A[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_A[i, :] = result.x

        # Goal B Optimization
        goal_vector = goal_B
        if goal_B[1] <= pool * allocation:
            optimal_weights_B[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_B[i, :] = result.x

        # Goal C Optimization
        goal_vector = goal_C
        if goal_C[1] <= pool * allocation:
            optimal_weights_C[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_C[i, :] = result.x

        # Goal D Optimization
        goal_vector = goal_D
        if goal_D[1] <= pool * allocation:
            optimal_weights_D[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_D[i, :] = result.x

    goal_optimal_weights_A[loop_year] = optimal_weights_A
    goal_optimal_weights_B[loop_year] = optimal_weights_B
    goal_optimal_weights_C[loop_year] = optimal_weights_C
    goal_optimal_weights_D[loop_year] = optimal_weights_D

    # Calculate the best probability (phi) for each allocation level for every goal
    phi_A = np.zeros(len(goal_allocation))
    phi_B = np.zeros(len(goal_allocation))
    phi_C = np.zeros(len(goal_allocation))
    phi_D = np.zeros(len(goal_allocation))

    for i, alloc in enumerate(goal_allocation):
        phi_A[i] = phi_f(goal_A, alloc, pool,
                         mean_f(optimal_weights_A[i, :], return_vector),
                         sd_f(optimal_weights_A[i, :], covariances))
        phi_B[i] = phi_f(goal_B, alloc, pool,
                         mean_f(optimal_weights_B[i, :], return_vector),
                         sd_f(optimal_weights_B[i, :], covariances))
        phi_C[i] = phi_f(goal_C, alloc, pool,
                         mean_f(optimal_weights_C[i, :], return_vector),
                         sd_f(optimal_weights_C[i, :], covariances))
        phi_D[i] = phi_f(goal_D, alloc, pool,
                         mean_f(optimal_weights_D[i, :], return_vector),
                         sd_f(optimal_weights_D[i, :], covariances))

    # Simulate goal weights: each row is a simulated allocation (in percentages)
    sim_goal_weights = np.random.multinomial(100, [1/num_goals]*num_goals, size=n_trials) #this one sums to 100 so its good
    for i in range(n_trials):
        rand_vector = np.random.uniform(0, 1, num_goals)
        normalizer = np.sum(rand_vector)
        percents = np.round((rand_vector / normalizer) * 100, 0)

        # Only enforce floor for active goals
        floor_applied = np.where(active_goal_mask, np.maximum(percents, 1), percents)
        sim_goal_weights[i, :] = floor_applied


    # Calculate utility for each simulated portfolio.
    # Note: subtract 1 from simulated weights for 0-indexing.
    utility = (
        goal_A[0] * phi_A[sim_goal_weights[:, 0] - 1] +
        goal_A[0] * goal_B[0] * phi_B[sim_goal_weights[:, 1] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * phi_C[sim_goal_weights[:, 2] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * goal_D[0] * phi_D[sim_goal_weights[:, 3] - 1]
    )

    # Find the index of the portfolio with the highest utility
    index = np.argmax(utility)
    optimal_goal_weights = sim_goal_weights[index, :]

    # - Optimal Subportfolio Allocation - #

    # Retrieve optimal subportfolio allocations
    optimal_subportfolios = np.zeros((num_goals, num_assets))

    # For each goal, use the simulated percentage to select the corresponding row
    # from the optimal weights matrix (adjust for zero-indexing)
    for i in range(num_goals):
        optimal_subportfolios[i, :] = eval(f"optimal_weights_{goals[i]}")[optimal_goal_weights[i] - 1, :]

    # Compute the optimal aggregate investment portfolio.
    optimal_aggregate_portfolio = (optimal_goal_weights / 100) @ optimal_subportfolios

    #Define asset names
    asset_names = capital_market_expectations_raw.iloc[:, 0].astype(str).tolist()

    # - Storing and exporting results - #

    # Create a DataFrame for the aggregate portfolio.
    # First calculate unrounded percentages
    raw_alloc = optimal_aggregate_portfolio * 100

    # Normalize to force sum = 100 after rounding
    normalized_alloc = raw_alloc / raw_alloc.sum() * 100
    normalized_goal_alloc = np.zeros_like(optimal_goal_weights, dtype=float)
    active_sum = np.sum(optimal_goal_weights[active_goal_mask])
    normalized_goal_alloc[active_goal_mask] = (optimal_goal_weights[active_goal_mask] / active_sum) * 100

    normalized_weights = normalized_alloc / 100  # convert back to decimal weights

    # Create a DataFrame for the across-goal allocation.
    df_across_goal = pd.DataFrame({
        "Goal": goals,
        "Allocation (%)": np.round(normalized_goal_alloc, 2) # Keep raw percentages
    })

    # Round after normalization
    df_aggregate = pd.DataFrame({
        "Asset": asset_names,
        "Weight": normalized_weights,
        "Invested Amt (DKK)": normalized_weights * pool,
        "Allocation (%)": np.round(normalized_alloc, 2)  # keep for display only
    })


    # - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #
    # --- NEW: Exact and Proportional ASK Logic ---
    account_allocations = []
    equity_rows = []
    non_equity_rows = []

    # First pass: split equity and non-equity rows
    for i, row in df_aggregate.iterrows():
        asset_name = row["Asset"]
        invested = row["Invested Amt (DKK)"]
        weight = row["Weight"]

        row_dict = {
            "Year": loop_year,
            "Asset": asset_name,
            "Invested": invested,
            "Weight": weight,
            "ASK (DKK)": 0,
            "Normal (DKK)": 0,
        }

        if "Equities" in asset_name:
            equity_rows.append(row_dict)
        else:
            row_dict["Normal (DKK)"] = invested
            non_equity_rows.append(row_dict)

    # Determine total equity to allocate proportionally if ASK cap remains
    total_equity = sum(row["Invested"] for row in equity_rows)
    remaining_ask_cap = max(0, aktiesparekonto_cap - aktiesparekonto_used_total)
    ask_fraction = min(1, remaining_ask_cap / total_equity) if total_equity > 0 else 0

    # Apply proportional ASK allocation to equities
    for row in equity_rows:
        ask_part = row["Invested"] * ask_fraction
        normal_part = row["Invested"] - ask_part
        row["ASK (DKK)"] = round(ask_part, 2)
        row["Normal (DKK)"] = round(normal_part, 2)
        aktiesparekonto_used_total += ask_part

    # Combine and finalize
    account_allocations = equity_rows + non_equity_rows


    df_accounts = pd.DataFrame(account_allocations)
    print(f"[DEBUG] Final weight sum: {sum(row['Weight'] for row in account_allocations):.10f}")
    # - V5 END - #


    # - NEW V6 CONTENT REGARDING GAINS & TAXES - #


    share_income_normal = 0  # for progressive tax
    tax_ask = 0  # Track ASK tax separately

    # Update portfolio and compute gains
    for row in account_allocations:
        asset = row["Asset"]
        ask = row["ASK (DKK)"]
        normal = row["Normal (DKK)"]
        weight = row["Weight"]
        expected_return_nominal = capital_market_expectations_raw.loc[
            capital_market_expectations_raw["Unnamed: 0"] == asset,
            "Return Forecast"
        ].values[0]
        expected_return_inflation_adj = (
            capital_market_expectations_raw.loc[
                capital_market_expectations_raw["Unnamed: 0"] == asset,
                "Return Forecast"
            ].values[0] - inflation_rate
        )

        # V7C -LOG ASSET RETURNS BY ACCOUNT
        if ask > 0:
            new_val = ask * (1 + expected_return_inflation_adj)
            gain = new_val - ask
            tax = 0.17 * gain
            asset_level_log.append({
                "Year": loop_year,
                "Account": "ASK",
                "Asset": asset,
                "Invested": ask,
                "Weight": ask / pool,
                "Return (Nominal)": expected_return_nominal,
                "Inflation Rate": inflation_rate,
                "Return (Inflation Adjusted)": expected_return_inflation_adj,
                "Gross Gain": gain,
                "Tax": tax,
                "Net Gain": gain - tax,
                "End Value": ask + gain - tax,
                "TOTAL ASK Cap (DKK)": aktiesparekonto_cap
            })

        if normal > 0:
            new_val = normal * (1 + expected_return_inflation_adj)
            gain = new_val - normal
            share_income_normal += gain
            asset_level_log.append({
                "Year": loop_year,
                "Account": "NORMAL",
                "Asset": asset,
                "Invested": normal,
                "Weight": normal / pool,
                "Return (Nominal)": expected_return_nominal,
                "Inflation Rate": inflation_rate,
                "Return (Inflation Adjusted)": expected_return_inflation_adj,
                "Gross Gain": gain,
                "Tax": None,  # progressive tax logged later
                "Net Gain": None,
                "End Value": None,
                "TOTAL ASK Cap (DKK)": aktiesparekonto_cap
            })

            #V7C END

    # Tax on Normal Account (progressive)
    cap = 67500
    if share_income_normal <= cap:
        tax_normal = 0.27 * share_income_normal
    else:
        tax_normal = 0.27 * cap + 0.42 * (share_income_normal - cap)

    # Distribute tax proportionally across NORMAL assets
    normal_log_rows = [
        row for row in asset_level_log
        if row["Account"] == "NORMAL" and row["Year"] == loop_year
    ]
    total_normal_gain = sum(row["Gross Gain"] for row in normal_log_rows)

    print(f"[DEBUG] Year: {loop_year}")
    print(f"[DEBUG] Gross Gains (Normal account): {share_income_normal:.2f}")
    print(f"[DEBUG] Tax Calculated (Normal account): {tax_normal:.2f}")

    for row in normal_log_rows:
        if total_normal_gain > 0:
            share = row["Gross Gain"] / total_normal_gain
            tax = share * tax_normal
        else:
            tax = 0

        row["Tax"] = tax
        row["Net Gain"] = row["Gross Gain"] - tax
        row["End Value"] = row["Invested"] + row["Net Gain"]

    total_gains_normal = share_income_normal - tax_normal


    print("Optimal Across-Goal Allocation:")
    print(df_across_goal.to_string(index=False))

    print("\nOptimal Aggregate Investment Allocation:")
    print(df_aggregate.to_string(index=False))

    print("\nUtility:")
    print(utility)

    print("\nProbability of Achieving Each Goal at Optimal Allocation:")
    print(f"Goal A: {phi_A[optimal_goal_weights[0] - 1]:.4f}")
    print(f"Goal B: {phi_B[optimal_goal_weights[1] - 1]:.4f}")
    print(f"Goal C: {phi_C[optimal_goal_weights[2] - 1]:.4f}")
    print(f"Goal D: {phi_D[optimal_goal_weights[3] - 1]:.4f}")

    # -- V15 Goal weights -- #

    # Store current year's across-goal allocation
    goal_weights_tracker.append({
        "Year": loop_year,
        **{f"Goal {goals[i]} (%)": normalized_goal_alloc[i] for i in range(num_goals)}
    })

    # Store current year's aggregate portfolio
    for i in range(num_assets):
        aggregate_portfolio_tracker.append({
            "Year": loop_year,
            "Asset": asset_names[i],
            "Weight": normalized_weights[i],
            "Allocation (%)": np.round(normalized_alloc[i], 2),
            "Invested Amt (DKK)": normalized_weights[i] * pool
        })


    # -- V13 - Modify Loop Check -- #
    print("Starting loop status check (in-memory)...")

    # Show up to 10 rows (adjust as needed) of the current loop status
    preview_rows = loop_df.tail(10)
    for i, row in preview_rows.iterrows():
        print(f"Row {i+2}: Year = {row['Year']}, Status = {row['LoopStatus']}")

    # Update the current year's loop status
    loop_df.loc[loop_df["Year"] == loop_year, "LoopStatus"] = "Y"
    print(f"✅ LoopStatus updated to 'Y' for Year {loop_year}")

    this_year_rows = [row for row in asset_level_log if row["Year"] == loop_year]
    end_value_sum = sum(row["End Value"] for row in this_year_rows)

    # - V9 - If a goal has 1 year left, annotate allocation & amount taken in asset_level_log --- #
    goal_payout_info = {}

    for i, goal in enumerate(goals):
        if adjusted_horizons[f"GOAL {goal}"] == 1:
            alloc_pct = normalized_goal_alloc[i]
            goal_required = goal_data_raw.loc["Funding Requirement", f"GOAL {goal}"]
            amount_alloc_based = (alloc_pct / 100) * end_value_sum

            future_goals = [
                goal_data_raw[f"GOAL {g}"].values
                for j, g in enumerate(goals)
                if g != goal and adjusted_horizons[f"GOAL {g}"] > 1
            ]
            future_weights = [
                optimal_subportfolios[j, :]
                for j, g in enumerate(goals)
                if g != goal and adjusted_horizons[f"GOAL {g}"] > 1
            ]

            value_now_nested = nested_value_ratio(i, [goal_data_raw.loc["Value Ratio", f"GOAL {g}"] for g in goals])

            net_util, fut_loss, phi_details = net_utility_change_from_goal_funding(
                value_now_nested,
                goal_required,
                end_value_sum,
                future_goals,
                future_weights,
                return_vector,
                covariances
            )

            if net_util > 0:
                amount_taken = min(goal_required, amount_alloc_based)
                print(f"[DECISION] ✅ Paying Goal {goal} | ΔUtility: {net_util:.3f}")
                end_value_sum -= amount_taken
            else:
                amount_taken = 0
                print(f"[DECISION] ❌ Skipping Goal {goal} | ΔUtility: {net_util:.3f}")

            goal_payout_info[f"Goal {goal} Allocation (%)"] = alloc_pct
            goal_payout_info[f"Goal {goal} Amount Taken (DKK)"] = amount_taken
            goal_payout_info[f"Goal {goal} Utility Net Δ"] = net_util
            goal_payout_info[f"Goal {goal} Utility Loss"] = fut_loss
            goal_payout_info[f"Goal {goal} Value Now"] = value_now_nested
            goal_payout_info[f"Goal {goal} Utility φ_before"] = ", ".join(str(round(p[0], 4)) for p in phi_details)
            goal_payout_info[f"Goal {goal} Utility φ_after"] = ", ".join(str(round(p[1], 4)) for p in phi_details)

    # Annotate each row in asset_level_log for current year
    for row in asset_level_log:
        if row["Year"] == loop_year:
            for key, value in goal_payout_info.items():
                row[key] = value
    # - V9 END -

    final_wealth_tracker[loop_year] = end_value_sum

    print(f"\n--- Year {loop_year} Summary ---")
    print(f"Income (Salary): {salary:.2f}")
    if loop_year != starting_year:
        print(f"Previous Wealth Carried: {prev_wealth:.2f}")
    print(f"Post-Tax Wealth (New Final Wealth): {pool:.2f}")
    print("------------------------------\n")
# Out:
# 2025 1 25 40
# Starting Year: 2025
# Current Year: 2025
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 50, 'GOAL B': 5, 'GOAL C': 10, 'GOAL D': 15}
# C:\Users\admin\AppData\Local\Temp\ipykernel_15544\4021808357.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2025
# [DEBUG] Gross Gains (Normal account): 0.00
# [DEBUG] Tax Calculated (Normal account): 0.00
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             9.0
#    B            30.0
#    C            24.0
#    D            37.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.218988                 0.0           21.90
#         Developed Markets - Equities 0.335343                 0.0           33.53
# Emerging Markets State - Obligations 0.085388                 0.0            8.54
#       High Yield Bonds - Obligations 0.128119                 0.0           12.81
# Investment Grade Bonds - Obligations 0.227360                 0.0           22.74
#    Government ZC Bonds - Obligations 0.004800                 0.0            0.48
#
# Utility:
# [0. 0. 0. ... 0. 0. 0.]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2025
#
# --- Year 2025 Summary ---
# Income (Salary): 0.00
# Post-Tax Wealth (New Final Wealth): 0.00
# ------------------------------
#
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 49, 'GOAL B': 4, 'GOAL C': 9, 'GOAL D': 14}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2026
# [DEBUG] Gross Gains (Normal account): 46.30
# [DEBUG] Tax Calculated (Normal account): 12.50
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            94.0
#    B             1.0
#    C             4.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.952924        50166.868457           95.29
#         Developed Markets - Equities 0.007042          370.720008            0.70
# Emerging Markets State - Obligations 0.013354          703.006773            1.34
#       High Yield Bonds - Obligations 0.007844          412.937835            0.78
# Investment Grade Bonds - Obligations 0.014420          759.155673            1.44
#    Government ZC Bonds - Obligations 0.004417          232.511253            0.44
#
# Utility:
# [0.19910508 0.13344257 0.19288023 ... 0.19288003 0.21309291 0.20207081]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3112
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2026
#
# --- Year 2026 Summary ---
# Income (Salary): 52645.20
# Previous Wealth Carried: 0.00
# Post-Tax Wealth (New Final Wealth): 52645.20
# ------------------------------
#
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 48, 'GOAL B': 3, 'GOAL C': 8, 'GOAL D': 13}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2027
# [DEBUG] Gross Gains (Normal account): 41.94
# [DEBUG] Tax Calculated (Normal account): 11.32
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           96.04
#    B            0.99
#    C            0.99
#    D            1.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.969657       105237.169228           96.97
#         Developed Markets - Equities 0.008867          962.353505            0.89
# Emerging Markets State - Obligations 0.005482          594.974358            0.55
#       High Yield Bonds - Obligations 0.001459          158.327498            0.15
# Investment Grade Bonds - Obligations 0.008485          920.863357            0.85
#    Government ZC Bonds - Obligations 0.006050          656.596932            0.60
#
# Utility:
# [0.30836526 0.2679162  0.05622025 ... 0.29200568 0.22882361 0.24862952]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3751
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2027
#
# --- Year 2027 Summary ---
# Income (Salary): 53171.65
# Previous Wealth Carried: 55358.63
# Post-Tax Wealth (New Final Wealth): 108530.28
# ------------------------------
#
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 47, 'GOAL B': 2, 'GOAL C': 7, 'GOAL D': 12}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2028
# [DEBUG] Gross Gains (Normal account): 5551.12
# [DEBUG] Tax Calculated (Normal account): 1498.80
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           93.07
#    B            1.98
#    C            0.99
#    D            3.96
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.941485       163074.598037           94.15
#         Developed Markets - Equities 0.015206         2633.856583            1.52
# Emerging Markets State - Obligations 0.008178         1416.471465            0.82
#       High Yield Bonds - Obligations 0.007656         1326.066538            0.77
# Investment Grade Bonds - Obligations 0.016874         2922.770826            1.69
#    Government ZC Bonds - Obligations 0.010601         1836.204627            1.06
#
# Utility:
# [0.26181898 0.38468287 0.28626271 ... 0.3175658  0.35019104 0.29472823]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4112
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2028
#
# --- Year 2028 Summary ---
# Income (Salary): 59020.53
# Previous Wealth Carried: 114189.43
# Post-Tax Wealth (New Final Wealth): 173209.97
# ------------------------------
#
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 46, 'GOAL B': 1, 'GOAL C': 6, 'GOAL D': 11}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2029
# [DEBUG] Gross Gains (Normal account): 13005.17
# [DEBUG] Tax Calculated (Normal account): 3511.40
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           93.07
#    B            0.99
#    C            0.99
#    D            4.95
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.942034       227172.336504           94.20
#         Developed Markets - Equities 0.012361         2980.834348            1.24
# Emerging Markets State - Obligations 0.012809         3088.857597            1.28
#       High Yield Bonds - Obligations 0.012319         2970.842149            1.23
# Investment Grade Bonds - Obligations 0.012906         3112.187427            1.29
#    Government ZC Bonds - Obligations 0.007571         1825.709925            0.76
#
# Utility:
# [0.34239449 0.33884721 0.18840764 ... 0.22737556 0.22537412 0.18211693]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4380
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2029
# [DECISION] ✅ Paying Goal B | ΔUtility: 0.020
#
# --- Year 2029 Summary ---
# Income (Salary): 59610.74
# Previous Wealth Carried: 181540.03
# Post-Tax Wealth (New Final Wealth): 241150.77
# ------------------------------
#
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 45, 'GOAL B': 0, 'GOAL C': 5, 'GOAL D': 10}
# C:\Users\admin\AppData\Local\Temp\ipykernel_15544\4021808357.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2030
# [DEBUG] Gross Gains (Normal account): 17547.38
# [DEBUG] Tax Calculated (Normal account): 4737.79
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           68.32
#    B            0.00
#    C            0.99
#    D           30.69
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.990480       306994.584689           99.05
#         Developed Markets - Equities 0.001077          333.878626            0.11
# Emerging Markets State - Obligations 0.000941          291.509692            0.09
#       High Yield Bonds - Obligations 0.003181          985.926975            0.32
# Investment Grade Bonds - Obligations 0.000682          211.493456            0.07
#    Government ZC Bonds - Obligations 0.003639         1127.953421            0.36
#
# Utility:
# [0.1881491  0.22303017 0.12633798 ... 0.39060678 0.25210764 1.2045318 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4235
# Goal B: 1.0000
# Goal C: 0.0000
# Goal D: 0.2553
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2030
#
# --- Year 2030 Summary ---
# Income (Salary): 60206.85
# Previous Wealth Carried: 249738.50
# Post-Tax Wealth (New Final Wealth): 309945.35
# ------------------------------
#
# 2031 7 31 46
# Starting Year: 2025
# Current Year: 2031
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 44, 'GOAL B': -1, 'GOAL C': 4, 'GOAL D': 9}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2031
# [DEBUG] Gross Gains (Normal account): 22122.18
# [DEBUG] Tax Calculated (Normal account): 5972.99
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           56.44
#    B            0.00
#    C            0.99
#    D           42.57
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.991799       382201.383290           99.18
#         Developed Markets - Equities 0.002845         1096.348015            0.28
# Emerging Markets State - Obligations 0.001278          492.447894            0.13
#       High Yield Bonds - Obligations 0.002336          900.159913            0.23
# Investment Grade Bonds - Obligations 0.000641          247.120440            0.06
#    Government ZC Bonds - Obligations 0.001101          424.370822            0.11
#
# Utility:
# [0.9789326  1.19633948 1.20916054 ... 1.24910021 1.11628553 1.11898894]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4178
# Goal B: 1.0000
# Goal C: 0.0000
# Goal D: 0.4806
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2031
#
# --- Year 2031 Summary ---
# Income (Salary): 60808.91
# Previous Wealth Carried: 324552.92
# Post-Tax Wealth (New Final Wealth): 385361.83
# ------------------------------
#
# 2032 8 32 47
# Starting Year: 2025
# Current Year: 2032
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 43, 'GOAL B': -2, 'GOAL C': 3, 'GOAL D': 8}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2032
# [DEBUG] Gross Gains (Normal account): 10273.31
# [DEBUG] Tax Calculated (Normal account): 2773.79
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           33.67
#    B            0.00
#    C            1.02
#    D           65.31
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.337692       159064.399875           33.77
#         Developed Markets - Equities 0.007674         3614.495181            0.77
# Emerging Markets State - Obligations 0.001486          699.780109            0.15
#       High Yield Bonds - Obligations 0.007330         3452.790362            0.73
# Investment Grade Bonds - Obligations 0.002202         1037.020082            0.22
#    Government ZC Bonds - Obligations 0.643617       303164.962004           64.36
#
# Utility:
# [1.15921985 1.27820494 1.26138317 ... 1.05618935 1.14551571 1.2176361 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3698
# Goal B: 1.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2032
#
# --- Year 2032 Summary ---
# Income (Salary): 67497.90
# Previous Wealth Carried: 403535.55
# Post-Tax Wealth (New Final Wealth): 471033.45
# ------------------------------
#
# 2033 9 33 48
# Starting Year: 2025
# Current Year: 2033
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 42, 'GOAL B': -3, 'GOAL C': 2, 'GOAL D': 7}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2033
# [DEBUG] Gross Gains (Normal account): 14492.24
# [DEBUG] Tax Calculated (Normal account): 3912.91
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           42.27
#    B            0.00
#    C            1.03
#    D           56.70
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.408124       224049.862005           40.81
#         Developed Markets - Equities 0.012981         7126.044663            1.30
# Emerging Markets State - Obligations 0.007989         4385.671047            0.80
#       High Yield Bonds - Obligations 0.012604         6919.221659            1.26
# Investment Grade Bonds - Obligations 0.003174         1742.499450            0.32
#    Government ZC Bonds - Obligations 0.555129       304752.138372           55.51
#
# Utility:
# [1.21609037 1.00092891 1.09366975 ... 1.27268566 1.10806581 1.10239228]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4023
# Goal B: 1.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2033
#
# --- Year 2033 Summary ---
# Income (Salary): 68172.87
# Previous Wealth Carried: 480802.56
# Post-Tax Wealth (New Final Wealth): 548975.44
# ------------------------------
#
# 2034 10 34 49
# Starting Year: 2025
# Current Year: 2034
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 41, 'GOAL B': -4, 'GOAL C': 1, 'GOAL D': 6}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2034
# [DEBUG] Gross Gains (Normal account): 19713.64
# [DEBUG] Tax Calculated (Normal account): 5322.68
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            51.0
#    B             0.0
#    C             1.0
#    D            48.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.506949       319865.053160           50.69
#         Developed Markets - Equities 0.000347          219.239164            0.03
# Emerging Markets State - Obligations 0.005413         3415.255018            0.54
#       High Yield Bonds - Obligations 0.003935         2482.889122            0.39
# Investment Grade Bonds - Obligations 0.003931         2480.307999            0.39
#    Government ZC Bonds - Obligations 0.479424       302497.790260           47.94
#
# Utility:
# [0.97585958 1.15667871 1.26471057 ... 1.190302   1.14748733 1.26006953]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4353
# Goal B: 1.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2034
# [DECISION] ❌ Skipping Goal C | ΔUtility: nan
#
# --- Year 2034 Summary ---
# Income (Salary): 68854.60
# Previous Wealth Carried: 562105.93
# Post-Tax Wealth (New Final Wealth): 630960.53
# ------------------------------
#
# 2035 11 35 50
# Starting Year: 2025
# Current Year: 2035
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 40, 'GOAL B': -5, 'GOAL C': 0, 'GOAL D': 5}
# C:\Users\admin\AppData\Local\Temp\ipykernel_15544\4021808357.py:3: RuntimeWarning: invalid value encountered in scalar power
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# C:\Users\admin\AppData\Local\Temp\ipykernel_15544\4021808357.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2035
# [DEBUG] Gross Gains (Normal account): 19010.32
# [DEBUG] Tax Calculated (Normal account): 5132.79
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           55.56
#    B            0.00
#    C            0.00
#    D           44.44
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.551678       395988.804150           55.17
#         Developed Markets - Equities 0.001070          768.390061            0.11
# Emerging Markets State - Obligations 0.002832         2033.089697            0.28
#       High Yield Bonds - Obligations 0.001645         1180.682341            0.16
# Investment Grade Bonds - Obligations 0.000788          565.523785            0.08
#    Government ZC Bonds - Obligations 0.441987       317253.848650           44.20
#
# Utility:
# [0.84616644 1.13122916 1.05848817 ... 1.12455197 1.02780497 1.06496839]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3569
# Goal B: 1.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2035
#
# --- Year 2035 Summary ---
# Income (Salary): 69543.15
# Previous Wealth Carried: 648247.19
# Post-Tax Wealth (New Final Wealth): 717790.34
# ------------------------------
#
# 2036 12 36 51
# Starting Year: 2025
# Current Year: 2036
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 39, 'GOAL B': -6, 'GOAL C': -1, 'GOAL D': 4}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2036
# [DEBUG] Gross Gains (Normal account): 22749.83
# [DEBUG] Tax Calculated (Normal account): 6142.45
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           61.22
#    B            0.00
#    C            0.00
#    D           38.78
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.602231       488441.388915           60.22
#         Developed Markets - Equities 0.004666         3784.271863            0.47
# Emerging Markets State - Obligations 0.005545         4497.054913            0.55
#       High Yield Bonds - Obligations 0.000046           37.591735            0.00
# Investment Grade Bonds - Obligations 0.002045         1658.257615            0.20
#    Government ZC Bonds - Obligations 0.385467       312634.239770           38.55
#
# Utility:
# [1.35939322 1.42189836 1.31833484 ... 1.29902072 1.31246384 1.32956825]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3735
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2036
#
# --- Year 2036 Summary ---
# Income (Salary): 77192.90
# Previous Wealth Carried: 733859.91
# Post-Tax Wealth (New Final Wealth): 811052.80
# ------------------------------
#
# 2037 13 37 52
# Starting Year: 2025
# Current Year: 2037
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 38, 'GOAL B': -7, 'GOAL C': -2, 'GOAL D': 3}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2037
# [DEBUG] Gross Gains (Normal account): 25937.41
# [DEBUG] Tax Calculated (Normal account): 7003.10
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           62.63
#    B            0.00
#    C            0.00
#    D           37.37
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.622639       565414.762178           62.26
#         Developed Markets - Equities 0.002905         2638.152839            0.29
# Emerging Markets State - Obligations 0.000508          461.699325            0.05
#       High Yield Bonds - Obligations 0.002142         1944.958799            0.21
# Investment Grade Bonds - Obligations 0.001214         1102.031014            0.12
#    Government ZC Bonds - Obligations 0.370592       336532.745174           37.06
#
# Utility:
# [1.22616088 1.40304156 1.35429224 ... 1.29051122 1.17897212 1.37811877]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3831
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2037
#
# --- Year 2037 Summary ---
# Income (Salary): 77964.82
# Previous Wealth Carried: 830129.52
# Post-Tax Wealth (New Final Wealth): 908094.35
# ------------------------------
#
# 2038 14 38 53
# Starting Year: 2025
# Current Year: 2038
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 37, 'GOAL B': -8, 'GOAL C': -3, 'GOAL D': 2}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2038
# [DEBUG] Gross Gains (Normal account): 30004.80
# [DEBUG] Tax Calculated (Normal account): 8101.30
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           67.68
#    B            0.00
#    C            0.00
#    D           32.32
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.666601       672303.884686           66.66
#         Developed Markets - Equities 0.002168         2186.641642            0.22
# Emerging Markets State - Obligations 0.000266          268.324563            0.03
#       High Yield Bonds - Obligations 0.004152         4187.851503            0.42
# Investment Grade Bonds - Obligations 0.005813         5862.603167            0.58
#    Government ZC Bonds - Obligations 0.320999       323745.530349           32.10
#
# Utility:
# [1.23097721 1.29148355 1.31551528 ... 1.1633458  1.18400081 1.30905018]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3980
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2038
#
# --- Year 2038 Summary ---
# Income (Salary): 78744.47
# Previous Wealth Carried: 929810.36
# Post-Tax Wealth (New Final Wealth): 1008554.84
# ------------------------------
#
# 2039 15 39 54
# Starting Year: 2025
# Current Year: 2039
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 36, 'GOAL B': -9, 'GOAL C': -4, 'GOAL D': 1}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2039
# [DEBUG] Gross Gains (Normal account): 34050.49
# [DEBUG] Tax Calculated (Normal account): 9193.63
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           71.13
#    B            0.00
#    C            0.00
#    D           28.87
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.691978       770256.999548           69.20
#         Developed Markets - Equities 0.008747         9736.865375            0.87
# Emerging Markets State - Obligations 0.001546         1720.665869            0.15
#       High Yield Bonds - Obligations 0.005043         5613.877197            0.50
# Investment Grade Bonds - Obligations 0.000262          292.001119            0.03
#    Government ZC Bonds - Obligations 0.292423       325503.444384           29.24
#
# Utility:
# [1.19415705 1.3352363  1.32685267 ... 1.38118719 1.43248774 1.42398742]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4067
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2039
# [DECISION] ✅ Paying Goal D | ΔUtility: 0.103
#
# --- Year 2039 Summary ---
# Income (Salary): 79531.92
# Previous Wealth Carried: 1033591.94
# Post-Tax Wealth (New Final Wealth): 1113123.85
# ------------------------------
#
# 2040 16 40 55
# Starting Year: 2025
# Current Year: 2040
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 35, 'GOAL B': -10, 'GOAL C': -5, 'GOAL D': 0}
# C:\Users\admin\AppData\Local\Temp\ipykernel_15544\4021808357.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2040
# [DEBUG] Gross Gains (Normal account): 33868.73
# [DEBUG] Tax Calculated (Normal account): 9144.56
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.930171       864864.770703           93.02
#         Developed Markets - Equities 0.020315        18888.805060            2.03
# Emerging Markets State - Obligations 0.012381        11511.436561            1.24
#       High Yield Bonds - Obligations 0.008476         7880.969549            0.85
# Investment Grade Bonds - Obligations 0.010556         9814.954331            1.06
#    Government ZC Bonds - Obligations 0.018101        16830.192303            1.81
#
# Utility:
# [1.25506479 1.26772815 1.32682865 ... 1.16011583 1.04908575 1.45633524]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4130
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2040
#
# --- Year 2040 Summary ---
# Income (Salary): 88280.43
# Previous Wealth Carried: 841510.70
# Post-Tax Wealth (New Final Wealth): 929791.13
# ------------------------------
#
# 2041 17 41 56
# Starting Year: 2025
# Current Year: 2041
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 34, 'GOAL B': -11, 'GOAL C': -6, 'GOAL D': -1}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2041
# [DEBUG] Gross Gains (Normal account): 38299.20
# [DEBUG] Tax Calculated (Normal account): 10340.78
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.948233       993420.878978           94.82
#         Developed Markets - Equities 0.006772         7094.927778            0.68
# Emerging Markets State - Obligations 0.016795        17595.002834            1.68
#       High Yield Bonds - Obligations 0.012517        13113.023308            1.25
# Investment Grade Bonds - Obligations 0.008678         9091.544054            0.87
#    Government ZC Bonds - Obligations 0.007006         7339.700217            0.70
#
# Utility:
# [1.3355927  1.43232507 1.43702392 ... 1.37515474 1.45450914 1.37508318]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4245
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2041
#
# --- Year 2041 Summary ---
# Income (Salary): 89163.23
# Previous Wealth Carried: 958491.84
# Post-Tax Wealth (New Final Wealth): 1047655.08
# ------------------------------
#
# 2042 18 42 57
# Starting Year: 2025
# Current Year: 2042
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 33, 'GOAL B': -12, 'GOAL C': -7, 'GOAL D': -2}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2042
# [DEBUG] Gross Gains (Normal account): 42839.91
# [DEBUG] Tax Calculated (Normal account): 11566.78
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.942934        1.103372e+06           94.29
#         Developed Markets - Equities 0.015478        1.811167e+04            1.55
# Emerging Markets State - Obligations 0.013526        1.582746e+04            1.35
#       High Yield Bonds - Obligations 0.000679        7.940653e+02            0.07
# Investment Grade Bonds - Obligations 0.010658        1.247108e+04            1.07
#    Government ZC Bonds - Obligations 0.016725        1.957125e+04            1.67
#
# Utility:
# [1.47322907 1.41298909 1.22855406 ... 1.52830185 1.22737115 1.46119909]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4307
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2042
#
# --- Year 2042 Summary ---
# Income (Salary): 90054.87
# Previous Wealth Carried: 1080093.07
# Post-Tax Wealth (New Final Wealth): 1170147.93
# ------------------------------
#
# 2043 19 43 58
# Starting Year: 2025
# Current Year: 2043
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 32, 'GOAL B': -13, 'GOAL C': -8, 'GOAL D': -3}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2043
# [DEBUG] Gross Gains (Normal account): 46782.23
# [DEBUG] Tax Calculated (Normal account): 12631.20
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.940665        1.220440e+06           94.07
#         Developed Markets - Equities 0.001379        1.788827e+03            0.14
# Emerging Markets State - Obligations 0.008007        1.038835e+04            0.80
#       High Yield Bonds - Obligations 0.007758        1.006598e+04            0.78
# Investment Grade Bonds - Obligations 0.019636        2.547572e+04            1.96
#    Government ZC Bonds - Obligations 0.022555        2.926344e+04            2.26
#
# Utility:
# [1.26094232 1.52068652 1.46300677 ... 1.45363936 1.49433171 1.33239422]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4377
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2043
#
# --- Year 2043 Summary ---
# Income (Salary): 90955.41
# Previous Wealth Carried: 1206467.30
# Post-Tax Wealth (New Final Wealth): 1297422.71
# ------------------------------
#
# 2044 20 44 59
# Starting Year: 2025
# Current Year: 2044
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 31, 'GOAL B': -14, 'GOAL C': -9, 'GOAL D': -4}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2044
# [DEBUG] Gross Gains (Normal account): 53085.40
# [DEBUG] Tax Calculated (Normal account): 14333.06
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.970874        1.396329e+06           97.09
#         Developed Markets - Equities 0.003864        5.557414e+03            0.39
# Emerging Markets State - Obligations 0.002158        3.104167e+03            0.22
#       High Yield Bonds - Obligations 0.009409        1.353203e+04            0.94
# Investment Grade Bonds - Obligations 0.009069        1.304378e+04            0.91
#    Government ZC Bonds - Obligations 0.004625        6.652018e+03            0.46
#
# Utility:
# [1.08498177 1.38054991 1.27241886 ... 1.4460902  1.47360066 1.3572379 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4502
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2044
#
# --- Year 2044 Summary ---
# Income (Salary): 100960.51
# Previous Wealth Carried: 1337258.32
# Post-Tax Wealth (New Final Wealth): 1438218.82
# ------------------------------
#
# 2045 21 45 60
# Starting Year: 2025
# Current Year: 2045
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 30, 'GOAL B': -15, 'GOAL C': -10, 'GOAL D': -5}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2045
# [DEBUG] Gross Gains (Normal account): 58076.91
# [DEBUG] Tax Calculated (Normal account): 15680.77
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.953323        1.511346e+06           95.33
#         Developed Markets - Equities 0.015871        2.516091e+04            1.59
# Emerging Markets State - Obligations 0.002024        3.208392e+03            0.20
#       High Yield Bonds - Obligations 0.001043        1.653233e+03            0.10
# Investment Grade Bonds - Obligations 0.010524        1.668399e+04            1.05
#    Government ZC Bonds - Obligations 0.017216        2.729280e+04            1.72
#
# Utility:
# [1.43898277 1.37135194 1.47068729 ... 1.32748248 1.45665582 1.44144805]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4541
# Goal B: 1.0000
# Goal C: 0.9999
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2045
#
# --- Year 2045 Summary ---
# Income (Salary): 101970.11
# Previous Wealth Carried: 1483374.85
# Post-Tax Wealth (New Final Wealth): 1585344.97
# ------------------------------
#
# 2046 22 46 61
# Starting Year: 2025
# Current Year: 2046
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 29, 'GOAL B': -16, 'GOAL C': -11, 'GOAL D': -6}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2046
# [DEBUG] Gross Gains (Normal account): 63943.36
# [DEBUG] Tax Calculated (Normal account): 17264.71
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.956009        1.661491e+06           95.60
#         Developed Markets - Equities 0.023991        4.169532e+04            2.40
# Emerging Markets State - Obligations 0.007032        1.222056e+04            0.70
#       High Yield Bonds - Obligations 0.006125        1.064577e+04            0.61
# Investment Grade Bonds - Obligations 0.003337        5.800351e+03            0.33
#    Government ZC Bonds - Obligations 0.003505        6.091317e+03            0.35
#
# Utility:
# [1.19892024 1.34322147 1.29076845 ... 1.52029904 1.26439668 1.49741498]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4626
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2046
#
# --- Year 2046 Summary ---
# Income (Salary): 102989.82
# Previous Wealth Carried: 1634954.85
# Post-Tax Wealth (New Final Wealth): 1737944.67
# ------------------------------
#
# 2047 23 47 62
# Starting Year: 2025
# Current Year: 2047
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 28, 'GOAL B': -17, 'GOAL C': -12, 'GOAL D': -7}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2047
# [DEBUG] Gross Gains (Normal account): 69394.48
# [DEBUG] Tax Calculated (Normal account): 19020.68
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.977768        1.854600e+06           97.78
#         Developed Markets - Equities 0.001339        2.539920e+03            0.13
# Emerging Markets State - Obligations 0.015095        2.863130e+04            1.51
#       High Yield Bonds - Obligations 0.003837        7.278110e+03            0.38
# Investment Grade Bonds - Obligations 0.001941        3.680952e+03            0.19
#    Government ZC Bonds - Obligations 0.000021        3.939031e+01            0.00
#
# Utility:
# [1.23043141 1.40290376 1.40959422 ... 1.42842195 1.47064908 1.33941562]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4710
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2047
#
# --- Year 2047 Summary ---
# Income (Salary): 104019.71
# Previous Wealth Carried: 1792749.61
# Post-Tax Wealth (New Final Wealth): 1896769.32
# ------------------------------
#
# 2048 24 48 63
# Starting Year: 2025
# Current Year: 2048
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 27, 'GOAL B': -18, 'GOAL C': -13, 'GOAL D': -8}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2048
# [DEBUG] Gross Gains (Normal account): 74655.18
# [DEBUG] Tax Calculated (Normal account): 21230.17
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.964099        1.997381e+06           96.41
#         Developed Markets - Equities 0.002163        4.481496e+03            0.22
# Emerging Markets State - Obligations 0.000524        1.084715e+03            0.05
#       High Yield Bonds - Obligations 0.003777        7.825861e+03            0.38
# Investment Grade Bonds - Obligations 0.006198        1.284090e+04            0.62
#    Government ZC Bonds - Obligations 0.023239        4.814561e+04            2.32
#
# Utility:
# [1.42174931 1.43906701 1.46124708 ... 1.45045074 1.45591871 1.1533946 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4782
# Goal B: 0.9996
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2048
#
# --- Year 2048 Summary ---
# Income (Salary): 115461.88
# Previous Wealth Carried: 1956297.38
# Post-Tax Wealth (New Final Wealth): 2071759.26
# ------------------------------
#
# 2049 25 49 64
# Starting Year: 2025
# Current Year: 2049
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 26, 'GOAL B': -19, 'GOAL C': -14, 'GOAL D': -9}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2049
# [DEBUG] Gross Gains (Normal account): 80321.08
# [DEBUG] Tax Calculated (Normal account): 23609.85
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.952546        2.145240e+06           95.25
#         Developed Markets - Equities 0.008410        1.894007e+04            0.84
# Emerging Markets State - Obligations 0.000456        1.025892e+03            0.05
#       High Yield Bonds - Obligations 0.004887        1.100538e+04            0.49
# Investment Grade Bonds - Obligations 0.016907        3.807651e+04            1.69
#    Government ZC Bonds - Obligations 0.016795        3.782474e+04            1.68
#
# Utility:
# [1.18390783 1.61532969 1.42917677 ... 1.45463512 1.28350895 1.17890407]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4811
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# ...
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2067
#
# --- Year 2067 Summary ---
# Income (Salary): 153301.48
# Previous Wealth Carried: 6707530.16
# Post-Tax Wealth (New Final Wealth): 6860831.64
# ------------------------------
#
# 2068 44 68 83
# Starting Year: 2025
# Current Year: 2068
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 7, 'GOAL B': -38, 'GOAL C': -33, 'GOAL D': -28}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2068
# [DEBUG] Gross Gains (Normal account): 76870.18
# [DEBUG] Tax Calculated (Normal account): 22160.47
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 1.829542e-01        1.315833e+06           18.30
#         Developed Markets - Equities 3.430632e-01        2.467360e+06           34.31
# Emerging Markets State - Obligations 7.360243e-05        5.293593e+02            0.01
#       High Yield Bonds - Obligations 6.289975e-16        4.523841e-09            0.00
# Investment Grade Bonds - Obligations 3.351862e-03        2.410707e+04            0.34
#    Government ZC Bonds - Obligations 4.705571e-01        3.384315e+06           47.06
#
# Utility:
# [1.32876223 1.76937119 1.21042853 ... 1.14910071 1.18293086 1.14910071]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.7127
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2068
#
# --- Year 2068 Summary ---
# Income (Salary): 154834.49
# Previous Wealth Carried: 7037309.55
# Post-Tax Wealth (New Final Wealth): 7192144.04
# ------------------------------
#
# 2069 45 69 84
# Starting Year: 2025
# Current Year: 2069
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 6, 'GOAL B': -39, 'GOAL C': -34, 'GOAL D': -29}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2069
# [DEBUG] Gross Gains (Normal account): 107313.29
# [DEBUG] Tax Calculated (Normal account): 34946.58
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.000717        5.389183e+03            0.07
#         Developed Markets - Equities 0.000679        5.102402e+03            0.07
# Emerging Markets State - Obligations 0.000060        4.500313e+02            0.01
#       High Yield Bonds - Obligations 0.000218        1.635138e+03            0.02
# Investment Grade Bonds - Obligations 0.004056        3.047851e+04            0.41
#    Government ZC Bonds - Obligations 0.994271        7.471862e+06           99.43
#
# Utility:
# [1.17961498 1.36249423 1.18011924 ... 1.17753975 1.19136416 1.19388097]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2069
#
# --- Year 2069 Summary ---
# Income (Salary): 156382.84
# Previous Wealth Carried: 7358534.50
# Post-Tax Wealth (New Final Wealth): 7514917.34
# ------------------------------
#
# 2070 46 70 85
# Starting Year: 2025
# Current Year: 2070
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 5, 'GOAL B': -40, 'GOAL C': -35, 'GOAL D': -30}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2070
# [DEBUG] Gross Gains (Normal account): 110762.15
# [DEBUG] Tax Calculated (Normal account): 36395.10
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset  Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities     0.0        0.000000e+00             0.0
#         Developed Markets - Equities     0.0        0.000000e+00             0.0
# Emerging Markets State - Obligations     0.0        0.000000e+00             0.0
#       High Yield Bonds - Obligations     0.0        0.000000e+00             0.0
# Investment Grade Bonds - Obligations     0.0        0.000000e+00             0.0
#    Government ZC Bonds - Obligations     1.0        7.745605e+06           100.0
#
# Utility:
# [1.26741528 1.2352837  1.13283409 ... 1.15256683 1.184      1.18220369]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2070
#
# --- Year 2070 Summary ---
# Income (Salary): 157946.67
# Previous Wealth Carried: 7587658.48
# Post-Tax Wealth (New Final Wealth): 7745605.15
# ------------------------------
#
# 2071 47 71 86
# Starting Year: 2025
# Current Year: 2071
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 4, 'GOAL B': -41, 'GOAL C': -36, 'GOAL D': -31}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2071
# [DEBUG] Gross Gains (Normal account): 111685.71
# [DEBUG] Tax Calculated (Normal account): 36783.00
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 1.250987e-03        9.782686e+03            0.13
#         Developed Markets - Equities 0.000000e+00        0.000000e+00            0.00
# Emerging Markets State - Obligations 2.064276e-04        1.614258e+03            0.02
#       High Yield Bonds - Obligations 6.988536e-17        5.465016e-10            0.00
# Investment Grade Bonds - Obligations 3.659124e-03        2.861425e+04            0.37
#    Government ZC Bonds - Obligations 9.948835e-01        7.779961e+06           99.49
#
# Utility:
# [1.16295058 1.18399762 1.17348325 ... 1.15296117 1.15439612 1.14726357]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2071
#
# --- Year 2071 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 7819972.20
# Post-Tax Wealth (New Final Wealth): 7819972.20
# ------------------------------
#
# 2072 48 72 87
# Starting Year: 2025
# Current Year: 2072
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 3, 'GOAL B': -42, 'GOAL C': -37, 'GOAL D': -32}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2072
# [DEBUG] Gross Gains (Normal account): 111973.41
# [DEBUG] Tax Calculated (Normal account): 36903.83
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 6.967908e-03        5.501319e+04            0.70
#         Developed Markets - Equities 1.254254e-03        9.902614e+03            0.13
# Emerging Markets State - Obligations 0.000000e+00        0.000000e+00            0.00
#       High Yield Bonds - Obligations 1.493592e-19        1.179225e-12            0.00
# Investment Grade Bonds - Obligations 5.064420e-03        3.998473e+04            0.51
#    Government ZC Bonds - Obligations 9.867134e-01        7.790324e+06           98.67
#
# Utility:
# [1.17265248 1.1661052  1.13188724 ... 1.1661052  1.154803   1.15623275]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.9509
# Goal C: 0.9999
# Goal D: 0.9190
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2072
#
# --- Year 2072 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 7895224.06
# Post-Tax Wealth (New Final Wealth): 7895224.06
# ------------------------------
#
# 2073 49 73 88
# Starting Year: 2025
# Current Year: 2073
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 2, 'GOAL B': -43, 'GOAL C': -38, 'GOAL D': -33}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2073
# [DEBUG] Gross Gains (Normal account): 113544.91
# [DEBUG] Tax Calculated (Normal account): 37563.86
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 3.995838e-03        3.185726e+04            0.40
#         Developed Markets - Equities 6.894289e-05        5.496548e+02            0.01
# Emerging Markets State - Obligations 0.000000e+00        0.000000e+00            0.00
#       High Yield Bonds - Obligations 2.505006e-19        1.997144e-12            0.00
# Investment Grade Bonds - Obligations 3.396116e-03        2.707591e+04            0.34
#    Government ZC Bonds - Obligations 9.925391e-01        7.913128e+06           99.25
#
# Utility:
# [0.96182231 1.11533977 1.15522212 ... 1.16233276 1.18121837 1.16233276]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 1.0000
# Goal C: 0.9999
# Goal D: 0.9819
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = Y
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2073
#
# --- Year 2073 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 7972610.47
# Post-Tax Wealth (New Final Wealth): 7972610.47
# ------------------------------
#
# 2074 50 74 89
# Starting Year: 2025
# Current Year: 2074
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 1, 'GOAL B': -44, 'GOAL C': -39, 'GOAL D': -34}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2074
# [DEBUG] Gross Gains (Normal account): 114955.12
# [DEBUG] Tax Calculated (Normal account): 38156.15
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 1.353834e-03        1.089802e+04            0.14
#         Developed Markets - Equities 3.773758e-06        3.037780e+01            0.00
# Emerging Markets State - Obligations 6.927187e-22        5.576211e-15            0.00
#       High Yield Bonds - Obligations 7.481140e-20        6.022129e-13            0.00
# Investment Grade Bonds - Obligations 6.050993e-04        4.870897e+03            0.06
#    Government ZC Bonds - Obligations 9.980373e-01        8.033949e+06           99.80
#
# Utility:
# [0.9936326  1.16557274 1.00536752 ... 1.16557274 1.16417758 1.17351864]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = Y
# Row 50: Year = 2073, Status = Y
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2074
# [DECISION] ✅ Paying Goal A | ΔUtility: 1.000
#
# --- Year 2074 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 8049748.12
# Post-Tax Wealth (New Final Wealth): 8049748.12
# ------------------------------
#
# 2075 51 75 90
# Starting Year: 2025
# Current Year: 2075
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 0, 'GOAL B': -45, 'GOAL C': -40, 'GOAL D': -35}
# C:\Users\admin\AppData\Local\Temp\ipykernel_15544\4021808357.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2075
# [DEBUG] Gross Gains (Normal account): 13733.87
# [DEBUG] Tax Calculated (Normal account): 3708.15
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.137423       154867.551333           13.74
#         Developed Markets - Equities 0.010346        11658.786131            1.03
# Emerging Markets State - Obligations 0.090902       102440.425898            9.09
#       High Yield Bonds - Obligations 0.080643        90879.185129            8.06
# Investment Grade Bonds - Obligations 0.027923        31467.786317            2.79
#    Government ZC Bonds - Obligations 0.652763       735623.387888           65.28
#
# Utility:
# [1.18398013 1.17979783 1.18399847 ... 1.00812341 1.03774792 1.15808972]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0000
# Goal B: 1.0000
# Goal C: 1.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = Y
# Row 50: Year = 2073, Status = Y
# Row 51: Year = 2074, Status = Y
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2075
#
# --- Year 2075 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 1126937.12
# Post-Tax Wealth (New Final Wealth): 1126937.12
# ------------------------------
#
# All loops completed

# %%
# V14 - Load salary data for all years
df_salary = pd.read_excel(master_excel_path, sheet_name=excel_income)
df_salary.set_index(df_salary.columns[0], inplace=True)

# %%
# V7C: Export new asset-level log for debugging
pd.DataFrame(asset_level_log).to_csv(os.path.join(output_folder, "asset_returns_log.csv"), index=False)

#V12 moved finalwealth to python
pd.DataFrame.from_dict(final_wealth_tracker, orient='index', columns=['Final Wealth']).to_csv(
    os.path.join(output_folder, "final_wealth_by_year.csv")
)

#V15
pd.DataFrame(goal_weights_tracker).to_csv(
    os.path.join(output_folder, "goal_weights_by_year.csv"), index=False
)

pd.DataFrame(aggregate_portfolio_tracker).to_csv(
    os.path.join(output_folder, "aggregate_portfolio_by_year.csv"), index=False
)

# V15: Save optimal_weights for Goals A–D
for goal_letter, matrix_dict in zip(
    ["A", "B", "C", "D"],
    [goal_optimal_weights_A, goal_optimal_weights_B, goal_optimal_weights_C, goal_optimal_weights_D]
):
    all_dfs = []
    for year, mat in matrix_dict.items():
        df = pd.DataFrame(mat)
        df.insert(0, "Year", year)
        df.insert(1, "Allocation Level", np.arange(0.01, 1.01, 0.01))
        all_dfs.append(df)

    df_all = pd.concat(all_dfs, ignore_index=True)
    df_all.to_csv(os.path.join(output_folder, f"optimal_weights_goal_{goal_letter}.csv"), index=False)

# %% [markdown]
# # Second Loop: Used right now to rerun everything but without having to do the optimisation (grabs the first loop's optimal weights)

# %%
print("\n===== BEGIN STATIC OPTIMIZATION LOOP =====\n")
# Trackers for the second (static) loop
final_wealth_tracker_second = {}
asset_level_log_second = []
goal_weights_tracker_second = []
aggregate_portfolio_tracker_second = []

aktiesparekonto_used_total = 0

for loop_year in range(start_year, end_year + 1):
    print(f"[STATIC LOOP] Year {loop_year}")

    salary = df_salary.loc[Profile, str(loop_year)]
    prev_year = loop_year - 1

    if loop_year == start_year:
        prev_wealth = 0
    else:
        prev_wealth = final_wealth_tracker[prev_year]

    pool = salary + prev_wealth

    # Retrieve stored goal weights for this year
    goal_weights_row = next(item for item in goal_weights_tracker if item["Year"] == loop_year)
    normalized_goal_alloc = np.array([goal_weights_row[f"Goal {g} (%)"] for g in goals])

    goal_weights_tracker_second.append({
    "Year": loop_year,
    **{f"Goal {goals[i]} (%)": normalized_goal_alloc[i] for i in range(len(goals))}
})

    # Retrieve stored aggregate portfolio for this year
    df_agg = pd.DataFrame([
        row for row in aggregate_portfolio_tracker if row["Year"] == loop_year
    ])
    asset_names = df_agg["Asset"].tolist()
    weights = df_agg["Weight"].to_numpy()

    # Calculate invested amounts
    df_agg["Invested Amt (DKK)"] = weights * pool

    for i in range(len(asset_names)):
        aggregate_portfolio_tracker_second.append({
            "Year": loop_year,
            "Asset": asset_names[i],
            "Weight": weights[i],
            "Allocation (%)": df_agg.iloc[i]["Invested Amt (DKK)"] / pool * 100,
            "Invested Amt (DKK)": df_agg.iloc[i]["Invested Amt (DKK)"]
        })

    # Apply ASK logic as before
    equity_rows = []
    non_equity_rows = []
    for _, row in df_agg.iterrows():
        asset = row["Asset"]
        invested = row["Invested Amt (DKK)"]
        weight = row["Weight"]

        row_dict = {
            "Year": loop_year,
            "Asset": asset,
            "Invested": invested,
            "Weight": weight,
            "ASK (DKK)": 0,
            "Normal (DKK)": 0
        }

        if "Equities" in asset:
            equity_rows.append(row_dict)
        else:
            row_dict["Normal (DKK)"] = invested
            non_equity_rows.append(row_dict)

    total_equity = sum(r["Invested"] for r in equity_rows)
    remaining_ask_cap = max(0, aktiesparekonto_cap - aktiesparekonto_used_total)
    ask_fraction = min(1, remaining_ask_cap / total_equity) if total_equity > 0 else 0

    for row in equity_rows:
        ask = row["Invested"] * ask_fraction
        row["ASK (DKK)"] = ask
        row["Normal (DKK)"] = row["Invested"] - ask
        aktiesparekonto_used_total += ask

    account_allocations = equity_rows + non_equity_rows

    # Tax logic from main loop (can be refactored if reused)
    share_income_normal = 0
    asset_level_this_year = []

    for row in account_allocations:
        asset = row["Asset"]
        ask = row["ASK (DKK)"]
        normal = row["Normal (DKK)"]
        expected_return = df_returns.loc[asset, str(loop_year)]
        expected_return_inflation_adj = expected_return - inflation_rate

        if ask > 0:
            gain = ask * expected_return_inflation_adj
            tax = 0.17 * gain
            asset_level_this_year.append({
                "Year": loop_year,
                "Account": "ASK",
                "Asset": asset,
                "Invested": ask,
                "Return (Adj)": expected_return_inflation_adj,
                "Tax": tax,
                "Net Gain": gain - tax,
                "End Value": ask + gain - tax
            })

        if normal > 0:
            gain = normal * expected_return_inflation_adj
            share_income_normal += gain
            asset_level_this_year.append({
                "Year": loop_year,
                "Account": "NORMAL",
                "Asset": asset,
                "Invested": normal,
                "Return (Adj)": expected_return_inflation_adj,
                "Gross Gain": gain
            })

    # Tax distribution for NORMAL accounts
    cap = 67500
    if share_income_normal <= cap:
        tax_normal = 0.27 * share_income_normal
    else:
        tax_normal = 0.27 * cap + 0.42 * (share_income_normal - cap)

    norm_rows = [r for r in asset_level_this_year if r["Account"] == "NORMAL"]
    total_normal_gain = sum(r["Gross Gain"] for r in norm_rows)
    for r in norm_rows:
        share = r["Gross Gain"] / total_normal_gain if total_normal_gain else 0
        tax = share * tax_normal
        r["Tax"] = tax
        r["Net Gain"] = r["Gross Gain"] - tax
        r["End Value"] = r["Invested"] + r["Net Gain"]

    end_value_sum = sum(r["End Value"] for r in asset_level_this_year)
    # -- V9 Logic in Static Loop -- #
    goal_data_raw = get_goal_data(master_excel_path, plan=Profile)
    goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
    goal_years = start_year + goal_horizons
    adjusted_horizons = goal_years - loop_year
    goal_data_raw.loc["Time Horizon"] = adjusted_horizons

    goal_payout_info = {}

    for i, goal in enumerate(goals):
        if adjusted_horizons[f"GOAL {goal}"] == 1:
            alloc_pct = normalized_goal_alloc[i]
            goal_required = goal_data_raw.loc["Funding Requirement", f"GOAL {goal}"]
            amount_alloc_based = (alloc_pct / 100) * end_value_sum

            future_goals = [
                goal_data_raw[f"GOAL {g}"].values
                for j, g in enumerate(goals)
                if g != goal and adjusted_horizons[f"GOAL {g}"] > 1
            ]
            future_weights = [
                df_agg["Weight"].to_numpy()
                for j, g in enumerate(goals)
                if g != goal and adjusted_horizons[f"GOAL {g}"] > 1
            ]

            value_now_nested = nested_value_ratio(i, [goal_data_raw.loc["Value Ratio", f"GOAL {g}"] for g in goals])

            net_util, fut_loss, phi_details = net_utility_change_from_goal_funding(
                value_now_nested,
                goal_required,
                end_value_sum,
                future_goals,
                future_weights,
                df_returns.loc[df_agg["Asset"], str(loop_year)].to_numpy() - inflation_rate,
                covariances
            )

            if net_util > 0:
                amount_taken = min(goal_required, amount_alloc_based)
                print(f"[STATIC DECISION] ✅ Paying Goal {goal} | ΔUtility: {net_util:.3f}")
                end_value_sum -= amount_taken
            else:
                amount_taken = 0
                print(f"[STATIC DECISION] ❌ Skipping Goal {goal} | ΔUtility: {net_util:.3f}")

            goal_payout_info[f"Goal {goal} Allocation (%)"] = alloc_pct
            goal_payout_info[f"Goal {goal} Amount Taken (DKK)"] = amount_taken
            goal_payout_info[f"Goal {goal} Utility Net Δ"] = net_util
            goal_payout_info[f"Goal {goal} Utility Loss"] = fut_loss
            goal_payout_info[f"Goal {goal} Value Now"] = value_now_nested
            goal_payout_info[f"Goal {goal} Utility φ_before"] = ", ".join(str(round(p[0], 4)) for p in phi_details)
            goal_payout_info[f"Goal {goal} Utility φ_after"] = ", ".join(str(round(p[1], 4)) for p in phi_details)

    # Annotate current year's static asset log
    for row in asset_level_this_year:
        for key, value in goal_payout_info.items():
            row[key] = value

    final_wealth_tracker_second[loop_year] = end_value_sum
    # Optional: Append asset_level_this_year to a new static log
    asset_level_log_second += asset_level_this_year

    print(f"→ [STATIC] Year {loop_year}: Final Wealth = {end_value_sum:.2f}")

print("\n===== END STATIC LOOP =====\n")
# Out:
# ===== BEGIN STATIC OPTIMIZATION LOOP =====
#
# [STATIC LOOP] Year 2025
# → [STATIC] Year 2025: Final Wealth = 0.00
# [STATIC LOOP] Year 2026
# C:\Users\admin\AppData\Local\Temp\ipykernel_15544\4290596699.py:40: RuntimeWarning: invalid value encountered in scalar divide
#   "Allocation (%)": df_agg.iloc[i]["Invested Amt (DKK)"] / pool * 100,
# → [STATIC] Year 2026: Final Wealth = 55035.78
# [STATIC LOOP] Year 2027
# → [STATIC] Year 2027: Final Wealth = 113511.30
# [STATIC LOOP] Year 2028
# → [STATIC] Year 2028: Final Wealth = 181024.63
# [STATIC LOOP] Year 2029
# [STATIC DECISION] ❌ Skipping Goal B | ΔUtility: -0.002
# → [STATIC] Year 2029: Final Wealth = 252609.52
# [STATIC LOOP] Year 2030
# → [STATIC] Year 2030: Final Wealth = 328880.44
# [STATIC LOOP] Year 2031
# → [STATIC] Year 2031: Final Wealth = 409907.20
# [STATIC LOOP] Year 2032
# → [STATIC] Year 2032: Final Wealth = 489571.00
# [STATIC LOOP] Year 2033
# → [STATIC] Year 2033: Final Wealth = 571851.30
# [STATIC LOOP] Year 2034
# C:\Users\admin\AppData\Local\Temp\ipykernel_15544\4021808357.py:3: RuntimeWarning: invalid value encountered in scalar power
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [STATIC DECISION] ❌ Skipping Goal C | ΔUtility: nan
# → [STATIC] Year 2034: Final Wealth = 659439.81
# [STATIC LOOP] Year 2035
# → [STATIC] Year 2035: Final Wealth = 747165.47
# [STATIC LOOP] Year 2036
# → [STATIC] Year 2036: Final Wealth = 845223.49
# [STATIC LOOP] Year 2037
# → [STATIC] Year 2037: Final Wealth = 947131.16
# [STATIC LOOP] Year 2038
# → [STATIC] Year 2038: Final Wealth = 1053508.57
# [STATIC LOOP] Year 2039
# [STATIC DECISION] ✅ Paying Goal D | ΔUtility: 0.090
# → [STATIC] Year 2039: Final Wealth = 864533.91
# [STATIC LOOP] Year 2040
# → [STATIC] Year 2040: Final Wealth = 1294367.34
# [STATIC LOOP] Year 2041
# → [STATIC] Year 2041: Final Wealth = 1430946.04
# [STATIC LOOP] Year 2042
# → [STATIC] Year 2042: Final Wealth = 1573296.48
# [STATIC LOOP] Year 2043
# → [STATIC] Year 2043: Final Wealth = 1720720.43
# [STATIC LOOP] Year 2044
# → [STATIC] Year 2044: Final Wealth = 1883644.50
# [STATIC LOOP] Year 2045
# → [STATIC] Year 2045: Final Wealth = 2053601.59
# [STATIC LOOP] Year 2046
# → [STATIC] Year 2046: Final Wealth = 2230839.13
# [STATIC LOOP] Year 2047
# → [STATIC] Year 2047: Final Wealth = 2415519.35
# [STATIC LOOP] Year 2048
# → [STATIC] Year 2048: Final Wealth = 2617855.89
# [STATIC LOOP] Year 2049
# → [STATIC] Year 2049: Final Wealth = 2827920.66
# [STATIC LOOP] Year 2050
# → [STATIC] Year 2050: Final Wealth = 3045512.69
# [STATIC LOOP] Year 2051
# → [STATIC] Year 2051: Final Wealth = 3271735.16
# [STATIC LOOP] Year 2052
# → [STATIC] Year 2052: Final Wealth = 3509559.23
# [STATIC LOOP] Year 2053
# → [STATIC] Year 2053: Final Wealth = 3756033.39
# [STATIC LOOP] Year 2054
# → [STATIC] Year 2054: Final Wealth = 4008791.75
# [STATIC LOOP] Year 2055
# → [STATIC] Year 2055: Final Wealth = 4244665.90
# [STATIC LOOP] Year 2056
# → [STATIC] Year 2056: Final Wealth = 4487142.51
# [STATIC LOOP] Year 2057
# → [STATIC] Year 2057: Final Wealth = 4736255.28
# [STATIC LOOP] Year 2058
# → [STATIC] Year 2058: Final Wealth = 4992534.73
# [STATIC LOOP] Year 2059
# → [STATIC] Year 2059: Final Wealth = 5256977.54
# [STATIC LOOP] Year 2060
# → [STATIC] Year 2060: Final Wealth = 5526279.98
# [STATIC LOOP] Year 2061
# → [STATIC] Year 2061: Final Wealth = 5818265.78
# [STATIC LOOP] Year 2062
# → [STATIC] Year 2062: Final Wealth = 6114556.70
# [STATIC LOOP] Year 2063
# → [STATIC] Year 2063: Final Wealth = 6423926.30
# [STATIC LOOP] Year 2064
# → [STATIC] Year 2064: Final Wealth = 6742146.91
# [STATIC LOOP] Year 2065
# → [STATIC] Year 2065: Final Wealth = 7062080.47
# [STATIC LOOP] Year 2066
# → [STATIC] Year 2066: Final Wealth = 7397898.78
# [STATIC LOOP] Year 2067
# → [STATIC] Year 2067: Final Wealth = 7711551.26
# [STATIC LOOP] Year 2068
# → [STATIC] Year 2068: Final Wealth = 8010633.30
# [STATIC LOOP] Year 2069
# → [STATIC] Year 2069: Final Wealth = 8245068.17
# [STATIC LOOP] Year 2070
# → [STATIC] Year 2070: Final Wealth = 8482834.44
# [STATIC LOOP] Year 2071
# → [STATIC] Year 2071: Final Wealth = 8563492.72
# [STATIC LOOP] Year 2072
# → [STATIC] Year 2072: Final Wealth = 8645815.38
# [STATIC LOOP] Year 2073
# → [STATIC] Year 2073: Final Wealth = 8728233.76
# [STATIC LOOP] Year 2074
# [STATIC DECISION] ✅ Paying Goal A | ΔUtility: 1.000
# → [STATIC] Year 2074: Final Wealth = 1810947.98
# [STATIC LOOP] Year 2075
# → [STATIC] Year 2075: Final Wealth = 8915823.82
#
# ===== END STATIC LOOP =====
