# %% [markdown]
# V1 (02 11 2025): Translated from R to Python and added the visualizations for goals B to D
#
#
# V2 (04 01 2025): Loop system implemented
#
# V2.5 (04 02 2025): Loops system tweaks. Removed openpyxl as it was corrupting files and replaced it with xlwings
#
# V3 & V4 finalize the loop except for the tax and asset channel

# %%
#!pip install numpy pandas scipy matplotlib xlwings

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import subprocess
import xlwings as xw
import time

# %%
# -- Variable Setup -- ##

#Monte Carlo Trials
n_trials = 10**5

#Case Study Profile Selection
Profile = "P1" #Either P1 or P2

#Excel worksheets
excel_returns = "Returns"
excel_volatilities = "Volatilities"
excel_correlation = "Correlation"
excel_gbi = "GBI Allocations P1" if Profile == "P1" else "GBI Allocations P2"
excel_gbi = "GBI Allocations P1" if Profile == "P1" else "GBI Allocations P2"
excel_gbi_goals = "GBI Goals P1" if Profile == "P1" else "GBI Goals P2"

# %% [markdown]
# # Define Functions
# This section defines the functions used for calculating portfolio volatility, expected return,
# goal achievement probability, and the objective (failure probability) to minimize.

# %%
def sd_f(weight_vector, covar_table):
    covar_vector = np.zeros(len(weight_vector))
    for z in range(len(weight_vector)):
        covar_vector[z] = np.sum(weight_vector * covar_table[:, z])
    return np.sqrt(np.sum(weight_vector * covar_vector))

# %%
def mean_f(weight_vector, return_vector):
    return np.sum(weight_vector * return_vector)

# %%
"""def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    # goal_vector is [value ratio, funding requirement, time horizon]
    required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
    if goal_allocation * pool >= goal_vector[1]:
        return 1
    else:
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)

""" #Made new version below that takes into account cases where the goal is too unreachable and writes down when that happens

def phi_f(goal_vector, goal_allocation, pool, mean, sd, year=None, goal_name=None):
    denominator = pool * goal_allocation
    if denominator <= 0:
        if year and goal_name:
            infeasible_goals_log.append((year, goal_name, "Zero allocation or pool"))
        return 0

    required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1

    if required_return > 1:
        if year and goal_name:
            infeasible_goals_log.append((year, goal_name, f"Required return > 100% ({required_return:.2%})"))
        return 0

    if denominator >= goal_vector[1]:
        return 1

    return 1 - norm.cdf(required_return, loc=mean, scale=sd)

# %%
def optim_function(weights):
    # Uses the current global variables: goal_vector, allocation, pool, return_vector, covar_table
    return 1 - phi_f(
        goal_vector,
        allocation,
        pool,
        mean_f(weights, return_vector),
        sd_f(weights, covar_table)
    )

# %%
def constraint_function(weights):
    # For SciPy equality constraints, we require constraint_function(weights) == 0.
    return np.sum(weights) - 1

# %%
def mvu_f(weights):
    # mvu_f is defined for mean-variance optimization (not used below).
    return -(mean_f(weights, return_vector) - 0.5 * gamma * sd_f(weights, covariances)**2)

# %%
def r_req_f(goal_vector, goal_allocation, pool):
    return (goal_vector[1] / (goal_allocation * pool))**(1 / goal_vector[2]) - 1

# %%
def get_goal_data(master_excel_path, plan=Profile):
    """
    Returns a DataFrame of the specified goal table (P1 or P2).
    P1 => B2:F5
    P2 => B7:F10
    """
    if plan == "P1":
        skip = 1  # start reading at row 2
    elif plan == "P2":
        skip = 6  # start reading at row 7
    else:
        raise ValueError("Plan not recognized. Use 'P1' or 'P2'.")

    df_goals = pd.read_excel(master_excel_path,sheet_name="Goals",skiprows=skip,nrows=4,usecols="B:F",header=0)
    # First column is "Goal Info", so make that the index
    df_goals.set_index(df_goals.columns[0], inplace=True)
    return df_goals

# %% [markdown]
# # Load & Parse Data

# %%
## -- Repo Root and Folders -- ##

# Get repo root and set folders
root = subprocess.run(["git", "rev-parse", "--show-toplevel"], capture_output=True, text=True).stdout.strip()
data_folder = os.path.join(root, "GBI Optimisation", "data")
output_folder = os.path.join(root, "GBI Optimisation")

# Get excel file and sheets
master_excel_path = os.path.join(data_folder, "Master.xlsx")

df_returns = pd.read_excel(master_excel_path, sheet_name=excel_returns)
df_vols = pd.read_excel(master_excel_path, sheet_name=excel_volatilities)

df_returns.set_index(df_returns.columns[0], inplace=True)
df_vols.set_index(df_vols.columns[0], inplace=True)

df_corr = pd.read_excel(master_excel_path, sheet_name=excel_correlation)
df_corr.set_index(df_corr.columns[0], inplace=True)

# %%
# - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #

# Initialize tracker for account allocations
all_account_allocations = []

# Aktiesparekonto cap
aktiesparekonto_cap = 166200
aktiesparekonto_used_total = 0

# %%
infeasible_goals_log = [] #Added for the new phi_f definition
tax_log = [] # - V6 - Added for following the tax stuff

while True:
    ## -- Loop Table -- ##
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop",usecols="B:F",skiprows=1,header=0)
    # Find Last looped year and select the next one
    # Filter only rows where LoopStatus is N
    pending_rows = table_loop_df[table_loop_df["LoopStatus"] == "N"]

    # If we find any rows, get the row with the lowest Year
    if pending_rows.empty:
        print("All loops completed")
        break


    chosen_row = pending_rows.loc[pending_rows["Year"].idxmin()]
    loop_year = chosen_row["Year"]
    loop_number = chosen_row["N"]
    loop_age1 = chosen_row["AgeP1"]
    loop_age2 = chosen_row["AgeP2"]

    print(loop_year, loop_number, loop_age1, loop_age2)

    # - Wealth - #

    # Retrieve Wealth value for selected profile and year from "Wealth" sheet
    df_wealth = pd.read_excel(master_excel_path, sheet_name="Salary")
    df_wealth.set_index(df_wealth.columns[0], inplace=True)  # Set P1/P2 as index

    # Use profile and loop_year to get the correct pool value
    try:
        pool = df_wealth.loc[Profile, str(loop_year)]
    except KeyError:
        raise KeyError(f"Wealth data for profile '{Profile}' in year {loop_year} not found.")

    capital_market_expectations_raw = {}
    for asset in df_returns.index:
        expected_return = df_returns.loc[asset, str(loop_year)]
        volatility = df_vols.loc[asset, 'volatility']
        capital_market_expectations_raw[asset] = {
            'Return Forecast': expected_return,
            'Volatility Forecast': volatility
        }

    capital_market_expectations_raw = pd.DataFrame.from_dict(capital_market_expectations_raw, orient='index')

    capital_market_expectations_raw = capital_market_expectations_raw.reset_index()
    capital_market_expectations_raw.rename(columns={'index': 'Unnamed: 0'}, inplace=True)

    # Rearrange columns to match your old format (optional):
    capital_market_expectations_raw = capital_market_expectations_raw[['Unnamed: 0', 'Return Forecast', 'Volatility Forecast']]

    goal_data_raw = get_goal_data(master_excel_path, plan="P1")

    # - Dynamic time horizon based on current year - #

    # Step 1: Get Starting Year (minimum year in Loop sheet)
    starting_year = table_loop_df["Year"].min()

    # Step 2: Compute Goal Years = starting_year + time_horizon
    goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
    goal_years = starting_year + goal_horizons

    # Step 3: Recalculate Time Horizons = goal_years - current loop_year
    adjusted_horizons = goal_years - loop_year

    # Step 4: Replace the "Time Horizon" row in goal_data_raw
    goal_data_raw.loc["Time Horizon"] = adjusted_horizons

    goals = ["A", "B", "C", "D"]
    active_goal_mask = np.array([adjusted_horizons[f"GOAL {g}"] > 0 for g in goals])

    # Optional: print to confirm
    print("Starting Year:", starting_year)
    print("Current Year:", loop_year)
    print("Goal Years:", goal_years.to_dict())
    print("Adjusted Horizons:", adjusted_horizons.to_dict())

    # - NEW V6 CONTENT REGARDING TAXATION # -
    # Track asset values and cost basis
    if loop_year == starting_year:
        portfolio_book = {}  # dict of form {(account_type, asset): [amount_invested, current_value]}
    else:
        # Carry forward previous year values (from last loop)
        portfolio_book = portfolio_book_last_year.copy()
    # - END OF V6 - #

    # Record number of potential investments and goals
    num_assets = capital_market_expectations_raw.shape[0]
    num_goals = goal_data_raw.shape[1]

    # Create vector of expected returns
    return_vector = capital_market_expectations_raw["Return Forecast"].to_numpy()

    # Get the correlations as a numeric DataFrame (just a num_assets × num_assets block)
    correlations = df_corr.iloc[:num_assets, :num_assets].astype(float)

    # Build the covariance matrix: stdev_i * stdev_j * correlation_ij
    stdevs = capital_market_expectations_raw["Volatility Forecast"].to_numpy()
    covariances = np.zeros((num_assets, num_assets))
    for i in range(num_assets):
        for j in range(num_assets):
            covariances[i, j] = stdevs[i] * stdevs[j] * correlations.iloc[i, j]

    goal_A = goal_data_raw["GOAL A"].values
    goal_B = goal_data_raw["GOAL B"].values
    goal_C = goal_data_raw["GOAL C"].values
    goal_D = goal_data_raw["GOAL D"].values

    # - Optimal Goal Allocation - #


    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    # Set SLSQP options to be more stringent, mimicking solnp's behavior.
    slsqp_opts = {
        'ftol': 1e-12,     # function tolerance
        'eps': 1e-12,      # finite-difference step size for gradient estimation
        'maxiter': 10000,  # maximum iterations
        'disp': False     # do not display convergence messages
    }

    for i, alloc in enumerate(goal_allocation):
        allocation = alloc      # Global variable used in optim_function
        covar_table = covariances

        # Goal A Optimization
        goal_vector = goal_A   # Global variable used in optim_function
        if goal_A[1] <= pool * allocation:
            optimal_weights_A[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_A[i, :] = result.x

        # Goal B Optimization
        goal_vector = goal_B
        if goal_B[1] <= pool * allocation:
            optimal_weights_B[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_B[i, :] = result.x

        # Goal C Optimization
        goal_vector = goal_C
        if goal_C[1] <= pool * allocation:
            optimal_weights_C[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_C[i, :] = result.x

        # Goal D Optimization
        goal_vector = goal_D
        if goal_D[1] <= pool * allocation:
            optimal_weights_D[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_D[i, :] = result.x

    # Calculate the best probability (phi) for each allocation level for every goal
    phi_A = np.zeros(len(goal_allocation))
    phi_B = np.zeros(len(goal_allocation))
    phi_C = np.zeros(len(goal_allocation))
    phi_D = np.zeros(len(goal_allocation))

    for i, alloc in enumerate(goal_allocation):
        phi_A[i] = phi_f(goal_A, alloc, pool,
                         mean_f(optimal_weights_A[i, :], return_vector),
                         sd_f(optimal_weights_A[i, :], covariances), year=loop_year, goal_name="Goal A")
        phi_B[i] = phi_f(goal_B, alloc, pool,
                         mean_f(optimal_weights_B[i, :], return_vector),
                         sd_f(optimal_weights_B[i, :], covariances), year=loop_year, goal_name="Goal B")
        phi_C[i] = phi_f(goal_C, alloc, pool,
                         mean_f(optimal_weights_C[i, :], return_vector),
                         sd_f(optimal_weights_C[i, :], covariances), year=loop_year, goal_name="Goal C")
        phi_D[i] = phi_f(goal_D, alloc, pool,
                         mean_f(optimal_weights_D[i, :], return_vector),
                         sd_f(optimal_weights_D[i, :], covariances), year=loop_year, goal_name="Goal D")

    # Simulate goal weights: each row is a simulated allocation (in percentages)
    sim_goal_weights = np.random.multinomial(100, [1/num_goals]*num_goals, size=n_trials) #this one sums to 100 so its good
    for i in range(n_trials):
        rand_vector = np.random.uniform(0, 1, num_goals)
        normalizer = np.sum(rand_vector)
        percents = np.round((rand_vector / normalizer) * 100, 0)

        # Only enforce floor for active goals
        floor_applied = np.where(active_goal_mask, np.maximum(percents, 1), percents)
        sim_goal_weights[i, :] = floor_applied


    # Calculate utility for each simulated portfolio.
    # Note: subtract 1 from simulated weights for 0-indexing.
    utility = (
        goal_A[0] * phi_A[sim_goal_weights[:, 0] - 1] +
        goal_A[0] * goal_B[0] * phi_B[sim_goal_weights[:, 1] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * phi_C[sim_goal_weights[:, 2] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * goal_D[0] * phi_D[sim_goal_weights[:, 3] - 1]
    )

    # Find the index of the portfolio with the highest utility
    index = np.argmax(utility)
    optimal_goal_weights = sim_goal_weights[index, :]

    # - Optimal Subportfolio Allocation - #

    # Retrieve optimal subportfolio allocations
    optimal_subportfolios = np.zeros((num_goals, num_assets))

    # For each goal, use the simulated percentage to select the corresponding row
    # from the optimal weights matrix (adjust for zero-indexing)
    for i in range(num_goals):
        optimal_subportfolios[i, :] = eval(f"optimal_weights_{goals[i]}")[optimal_goal_weights[i] - 1, :]

    # Compute the optimal aggregate investment portfolio.
    optimal_aggregate_portfolio = (optimal_goal_weights / 100) @ optimal_subportfolios

    #Define asset names
    asset_names = capital_market_expectations_raw.iloc[:, 0].astype(str).tolist()

    # - Storing and exporting results - #

    # Create a DataFrame for the aggregate portfolio.
    # First calculate unrounded percentages
    raw_alloc = optimal_aggregate_portfolio * 100

    # Normalize to force sum = 100 after rounding
    normalized_alloc = raw_alloc / raw_alloc.sum() * 100
    normalized_goal_alloc = np.zeros_like(optimal_goal_weights, dtype=float)
    active_sum = np.sum(optimal_goal_weights[active_goal_mask])
    normalized_goal_alloc[active_goal_mask] = (optimal_goal_weights[active_goal_mask] / active_sum) * 100

    # Create a DataFrame for the across-goal allocation.
    df_across_goal = pd.DataFrame({
        "Goal": goals,
        "Allocation (%)": np.round(normalized_goal_alloc, 2) # Keep raw percentages
    })

    # Round after normalization
    df_aggregate = pd.DataFrame({
        "Asset": asset_names,
        "Weight": optimal_aggregate_portfolio,
        "Allocation (%)": np.round(normalized_alloc, 2)
    })

    # - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #
    account_allocations = []

    for i, row in df_aggregate.iterrows():
        asset_name = row["Asset"]
        weight = row["Weight"]
        allocation_value = weight * pool  # actual money invested this year

        if "Equities" in asset_name:
            remaining_cap = aktiesparekonto_cap - aktiesparekonto_used_total
            if remaining_cap > 0:
                invested_in_ask = min(allocation_value, remaining_cap)
                invested_in_normal = allocation_value - invested_in_ask
                aktiesparekonto_used_total += invested_in_ask
            else:
                invested_in_ask = 0
                invested_in_normal = allocation_value
        else:
            invested_in_ask = 0
            invested_in_normal = allocation_value

        account_allocations.append({
            "Year": loop_year,
            "Asset": asset_name,
            "ASK (DKK)": invested_in_ask,
            "Normal (DKK)": invested_in_normal
        })

    df_accounts = pd.DataFrame(account_allocations)
    all_account_allocations.append(df_accounts)

    # - V5 END - #

    # - NEW V6 CONTENT REGARDING GAINS & TAXES - #

    total_gains_ask = 0
    total_gains_normal = 0
    share_income_normal = 0  # for progressive tax
    tax_ask = 0  # Track ASK tax separately

    # Update portfolio and compute gains
    for row in account_allocations:
        asset = row["Asset"]
        ask = row["ASK (DKK)"]
        normal = row["Normal (DKK)"]
        expected_return = capital_market_expectations_raw.loc[
            capital_market_expectations_raw["Unnamed: 0"] == asset,
            "Return Forecast"
        ].values[0]

        # Aktiesparekonto
        if ask > 0:
            prev_amt, prev_val = portfolio_book.get(("ASK", asset), [0, 0])
            new_val = prev_val * (1 + expected_return) + ask
            gain = new_val - (prev_val + ask)
            tax = 0.17 * gain
            tax_ask += tax
            total_gains_ask += (gain - tax)
            portfolio_book[("ASK", asset)] = [ask, new_val]

        # Normal Account
        if normal > 0:
            prev_amt, prev_val = portfolio_book.get(("NORMAL", asset), [0, 0])
            new_val = prev_val * (1 + expected_return) + normal
            gain = new_val - (prev_val + normal)
            share_income_normal += gain
            portfolio_book[("NORMAL", asset)] = [normal, new_val]

    # Tax on Normal Account (progressive)
    cap = 67500
    if share_income_normal <= cap:
        tax_normal = 0.27 * share_income_normal
    else:
        tax_normal = 0.27 * cap + 0.42 * (share_income_normal - cap)
    total_gains_normal = share_income_normal - tax_normal

    # Adjust wealth by net gains
    net_gains = total_gains_ask + total_gains_normal
    pool += net_gains

    tax_log.append({
        "Year": loop_year,
        "Gains ASK (gross)": total_gains_ask + tax_ask,
        "Tax ASK": tax_ask,
        "Gains Normal (gross)": share_income_normal,
        "Tax Normal": tax_normal,
        "Net Gains": net_gains,
        "Post-Tax Wealth": pool
    })

    # - END OF V6 GAINS/TAX BLOCK - #

    print("Optimal Across-Goal Allocation:")
    print(df_across_goal.to_string(index=False))

    print("\nOptimal Aggregate Investment Allocation:")
    print(df_aggregate.to_string(index=False))

    # -- Safer Excel launch --
    app = xw.App(visible=False)
    app.display_alerts = False
    app.screen_updating = False

    time.sleep(1)

    # Open workbook
    wb = app.books.open(master_excel_path)
    ws = wb.sheets[excel_gbi]

    # Get header values from row 1 (columns B to AY ~= cols 2 to 51)
    header_values = [ws.cells(1, col).value for col in range(2, 53)]

    try:
        year_col = header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in worksheet headers.")

    # Write weights
    for i, asset in enumerate(asset_names):
        allocation = float(np.round(normalized_alloc[i], 2)) / 100
        cell = ws.cells(i + 2, year_col)
        cell.value = allocation
        cell.number_format = '0.00%'  # display as percentage

    # -- Export Goal Weights to Excel -- #

    # Re-access the sheet after workbook is open
    ws_goals = wb.sheets[excel_gbi_goals]

    # Read header values from row 1 (columns B to AY ≈ cols 2 to 52)
    goal_header_values = [ws_goals.cells(1, col).value for col in range(2, 53)]

    try:
        goal_year_col = goal_header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in goal worksheet headers.")

    # Write each across-goal allocation to the appropriate row
    for i, allocation in enumerate(df_across_goal["Allocation (%)"]):
        value = float(np.round(allocation / 100, 6))  # convert to decimal
        row = i + 2  # assuming goal names are in rows starting at 2
        cell = ws_goals.cells(row, goal_year_col)
        cell.value = value
        cell.number_format = '0.00%'  # display as percentage

    # -- Modify Loop Check -- #
    print("Starting loop status check...")

    ws_loop = wb.sheets["Loop"]
    print("Accessed 'Loop' worksheet.")

    # Read data range again (columns B to F)
    last_row = ws_loop.cells.last_cell.row
    print(f"Last cell row: {last_row}")

    loop_data = ws_loop.range("B2:F" + str(last_row)).value
    print(f"Loaded loop data. Total rows read: {len(loop_data)}")

    # Find and update the matching year with LoopStatus 'N'
    found = False
    for i, row in enumerate(loop_data):
        year = row[1]
        status = row[4]
        print(f"Row {i+2}: Year = {year}, Status = {status}")
        if year == loop_year and status == 'N':
            print(f"Match found at row {i+2}. Updating status to 'Y'.")
            ws_loop.cells(i + 2, 6).value = 'Y'  # Column F is column 6
            found = True
            break

    if not found:
        print(f"No matching row found for year {loop_year} with status 'N'.")
    else:
        print("Status updated successfully.")

    wb.save()
    wb.close()
    app.quit()
    time.sleep(1)
    portfolio_book_last_year = portfolio_book.copy() # - V6 - Save portfolio state for next iteration
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop", usecols="B:F", skiprows=1, header=0)
# Out:
# 2025 1 25 40
# Starting Year: 2025
# Current Year: 2025
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 10, 'GOAL B': 15, 'GOAL C': 20, 'GOAL D': 45}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            22.0
#    B            44.0
#    C            11.0
#    D            23.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.289314           28.93
#         Developed Markets - Equities 0.285208           28.52
# Emerging Markets State - Obligations 0.051609            5.16
#       High Yield Bonds - Obligations 0.235399           23.54
# Investment Grade Bonds - Obligations 0.061644            6.16
#    Government ZC Bonds - Obligations 0.076826            7.68
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = N
# Match found at row 3. Updating status to 'Y'.
# Status updated successfully.
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 9, 'GOAL B': 14, 'GOAL C': 19, 'GOAL D': 44}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.99
#    B           92.08
#    C            2.97
#    D            3.96
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.639081           63.28
#         Developed Markets - Equities 0.092790            9.19
# Emerging Markets State - Obligations 0.015897            1.57
#       High Yield Bonds - Obligations 0.003681            0.36
# Investment Grade Bonds - Obligations 0.254388           25.19
#    Government ZC Bonds - Obligations 0.004164            0.41
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = N
# Match found at row 4. Updating status to 'Y'.
# Status updated successfully.
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 8, 'GOAL B': 13, 'GOAL C': 18, 'GOAL D': 43}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             1.0
#    B            97.0
#    C             1.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.650568           65.06
#         Developed Markets - Equities 0.127520           12.75
# Emerging Markets State - Obligations 0.006446            0.64
#       High Yield Bonds - Obligations 0.000088            0.01
# Investment Grade Bonds - Obligations 0.209141           20.91
#    Government ZC Bonds - Obligations 0.006237            0.62
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = N
# Match found at row 5. Updating status to 'Y'.
# Status updated successfully.
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 7, 'GOAL B': 12, 'GOAL C': 17, 'GOAL D': 42}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.98
#    B           94.12
#    C            0.98
#    D            3.92
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.452862           44.40
#         Developed Markets - Equities 0.067007            6.57
# Emerging Markets State - Obligations 0.006599            0.65
#       High Yield Bonds - Obligations 0.061661            6.05
# Investment Grade Bonds - Obligations 0.429905           42.15
#    Government ZC Bonds - Obligations 0.001967            0.19
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = N
# Match found at row 6. Updating status to 'Y'.
# Status updated successfully.
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 6, 'GOAL B': 11, 'GOAL C': 16, 'GOAL D': 41}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.99
#    B           95.05
#    C            2.97
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.459910           45.54
#         Developed Markets - Equities 0.006572            0.65
# Emerging Markets State - Obligations 0.023585            2.34
#       High Yield Bonds - Obligations 0.079375            7.86
# Investment Grade Bonds - Obligations 0.425363           42.12
#    Government ZC Bonds - Obligations 0.015194            1.50
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = N
# Match found at row 7. Updating status to 'Y'.
# Status updated successfully.
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 5, 'GOAL B': 10, 'GOAL C': 15, 'GOAL D': 40}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.98
#    B           97.06
#    C            0.98
#    D            0.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.348796           34.20
#         Developed Markets - Equities 0.018034            1.77
# Emerging Markets State - Obligations 0.009440            0.93
#       High Yield Bonds - Obligations 0.212815           20.86
# Investment Grade Bonds - Obligations 0.421207           41.29
#    Government ZC Bonds - Obligations 0.009708            0.95
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = N
# Match found at row 8. Updating status to 'Y'.
# Status updated successfully.
# 2031 7 31 46
# Starting Year: 2025
# Current Year: 2031
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 4, 'GOAL B': 9, 'GOAL C': 14, 'GOAL D': 39}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            1.98
#    B           94.06
#    C            1.98
#    D            1.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.401394           39.74
#         Developed Markets - Equities 0.012303            1.22
# Emerging Markets State - Obligations 0.002956            0.29
#       High Yield Bonds - Obligations 0.369257           36.56
# Investment Grade Bonds - Obligations 0.206784           20.47
#    Government ZC Bonds - Obligations 0.017306            1.71
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = N
# Match found at row 9. Updating status to 'Y'.
# Status updated successfully.
# 2032 8 32 47
# Starting Year: 2025
# Current Year: 2032
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 3, 'GOAL B': 8, 'GOAL C': 13, 'GOAL D': 38}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            1.98
#    B           95.05
#    C            0.99
#    D            1.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.278333           27.56
#         Developed Markets - Equities 0.003116            0.31
# Emerging Markets State - Obligations 0.010291            1.02
#       High Yield Bonds - Obligations 0.230602           22.83
# Investment Grade Bonds - Obligations 0.475773           47.11
#    Government ZC Bonds - Obligations 0.011886            1.18
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = N
# Match found at row 10. Updating status to 'Y'.
# Status updated successfully.
# 2033 9 33 48
# Starting Year: 2025
# Current Year: 2033
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 2, 'GOAL B': 7, 'GOAL C': 12, 'GOAL D': 37}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             2.0
#    B            94.0
#    C             3.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.257036           25.70
#         Developed Markets - Equities 0.065896            6.59
# Emerging Markets State - Obligations 0.011867            1.19
#       High Yield Bonds - Obligations 0.248556           24.86
# Investment Grade Bonds - Obligations 0.397540           39.75
#    Government ZC Bonds - Obligations 0.019104            1.91
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = N
# Match found at row 11. Updating status to 'Y'.
# Status updated successfully.
# 2034 10 34 49
# Starting Year: 2025
# Current Year: 2034
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 1, 'GOAL B': 6, 'GOAL C': 11, 'GOAL D': 36}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            3.03
#    B           93.94
#    C            2.02
#    D            1.01
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.207131           20.92
#         Developed Markets - Equities 0.197393           19.94
# Emerging Markets State - Obligations 0.001885            0.19
#       High Yield Bonds - Obligations 0.308240           31.14
# Investment Grade Bonds - Obligations 0.266714           26.94
#    Government ZC Bonds - Obligations 0.008637            0.87
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = N
# Match found at row 12. Updating status to 'Y'.
# Status updated successfully.
# 2035 11 35 50
# Starting Year: 2025
# Current Year: 2035
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': 0, 'GOAL B': 5, 'GOAL C': 10, 'GOAL D': 35}
# C:\Users\admin\AppData\Local\Temp\ipykernel_22828\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B           95.83
#    C            2.08
#    D            2.08
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.144227           14.57
#         Developed Markets - Equities 0.370831           37.46
# Emerging Markets State - Obligations 0.015268            1.54
#       High Yield Bonds - Obligations 0.428633           43.30
# Investment Grade Bonds - Obligations 0.010145            1.02
#    Government ZC Bonds - Obligations 0.020896            2.11
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = N
# Match found at row 13. Updating status to 'Y'.
# Status updated successfully.
# 2036 12 36 51
# Starting Year: 2025
# Current Year: 2036
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -1, 'GOAL B': 4, 'GOAL C': 9, 'GOAL D': 34}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B           95.92
#    C            2.04
#    D            2.04
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.176832           17.68
#         Developed Markets - Equities 0.081756            8.18
# Emerging Markets State - Obligations 0.004007            0.40
#       High Yield Bonds - Obligations 0.013077            1.31
# Investment Grade Bonds - Obligations 0.281598           28.16
#    Government ZC Bonds - Obligations 0.442731           44.27
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = N
# Match found at row 14. Updating status to 'Y'.
# Status updated successfully.
# 2037 13 37 52
# Starting Year: 2025
# Current Year: 2037
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -2, 'GOAL B': 3, 'GOAL C': 8, 'GOAL D': 33}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B           97.96
#    C            1.02
#    D            1.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.152706           15.12
#         Developed Markets - Equities 0.090263            8.94
# Emerging Markets State - Obligations 0.003054            0.30
#       High Yield Bonds - Obligations 0.000526            0.05
# Investment Grade Bonds - Obligations 0.236811           23.45
#    Government ZC Bonds - Obligations 0.526639           52.14
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = N
# Match found at row 15. Updating status to 'Y'.
# Status updated successfully.
# 2038 14 38 53
# Starting Year: 2025
# Current Year: 2038
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -3, 'GOAL B': 2, 'GOAL C': 7, 'GOAL D': 32}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B           94.06
#    C            0.99
#    D            4.95
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.148609           14.71
#         Developed Markets - Equities 0.094670            9.37
# Emerging Markets State - Obligations 0.005786            0.57
#       High Yield Bonds - Obligations 0.013943            1.38
# Investment Grade Bonds - Obligations 0.224310           22.21
#    Government ZC Bonds - Obligations 0.522682           51.75
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = N
# Match found at row 16. Updating status to 'Y'.
# Status updated successfully.
# 2039 15 39 54
# Starting Year: 2025
# Current Year: 2039
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -4, 'GOAL B': 1, 'GOAL C': 6, 'GOAL D': 31}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B           97.03
#    C            1.98
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.005781            0.57
#         Developed Markets - Equities 0.006558            0.65
# Emerging Markets State - Obligations 0.002906            0.29
#       High Yield Bonds - Obligations 0.003972            0.39
# Investment Grade Bonds - Obligations 0.006299            0.62
#    Government ZC Bonds - Obligations 0.984484           97.47
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = N
# Match found at row 17. Updating status to 'Y'.
# Status updated successfully.
# 2040 16 40 55
# Starting Year: 2025
# Current Year: 2040
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -5, 'GOAL B': 0, 'GOAL C': 5, 'GOAL D': 30}
# C:\Users\admin\AppData\Local\Temp\ipykernel_22828\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C            8.25
#    D           91.75
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.002248            0.22
#         Developed Markets - Equities 0.928278           92.83
# Emerging Markets State - Obligations 0.005286            0.53
#       High Yield Bonds - Obligations 0.018694            1.87
# Investment Grade Bonds - Obligations 0.038994            3.90
#    Government ZC Bonds - Obligations 0.006500            0.65
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = N
# Match found at row 18. Updating status to 'Y'.
# Status updated successfully.
# 2041 17 41 56
# Starting Year: 2025
# Current Year: 2041
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -6, 'GOAL B': -1, 'GOAL C': 4, 'GOAL D': 29}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C            1.02
#    D           98.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.976314           96.66
#         Developed Markets - Equities 0.005952            0.59
# Emerging Markets State - Obligations 0.003427            0.34
#       High Yield Bonds - Obligations 0.007464            0.74
# Investment Grade Bonds - Obligations 0.013898            1.38
#    Government ZC Bonds - Obligations 0.002945            0.29
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = N
# Match found at row 19. Updating status to 'Y'.
# Status updated successfully.
# 2042 18 42 57
# Starting Year: 2025
# Current Year: 2042
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -7, 'GOAL B': -2, 'GOAL C': 3, 'GOAL D': 28}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C            2.06
#    D           97.94
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.964809           96.48
#         Developed Markets - Equities 0.008513            0.85
# Emerging Markets State - Obligations 0.000160            0.02
#       High Yield Bonds - Obligations 0.011372            1.14
# Investment Grade Bonds - Obligations 0.001715            0.17
#    Government ZC Bonds - Obligations 0.013432            1.34
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = N
# Match found at row 20. Updating status to 'Y'.
# Status updated successfully.
# 2043 19 43 58
# Starting Year: 2025
# Current Year: 2043
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -8, 'GOAL B': -3, 'GOAL C': 2, 'GOAL D': 27}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             5.1
#    D            94.9
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.947297           93.79
#         Developed Markets - Equities 0.007893            0.78
# Emerging Markets State - Obligations 0.007710            0.76
#       High Yield Bonds - Obligations 0.021372            2.12
# Investment Grade Bonds - Obligations 0.020081            1.99
#    Government ZC Bonds - Obligations 0.005647            0.56
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = N
# Match found at row 21. Updating status to 'Y'.
# Status updated successfully.
# 2044 20 44 59
# Starting Year: 2025
# Current Year: 2044
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -9, 'GOAL B': -4, 'GOAL C': 1, 'GOAL D': 26}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C            1.08
#    D           98.92
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.000840            0.08
#         Developed Markets - Equities 0.937657           94.71
# Emerging Markets State - Obligations 0.024438            2.47
#       High Yield Bonds - Obligations 0.005452            0.55
# Investment Grade Bonds - Obligations 0.016448            1.66
#    Government ZC Bonds - Obligations 0.005165            0.52
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = N
# Match found at row 22. Updating status to 'Y'.
# Status updated successfully.
# 2045 21 45 60
# Starting Year: 2025
# Current Year: 2045
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -10, 'GOAL B': -5, 'GOAL C': 0, 'GOAL D': 25}
# C:\Users\admin\AppData\Local\Temp\ipykernel_22828\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.967102           96.71
#         Developed Markets - Equities 0.007397            0.74
# Emerging Markets State - Obligations 0.002951            0.30
#       High Yield Bonds - Obligations 0.003388            0.34
# Investment Grade Bonds - Obligations 0.010798            1.08
#    Government ZC Bonds - Obligations 0.008364            0.84
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = N
# Match found at row 23. Updating status to 'Y'.
# Status updated successfully.
# 2046 22 46 61
# Starting Year: 2025
# Current Year: 2046
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -11, 'GOAL B': -6, 'GOAL C': -1, 'GOAL D': 24}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.944349           94.43
#         Developed Markets - Equities 0.008189            0.82
# Emerging Markets State - Obligations 0.010664            1.07
#       High Yield Bonds - Obligations 0.014010            1.40
# Investment Grade Bonds - Obligations 0.001276            0.13
#    Government ZC Bonds - Obligations 0.021511            2.15
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = N
# Match found at row 24. Updating status to 'Y'.
# Status updated successfully.
# 2047 23 47 62
# Starting Year: 2025
# Current Year: 2047
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -12, 'GOAL B': -7, 'GOAL C': -2, 'GOAL D': 23}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.976461           97.65
#         Developed Markets - Equities 0.006173            0.62
# Emerging Markets State - Obligations 0.001426            0.14
#       High Yield Bonds - Obligations 0.006084            0.61
# Investment Grade Bonds - Obligations 0.001784            0.18
#    Government ZC Bonds - Obligations 0.008072            0.81
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = N
# Match found at row 25. Updating status to 'Y'.
# Status updated successfully.
# 2048 24 48 63
# Starting Year: 2025
# Current Year: 2048
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -13, 'GOAL B': -8, 'GOAL C': -3, 'GOAL D': 22}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.965354           96.54
#         Developed Markets - Equities 0.003875            0.39
# Emerging Markets State - Obligations 0.012636            1.26
#       High Yield Bonds - Obligations 0.008926            0.89
# Investment Grade Bonds - Obligations 0.000500            0.05
#    Government ZC Bonds - Obligations 0.008709            0.87
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = N
# Match found at row 26. Updating status to 'Y'.
# Status updated successfully.
# 2049 25 49 64
# Starting Year: 2025
# Current Year: 2049
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -14, 'GOAL B': -9, 'GOAL C': -4, 'GOAL D': 21}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.946107           94.61
#         Developed Markets - Equities 0.021244            2.12
# Emerging Markets State - Obligations 0.004176            0.42
#       High Yield Bonds - Obligations 0.001519            0.15
# Investment Grade Bonds - Obligations 0.021270            2.13
#    Government ZC Bonds - Obligations 0.005684            0.57
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = N
# Match found at row 27. Updating status to 'Y'.
# Status updated successfully.
# 2050 26 50 65
# Starting Year: 2025
# Current Year: 2050
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -15, 'GOAL B': -10, 'GOAL C': -5, 'GOAL D': 20}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.161995           16.20
#         Developed Markets - Equities 0.023836            2.38
# Emerging Markets State - Obligations 0.286739           28.67
#       High Yield Bonds - Obligations 0.070271            7.03
# Investment Grade Bonds - Obligations 0.255754           25.58
#    Government ZC Bonds - Obligations 0.201405           20.14
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = N
# Match found at row 28. Updating status to 'Y'.
# Status updated successfully.
# 2051 27 51 66
# Starting Year: 2025
# Current Year: 2051
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -16, 'GOAL B': -11, 'GOAL C': -6, 'GOAL D': 19}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.141733           14.17
#         Developed Markets - Equities 0.178919           17.89
# Emerging Markets State - Obligations 0.035415            3.54
#       High Yield Bonds - Obligations 0.245145           24.51
# Investment Grade Bonds - Obligations 0.234080           23.41
#    Government ZC Bonds - Obligations 0.164709           16.47
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = N
# Match found at row 29. Updating status to 'Y'.
# Status updated successfully.
# 2052 28 52 67
# Starting Year: 2025
# Current Year: 2052
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -17, 'GOAL B': -12, 'GOAL C': -7, 'GOAL D': 18}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.281574           28.16
#         Developed Markets - Equities 0.047027            4.70
# Emerging Markets State - Obligations 0.199337           19.93
#       High Yield Bonds - Obligations 0.083092            8.31
# Investment Grade Bonds - Obligations 0.174653           17.47
#    Government ZC Bonds - Obligations 0.214317           21.43
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = N
# Match found at row 30. Updating status to 'Y'.
# Status updated successfully.
# 2053 29 53 68
# Starting Year: 2025
# Current Year: 2053
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -18, 'GOAL B': -13, 'GOAL C': -8, 'GOAL D': 17}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.247537           25.00
#         Developed Markets - Equities 0.305020           30.81
# Emerging Markets State - Obligations 0.253319           25.59
#       High Yield Bonds - Obligations 0.019726            1.99
# Investment Grade Bonds - Obligations 0.023005            2.32
#    Government ZC Bonds - Obligations 0.141393           14.28
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = N
# Match found at row 31. Updating status to 'Y'.
# Status updated successfully.
# 2054 30 54 69
# Starting Year: 2025
# Current Year: 2054
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -19, 'GOAL B': -14, 'GOAL C': -9, 'GOAL D': 16}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.231946           23.43
#         Developed Markets - Equities 0.232473           23.48
# Emerging Markets State - Obligations 0.015428            1.56
#       High Yield Bonds - Obligations 0.298685           30.17
# Investment Grade Bonds - Obligations 0.055737            5.63
#    Government ZC Bonds - Obligations 0.155731           15.73
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = N
# Match found at row 32. Updating status to 'Y'.
# Status updated successfully.
# 2055 31 55 70
# Starting Year: 2025
# Current Year: 2055
# ...
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.082574            8.18
#         Developed Markets - Equities 0.023744            2.35
# Emerging Markets State - Obligations 0.180217           17.84
#       High Yield Bonds - Obligations 0.110225           10.91
# Investment Grade Bonds - Obligations 0.077319            7.66
#    Government ZC Bonds - Obligations 0.535921           53.06
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = N
# Match found at row 48. Updating status to 'Y'.
# Status updated successfully.
# 2071 47 71 86
# Starting Year: 2025
# Current Year: 2071
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -36, 'GOAL B': -31, 'GOAL C': -26, 'GOAL D': -1}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.186871           18.69
#         Developed Markets - Equities 0.324075           32.41
# Emerging Markets State - Obligations 0.136852           13.69
#       High Yield Bonds - Obligations 0.016388            1.64
# Investment Grade Bonds - Obligations 0.331940           33.19
#    Government ZC Bonds - Obligations 0.003875            0.39
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = N
# Match found at row 49. Updating status to 'Y'.
# Status updated successfully.
# 2072 48 72 87
# Starting Year: 2025
# Current Year: 2072
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -37, 'GOAL B': -32, 'GOAL C': -27, 'GOAL D': -2}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.055591            5.56
#         Developed Markets - Equities 0.192505           19.25
# Emerging Markets State - Obligations 0.190979           19.10
#       High Yield Bonds - Obligations 0.124227           12.42
# Investment Grade Bonds - Obligations 0.219711           21.97
#    Government ZC Bonds - Obligations 0.216987           21.70
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = N
# Match found at row 50. Updating status to 'Y'.
# Status updated successfully.
# 2073 49 73 88
# Starting Year: 2025
# Current Year: 2073
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -38, 'GOAL B': -33, 'GOAL C': -28, 'GOAL D': -3}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.110869           10.98
#         Developed Markets - Equities 0.243897           24.15
# Emerging Markets State - Obligations 0.138385           13.70
#       High Yield Bonds - Obligations 0.244369           24.19
# Investment Grade Bonds - Obligations 0.081094            8.03
#    Government ZC Bonds - Obligations 0.191387           18.95
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = N
# Match found at row 51. Updating status to 'Y'.
# Status updated successfully.
# 2074 50 74 89
# Starting Year: 2025
# Current Year: 2074
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2070}
# Adjusted Horizons: {'GOAL A': -39, 'GOAL B': -34, 'GOAL C': -29, 'GOAL D': -4}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.197759           19.98
#         Developed Markets - Equities 0.217139           21.93
# Emerging Markets State - Obligations 0.191796           19.37
#       High Yield Bonds - Obligations 0.054335            5.49
# Investment Grade Bonds - Obligations 0.085016            8.59
#    Government ZC Bonds - Obligations 0.243954           24.64
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = Y
# Row 52: Year = 2074.0, Status = N
# Match found at row 52. Updating status to 'Y'.
# Status updated successfully.
# 2075 51 75 90
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\Thesis\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2075'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 33
#      32 try:
# ---> 33     pool = df_wealth.loc[Profile, str(loop_year)]
#      34 except KeyError:
#
# File ~\anaconda3\envs\Thesis\Lib\site-packages\pandas\core\indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1182 if self._is_scalar_access(key):
# -> 1183     return self.obj._get_value(*key, takeable=self._takeable)
#    1184 return self._getitem_tuple(key)
#
# File ~\anaconda3\envs\Thesis\Lib\site-packages\pandas\core\frame.py:4214, in DataFrame._get_value(self, index, col, takeable)
#    4212     return series._values[index]
# -> 4214 series = self._get_item_cache(col)
#    4215 engine = self.index._engine
#
# File ~\anaconda3\envs\Thesis\Lib\site-packages\pandas\core\frame.py:4638, in DataFrame._get_item_cache(self, item)
#    4634 if res is None:
#    4635     # All places that call _get_item_cache have unique columns,
#    4636     #  pending resolution of GH#33047
# -> 4638     loc = self.columns.get_loc(item)
#    4639     res = self._ixs(loc, axis=1)
#
# File ~\anaconda3\envs\Thesis\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: '2075'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 35
#      33     pool = df_wealth.loc[Profile, str(loop_year)]
#      34 except KeyError:
# ---> 35     raise KeyError(f"Wealth data for profile '{Profile}' in year {loop_year} not found.")
#      37 capital_market_expectations_raw = {}
#      38 for asset in df_returns.index:
#
# KeyError: "Wealth data for profile 'P1' in year 2075 not found."

# %%
# - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #
final_accounts_df = pd.concat(all_account_allocations, ignore_index=True)
final_accounts_df.to_csv(os.path.join(output_folder, "account_allocations_log.csv"), index=False)

# %%
# V6 Export
pd.DataFrame(tax_log).to_csv(os.path.join(output_folder, "tax_log.csv"), index=False)

# %%
if infeasible_goals_log:
    print("\n⚠️ Infeasible goal scenarios encountered:")
    for year, goal, reason in infeasible_goals_log:
        print(f" - Year {year}, Goal {goal}: {reason}")

    # Optional: write to CSV
    pd.DataFrame(infeasible_goals_log, columns=["Year", "Goal", "Reason"]).to_csv(
        os.path.join(output_folder, "infeasible_goals_log.csv"), index=False)
else:
    print("\n✅ No infeasible goals encountered.")
# Out:
# ⚠️ Infeasible goal scenarios encountered:
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2025, Goal Goal A: Zero allocation or pool
#  - Year 2025, Goal Goal B: Zero allocation or pool
#  - Year 2025, Goal Goal C: Zero allocation or pool
#  - Year 2025, Goal Goal D: Zero allocation or pool
#  - Year 2026, Goal Goal A: Required return > 100% (108.97%)
#  - Year 2027, Goal Goal A: Required return > 100% (128.85%)
#  - Year 2027, Goal Goal A: Required return > 100% (109.85%)
#  - Year 2028, Goal Goal A: Required return > 100% (153.77%)
#  - Year 2028, Goal Goal A: Required return > 100% (129.84%)
#  - Year 2028, Goal Goal A: Required return > 100% (116.91%)
#  - Year 2028, Goal Goal A: Required return > 100% (108.17%)
#  - Year 2028, Goal Goal A: Required return > 100% (101.64%)
#  - Year 2029, Goal Goal A: Required return > 100% (195.88%)
#  - Year 2029, Goal Goal A: Required return > 100% (163.60%)
#  - Year 2029, Goal Goal A: Required return > 100% (146.38%)
#  - Year 2029, Goal Goal A: Required return > 100% (134.84%)
#  - Year 2029, Goal Goal A: Required return > 100% (126.27%)
#  - Year 2029, Goal Goal A: Required return > 100% (119.50%)
#  - Year 2029, Goal Goal A: Required return > 100% (113.93%)
#  - Year 2029, Goal Goal A: Required return > 100% (109.22%)
#  - Year 2029, Goal Goal A: Required return > 100% (105.16%)
#  - Year 2029, Goal Goal A: Required return > 100% (101.58%)
#  - Year 2030, Goal Goal A: Required return > 100% (266.85%)
#  - Year 2030, Goal Goal A: Required return > 100% (219.36%)
#  - Year 2030, Goal Goal A: Required return > 100% (194.48%)
#  - Year 2030, Goal Goal A: Required return > 100% (178.02%)
#  - Year 2030, Goal Goal A: Required return > 100% (165.88%)
#  - Year 2030, Goal Goal A: Required return > 100% (156.36%)
#  - Year 2030, Goal Goal A: Required return > 100% (148.58%)
#  - Year 2030, Goal Goal A: Required return > 100% (142.03%)
#  - Year 2030, Goal Goal A: Required return > 100% (136.39%)
#  - Year 2030, Goal Goal A: Required return > 100% (131.46%)
#  - Year 2030, Goal Goal A: Required return > 100% (127.09%)
#  - Year 2030, Goal Goal A: Required return > 100% (123.18%)
#  - Year 2030, Goal Goal A: Required return > 100% (119.63%)
#  - Year 2030, Goal Goal A: Required return > 100% (116.40%)
#  - Year 2030, Goal Goal A: Required return > 100% (113.43%)
#  - Year 2030, Goal Goal A: Required return > 100% (110.70%)
#  - Year 2030, Goal Goal A: Required return > 100% (108.16%)
#  - Year 2030, Goal Goal A: Required return > 100% (105.79%)
#  - Year 2030, Goal Goal A: Required return > 100% (103.58%)
#  - Year 2030, Goal Goal A: Required return > 100% (101.50%)
#  - Year 2031, Goal Goal A: Required return > 100% (406.43%)
#  - Year 2031, Goal Goal A: Required return > 100% (325.86%)
#  - Year 2031, Goal Goal A: Required return > 100% (284.81%)
#  - Year 2031, Goal Goal A: Required return > 100% (258.10%)
#  - Year 2031, Goal Goal A: Required return > 100% (238.67%)
#  - Year 2031, Goal Goal A: Required return > 100% (223.58%)
#  - Year 2031, Goal Goal A: Required return > 100% (211.35%)
#  - Year 2031, Goal Goal A: Required return > 100% (201.13%)
#  - Year 2031, Goal Goal A: Required return > 100% (192.39%)
#  - Year 2031, Goal Goal A: Required return > 100% (184.79%)
#  - Year 2031, Goal Goal A: Required return > 100% (178.08%)
#  - Year 2031, Goal Goal A: Required return > 100% (172.10%)
#  - Year 2031, Goal Goal A: Required return > 100% (166.71%)
#  - Year 2031, Goal Goal A: Required return > 100% (161.81%)
#  - Year 2031, Goal Goal A: Required return > 100% (157.34%)
#  - Year 2031, Goal Goal A: Required return > 100% (153.22%)
#  - Year 2031, Goal Goal A: Required return > 100% (149.41%)
#  - Year 2031, Goal Goal A: Required return > 100% (145.87%)
#  - Year 2031, Goal Goal A: Required return > 100% (142.57%)
#  - Year 2031, Goal Goal A: Required return > 100% (139.48%)
#  - Year 2031, Goal Goal A: Required return > 100% (136.57%)
#  - Year 2031, Goal Goal A: Required return > 100% (133.84%)
#  - Year 2031, Goal Goal A: Required return > 100% (131.26%)
#  - Year 2031, Goal Goal A: Required return > 100% (128.81%)
#  - Year 2031, Goal Goal A: Required return > 100% (126.48%)
#  - Year 2031, Goal Goal A: Required return > 100% (124.27%)
#  - Year 2031, Goal Goal A: Required return > 100% (122.17%)
#  - Year 2031, Goal Goal A: Required return > 100% (120.16%)
#  - Year 2031, Goal Goal A: Required return > 100% (118.23%)
#  - Year 2031, Goal Goal A: Required return > 100% (116.39%)
#  - Year 2031, Goal Goal A: Required return > 100% (114.63%)
#  - Year 2031, Goal Goal A: Required return > 100% (112.93%)
#  - Year 2031, Goal Goal A: Required return > 100% (111.30%)
#  - Year 2031, Goal Goal A: Required return > 100% (109.73%)
#  - Year 2031, Goal Goal A: Required return > 100% (108.21%)
#  - Year 2031, Goal Goal A: Required return > 100% (106.75%)
#  - Year 2031, Goal Goal A: Required return > 100% (105.34%)
#  - Year 2031, Goal Goal A: Required return > 100% (103.98%)
#  - Year 2031, Goal Goal A: Required return > 100% (102.65%)
#  - Year 2031, Goal Goal A: Required return > 100% (101.38%)
#  - Year 2031, Goal Goal A: Required return > 100% (100.14%)
#  - Year 2032, Goal Goal A: Required return > 100% (739.96%)
#  - Year 2032, Goal Goal A: Required return > 100% (566.67%)
#  - Year 2032, Goal Goal A: Required return > 100% (482.39%)
#  - Year 2032, Goal Goal A: Required return > 100% (429.14%)
#  - Year 2032, Goal Goal A: Required return > 100% (391.21%)
#  - Year 2032, Goal Goal A: Required return > 100% (362.25%)
#  - Year 2032, Goal Goal A: Required return > 100% (339.09%)
#  - Year 2032, Goal Goal A: Required return > 100% (319.98%)
#  - Year 2032, Goal Goal A: Required return > 100% (303.81%)
#  - Year 2032, Goal Goal A: Required return > 100% (289.87%)
#  - Year 2032, Goal Goal A: Required return > 100% (277.68%)
#  - Year 2032, Goal Goal A: Required return > 100% (266.88%)
#  - Year 2032, Goal Goal A: Required return > 100% (257.23%)
#  - Year 2032, Goal Goal A: Required return > 100% (248.51%)
#  - Year 2032, Goal Goal A: Required return > 100% (240.59%)
#  - Year 2032, Goal Goal A: Required return > 100% (233.34%)
#  - Year 2032, Goal Goal A: Required return > 100% (226.67%)
#  - Year 2032, Goal Goal A: Required return > 100% (220.50%)
#  - Year 2032, Goal Goal A: Required return > 100% (214.78%)
#  - Year 2032, Goal Goal A: Required return > 100% (209.44%)
#  - Year 2032, Goal Goal A: Required return > 100% (204.45%)
#  - Year 2032, Goal Goal A: Required return > 100% (199.77%)
#  - Year 2032, Goal Goal A: Required return > 100% (195.36%)
#  - Year 2032, Goal Goal A: Required return > 100% (191.20%)
#  - Year 2032, Goal Goal A: Required return > 100% (187.26%)
#  - Year 2032, Goal Goal A: Required return > 100% (183.53%)
#  - Year 2032, Goal Goal A: Required return > 100% (179.99%)
#  - Year 2032, Goal Goal A: Required return > 100% (176.61%)
#  - Year 2032, Goal Goal A: Required return > 100% (173.40%)
#  - Year 2032, Goal Goal A: Required return > 100% (170.32%)
#  - Year 2032, Goal Goal A: Required return > 100% (167.38%)
#  - Year 2032, Goal Goal A: Required return > 100% (164.57%)
#  - Year 2032, Goal Goal A: Required return > 100% (161.87%)
#  - Year 2032, Goal Goal A: Required return > 100% (159.28%)
#  - Year 2032, Goal Goal A: Required return > 100% (156.78%)
#  - Year 2032, Goal Goal A: Required return > 100% (154.38%)
#  - Year 2032, Goal Goal A: Required return > 100% (152.07%)
#  - Year 2032, Goal Goal A: Required return > 100% (149.84%)
#  - Year 2032, Goal Goal A: Required return > 100% (147.69%)
#  - Year 2032, Goal Goal A: Required return > 100% (145.60%)
#  - Year 2032, Goal Goal A: Required return > 100% (143.59%)
#  - Year 2032, Goal Goal A: Required return > 100% (141.64%)
#  - Year 2032, Goal Goal A: Required return > 100% (139.75%)
#  - Year 2032, Goal Goal A: Required return > 100% (137.92%)
#  - Year 2032, Goal Goal A: Required return > 100% (136.15%)
#  - Year 2032, Goal Goal A: Required return > 100% (134.43%)
#  - Year 2032, Goal Goal A: Required return > 100% (132.75%)
#  - Year 2032, Goal Goal A: Required return > 100% (131.12%)
#  - Year 2032, Goal Goal A: Required return > 100% (129.54%)
#  - Year 2032, Goal Goal A: Required return > 100% (128.00%)
#  - Year 2032, Goal Goal A: Required return > 100% (126.50%)
#  - Year 2032, Goal Goal A: Required return > 100% (125.04%)
#  - Year 2032, Goal Goal A: Required return > 100% (123.61%)
#  - Year 2032, Goal Goal A: Required return > 100% (122.22%)
#  - Year 2032, Goal Goal A: Required return > 100% (120.87%)
#  - Year 2032, Goal Goal A: Required return > 100% (119.55%)
#  - Year 2032, Goal Goal A: Required return > 100% (118.26%)
#  - Year 2032, Goal Goal A: Required return > 100% (116.99%)
#  - Year 2032, Goal Goal A: Required return > 100% (115.76%)
#  - Year 2032, Goal Goal A: Required return > 100% (114.56%)
#  - Year 2032, Goal Goal A: Required return > 100% (113.38%)
#  - Year 2032, Goal Goal A: Required return > 100% (112.22%)
#  - Year 2032, Goal Goal A: Required return > 100% (111.09%)
#  - Year 2032, Goal Goal A: Required return > 100% (109.99%)
#  - Year 2032, Goal Goal A: Required return > 100% (108.91%)
#  - Year 2032, Goal Goal A: Required return > 100% (107.85%)
#  - Year 2032, Goal Goal A: Required return > 100% (106.81%)
#  - Year 2032, Goal Goal A: Required return > 100% (105.79%)
#  - Year 2032, Goal Goal A: Required return > 100% (104.79%)
#  - Year 2032, Goal Goal A: Required return > 100% (103.81%)
#  - Year 2032, Goal Goal A: Required return > 100% (102.85%)
#  - Year 2032, Goal Goal A: Required return > 100% (101.90%)
#  - Year 2032, Goal Goal A: Required return > 100% (100.98%)
#  - Year 2032, Goal Goal A: Required return > 100% (100.07%)
#  - Year 2033, Goal Goal A: Required return > 100% (2322.28%)
#  - Year 2033, Goal Goal A: Required return > 100% (1612.81%)
#  - Year 2033, Goal Goal A: Required return > 100% (1298.50%)
#  - Year 2033, Goal Goal A: Required return > 100% (1111.14%)
#  - Year 2033, Goal Goal A: Required return > 100% (983.28%)
#  - Year 2033, Goal Goal A: Required return > 100% (888.89%)
#  - Year 2033, Goal Goal A: Required return > 100% (815.54%)
#  - Year 2033, Goal Goal A: Required return > 100% (756.41%)
#  - Year 2033, Goal Goal A: Required return > 100% (707.43%)
#  - Year 2033, Goal Goal A: Required return > 100% (665.99%)
#  - Year 2033, Goal Goal A: Required return > 100% (630.34%)
#  - Year 2033, Goal Goal A: Required return > 100% (599.25%)
#  - Year 2033, Goal Goal A: Required return > 100% (571.82%)
#  - Year 2033, Goal Goal A: Required return > 100% (547.38%)
#  - Year 2033, Goal Goal A: Required return > 100% (525.43%)
#  - Year 2033, Goal Goal A: Required return > 100% (505.57%)
#  - Year 2033, Goal Goal A: Required return > 100% (487.49%)
#  - Year 2033, Goal Goal A: Required return > 100% (470.94%)
#  - Year 2033, Goal Goal A: Required return > 100% (455.71%)
#  - Year 2033, Goal Goal A: Required return > 100% (441.64%)
#  - Year 2033, Goal Goal A: Required return > 100% (428.58%)
#  - Year 2033, Goal Goal A: Required return > 100% (416.43%)
#  - Year 2033, Goal Goal A: Required return > 100% (405.08%)
#  - Year 2033, Goal Goal A: Required return > 100% (394.45%)
#  - Year 2033, Goal Goal A: Required return > 100% (384.46%)
#  - Year 2033, Goal Goal A: Required return > 100% (375.05%)
#  - Year 2033, Goal Goal A: Required return > 100% (366.17%)
#  - Year 2033, Goal Goal A: Required return > 100% (357.77%)
#  - Year 2033, Goal Goal A: Required return > 100% (349.81%)
#  - Year 2033, Goal Goal A: Required return > 100% (342.25%)
#  - Year 2033, Goal Goal A: Required return > 100% (335.05%)
#  - Year 2033, Goal Goal A: Required return > 100% (328.20%)
#  - Year 2033, Goal Goal A: Required return > 100% (321.66%)
#  - Year 2033, Goal Goal A: Required return > 100% (315.42%)
#  - Year 2033, Goal Goal A: Required return > 100% (309.44%)
#  - Year 2033, Goal Goal A: Required return > 100% (303.71%)
#  - Year 2033, Goal Goal A: Required return > 100% (298.22%)
#  - Year 2033, Goal Goal A: Required return > 100% (292.95%)
#  - Year 2033, Goal Goal A: Required return > 100% (287.88%)
#  - Year 2033, Goal Goal A: Required return > 100% (283.00%)
#  - Year 2033, Goal Goal A: Required return > 100% (278.30%)
#  - Year 2033, Goal Goal A: Required return > 100% (273.77%)
#  - Year 2033, Goal Goal A: Required return > 100% (269.39%)
#  - Year 2033, Goal Goal A: Required return > 100% (265.17%)
#  - Year 2033, Goal Goal A: Required return > 100% (261.09%)
#  - Year 2033, Goal Goal A: Required return > 100% (257.15%)
#  - Year 2033, Goal Goal A: Required return > 100% (253.33%)
#  - Year 2033, Goal Goal A: Required return > 100% (249.63%)
#  - Year 2033, Goal Goal A: Required return > 100% (246.04%)
#  - Year 2033, Goal Goal A: Required return > 100% (242.56%)
#  - Year 2033, Goal Goal A: Required return > 100% (239.19%)
#  - Year 2033, Goal Goal A: Required return > 100% (235.91%)
#  - Year 2033, Goal Goal A: Required return > 100% (232.73%)
#  - Year 2033, Goal Goal A: Required return > 100% (229.63%)
#  - Year 2033, Goal Goal A: Required return > 100% (226.62%)
#  - Year 2033, Goal Goal A: Required return > 100% (223.69%)
#  - Year 2033, Goal Goal A: Required return > 100% (220.84%)
#  - Year 2033, Goal Goal A: Required return > 100% (218.06%)
#  - Year 2033, Goal Goal A: Required return > 100% (215.35%)
#  - Year 2033, Goal Goal A: Required return > 100% (212.71%)
#  - Year 2033, Goal Goal A: Required return > 100% (210.14%)
#  - Year 2033, Goal Goal A: Required return > 100% (207.63%)
#  - Year 2033, Goal Goal A: Required return > 100% (205.18%)
#  - Year 2033, Goal Goal A: Required return > 100% (202.78%)
#  - Year 2033, Goal Goal A: Required return > 100% (200.45%)
#  - Year 2033, Goal Goal A: Required return > 100% (198.16%)
#  - Year 2033, Goal Goal A: Required return > 100% (195.93%)
#  - Year 2033, Goal Goal A: Required return > 100% (193.74%)
#  - Year 2033, Goal Goal A: Required return > 100% (191.61%)
#  - Year 2033, Goal Goal A: Required return > 100% (189.52%)
#  - Year 2033, Goal Goal A: Required return > 100% (187.47%)
#  - Year 2033, Goal Goal A: Required return > 100% (185.47%)
#  - Year 2033, Goal Goal A: Required return > 100% (183.51%)
#  - Year 2033, Goal Goal A: Required return > 100% (181.58%)
#  - Year 2033, Goal Goal A: Required return > 100% (179.70%)
#  - Year 2033, Goal Goal A: Required return > 100% (177.85%)
#  - Year 2033, Goal Goal A: Required return > 100% (176.04%)
#  - Year 2033, Goal Goal A: Required return > 100% (174.27%)
#  - Year 2033, Goal Goal A: Required return > 100% (172.53%)
#  - Year 2033, Goal Goal A: Required return > 100% (170.82%)
#  - Year 2033, Goal Goal A: Required return > 100% (169.14%)
#  - Year 2033, Goal Goal A: Required return > 100% (167.50%)
#  - Year 2033, Goal Goal A: Required return > 100% (165.88%)
#  - Year 2033, Goal Goal A: Required return > 100% (164.29%)
#  - Year 2033, Goal Goal A: Required return > 100% (162.73%)
#  - Year 2033, Goal Goal A: Required return > 100% (161.20%)
#  - Year 2033, Goal Goal A: Required return > 100% (159.70%)
#  - Year 2033, Goal Goal A: Required return > 100% (158.22%)
#  - Year 2033, Goal Goal A: Required return > 100% (156.76%)
#  - Year 2033, Goal Goal A: Required return > 100% (155.33%)
#  - Year 2033, Goal Goal A: Required return > 100% (153.92%)
#  - Year 2033, Goal Goal A: Required return > 100% (152.54%)
#  - Year 2033, Goal Goal A: Required return > 100% (151.18%)
#  - Year 2033, Goal Goal A: Required return > 100% (149.84%)
#  - Year 2033, Goal Goal A: Required return > 100% (148.52%)
#  - Year 2033, Goal Goal A: Required return > 100% (147.22%)
#  - Year 2033, Goal Goal A: Required return > 100% (145.95%)
#  - Year 2033, Goal Goal A: Required return > 100% (144.69%)
#  - Year 2033, Goal Goal A: Required return > 100% (143.45%)
#  - Year 2033, Goal Goal A: Required return > 100% (142.23%)
#  - Year 2034, Goal Goal A: Required return > 100% (57993.43%)
#  - Year 2034, Goal Goal B: Required return > 100% (118.54%)
#  - Year 2034, Goal Goal A: Required return > 100% (28946.71%)
#  - Year 2034, Goal Goal A: Required return > 100% (19264.48%)
#  - Year 2034, Goal Goal A: Required return > 100% (14423.36%)
#  - Year 2034, Goal Goal A: Required return > 100% (11518.69%)
#  - Year 2034, Goal Goal A: Required return > 100% (9582.24%)
#  - Year 2034, Goal Goal A: Required return > 100% (8199.06%)
#  - Year 2034, Goal Goal A: Required return > 100% (7161.68%)
#  - Year 2034, Goal Goal A: Required return > 100% (6354.83%)
#  - Year 2034, Goal Goal A: Required return > 100% (5709.34%)
#  - Year 2034, Goal Goal A: Required return > 100% (5181.22%)
#  - Year 2034, Goal Goal A: Required return > 100% (4741.12%)
#  - Year 2034, Goal Goal A: Required return > 100% (4368.73%)
#  - Year 2034, Goal Goal A: Required return > 100% (4049.53%)
#  - Year 2034, Goal Goal A: Required return > 100% (3772.90%)
#  - Year 2034, Goal Goal A: Required return > 100% (3530.84%)
#  - Year 2034, Goal Goal A: Required return > 100% (3317.26%)
#  - Year 2034, Goal Goal A: Required return > 100% (3127.41%)
#  - Year 2034, Goal Goal A: Required return > 100% (2957.55%)
#  - Year 2034, Goal Goal A: Required return > 100% (2804.67%)
#  - Year 2034, Goal Goal A: Required return > 100% (2666.35%)
#  - Year 2034, Goal Goal A: Required return > 100% (2540.61%)
#  - Year 2034, Goal Goal A: Required return > 100% (2425.80%)
#  - Year 2034, Goal Goal A: Required return > 100% (2320.56%)
#  - Year 2034, Goal Goal A: Required return > 100% (2223.74%)
#  - Year 2034, Goal Goal A: Required return > 100% (2134.36%)
#  - Year 2034, Goal Goal A: Required return > 100% (2051.61%)
#  - Year 2034, Goal Goal A: Required return > 100% (1974.77%)
#  - Year 2034, Goal Goal A: Required return > 100% (1903.22%)
#  - Year 2034, Goal Goal A: Required return > 100% (1836.45%)
#  - Year 2034, Goal Goal A: Required return > 100% (1773.98%)
#  - Year 2034, Goal Goal A: Required return > 100% (1715.42%)
#  - Year 2034, Goal Goal A: Required return > 100% (1660.41%)
#  - Year 2034, Goal Goal A: Required return > 100% (1608.63%)
#  - Year 2034, Goal Goal A: Required return > 100% (1559.81%)
#  - Year 2034, Goal Goal A: Required return > 100% (1513.71%)
#  - Year 2034, Goal Goal A: Required return > 100% (1470.09%)
#  - Year 2034, Goal Goal A: Required return > 100% (1428.77%)
#  - Year 2034, Goal Goal A: Required return > 100% (1389.58%)
#  - Year 2034, Goal Goal A: Required return > 100% (1352.34%)
#  - Year 2034, Goal Goal A: Required return > 100% (1316.91%)
#  - Year 2034, Goal Goal A: Required return > 100% (1283.18%)
#  - Year 2034, Goal Goal A: Required return > 100% (1251.01%)
#  - Year 2034, Goal Goal A: Required return > 100% (1220.31%)
#  - Year 2034, Goal Goal A: Required return > 100% (1190.97%)
#  - Year 2034, Goal Goal A: Required return > 100% (1162.90%)
#  - Year 2034, Goal Goal A: Required return > 100% (1136.03%)
#  - Year 2034, Goal Goal A: Required return > 100% (1110.28%)
#  - Year 2034, Goal Goal A: Required return > 100% (1085.58%)
#  - Year 2034, Goal Goal A: Required return > 100% (1061.87%)
#  - Year 2034, Goal Goal A: Required return > 100% (1039.09%)
#  - Year 2034, Goal Goal A: Required return > 100% (1017.18%)
#  - Year 2034, Goal Goal A: Required return > 100% (996.10%)
#  - Year 2034, Goal Goal A: Required return > 100% (975.80%)
#  - Year 2034, Goal Goal A: Required return > 100% (956.24%)
#  - Year 2034, Goal Goal A: Required return > 100% (937.38%)
#  - Year 2034, Goal Goal A: Required return > 100% (919.18%)
#  - Year 2034, Goal Goal A: Required return > 100% (901.61%)
#  - Year 2034, Goal Goal A: Required return > 100% (884.63%)
#  - Year 2034, Goal Goal A: Required return > 100% (868.22%)
#  - Year 2034, Goal Goal A: Required return > 100% (852.35%)
#  - Year 2034, Goal Goal A: Required return > 100% (836.99%)
#  - Year 2034, Goal Goal A: Required return > 100% (822.12%)
#  - Year 2034, Goal Goal A: Required return > 100% (807.71%)
#  - Year 2034, Goal Goal A: Required return > 100% (793.75%)
#  - Year 2034, Goal Goal A: Required return > 100% (780.20%)
#  - Year 2034, Goal Goal A: Required return > 100% (767.07%)
#  - Year 2034, Goal Goal A: Required return > 100% (754.32%)
#  - Year 2034, Goal Goal A: Required return > 100% (741.93%)
#  - Year 2034, Goal Goal A: Required return > 100% (729.91%)
#  - Year 2034, Goal Goal A: Required return > 100% (718.22%)
#  - Year 2034, Goal Goal A: Required return > 100% (706.85%)
#  - Year 2034, Goal Goal A: Required return > 100% (695.80%)
#  - Year 2034, Goal Goal A: Required return > 100% (685.05%)
#  - Year 2034, Goal Goal A: Required return > 100% (674.58%)
#  - Year 2034, Goal Goal A: Required return > 100% (664.39%)
#  - Year 2034, Goal Goal A: Required return > 100% (654.46%)
#  - Year 2034, Goal Goal A: Required return > 100% (644.79%)
#  - Year 2034, Goal Goal A: Required return > 100% (635.36%)
#  - Year 2034, Goal Goal A: Required return > 100% (626.17%)
#  - Year 2034, Goal Goal A: Required return > 100% (617.20%)
#  - Year 2034, Goal Goal A: Required return > 100% (608.46%)
#  - Year 2034, Goal Goal A: Required return > 100% (599.92%)
#  - Year 2034, Goal Goal A: Required return > 100% (591.59%)
#  - Year 2034, Goal Goal A: Required return > 100% (583.45%)
#  - Year 2034, Goal Goal A: Required return > 100% (575.50%)
#  - Year 2034, Goal Goal A: Required return > 100% (567.74%)
#  - Year 2034, Goal Goal A: Required return > 100% (560.15%)
#  - Year 2034, Goal Goal A: Required return > 100% (552.74%)
#  - Year 2034, Goal Goal A: Required return > 100% (545.48%)
#  - Year 2034, Goal Goal A: Required return > 100% (538.39%)
#  - Year 2034, Goal Goal A: Required return > 100% (531.45%)
#  - Year 2034, Goal Goal A: Required return > 100% (524.66%)
#  - Year 2034, Goal Goal A: Required return > 100% (518.02%)
#  - Year 2034, Goal Goal A: Required return > 100% (511.51%)
#  - Year 2034, Goal Goal A: Required return > 100% (505.14%)
#  - Year 2034, Goal Goal A: Required return > 100% (498.90%)
#  - Year 2034, Goal Goal A: Required return > 100% (492.79%)
#  - Year 2034, Goal Goal A: Required return > 100% (486.80%)
#  - Year 2034, Goal Goal A: Required return > 100% (480.93%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal B: Required return > 100% (155.01%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal B: Required return > 100% (122.00%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal B: Required return > 100% (104.71%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2036, Goal Goal B: Required return > 100% (213.96%)
#  - Year 2036, Goal Goal B: Required return > 100% (164.01%)
#  - Year 2036, Goal Goal B: Required return > 100% (138.56%)
#  - Year 2036, Goal Goal B: Required return > 100% (122.00%)
#  - Year 2036, Goal Goal B: Required return > 100% (109.96%)
#  - Year 2036, Goal Goal B: Required return > 100% (100.60%)
# ...
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
#  - Year 2071, Goal Goal A: Zero allocation or pool
#  - Year 2071, Goal Goal B: Zero allocation or pool
#  - Year 2071, Goal Goal C: Zero allocation or pool
#  - Year 2071, Goal Goal D: Zero allocation or pool
