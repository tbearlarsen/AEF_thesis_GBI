# %% [markdown]
# V1 (02 11 2025): Translated from R to Python and added the visualizations for goals B to D
#
#
# V2 (04 01 2025): Loop system implemented
#
# V2.5 (04 02 2025): Loops system tweaks. Removed openpyxl as it was corrupting files and replaced it with xlwings
#
# V3 & V4 finalize the loop except for the tax and asset channel
#
# V 5,6,7 add tax shenanigans. V7C added the fully functioning inflow and outflow of wealth with the returns and taxes in it.
#
# V8 modifies the aktiesparekonto pool so that it is increased when taxes are payed.

# %%
#!pip install numpy pandas scipy matplotlib xlwings

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import subprocess
import xlwings as xw
import time

# %%
# -- Variable Setup -- ##

#Monte Carlo Trials
n_trials = 10**5

#Case Study Profile Selection
Profile = "P1" #Either P1 or P2

#Excel worksheets
excel_returns = "Returns"
excel_volatilities = "Volatilities"
excel_correlation = "Correlation"
excel_gbi = "GBI Allocations P1" if Profile == "P1" else "GBI Allocations P2"
excel_gbi_goals = "GBI Goals P1" if Profile == "P1" else "GBI Goals P2"
excel_final_wealth = "FinalWealth"
excel_income = "Salary"

# %% [markdown]
# # Define Functions
# This section defines the functions used for calculating portfolio volatility, expected return,
# goal achievement probability, and the objective (failure probability) to minimize.

# %%
def sd_f(weight_vector, covar_table):
    covar_vector = np.zeros(len(weight_vector))
    for z in range(len(weight_vector)):
        covar_vector[z] = np.sum(weight_vector * covar_table[:, z])
    return np.sqrt(np.sum(weight_vector * covar_vector))

# %%
def mean_f(weight_vector, return_vector):
    return np.sum(weight_vector * return_vector)

# %%
def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    # goal_vector is [value ratio, funding requirement, time horizon]
    required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
    if goal_allocation * pool >= goal_vector[1]:
        return 1
    else:
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)

# %%
def optim_function(weights):
    # Uses the current global variables: goal_vector, allocation, pool, return_vector, covar_table
    return 1 - phi_f(
        goal_vector,
        allocation,
        pool,
        mean_f(weights, return_vector),
        sd_f(weights, covar_table)
    )

# %%
def constraint_function(weights):
    # For SciPy equality constraints, we require constraint_function(weights) == 0.
    return np.sum(weights) - 1

# %%
def mvu_f(weights):
    # mvu_f is defined for mean-variance optimization (not used below).
    return -(mean_f(weights, return_vector) - 0.5 * gamma * sd_f(weights, covariances)**2)

# %%
def r_req_f(goal_vector, goal_allocation, pool):
    return (goal_vector[1] / (goal_allocation * pool))**(1 / goal_vector[2]) - 1

# %%
def get_goal_data(master_excel_path, plan=Profile):
    """
    Returns a DataFrame of the specified goal table (P1 or P2).
    P1 => B2:F5
    P2 => B7:F10
    """
    if plan == "P1":
        skip = 1  # start reading at row 2
    elif plan == "P2":
        skip = 6  # start reading at row 7
    else:
        raise ValueError("Plan not recognized. Use 'P1' or 'P2'.")

    df_goals = pd.read_excel(master_excel_path,sheet_name="Goals",skiprows=skip,nrows=4,usecols="B:F",header=0)
    # First column is "Goal Info", so make that the index
    df_goals.set_index(df_goals.columns[0], inplace=True)
    return df_goals

# %% [markdown]
# # Load & Parse Data

# %%
## -- Repo Root and Folders -- ##

# Get repo root and set folders
root = subprocess.run(["git", "rev-parse", "--show-toplevel"], capture_output=True, text=True).stdout.strip()
data_folder = os.path.join(root, "GBI Optimisation", "data")
output_folder = os.path.join(root, "GBI Optimisation")

# Get excel file and sheets
master_excel_path = os.path.join(data_folder, "Master.xlsx")

df_returns = pd.read_excel(master_excel_path, sheet_name=excel_returns)
df_vols = pd.read_excel(master_excel_path, sheet_name=excel_volatilities)

df_returns.set_index(df_returns.columns[0], inplace=True)
df_vols.set_index(df_vols.columns[0], inplace=True)

df_corr = pd.read_excel(master_excel_path, sheet_name=excel_correlation)
df_corr.set_index(df_corr.columns[0], inplace=True)

# %%
# - NEW V8 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #

# Initial cap in 2025
initial_ask_cap = 166200
growth_rate = 0.1265  # 12.65% annual increase

# %%
asset_level_log = []  # NEW: Log each asset's return pre- and post-tax by account

while True:
    ## -- Loop Table -- ##
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop",usecols="B:F",skiprows=1,header=0)
    # Find Last looped year and select the next one
    # Filter only rows where LoopStatus is N
    pending_rows = table_loop_df[table_loop_df["LoopStatus"] == "N"]

    # If we find any rows, get the row with the lowest Year
    if pending_rows.empty:
        print("All loops completed")
        break


    chosen_row = pending_rows.loc[pending_rows["Year"].idxmin()]
    loop_year = chosen_row["Year"]
    loop_number = chosen_row["N"]
    loop_age1 = chosen_row["AgeP1"]
    loop_age2 = chosen_row["AgeP2"]

    print(loop_year, loop_number, loop_age1, loop_age2)

    # - Wealth - #

    # Get salary for current year
    df_salary = pd.read_excel(master_excel_path, sheet_name=excel_income)
    df_salary.set_index(df_salary.columns[0], inplace=True)
    salary = df_salary.loc[Profile, str(loop_year)]

    # Load FinalWealth sheet
    df_final_wealth = pd.read_excel(master_excel_path, sheet_name=excel_final_wealth)
    df_final_wealth.set_index(df_final_wealth.columns[0], inplace=True)

    # - Dynamic time horizon based on current year - #

    # Step 1: Get Starting Year (minimum year in Loop sheet)
    starting_year = table_loop_df["Year"].min()
    prev_year = str(loop_year - 1)

    # If first loop year, no previous wealth exists
    if loop_year == starting_year:
        prev_wealth = 0
        pool = salary
    else:
        try:
            prev_wealth = df_final_wealth.loc[Profile, prev_year]
        except KeyError:
            raise KeyError(f"Previous wealth not found for {Profile} in {prev_year}")
        pool = salary + prev_wealth

    capital_market_expectations_raw = {}
    for asset in df_returns.index:
        expected_return = df_returns.loc[asset, str(loop_year)]
        volatility = df_vols.loc[asset, 'volatility']
        capital_market_expectations_raw[asset] = {
            'Return Forecast': expected_return,
            'Volatility Forecast': volatility
        }

    capital_market_expectations_raw = pd.DataFrame.from_dict(capital_market_expectations_raw, orient='index')

    capital_market_expectations_raw = capital_market_expectations_raw.reset_index()
    capital_market_expectations_raw.rename(columns={'index': 'Unnamed: 0'}, inplace=True)

    # Rearrange columns to match your old format (optional):
    capital_market_expectations_raw = capital_market_expectations_raw[['Unnamed: 0', 'Return Forecast', 'Volatility Forecast']]

    goal_data_raw = get_goal_data(master_excel_path, plan="P1")

    # - Dynamic time horizon based on current year - #


    # Step 2: Compute Goal Years = starting_year + time_horizon
    goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
    goal_years = starting_year + goal_horizons

    # Step 3: Recalculate Time Horizons = goal_years - current loop_year
    adjusted_horizons = goal_years - loop_year

    # Step 4: Replace the "Time Horizon" row in goal_data_raw
    goal_data_raw.loc["Time Horizon"] = adjusted_horizons

    # - V8 - Dynamically compute ASK cap per year
    aktiesparekonto_cap = initial_ask_cap * ((1 + growth_rate) ** (loop_year - starting_year))

    goals = ["A", "B", "C", "D"]
    active_goal_mask = np.array([adjusted_horizons[f"GOAL {g}"] > 0 for g in goals])

    # Optional: print to confirm
    print("Starting Year:", starting_year)
    print("Current Year:", loop_year)
    print("Goal Years:", goal_years.to_dict())
    print("Adjusted Horizons:", adjusted_horizons.to_dict())



    # Record number of potential investments and goals
    num_assets = capital_market_expectations_raw.shape[0]
    num_goals = goal_data_raw.shape[1]

    # Create vector of expected returns
    return_vector = capital_market_expectations_raw["Return Forecast"].to_numpy()

    # Get the correlations as a numeric DataFrame (just a num_assets × num_assets block)
    correlations = df_corr.iloc[:num_assets, :num_assets].astype(float)

    # Build the covariance matrix: stdev_i * stdev_j * correlation_ij
    stdevs = capital_market_expectations_raw["Volatility Forecast"].to_numpy()
    covariances = np.zeros((num_assets, num_assets))
    for i in range(num_assets):
        for j in range(num_assets):
            covariances[i, j] = stdevs[i] * stdevs[j] * correlations.iloc[i, j]

    goal_A = goal_data_raw["GOAL A"].values
    goal_B = goal_data_raw["GOAL B"].values
    goal_C = goal_data_raw["GOAL C"].values
    goal_D = goal_data_raw["GOAL D"].values

    # - Optimal Goal Allocation - #


    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Set SLSQP options to be more stringent, mimicking solnp's behavior.
    slsqp_opts = {
        'ftol': 1e-12,     # function tolerance
        'eps': 1e-12,      # finite-difference step size for gradient estimation
        'maxiter': 10000,  # maximum iterations
        'disp': False     # do not display convergence messages
    }

    for i, alloc in enumerate(goal_allocation):
        allocation = alloc      # Global variable used in optim_function
        covar_table = covariances

        # Goal A Optimization
        goal_vector = goal_A   # Global variable used in optim_function
        if goal_A[1] <= pool * allocation:
            optimal_weights_A[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_A[i, :] = result.x

        # Goal B Optimization
        goal_vector = goal_B
        if goal_B[1] <= pool * allocation:
            optimal_weights_B[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_B[i, :] = result.x

        # Goal C Optimization
        goal_vector = goal_C
        if goal_C[1] <= pool * allocation:
            optimal_weights_C[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_C[i, :] = result.x

        # Goal D Optimization
        goal_vector = goal_D
        if goal_D[1] <= pool * allocation:
            optimal_weights_D[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_D[i, :] = result.x

    # Calculate the best probability (phi) for each allocation level for every goal
    phi_A = np.zeros(len(goal_allocation))
    phi_B = np.zeros(len(goal_allocation))
    phi_C = np.zeros(len(goal_allocation))
    phi_D = np.zeros(len(goal_allocation))

    for i, alloc in enumerate(goal_allocation):
        phi_A[i] = phi_f(goal_A, alloc, pool,
                         mean_f(optimal_weights_A[i, :], return_vector),
                         sd_f(optimal_weights_A[i, :], covariances))
        phi_B[i] = phi_f(goal_B, alloc, pool,
                         mean_f(optimal_weights_B[i, :], return_vector),
                         sd_f(optimal_weights_B[i, :], covariances))
        phi_C[i] = phi_f(goal_C, alloc, pool,
                         mean_f(optimal_weights_C[i, :], return_vector),
                         sd_f(optimal_weights_C[i, :], covariances))
        phi_D[i] = phi_f(goal_D, alloc, pool,
                         mean_f(optimal_weights_D[i, :], return_vector),
                         sd_f(optimal_weights_D[i, :], covariances))

    # Simulate goal weights: each row is a simulated allocation (in percentages)
    sim_goal_weights = np.random.multinomial(100, [1/num_goals]*num_goals, size=n_trials) #this one sums to 100 so its good
    for i in range(n_trials):
        rand_vector = np.random.uniform(0, 1, num_goals)
        normalizer = np.sum(rand_vector)
        percents = np.round((rand_vector / normalizer) * 100, 0)

        # Only enforce floor for active goals
        floor_applied = np.where(active_goal_mask, np.maximum(percents, 1), percents)
        sim_goal_weights[i, :] = floor_applied


    # Calculate utility for each simulated portfolio.
    # Note: subtract 1 from simulated weights for 0-indexing.
    utility = (
        goal_A[0] * phi_A[sim_goal_weights[:, 0] - 1] +
        goal_A[0] * goal_B[0] * phi_B[sim_goal_weights[:, 1] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * phi_C[sim_goal_weights[:, 2] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * goal_D[0] * phi_D[sim_goal_weights[:, 3] - 1]
    )

    # Find the index of the portfolio with the highest utility
    index = np.argmax(utility)
    optimal_goal_weights = sim_goal_weights[index, :]

    # - Optimal Subportfolio Allocation - #

    # Retrieve optimal subportfolio allocations
    optimal_subportfolios = np.zeros((num_goals, num_assets))

    # For each goal, use the simulated percentage to select the corresponding row
    # from the optimal weights matrix (adjust for zero-indexing)
    for i in range(num_goals):
        optimal_subportfolios[i, :] = eval(f"optimal_weights_{goals[i]}")[optimal_goal_weights[i] - 1, :]

    # Compute the optimal aggregate investment portfolio.
    optimal_aggregate_portfolio = (optimal_goal_weights / 100) @ optimal_subportfolios

    #Define asset names
    asset_names = capital_market_expectations_raw.iloc[:, 0].astype(str).tolist()

    # - Storing and exporting results - #

    # Create a DataFrame for the aggregate portfolio.
    # First calculate unrounded percentages
    raw_alloc = optimal_aggregate_portfolio * 100

    # Normalize to force sum = 100 after rounding
    normalized_alloc = raw_alloc / raw_alloc.sum() * 100
    normalized_goal_alloc = np.zeros_like(optimal_goal_weights, dtype=float)
    active_sum = np.sum(optimal_goal_weights[active_goal_mask])
    normalized_goal_alloc[active_goal_mask] = (optimal_goal_weights[active_goal_mask] / active_sum) * 100

    normalized_weights = normalized_alloc / 100  # convert back to decimal weights

    # Create a DataFrame for the across-goal allocation.
    df_across_goal = pd.DataFrame({
        "Goal": goals,
        "Allocation (%)": np.round(normalized_goal_alloc, 2) # Keep raw percentages
    })

    # Round after normalization
    df_aggregate = pd.DataFrame({
        "Asset": asset_names,
        "Weight": normalized_weights,
        "Invested Amt (DKK)": normalized_weights * pool,
        "Allocation (%)": np.round(normalized_alloc, 2)  # keep for display only
    })


    # - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #
    # --- NEW: Exact and Proportional ASK Logic ---
    account_allocations = []
    equity_rows = []
    non_equity_rows = []

    # First pass: split equity and non-equity rows
    for i, row in df_aggregate.iterrows():
        asset_name = row["Asset"]
        invested = row["Invested Amt (DKK)"]
        weight = row["Weight"]

        row_dict = {
            "Year": loop_year,
            "Asset": asset_name,
            "Invested": invested,
            "Weight": weight,
            "ASK (DKK)": 0,
            "Normal (DKK)": 0,
        }

        if "Equities" in asset_name:
            equity_rows.append(row_dict)
        else:
            row_dict["Normal (DKK)"] = invested
            non_equity_rows.append(row_dict)

    # Determine total equity to allocate proportionally if ASK cap remains
    total_equity = sum(row["Invested"] for row in equity_rows)
    remaining_ask_cap = max(0, aktiesparekonto_cap - aktiesparekonto_used_total)
    ask_fraction = min(1, remaining_ask_cap / total_equity) if total_equity > 0 else 0

    # Apply proportional ASK allocation to equities
    for row in equity_rows:
        ask_part = row["Invested"] * ask_fraction
        normal_part = row["Invested"] - ask_part
        row["ASK (DKK)"] = round(ask_part, 2)
        row["Normal (DKK)"] = round(normal_part, 2)
        aktiesparekonto_used_total += ask_part

    # Combine and finalize
    account_allocations = equity_rows + non_equity_rows


    df_accounts = pd.DataFrame(account_allocations)
    print(f"[DEBUG] Final weight sum: {sum(row['Weight'] for row in account_allocations):.10f}")
    # - V5 END - #


    # - NEW V6 CONTENT REGARDING GAINS & TAXES - #


    share_income_normal = 0  # for progressive tax
    tax_ask = 0  # Track ASK tax separately

    # Update portfolio and compute gains
    for row in account_allocations:
        asset = row["Asset"]
        ask = row["ASK (DKK)"]
        normal = row["Normal (DKK)"]
        weight = row["Weight"]
        expected_return = capital_market_expectations_raw.loc[
            capital_market_expectations_raw["Unnamed: 0"] == asset,
            "Return Forecast"
        ].values[0]

        # V7C -LOG ASSET RETURNS BY ACCOUNT
        if ask > 0:
            new_val = ask * (1 + expected_return)
            gain = new_val - ask
            tax = 0.17 * gain
            asset_level_log.append({
                "Year": loop_year,
                "Account": "ASK",
                "Asset": asset,
                "Invested": ask,
                "Weight": ask / pool,
                "Return": expected_return,
                "Gross Gain": gain,
                "Tax": tax,
                "Net Gain": gain - tax,
                "End Value": ask + gain - tax,
                "TOTAL ASK Cap (DKK)": aktiesparekonto_cap
            })

        if normal > 0:
            new_val = normal * (1 + expected_return)
            gain = new_val - normal
            share_income_normal += gain
            asset_level_log.append({
                "Year": loop_year,
                "Account": "NORMAL",
                "Asset": asset,
                "Invested": normal,
                "Weight": normal / pool,
                "Return": expected_return,
                "Gross Gain": gain,
                "Tax": None,  # progressive tax logged later
                "Net Gain": None,
                "End Value": None,
                "TOTAL ASK Cap (DKK)": aktiesparekonto_cap
            })

            #V7C END

    # Tax on Normal Account (progressive)
    cap = 67500
    if share_income_normal <= cap:
        tax_normal = 0.27 * share_income_normal
    else:
        tax_normal = 0.27 * cap + 0.42 * (share_income_normal - cap)

    # Distribute tax proportionally across NORMAL assets
    normal_log_rows = [
        row for row in asset_level_log
        if row["Account"] == "NORMAL" and row["Year"] == loop_year
    ]
    total_normal_gain = sum(row["Gross Gain"] for row in normal_log_rows)

    print(f"[DEBUG] Year: {loop_year}")
    print(f"[DEBUG] Gross Gains (Normal account): {share_income_normal:.2f}")
    print(f"[DEBUG] Tax Calculated (Normal account): {tax_normal:.2f}")

    for row in normal_log_rows:
        if total_normal_gain > 0:
            share = row["Gross Gain"] / total_normal_gain
            tax = share * tax_normal
        else:
            tax = 0

        row["Tax"] = tax
        row["Net Gain"] = row["Gross Gain"] - tax
        row["End Value"] = row["Invested"] + row["Net Gain"]

    total_gains_normal = share_income_normal - tax_normal


    print("Optimal Across-Goal Allocation:")
    print(df_across_goal.to_string(index=False))

    print("\nOptimal Aggregate Investment Allocation:")
    print(df_aggregate.to_string(index=False))

    # -- Safer Excel launch --
    app = xw.App(visible=False)
    app.display_alerts = False
    app.screen_updating = False

    time.sleep(1)

    # Open workbook
    wb = app.books.open(master_excel_path)
    ws = wb.sheets[excel_gbi]
    ws_final_wealth = wb.sheets[excel_final_wealth]

    # Get header values from row 1 (columns B to AY ~= cols 2 to 51)
    header_values = [ws.cells(1, col).value for col in range(2, 53)]

    try:
        year_col = header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in worksheet headers.")

    # Write weights
    for i, asset in enumerate(asset_names):
        allocation = float(np.round(normalized_alloc[i], 2)) / 100
        cell = ws.cells(i + 2, year_col)
        cell.value = allocation
        cell.number_format = '0.00%'  # display as percentage

    # -- Export Goal Weights to Excel -- #

    # Re-access the sheet after workbook is open
    ws_goals = wb.sheets[excel_gbi_goals]

    # Read header values from row 1 (columns B to AY ≈ cols 2 to 52)
    goal_header_values = [ws_goals.cells(1, col).value for col in range(2, 53)]

    try:
        goal_year_col = goal_header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in goal worksheet headers.")

    # Write each across-goal allocation to the appropriate row
    for i, allocation in enumerate(df_across_goal["Allocation (%)"]):
        value = float(np.round(allocation / 100, 6))  # convert to decimal
        row = i + 2  # assuming goal names are in rows starting at 2
        cell = ws_goals.cells(row, goal_year_col)
        cell.value = value
        cell.number_format = '0.00%'  # display as percentage

    # -- Modify Loop Check -- #
    print("Starting loop status check...")

    ws_loop = wb.sheets["Loop"]
    print("Accessed 'Loop' worksheet.")

    # Read data range again (columns B to F)
    last_row = ws_loop.cells.last_cell.row
    print(f"Last cell row: {last_row}")

    loop_data = ws_loop.range("B2:F" + str(last_row)).value
    print(f"Loaded loop data. Total rows read: {len(loop_data)}")

    # Find and update the matching year with LoopStatus 'N'
    found = False
    for i, row in enumerate(loop_data):
        year = row[1]
        status = row[4]
        print(f"Row {i+2}: Year = {year}, Status = {status}")
        if year == loop_year and status == 'N':
            print(f"Match found at row {i+2}. Updating status to 'Y'.")
            ws_loop.cells(i + 2, 6).value = 'Y'  # Column F is column 6
            found = True
            break

    if not found:
        print(f"No matching row found for year {loop_year} with status 'N'.")
    else:
        print("Status updated successfully.")

    # Update FinalWealth sheet with new pool
    final_header_values = [ws_final_wealth.cells(1, col).value for col in range(2, 53)]
    try:
        final_year_col = final_header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in FinalWealth headers.")

    profile_row = 2 if Profile == "P1" else 3
    # Calculate total value of all assets across both accounts

    this_year_rows = [row for row in asset_level_log if row["Year"] == loop_year]
    end_value_sum = sum(row["End Value"] for row in this_year_rows)

    ws_final_wealth.cells(profile_row, final_year_col).value = end_value_sum

    print(f"\n--- Year {loop_year} Summary ---")
    print(f"Income (Salary): {salary:.2f}")
    if loop_year != starting_year:
        print(f"Previous Wealth Carried: {prev_wealth:.2f}")
    print(f"Post-Tax Wealth (New Final Wealth): {pool:.2f}")
    print("------------------------------\n")


    wb.save()
    wb.close()
    app.quit()
    time.sleep(1)
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop", usecols="B:F", skiprows=1, header=0)
# Out:
# 2025 1 25 40
# Starting Year: 2025
# Current Year: 2025
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 10, 'GOAL B': 15, 'GOAL C': 20, 'GOAL D': 50}
# C:\Users\admin\AppData\Local\Temp\ipykernel_27560\4021808357.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2025
# [DEBUG] Gross Gains (Normal account): 0.00
# [DEBUG] Tax Calculated (Normal account): 0.00
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            17.0
#    B            36.0
#    C            44.0
#    D             3.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.056436                 0.0            5.64
#         Developed Markets - Equities 0.276919                 0.0           27.69
# Emerging Markets State - Obligations 0.195829                 0.0           19.58
#       High Yield Bonds - Obligations 0.172641                 0.0           17.26
# Investment Grade Bonds - Obligations 0.043384                 0.0            4.34
#    Government ZC Bonds - Obligations 0.254791                 0.0           25.48
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = N
# Match found at row 3. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2025 Summary ---
# Income (Salary): 0.00
# Post-Tax Wealth (New Final Wealth): 0.00
# ------------------------------
#
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 9, 'GOAL B': 14, 'GOAL C': 19, 'GOAL D': 49}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2026
# [DEBUG] Gross Gains (Normal account): 3530.78
# [DEBUG] Tax Calculated (Normal account): 953.31
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             1.0
#    B            96.0
#    C             1.0
#    D             2.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.515887        27158.962136           51.59
#         Developed Markets - Equities 0.058631         3086.637986            5.86
# Emerging Markets State - Obligations 0.355296        18704.644174           35.53
#       High Yield Bonds - Obligations 0.004031          212.192791            0.40
# Investment Grade Bonds - Obligations 0.064291         3384.611083            6.43
#    Government ZC Bonds - Obligations 0.001864           98.151830            0.19
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = N
# Match found at row 4. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2026 Summary ---
# Income (Salary): 52645.20
# Previous Wealth Carried: 0.00
# Post-Tax Wealth (New Final Wealth): 52645.20
# ------------------------------
#
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 8, 'GOAL B': 13, 'GOAL C': 18, 'GOAL D': 48}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2027
# [DEBUG] Gross Gains (Normal account): 4871.81
# [DEBUG] Tax Calculated (Normal account): 1315.39
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.98
#    B           69.61
#    C           25.49
#    D            3.92
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.295238        32002.158519           29.52
#         Developed Markets - Equities 0.002090          226.491379            0.21
# Emerging Markets State - Obligations 0.001171          126.913344            0.12
#       High Yield Bonds - Obligations 0.004223          457.769232            0.42
# Investment Grade Bonds - Obligations 0.000672           72.879349            0.07
#    Government ZC Bonds - Obligations 0.696606        75508.108474           69.66
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = N
# Match found at row 5. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2027 Summary ---
# Income (Salary): 53171.65
# Previous Wealth Carried: 55222.67
# Post-Tax Wealth (New Final Wealth): 108394.32
# ------------------------------
#
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 7, 'GOAL B': 12, 'GOAL C': 17, 'GOAL D': 47}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2028
# [DEBUG] Gross Gains (Normal account): 10162.14
# [DEBUG] Tax Calculated (Normal account): 2743.78
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.99
#    B           43.56
#    C           44.55
#    D           10.89
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.556605        95163.394070           55.66
#         Developed Markets - Equities 0.001846          315.642374            0.18
# Emerging Markets State - Obligations 0.002014          344.356072            0.20
#       High Yield Bonds - Obligations 0.000334           57.161171            0.03
# Investment Grade Bonds - Obligations 0.001779          304.178286            0.18
#    Government ZC Bonds - Obligations 0.437422        74786.540299           43.74
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = N
# Match found at row 6. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2028 Summary ---
# Income (Salary): 59020.53
# Previous Wealth Carried: 111950.74
# Post-Tax Wealth (New Final Wealth): 170971.27
# ------------------------------
#
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 6, 'GOAL B': 11, 'GOAL C': 16, 'GOAL D': 46}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2029
# [DEBUG] Gross Gains (Normal account): 15541.89
# [DEBUG] Tax Calculated (Normal account): 4196.31
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            64.0
#    B            33.0
#    C             1.0
#    D             2.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.661153       157354.616425           66.12
#         Developed Markets - Equities 0.002311          550.031631            0.23
# Emerging Markets State - Obligations 0.002146          510.828138            0.21
#       High Yield Bonds - Obligations 0.001098          261.205968            0.11
# Investment Grade Bonds - Obligations 0.002251          535.649590            0.23
#    Government ZC Bonds - Obligations 0.331042        78788.034957           33.10
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = N
# Match found at row 7. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2029 Summary ---
# Income (Salary): 59610.74
# Previous Wealth Carried: 178389.63
# Post-Tax Wealth (New Final Wealth): 238000.37
# ------------------------------
#
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 5, 'GOAL B': 10, 'GOAL C': 15, 'GOAL D': 45}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2030
# [DEBUG] Gross Gains (Normal account): 23598.19
# [DEBUG] Tax Calculated (Normal account): 6371.51
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           76.24
#    B           21.78
#    C            0.99
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.835595       258660.812039           83.56
#         Developed Markets - Equities 0.005755         1781.366332            0.58
# Emerging Markets State - Obligations 0.023522         7281.344184            2.35
#       High Yield Bonds - Obligations 0.003012          932.492074            0.30
# Investment Grade Bonds - Obligations 0.078546        24314.166957            7.85
#    Government ZC Bonds - Obligations 0.053570        16582.610327            5.36
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = N
# Match found at row 8. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2030 Summary ---
# Income (Salary): 60206.85
# Previous Wealth Carried: 249345.95
# Post-Tax Wealth (New Final Wealth): 309552.79
# ------------------------------
#
# 2031 7 31 46
# Starting Year: 2025
# Current Year: 2031
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 4, 'GOAL B': 9, 'GOAL C': 14, 'GOAL D': 44}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2031
# [DEBUG] Gross Gains (Normal account): 30007.29
# [DEBUG] Tax Calculated (Normal account): 8101.97
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           80.20
#    B           17.82
#    C            0.99
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.863890       334833.597648           86.39
#         Developed Markets - Equities 0.004771         1849.210929            0.48
# Emerging Markets State - Obligations 0.014573         5648.406033            1.46
#       High Yield Bonds - Obligations 0.000289          112.025183            0.03
# Investment Grade Bonds - Obligations 0.064362        24946.009128            6.44
#    Government ZC Bonds - Obligations 0.052115        20199.141236            5.21
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = N
# Match found at row 9. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2031 Summary ---
# Income (Salary): 60808.91
# Previous Wealth Carried: 326779.48
# Post-Tax Wealth (New Final Wealth): 387588.39
# ------------------------------
#
# 2032 8 32 47
# Starting Year: 2025
# Current Year: 2032
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 3, 'GOAL B': 8, 'GOAL C': 13, 'GOAL D': 43}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2032
# [DEBUG] Gross Gains (Normal account): 21543.14
# [DEBUG] Tax Calculated (Normal account): 5816.65
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           80.39
#    B           17.65
#    C            0.98
#    D            0.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.228808       109139.294428           22.88
#         Developed Markets - Equities 0.014614         6970.680880            1.46
# Emerging Markets State - Obligations 0.062950        30026.538276            6.29
#       High Yield Bonds - Obligations 0.001808          862.227081            0.18
# Investment Grade Bonds - Obligations 0.280362       133730.259695           28.04
#    Government ZC Bonds - Obligations 0.411459       196262.605085           41.15
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = N
# Match found at row 10. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2032 Summary ---
# Income (Salary): 67497.90
# Previous Wealth Carried: 409493.71
# Post-Tax Wealth (New Final Wealth): 476991.61
# ------------------------------
#
# 2033 9 33 48
# Starting Year: 2025
# Current Year: 2033
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 2, 'GOAL B': 7, 'GOAL C': 12, 'GOAL D': 42}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2033
# [DEBUG] Gross Gains (Normal account): 19975.65
# [DEBUG] Tax Calculated (Normal account): 5393.43
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           72.73
#    B           14.14
#    C           11.11
#    D            2.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 1.313131e-01        7.365235e+04           13.13
#         Developed Markets - Equities 1.025316e-16        5.750907e-11            0.00
# Emerging Markets State - Obligations 0.000000e+00        0.000000e+00            0.00
#       High Yield Bonds - Obligations 1.777742e-17        9.971194e-12            0.00
# Investment Grade Bonds - Obligations 0.000000e+00        0.000000e+00            0.00
#    Government ZC Bonds - Obligations 8.686869e-01        4.872386e+05           86.87
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = N
# Match found at row 11. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2033 Summary ---
# Income (Salary): 68172.87
# Previous Wealth Carried: 492718.09
# Post-Tax Wealth (New Final Wealth): 560890.96
# ------------------------------
#
# 2034 10 34 49
# Starting Year: 2025
# Current Year: 2034
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 1, 'GOAL B': 6, 'GOAL C': 11, 'GOAL D': 41}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2034
# [DEBUG] Gross Gains (Normal account): 26488.96
# [DEBUG] Tax Calculated (Normal account): 7152.02
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            63.0
#    B            14.0
#    C            18.0
#    D             5.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 2.300000e-01        1.481954e+05            23.0
#         Developed Markets - Equities 1.417166e-14        9.131192e-09             0.0
# Emerging Markets State - Obligations 1.180558e-17        7.606662e-12             0.0
#       High Yield Bonds - Obligations 5.198681e-18        3.349655e-12             0.0
# Investment Grade Bonds - Obligations 0.000000e+00        0.000000e+00             0.0
#    Government ZC Bonds - Obligations 7.700000e-01        4.961324e+05            77.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = N
# Match found at row 12. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2034 Summary ---
# Income (Salary): 68854.60
# Previous Wealth Carried: 575473.19
# Post-Tax Wealth (New Final Wealth): 644327.79
# ------------------------------
#
# 2035 11 35 50
# Starting Year: 2025
# Current Year: 2035
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 0, 'GOAL B': 5, 'GOAL C': 10, 'GOAL D': 40}
# C:\Users\admin\AppData\Local\Temp\ipykernel_27560\4021808357.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2035
# [DEBUG] Gross Gains (Normal account): 34828.84
# [DEBUG] Tax Calculated (Normal account): 9403.79
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B            11.0
#    C            43.0
#    D            46.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 4.600000e-01        3.372756e+05            46.0
#         Developed Markets - Equities 0.000000e+00        0.000000e+00             0.0
# Emerging Markets State - Obligations 6.144391e-17        4.505116e-11             0.0
#       High Yield Bonds - Obligations 3.191891e-17        2.340320e-11             0.0
# Investment Grade Bonds - Obligations 6.383782e-17        4.680640e-11             0.0
#    Government ZC Bonds - Obligations 5.400000e-01        3.959323e+05            54.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = N
# Match found at row 13. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2035 Summary ---
# Income (Salary): 69543.15
# Previous Wealth Carried: 663664.73
# Post-Tax Wealth (New Final Wealth): 733207.88
# ------------------------------
#
# 2036 12 36 51
# Starting Year: 2025
# Current Year: 2036
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -1, 'GOAL B': 4, 'GOAL C': 9, 'GOAL D': 39}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2036
# [DEBUG] Gross Gains (Normal account): 37204.15
# [DEBUG] Tax Calculated (Normal account): 10045.12
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             9.0
#    C            37.0
#    D            54.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.536428       448360.017765           53.64
#         Developed Markets - Equities 0.001095          915.017835            0.11
# Emerging Markets State - Obligations 0.000562          469.946971            0.06
#       High Yield Bonds - Obligations 0.002500         2089.885782            0.25
# Investment Grade Bonds - Obligations 0.002100         1754.852771            0.21
#    Government ZC Bonds - Obligations 0.457316       382236.114120           45.73
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = N
# Match found at row 14. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2036 Summary ---
# Income (Salary): 77192.90
# Previous Wealth Carried: 758632.94
# Post-Tax Wealth (New Final Wealth): 835825.84
# ------------------------------
#
# 2037 13 37 52
# Starting Year: 2025
# Current Year: 2037
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -2, 'GOAL B': 3, 'GOAL C': 8, 'GOAL D': 38}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2037
# [DEBUG] Gross Gains (Normal account): 43331.42
# [DEBUG] Tax Calculated (Normal account): 11699.48
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            8.08
#    C           33.33
#    D           58.59
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.581509       549274.580172           58.15
#         Developed Markets - Equities 0.002908         2747.170545            0.29
# Emerging Markets State - Obligations 0.002298         2170.821669            0.23
#       High Yield Bonds - Obligations 0.001709         1614.106391            0.17
# Investment Grade Bonds - Obligations 0.000141          132.936420            0.01
#    Government ZC Bonds - Obligations 0.411435       388627.930321           41.14
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = N
# Match found at row 15. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2037 Summary ---
# Income (Salary): 77964.82
# Previous Wealth Carried: 866602.72
# Post-Tax Wealth (New Final Wealth): 944567.55
# ------------------------------
#
# 2038 14 38 53
# Starting Year: 2025
# Current Year: 2038
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -3, 'GOAL B': 2, 'GOAL C': 7, 'GOAL D': 37}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2038
# [DEBUG] Gross Gains (Normal account): 49530.19
# [DEBUG] Tax Calculated (Normal account): 13373.15
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            8.08
#    C           30.30
#    D           61.62
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.000188          198.824701            0.02
#         Developed Markets - Equities 0.616293       652666.540121           61.63
# Emerging Markets State - Obligations 0.000986         1044.641352            0.10
#       High Yield Bonds - Obligations 0.000610          646.292748            0.06
# Investment Grade Bonds - Obligations 0.005187         5492.605386            0.52
#    Government ZC Bonds - Obligations 0.376736       398970.574694           37.67
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = N
# Match found at row 16. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2038 Summary ---
# Income (Salary): 78744.47
# Previous Wealth Carried: 980275.01
# Post-Tax Wealth (New Final Wealth): 1059019.48
# ------------------------------
#
# 2039 15 39 54
# Starting Year: 2025
# Current Year: 2039
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -4, 'GOAL B': 1, 'GOAL C': 6, 'GOAL D': 36}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2039
# [DEBUG] Gross Gains (Normal account): 55767.87
# [DEBUG] Tax Calculated (Normal account): 15057.32
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             9.0
#    C            27.0
#    D            64.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.635007       748863.403723           63.50
#         Developed Markets - Equities 0.001674         1974.192002            0.17
# Emerging Markets State - Obligations 0.001847         2178.135382            0.18
#       High Yield Bonds - Obligations 0.000570          671.720780            0.06
# Investment Grade Bonds - Obligations 0.001089         1284.073960            0.11
#    Government ZC Bonds - Obligations 0.359814       424327.988969           35.98
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = N
# Match found at row 17. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2039 Summary ---
# Income (Salary): 79531.92
# Previous Wealth Carried: 1099767.60
# Post-Tax Wealth (New Final Wealth): 1179299.51
# ------------------------------
#
# 2040 16 40 55
# Starting Year: 2025
# Current Year: 2040
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -5, 'GOAL B': 0, 'GOAL C': 5, 'GOAL D': 35}
# C:\Users\admin\AppData\Local\Temp\ipykernel_27560\4021808357.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2040
# [DEBUG] Gross Gains (Normal account): 65642.68
# [DEBUG] Tax Calculated (Normal account): 17723.52
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C           25.53
#    D           74.47
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.184193       241930.953444           18.42
#         Developed Markets - Equities 0.548246       720100.612945           54.82
# Emerging Markets State - Obligations 0.001533         2013.366108            0.15
#       High Yield Bonds - Obligations 0.007475         9817.769802            0.75
# Investment Grade Bonds - Obligations 0.009507        12487.686991            0.95
#    Government ZC Bonds - Obligations 0.249046       327111.951823           24.90
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = N
# Match found at row 18. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2040 Summary ---
# Income (Salary): 88280.43
# Previous Wealth Carried: 1225181.91
# Post-Tax Wealth (New Final Wealth): 1313462.34
# ------------------------------
#
# 2041 17 41 56
# Starting Year: 2025
# Current Year: 2041
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -6, 'GOAL B': -1, 'GOAL C': 4, 'GOAL D': 34}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2041
# [DEBUG] Gross Gains (Normal account): 74632.49
# [DEBUG] Tax Calculated (Normal account): 21220.64
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C           21.43
#    D           78.57
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.201101       292878.202450           20.11
#         Developed Markets - Equities 0.578515       842532.950501           57.85
# Emerging Markets State - Obligations 0.001841         2681.349359            0.18
#       High Yield Bonds - Obligations 0.002732         3978.250518            0.27
# Investment Grade Bonds - Obligations 0.002371         3452.826005            0.24
#    Government ZC Bonds - Obligations 0.213440       310847.233493           21.34
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = N
# Match found at row 19. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2041 Summary ---
# Income (Salary): 89163.23
# Previous Wealth Carried: 1367207.58
# Post-Tax Wealth (New Final Wealth): 1456370.81
# ------------------------------
#
# 2042 18 42 57
# Starting Year: 2025
# Current Year: 2042
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -7, 'GOAL B': -2, 'GOAL C': 3, 'GOAL D': 33}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2042
# [DEBUG] Gross Gains (Normal account): 82152.81
# [DEBUG] Tax Calculated (Normal account): 24379.18
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C            22.0
#    D            78.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 1.971551e-01        3.167101e+05           19.72
#         Developed Markets - Equities 5.828449e-01        9.362824e+05           58.28
# Emerging Markets State - Obligations 1.463022e-16        2.350200e-10            0.00
#       High Yield Bonds - Obligations 5.412337e-18        8.694382e-12            0.00
# Investment Grade Bonds - Obligations 0.000000e+00        0.000000e+00            0.00
#    Government ZC Bonds - Obligations 2.200000e-01        3.534081e+05           22.00
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = N
# Match found at row 20. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2042 Summary ---
# Income (Salary): 90054.87
# Previous Wealth Carried: 1516345.74
# Post-Tax Wealth (New Final Wealth): 1606400.60
# ------------------------------
#
# 2043 19 43 58
# Starting Year: 2025
# Current Year: 2043
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -8, 'GOAL B': -3, 'GOAL C': 2, 'GOAL D': 32}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2043
# [DEBUG] Gross Gains (Normal account): 90395.66
# [DEBUG] Tax Calculated (Normal account): 27841.18
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C           18.75
#    D           81.25
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.199456        3.515466e+05           19.95
#         Developed Markets - Equities 0.590818        1.041330e+06           59.08
# Emerging Markets State - Obligations 0.004302        7.582466e+03            0.43
#       High Yield Bonds - Obligations 0.011507        2.028156e+04            1.15
# Investment Grade Bonds - Obligations 0.005810        1.024066e+04            0.58
#    Government ZC Bonds - Obligations 0.188107        3.315421e+05           18.81
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = N
# Match found at row 21. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2043 Summary ---
# Income (Salary): 90955.41
# Previous Wealth Carried: 1671567.55
# Post-Tax Wealth (New Final Wealth): 1762522.97
# ------------------------------
#
# 2044 20 44 59
# Starting Year: 2025
# Current Year: 2044
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -9, 'GOAL B': -4, 'GOAL C': 1, 'GOAL D': 31}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2044
# [DEBUG] Gross Gains (Normal account): 100013.21
# [DEBUG] Tax Calculated (Normal account): 31880.55
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C            19.0
#    D            81.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 2.059142e-01        3.983135e+05           20.59
#         Developed Markets - Equities 6.040858e-01        1.168523e+06           60.41
# Emerging Markets State - Obligations 2.501142e-17        4.838125e-11            0.00
#       High Yield Bonds - Obligations 7.518241e-17        1.454303e-10            0.00
# Investment Grade Bonds - Obligations 1.331741e-17        2.576076e-11            0.00
#    Government ZC Bonds - Obligations 1.900000e-01        3.675296e+05           19.00
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = N
# Match found at row 22. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2044 Summary ---
# Income (Salary): 100960.51
# Previous Wealth Carried: 1833406.02
# Post-Tax Wealth (New Final Wealth): 1934366.53
# ------------------------------
#
# 2045 21 45 60
# Starting Year: 2025
# Current Year: 2045
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -10, 'GOAL B': -5, 'GOAL C': 0, 'GOAL D': 30}
# C:\Users\admin\AppData\Local\Temp\ipykernel_27560\4021808357.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2045
# [DEBUG] Gross Gains (Normal account): 115308.36
# [DEBUG] Tax Calculated (Normal account): 38304.51
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.241843        5.112208e+05           24.18
#         Developed Markets - Equities 0.673588        1.423865e+06           67.36
# Emerging Markets State - Obligations 0.002074        4.384813e+03            0.21
#       High Yield Bonds - Obligations 0.002686        5.678731e+03            0.27
# Investment Grade Bonds - Obligations 0.024303        5.137351e+04            2.43
#    Government ZC Bonds - Obligations 0.055505        1.173285e+05            5.55
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = N
# Match found at row 23. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2045 Summary ---
# Income (Salary): 101970.11
# Previous Wealth Carried: 2011881.33
# Post-Tax Wealth (New Final Wealth): 2113851.44
# ------------------------------
#
# 2046 22 46 61
# Starting Year: 2025
# Current Year: 2046
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -11, 'GOAL B': -6, 'GOAL C': -1, 'GOAL D': 29}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2046
# [DEBUG] Gross Gains (Normal account): 129783.25
# [DEBUG] Tax Calculated (Normal account): 44383.97
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.251342        5.791951e+05           25.13
#         Developed Markets - Equities 0.732777        1.688623e+06           73.28
# Emerging Markets State - Obligations 0.003057        7.045208e+03            0.31
#       High Yield Bonds - Obligations 0.001390        3.203072e+03            0.14
# Investment Grade Bonds - Obligations 0.004291        9.887372e+03            0.43
#    Government ZC Bonds - Obligations 0.007143        1.646075e+04            0.71
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = N
# Match found at row 24. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2046 Summary ---
# Income (Salary): 102989.82
# Previous Wealth Carried: 2201424.27
# Post-Tax Wealth (New Final Wealth): 2304414.09
# ------------------------------
#
# 2047 23 47 62
# Starting Year: 2025
# Current Year: 2047
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -12, 'GOAL B': -7, 'GOAL C': -2, 'GOAL D': 28}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2047
# [DEBUG] Gross Gains (Normal account): 140720.86
# [DEBUG] Tax Calculated (Normal account): 48977.76
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.252896        6.336907e+05           25.29
#         Developed Markets - Equities 0.733455        1.837847e+06           73.35
# Emerging Markets State - Obligations 0.006284        1.574652e+04            0.63
#       High Yield Bonds - Obligations 0.001172        2.936360e+03            0.12
# Investment Grade Bonds - Obligations 0.000624        1.563501e+03            0.06
#    Government ZC Bonds - Obligations 0.005569        1.395549e+04            0.56
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = N
# Match found at row 25. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2047 Summary ---
# Income (Salary): 104019.71
# Previous Wealth Carried: 2401719.32
# Post-Tax Wealth (New Final Wealth): 2505739.04
# ------------------------------
#
# 2048 24 48 63
# Starting Year: 2025
# Current Year: 2048
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -13, 'GOAL B': -8, 'GOAL C': -3, 'GOAL D': 27}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2048
# [DEBUG] Gross Gains (Normal account): 149131.01
# [DEBUG] Tax Calculated (Normal account): 52510.02
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.240916        6.568235e+05           24.09
#         Developed Markets - Equities 0.702516        1.915310e+06           70.25
# Emerging Markets State - Obligations 0.001807        4.926440e+03            0.18
#       High Yield Bonds - Obligations 0.001286        3.505714e+03            0.13
# Investment Grade Bonds - Obligations 0.001746        4.759802e+03            0.17
#    Government ZC Bonds - Obligations 0.051729        1.410308e+05            5.17
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = N
# Match found at row 26. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2048 Summary ---
# Income (Salary): 115461.88
# Previous Wealth Carried: 2610894.19
# Post-Tax Wealth (New Final Wealth): 2726356.07
# ------------------------------
#
# 2049 25 49 64
# Starting Year: 2025
# Current Year: 2049
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -14, 'GOAL B': -9, 'GOAL C': -4, 'GOAL D': 26}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2049
# [DEBUG] Gross Gains (Normal account): 163785.20
# [DEBUG] Tax Calculated (Normal account): 58664.78
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
# ...
# Adjusted Horizons: {'GOAL A': -36, 'GOAL B': -31, 'GOAL C': -26, 'GOAL D': 4}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2071
# [DEBUG] Gross Gains (Normal account): 330672.07
# [DEBUG] Tax Calculated (Normal account): 128757.27
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset  Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities     0.0        0.000000e+00             0.0
#         Developed Markets - Equities     0.0        0.000000e+00             0.0
# Emerging Markets State - Obligations     0.0        0.000000e+00             0.0
#       High Yield Bonds - Obligations     0.0        0.000000e+00             0.0
# Investment Grade Bonds - Obligations     0.0        0.000000e+00             0.0
#    Government ZC Bonds - Obligations     1.0        9.640585e+06           100.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = N
# Match found at row 49. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2071 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 9640585.18
# Post-Tax Wealth (New Final Wealth): 9640585.18
# ------------------------------
#
# 2072 48 72 87
# Starting Year: 2025
# Current Year: 2072
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -37, 'GOAL B': -32, 'GOAL C': -27, 'GOAL D': 3}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2072
# [DEBUG] Gross Gains (Normal account): 337597.75
# [DEBUG] Tax Calculated (Normal account): 131666.05
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset  Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities     0.0        0.000000e+00             0.0
#         Developed Markets - Equities     0.0        0.000000e+00             0.0
# Emerging Markets State - Obligations     0.0        0.000000e+00             0.0
#       High Yield Bonds - Obligations     0.0        0.000000e+00             0.0
# Investment Grade Bonds - Obligations     0.0        0.000000e+00             0.0
#    Government ZC Bonds - Obligations     1.0        9.842500e+06           100.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = N
# Match found at row 50. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2072 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 9842499.98
# Post-Tax Wealth (New Final Wealth): 9842499.98
# ------------------------------
#
# 2073 49 73 88
# Starting Year: 2025
# Current Year: 2073
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -38, 'GOAL B': -33, 'GOAL C': -28, 'GOAL D': 2}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2073
# [DEBUG] Gross Gains (Normal account): 344661.21
# [DEBUG] Tax Calculated (Normal account): 134632.71
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset  Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities     0.0        0.000000e+00             0.0
#         Developed Markets - Equities     0.0        0.000000e+00             0.0
# Emerging Markets State - Obligations     0.0        0.000000e+00             0.0
#       High Yield Bonds - Obligations     0.0        0.000000e+00             0.0
# Investment Grade Bonds - Obligations     0.0        0.000000e+00             0.0
#    Government ZC Bonds - Obligations     1.0        1.004843e+07           100.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = N
# Match found at row 51. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2073 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 10048431.67
# Post-Tax Wealth (New Final Wealth): 10048431.67
# ------------------------------
#
# 2074 50 74 89
# Starting Year: 2025
# Current Year: 2074
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -39, 'GOAL B': -34, 'GOAL C': -29, 'GOAL D': 1}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2074
# [DEBUG] Gross Gains (Normal account): 351865.18
# [DEBUG] Tax Calculated (Normal account): 137658.38
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset  Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities     0.0        0.000000e+00             0.0
#         Developed Markets - Equities     0.0        0.000000e+00             0.0
# Emerging Markets State - Obligations     0.0        0.000000e+00             0.0
#       High Yield Bonds - Obligations     0.0        0.000000e+00             0.0
# Investment Grade Bonds - Obligations     0.0        0.000000e+00             0.0
#    Government ZC Bonds - Obligations     1.0        1.025846e+07           100.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = Y
# Row 52: Year = 2074.0, Status = N
# Match found at row 52. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2074 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 10258460.17
# Post-Tax Wealth (New Final Wealth): 10258460.17
# ------------------------------
#
# 2075 51 75 90
# Starting Year: 2025
# Current Year: 2075
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -40, 'GOAL B': -35, 'GOAL C': -30, 'GOAL D': 0}
# C:\Users\admin\AppData\Local\Temp\ipykernel_27560\4021808357.py:3: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2075
# [DEBUG] Gross Gains (Normal account): 359212.48
# [DEBUG] Tax Calculated (Normal account): 140744.24
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset  Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities     0.0        0.000000e+00             0.0
#         Developed Markets - Equities     0.0        0.000000e+00             0.0
# Emerging Markets State - Obligations     0.0        0.000000e+00             0.0
#       High Yield Bonds - Obligations     0.0        0.000000e+00             0.0
# Investment Grade Bonds - Obligations     0.0        0.000000e+00             0.0
#    Government ZC Bonds - Obligations     1.0        1.047267e+07           100.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = Y
# Row 52: Year = 2074.0, Status = Y
# Row 53: Year = 2075.0, Status = N
# Match found at row 53. Updating status to 'Y'.
# Status updated successfully.
#
# --- Year 2075 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 10472666.98
# Post-Tax Wealth (New Final Wealth): 10472666.98
# ------------------------------
#
# All loops completed

# %%
# V7C: Export new asset-level log for debugging
pd.DataFrame(asset_level_log).to_csv(os.path.join(output_folder, "asset_returns_log.csv"), index=False)
