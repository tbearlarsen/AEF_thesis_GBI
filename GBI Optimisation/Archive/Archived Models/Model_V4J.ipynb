# %% [markdown]
# V1 (02 11 2025): Translated from R to Python and added the visualizations for goals B to D
#
#
# V2 (04 01 2025): Loop system implemented
#
# V2.5 (04 02 2025): Loops system tweaks. Removed openpyxl as it was corrupting files and replaced it with xlwings

# %%
#!pip install numpy pandas scipy matplotlib xlwings

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import subprocess
import xlwings as xw
import time

# %%
# -- Variable Setup -- ##

#Monte Carlo Trials
n_trials = 10**5

#Case Study Profile Selection
Profile = "P1" #Either P1 or P2

#Excel worksheets
excel_returns = "Returns3"
excel_volatilities = "Volatilities"
excel_correlation = "Correlation"
excel_gbi = "GBI Allocations P1" if Profile == "P1" else "GBI Allocations P2"
excel_gbi_goals = "GBI Goals P1" if Profile == "P1" else "GBI Goals P2"

# %% [markdown]
# # Define Functions
# This section defines the functions used for calculating portfolio volatility, expected return,
# goal achievement probability, and the objective (failure probability) to minimize.

# %%
def sd_f(weight_vector, covar_table):
    covar_vector = np.zeros(len(weight_vector))
    for z in range(len(weight_vector)):
        covar_vector[z] = np.sum(weight_vector * covar_table[:, z])
    return np.sqrt(np.sum(weight_vector * covar_vector))

# %%
def mean_f(weight_vector, return_vector):
    return np.sum(weight_vector * return_vector)

# %%
"""def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    # goal_vector is [value ratio, funding requirement, time horizon]
    required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
    if goal_allocation * pool >= goal_vector[1]:
        return 1
    else:
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)

""" #Made new version below that takes into account cases where the goal is too unreachable and writes down when that happens

def phi_f(goal_vector, goal_allocation, pool, mean, sd, year=None, goal_name=None):
    denominator = pool * goal_allocation
    if denominator <= 0:
        if year and goal_name:
            infeasible_goals_log.append((year, goal_name, "Zero allocation or pool"))
        return 0

    required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1

    if required_return > 1:
        if year and goal_name:
            infeasible_goals_log.append((year, goal_name, f"Required return > 100% ({required_return:.2%})"))
        return 0

    if denominator >= goal_vector[1]:
        return 1

    return 1 - norm.cdf(required_return, loc=mean, scale=sd)

# %%
def optim_function(weights):
    # Uses the current global variables: goal_vector, allocation, pool, return_vector, covar_table
    return 1 - phi_f(
        goal_vector,
        allocation,
        pool,
        mean_f(weights, return_vector),
        sd_f(weights, covar_table)
    )

# %%
def constraint_function(weights):
    # For SciPy equality constraints, we require constraint_function(weights) == 0.
    return np.sum(weights) - 1

# %%
def mvu_f(weights):
    # mvu_f is defined for mean-variance optimization (not used below).
    return -(mean_f(weights, return_vector) - 0.5 * gamma * sd_f(weights, covariances)**2)

# %%
def r_req_f(goal_vector, goal_allocation, pool):
    return (goal_vector[1] / (goal_allocation * pool))**(1 / goal_vector[2]) - 1

# %%
def get_goal_data(master_excel_path, plan=Profile):
    """
    Returns a DataFrame of the specified goal table (P1 or P2).
    P1 => B2:F5
    P2 => B7:F10
    """
    if plan == "P1":
        skip = 1  # start reading at row 2
    elif plan == "P2":
        skip = 6  # start reading at row 7
    else:
        raise ValueError("Plan not recognized. Use 'P1' or 'P2'.")

    df_goals = pd.read_excel(master_excel_path,sheet_name="Goals",skiprows=skip,nrows=4,usecols="B:F",header=0)
    # First column is "Goal Info", so make that the index
    df_goals.set_index(df_goals.columns[0], inplace=True)
    return df_goals

# %% [markdown]
# # Load & Parse Data

# %%
## -- Repo Root and Folders -- ##

# Get repo root and set folders
root = subprocess.run(["git", "rev-parse", "--show-toplevel"], capture_output=True, text=True).stdout.strip()
data_folder = os.path.join(root, "GBI Optimisation", "data")
output_folder = os.path.join(root, "GBI Optimisation")

# Get excel file and sheets
master_excel_path = os.path.join(data_folder, "Master.xlsx")

df_returns = pd.read_excel(master_excel_path, sheet_name=excel_returns)
df_vols = pd.read_excel(master_excel_path, sheet_name=excel_volatilities)

df_returns.set_index(df_returns.columns[0], inplace=True)
df_vols.set_index(df_vols.columns[0], inplace=True)

df_corr = pd.read_excel(master_excel_path, sheet_name=excel_correlation)
df_corr.set_index(df_corr.columns[0], inplace=True)

# %%
infeasible_goals_log = [] #Added for the new phi_f definition


while True:
    ## -- Loop Table -- ##
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop",usecols="B:F",skiprows=1,header=0)
    # Find Last looped year and select the next one
    # Filter only rows where LoopStatus is N
    pending_rows = table_loop_df[table_loop_df["LoopStatus"] == "N"]

    # If we find any rows, get the row with the lowest Year
    if pending_rows.empty:
        print("All loops completed")
        break


    chosen_row = pending_rows.loc[pending_rows["Year"].idxmin()]
    loop_year = chosen_row["Year"]
    loop_number = chosen_row["N"]
    loop_age1 = chosen_row["AgeP1"]
    loop_age2 = chosen_row["AgeP2"]

    print(loop_year, loop_number, loop_age1, loop_age2)

    # - Wealth - #

    # Retrieve Wealth value for selected profile and year from "Wealth" sheet
    df_wealth = pd.read_excel(master_excel_path, sheet_name="Wealth")
    df_wealth.set_index(df_wealth.columns[0], inplace=True)  # Set P1/P2 as index

    # Use profile and loop_year to get the correct pool value
    try:
        pool = df_wealth.loc[Profile, str(loop_year)]
    except KeyError:
        raise KeyError(f"Wealth data for profile '{Profile}' in year {loop_year} not found.")

    capital_market_expectations_raw = {}
    for asset in df_returns.index:
        expected_return = df_returns.loc[asset, str(loop_year)]
        volatility = df_vols.loc[asset, 'volatility']
        capital_market_expectations_raw[asset] = {
            'Return Forecast': expected_return,
            'Volatility Forecast': volatility
        }

    capital_market_expectations_raw = pd.DataFrame.from_dict(capital_market_expectations_raw, orient='index')

    capital_market_expectations_raw = capital_market_expectations_raw.reset_index()
    capital_market_expectations_raw.rename(columns={'index': 'Unnamed: 0'}, inplace=True)

    # Rearrange columns to match your old format (optional):
    capital_market_expectations_raw = capital_market_expectations_raw[['Unnamed: 0', 'Return Forecast', 'Volatility Forecast']]

    goal_data_raw = get_goal_data(master_excel_path, plan="P1")

    # - Dynamic time horizon based on current year - #

    # Step 1: Get Starting Year (minimum year in Loop sheet)
    starting_year = table_loop_df["Year"].min()

    # Step 2: Compute Goal Years = starting_year + time_horizon
    goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
    goal_years = starting_year + goal_horizons

    # Step 3: Recalculate Time Horizons = goal_years - current loop_year
    adjusted_horizons = goal_years - loop_year

    # Step 4: Replace the "Time Horizon" row in goal_data_raw
    goal_data_raw.loc["Time Horizon"] = adjusted_horizons

    goals = ["A", "B", "C", "D"]
    active_goal_mask = np.array([adjusted_horizons[f"GOAL {g}"] > 0 for g in goals])

    # Optional: print to confirm
    print("Starting Year:", starting_year)
    print("Current Year:", loop_year)
    print("Goal Years:", goal_years.to_dict())
    print("Adjusted Horizons:", adjusted_horizons.to_dict())

    # Record number of potential investments and goals
    num_assets = capital_market_expectations_raw.shape[0]
    num_goals = goal_data_raw.shape[1]

    # Create vector of expected returns
    return_vector = capital_market_expectations_raw["Return Forecast"].to_numpy()

    # Get the correlations as a numeric DataFrame (just a num_assets × num_assets block)
    correlations = df_corr.iloc[:num_assets, :num_assets].astype(float)

    # Build the covariance matrix: stdev_i * stdev_j * correlation_ij
    stdevs = capital_market_expectations_raw["Volatility Forecast"].to_numpy()
    covariances = np.zeros((num_assets, num_assets))
    for i in range(num_assets):
        for j in range(num_assets):
            covariances[i, j] = stdevs[i] * stdevs[j] * correlations.iloc[i, j]

    goal_A = goal_data_raw["GOAL A"].values
    goal_B = goal_data_raw["GOAL B"].values
    goal_C = goal_data_raw["GOAL C"].values
    goal_D = goal_data_raw["GOAL D"].values

    # - Optimal Goal Allocation - #


    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    # Set SLSQP options to be more stringent, mimicking solnp's behavior.
    slsqp_opts = {
        'ftol': 1e-12,     # function tolerance
        'eps': 1e-12,      # finite-difference step size for gradient estimation
        'maxiter': 10000,  # maximum iterations
        'disp': False     # do not display convergence messages
    }

    for i, alloc in enumerate(goal_allocation):
        allocation = alloc      # Global variable used in optim_function
        covar_table = covariances

        # Goal A Optimization
        goal_vector = goal_A   # Global variable used in optim_function
        if goal_A[1] <= pool * allocation:
            optimal_weights_A[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_A[i, :] = result.x

        # Goal B Optimization
        goal_vector = goal_B
        if goal_B[1] <= pool * allocation:
            optimal_weights_B[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_B[i, :] = result.x

        # Goal C Optimization
        goal_vector = goal_C
        if goal_C[1] <= pool * allocation:
            optimal_weights_C[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_C[i, :] = result.x

        # Goal D Optimization
        goal_vector = goal_D
        if goal_D[1] <= pool * allocation:
            optimal_weights_D[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_D[i, :] = result.x

    # Calculate the best probability (phi) for each allocation level for every goal
    phi_A = np.zeros(len(goal_allocation))
    phi_B = np.zeros(len(goal_allocation))
    phi_C = np.zeros(len(goal_allocation))
    phi_D = np.zeros(len(goal_allocation))

    for i, alloc in enumerate(goal_allocation):
        phi_A[i] = phi_f(goal_A, alloc, pool,
                         mean_f(optimal_weights_A[i, :], return_vector),
                         sd_f(optimal_weights_A[i, :], covariances), year=loop_year, goal_name="Goal A")
        phi_B[i] = phi_f(goal_B, alloc, pool,
                         mean_f(optimal_weights_B[i, :], return_vector),
                         sd_f(optimal_weights_B[i, :], covariances), year=loop_year, goal_name="Goal B")
        phi_C[i] = phi_f(goal_C, alloc, pool,
                         mean_f(optimal_weights_C[i, :], return_vector),
                         sd_f(optimal_weights_C[i, :], covariances), year=loop_year, goal_name="Goal C")
        phi_D[i] = phi_f(goal_D, alloc, pool,
                         mean_f(optimal_weights_D[i, :], return_vector),
                         sd_f(optimal_weights_D[i, :], covariances), year=loop_year, goal_name="Goal D")

    # Simulate goal weights: each row is a simulated allocation (in percentages)
    sim_goal_weights = np.random.multinomial(100, [1/num_goals]*num_goals, size=n_trials) #this one sums to 100 so its good
    for i in range(n_trials):
        rand_vector = np.random.uniform(0, 1, num_goals)
        normalizer = np.sum(rand_vector)
        percents = np.round((rand_vector / normalizer) * 100, 0)

        # Only enforce floor for active goals
        floor_applied = np.where(active_goal_mask, np.maximum(percents, 1), percents)
        sim_goal_weights[i, :] = floor_applied


    # Calculate utility for each simulated portfolio.
    # Note: subtract 1 from simulated weights for 0-indexing.
    utility = (
        goal_A[0] * phi_A[sim_goal_weights[:, 0] - 1] +
        goal_A[0] * goal_B[0] * phi_B[sim_goal_weights[:, 1] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * phi_C[sim_goal_weights[:, 2] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * goal_D[0] * phi_D[sim_goal_weights[:, 3] - 1]
    )

    # Find the index of the portfolio with the highest utility
    index = np.argmax(utility)
    optimal_goal_weights = sim_goal_weights[index, :]

    # - Optimal Subportfolio Allocation - #

    # Retrieve optimal subportfolio allocations
    optimal_subportfolios = np.zeros((num_goals, num_assets))

    # For each goal, use the simulated percentage to select the corresponding row
    # from the optimal weights matrix (adjust for zero-indexing)
    for i in range(num_goals):
        optimal_subportfolios[i, :] = eval(f"optimal_weights_{goals[i]}")[optimal_goal_weights[i] - 1, :]

    # Compute the optimal aggregate investment portfolio.
    optimal_aggregate_portfolio = (optimal_goal_weights / 100) @ optimal_subportfolios

    #Define asset names
    asset_names = capital_market_expectations_raw.iloc[:, 0].astype(str).tolist()

    # - Storing and exporting results - #

    # Create a DataFrame for the aggregate portfolio.
    # First calculate unrounded percentages
    raw_alloc = optimal_aggregate_portfolio * 100

    # Normalize to force sum = 100 after rounding
    normalized_alloc = raw_alloc / raw_alloc.sum() * 100
    normalized_goal_alloc = np.zeros_like(optimal_goal_weights, dtype=float)
    active_sum = np.sum(optimal_goal_weights[active_goal_mask])
    normalized_goal_alloc[active_goal_mask] = (optimal_goal_weights[active_goal_mask] / active_sum) * 100

    # Create a DataFrame for the across-goal allocation.
    df_across_goal = pd.DataFrame({
        "Goal": goals,
        "Allocation (%)": np.round(normalized_goal_alloc, 2) # Keep raw percentages
    })

    # Round after normalization
    df_aggregate = pd.DataFrame({
        "Asset": asset_names,
        "Weight": optimal_aggregate_portfolio,
        "Allocation (%)": np.round(normalized_alloc, 2)
    })

    print("Optimal Across-Goal Allocation:")
    print(df_across_goal.to_string(index=False))

    print("\nOptimal Aggregate Investment Allocation:")
    print(df_aggregate.to_string(index=False))

    # -- Safer Excel launch --
    app = xw.App(visible=False)
    app.display_alerts = False
    app.screen_updating = False

    time.sleep(1)

    # Open workbook
    wb = app.books.open(master_excel_path)
    ws = wb.sheets[excel_gbi]

    # Get header values from row 1 (columns B to AY ~= cols 2 to 51)
    header_values = [ws.cells(1, col).value for col in range(2, 53)]

    try:
        year_col = header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in worksheet headers.")

    # Write weights
    for i, asset in enumerate(asset_names):
        allocation = float(np.round(normalized_alloc[i], 2)) / 100
        cell = ws.cells(i + 2, year_col)
        cell.value = allocation
        cell.number_format = '0.00%'  # display as percentage

    # -- Export Goal Weights to Excel -- #

    # Re-access the sheet after workbook is open
    ws_goals = wb.sheets[excel_gbi_goals]

    # Read header values from row 1 (columns B to AY ≈ cols 2 to 52)
    goal_header_values = [ws_goals.cells(1, col).value for col in range(2, 53)]

    try:
        goal_year_col = goal_header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in goal worksheet headers.")

    # Write each across-goal allocation to the appropriate row
    for i, allocation in enumerate(df_across_goal["Allocation (%)"]):
        value = float(np.round(allocation / 100, 6))  # convert to decimal
        row = i + 2  # assuming goal names are in rows starting at 2
        cell = ws_goals.cells(row, goal_year_col)
        cell.value = value
        cell.number_format = '0.00%'  # display as percentage

    # -- Modify Loop Check -- #
    print("Starting loop status check...")

    ws_loop = wb.sheets["Loop"]
    print("Accessed 'Loop' worksheet.")

    # Read data range again (columns B to F)
    last_row = ws_loop.cells.last_cell.row
    print(f"Last cell row: {last_row}")

    loop_data = ws_loop.range("B2:F" + str(last_row)).value
    print(f"Loaded loop data. Total rows read: {len(loop_data)}")

    # Find and update the matching year with LoopStatus 'N'
    found = False
    for i, row in enumerate(loop_data):
        year = row[1]
        status = row[4]
        print(f"Row {i+2}: Year = {year}, Status = {status}")
        if year == loop_year and status == 'N':
            print(f"Match found at row {i+2}. Updating status to 'Y'.")
            ws_loop.cells(i + 2, 6).value = 'Y'  # Column F is column 6
            found = True
            break

    if not found:
        print(f"No matching row found for year {loop_year} with status 'N'.")
    else:
        print("Status updated successfully.")

    wb.save()
    wb.close()
    app.quit()
    time.sleep(1)
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop", usecols="B:F", skiprows=1, header=0)
# Out:
# 2025 1 25 40
# Starting Year: 2025
# Current Year: 2025
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 10, 'GOAL B': 15, 'GOAL C': 20, 'GOAL D': 35}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             2.0
#    B            95.0
#    C             1.0
#    D             2.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.513567           51.36
#         Developed Markets - Equities 0.057907            5.79
# Emerging Markets State - Obligations 0.010068            1.01
#       High Yield Bonds - Obligations 0.006976            0.70
# Investment Grade Bonds - Obligations 0.403725           40.37
#    Government ZC Bonds - Obligations 0.007758            0.78
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = N
# Match found at row 3. Updating status to 'Y'.
# Status updated successfully.
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 9, 'GOAL B': 14, 'GOAL C': 19, 'GOAL D': 34}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.99
#    B           70.30
#    C           27.72
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.284041           28.12
#         Developed Markets - Equities 0.001760            0.17
# Emerging Markets State - Obligations 0.004392            0.43
#       High Yield Bonds - Obligations 0.004300            0.43
# Investment Grade Bonds - Obligations 0.001370            0.14
#    Government ZC Bonds - Obligations 0.714137           70.71
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = N
# Match found at row 4. Updating status to 'Y'.
# Status updated successfully.
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 8, 'GOAL B': 13, 'GOAL C': 18, 'GOAL D': 33}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           77.23
#    B           20.79
#    C            0.99
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.993876           98.40
#         Developed Markets - Equities 0.000980            0.10
# Emerging Markets State - Obligations 0.004711            0.47
#       High Yield Bonds - Obligations 0.003571            0.35
# Investment Grade Bonds - Obligations 0.001431            0.14
#    Government ZC Bonds - Obligations 0.005431            0.54
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = N
# Match found at row 5. Updating status to 'Y'.
# Status updated successfully.
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 7, 'GOAL B': 12, 'GOAL C': 17, 'GOAL D': 32}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           77.23
#    B           20.79
#    C            0.99
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.975022           96.54
#         Developed Markets - Equities 0.021877            2.17
# Emerging Markets State - Obligations 0.006035            0.60
#       High Yield Bonds - Obligations 0.001035            0.10
# Investment Grade Bonds - Obligations 0.005617            0.56
#    Government ZC Bonds - Obligations 0.000415            0.04
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = N
# Match found at row 6. Updating status to 'Y'.
# Status updated successfully.
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 6, 'GOAL B': 11, 'GOAL C': 16, 'GOAL D': 31}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            81.0
#    B            17.0
#    C             1.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.982528           98.25
#         Developed Markets - Equities 0.003228            0.32
# Emerging Markets State - Obligations 0.004338            0.43
#       High Yield Bonds - Obligations 0.004605            0.46
# Investment Grade Bonds - Obligations 0.000636            0.06
#    Government ZC Bonds - Obligations 0.004665            0.47
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = N
# Match found at row 7. Updating status to 'Y'.
# Status updated successfully.
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 5, 'GOAL B': 10, 'GOAL C': 15, 'GOAL D': 30}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           75.25
#    B           21.78
#    C            0.99
#    D            1.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.760287           75.28
#         Developed Markets - Equities 0.009606            0.95
# Emerging Markets State - Obligations 0.000327            0.03
#       High Yield Bonds - Obligations 0.000465            0.05
# Investment Grade Bonds - Obligations 0.010457            1.04
#    Government ZC Bonds - Obligations 0.228858           22.66
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = N
# Match found at row 8. Updating status to 'Y'.
# Status updated successfully.
# 2031 7 31 46
# Starting Year: 2025
# Current Year: 2031
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 4, 'GOAL B': 9, 'GOAL C': 14, 'GOAL D': 29}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           94.12
#    B            0.98
#    C            1.96
#    D            2.94
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.198328           19.44
#         Developed Markets - Equities 0.008945            0.88
# Emerging Markets State - Obligations 0.008159            0.80
#       High Yield Bonds - Obligations 0.010928            1.07
# Investment Grade Bonds - Obligations 0.287744           28.21
#    Government ZC Bonds - Obligations 0.505896           49.60
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = N
# Match found at row 9. Updating status to 'Y'.
# Status updated successfully.
# 2032 8 32 47
# Starting Year: 2025
# Current Year: 2032
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 3, 'GOAL B': 8, 'GOAL C': 13, 'GOAL D': 28}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            84.0
#    B            12.0
#    C             1.0
#    D             3.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.067391            6.74
#         Developed Markets - Equities 0.003496            0.35
# Emerging Markets State - Obligations 0.020420            2.04
#       High Yield Bonds - Obligations 0.062934            6.29
# Investment Grade Bonds - Obligations 0.002569            0.26
#    Government ZC Bonds - Obligations 0.843190           84.32
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = N
# Match found at row 10. Updating status to 'Y'.
# Status updated successfully.
# 2033 9 33 48
# Starting Year: 2025
# Current Year: 2033
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 2, 'GOAL B': 7, 'GOAL C': 12, 'GOAL D': 27}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           73.27
#    B           13.86
#    C           10.89
#    D            1.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.112166           11.11
#         Developed Markets - Equities 0.004905            0.49
# Emerging Markets State - Obligations 0.003335            0.33
#       High Yield Bonds - Obligations 0.003705            0.37
# Investment Grade Bonds - Obligations 0.005124            0.51
#    Government ZC Bonds - Obligations 0.880764           87.20
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = N
# Match found at row 11. Updating status to 'Y'.
# Status updated successfully.
# 2034 10 34 49
# Starting Year: 2025
# Current Year: 2034
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 1, 'GOAL B': 6, 'GOAL C': 11, 'GOAL D': 26}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            65.0
#    B            13.0
#    C            20.0
#    D             2.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.200773           20.08
#         Developed Markets - Equities 0.004604            0.46
# Emerging Markets State - Obligations 0.000957            0.10
#       High Yield Bonds - Obligations 0.003399            0.34
# Investment Grade Bonds - Obligations 0.004071            0.41
#    Government ZC Bonds - Obligations 0.786196           78.62
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = N
# Match found at row 12. Updating status to 'Y'.
# Status updated successfully.
# 2035 11 35 50
# Starting Year: 2025
# Current Year: 2035
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': 0, 'GOAL B': 5, 'GOAL C': 10, 'GOAL D': 25}
# C:\Users\admin\AppData\Local\Temp\ipykernel_19344\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B            11.0
#    C            45.0
#    D            44.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Allocation (%)
#          Emerging Markets - Equities 4.400000e-01            44.0
#         Developed Markets - Equities 5.301104e-17             0.0
# Emerging Markets State - Obligations 0.000000e+00             0.0
#       High Yield Bonds - Obligations 0.000000e+00             0.0
# Investment Grade Bonds - Obligations 0.000000e+00             0.0
#    Government ZC Bonds - Obligations 5.600000e-01            56.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = N
# Match found at row 13. Updating status to 'Y'.
# Status updated successfully.
# 2036 12 36 51
# Starting Year: 2025
# Current Year: 2036
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -1, 'GOAL B': 4, 'GOAL C': 9, 'GOAL D': 24}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B           10.10
#    C           39.39
#    D           50.51
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.508298           50.33
#         Developed Markets - Equities 0.003802            0.38
# Emerging Markets State - Obligations 0.003275            0.32
#       High Yield Bonds - Obligations 0.001892            0.19
# Investment Grade Bonds - Obligations 0.000653            0.06
#    Government ZC Bonds - Obligations 0.492080           48.72
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = N
# Match found at row 14. Updating status to 'Y'.
# Status updated successfully.
# 2037 13 37 52
# Starting Year: 2025
# Current Year: 2037
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -2, 'GOAL B': 3, 'GOAL C': 8, 'GOAL D': 23}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            9.90
#    C           37.62
#    D           52.48
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Allocation (%)
#          Emerging Markets - Equities 5.300000e-01           52.48
#         Developed Markets - Equities 0.000000e+00            0.00
# Emerging Markets State - Obligations 0.000000e+00            0.00
#       High Yield Bonds - Obligations 0.000000e+00            0.00
# Investment Grade Bonds - Obligations 1.140060e-16            0.00
#    Government ZC Bonds - Obligations 4.800000e-01           47.52
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = N
# Match found at row 15. Updating status to 'Y'.
# Status updated successfully.
# 2038 14 38 53
# Starting Year: 2025
# Current Year: 2038
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -3, 'GOAL B': 2, 'GOAL C': 7, 'GOAL D': 22}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B           10.10
#    C           33.33
#    D           56.57
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.000003            0.00
#         Developed Markets - Equities 0.561587           56.16
# Emerging Markets State - Obligations 0.003234            0.32
#       High Yield Bonds - Obligations 0.002326            0.23
# Investment Grade Bonds - Obligations 0.000003            0.00
#    Government ZC Bonds - Obligations 0.432847           43.28
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = N
# Match found at row 16. Updating status to 'Y'.
# Status updated successfully.
# 2039 15 39 54
# Starting Year: 2025
# Current Year: 2039
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -4, 'GOAL B': 1, 'GOAL C': 6, 'GOAL D': 21}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            8.08
#    C           30.30
#    D           61.62
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Allocation (%)
#          Emerging Markets - Equities 6.100000e-01           61.62
#         Developed Markets - Equities 7.788215e-15            0.00
# Emerging Markets State - Obligations 0.000000e+00            0.00
#       High Yield Bonds - Obligations 0.000000e+00            0.00
# Investment Grade Bonds - Obligations 0.000000e+00            0.00
#    Government ZC Bonds - Obligations 3.800000e-01           38.38
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = N
# Match found at row 17. Updating status to 'Y'.
# Status updated successfully.
# 2040 16 40 55
# Starting Year: 2025
# Current Year: 2040
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -5, 'GOAL B': 0, 'GOAL C': 5, 'GOAL D': 20}
# C:\Users\admin\AppData\Local\Temp\ipykernel_19344\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C            30.3
#    D            69.7
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.692426           69.24
#         Developed Markets - Equities 0.003542            0.35
# Emerging Markets State - Obligations 0.001366            0.14
#       High Yield Bonds - Obligations 0.000922            0.09
# Investment Grade Bonds - Obligations 0.001039            0.10
#    Government ZC Bonds - Obligations 0.300704           30.07
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = N
# Match found at row 18. Updating status to 'Y'.
# Status updated successfully.
# 2041 17 41 56
# Starting Year: 2025
# Current Year: 2041
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -6, 'GOAL B': -1, 'GOAL C': 4, 'GOAL D': 19}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C           25.77
#    D           74.23
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.722387           72.24
#         Developed Markets - Equities 0.003316            0.33
# Emerging Markets State - Obligations 0.005287            0.53
#       High Yield Bonds - Obligations 0.005351            0.54
# Investment Grade Bonds - Obligations 0.007655            0.77
#    Government ZC Bonds - Obligations 0.256003           25.60
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = N
# Match found at row 19. Updating status to 'Y'.
# Status updated successfully.
# 2042 18 42 57
# Starting Year: 2025
# Current Year: 2042
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -7, 'GOAL B': -2, 'GOAL C': 3, 'GOAL D': 18}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C           25.77
#    D           74.23
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.000441            0.04
#         Developed Markets - Equities 0.728098           72.81
# Emerging Markets State - Obligations 0.008573            0.86
#       High Yield Bonds - Obligations 0.003376            0.34
# Investment Grade Bonds - Obligations 0.007422            0.74
#    Government ZC Bonds - Obligations 0.252090           25.21
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = N
# Match found at row 20. Updating status to 'Y'.
# Status updated successfully.
# 2043 19 43 58
# Starting Year: 2025
# Current Year: 2043
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -8, 'GOAL B': -3, 'GOAL C': 2, 'GOAL D': 17}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C           24.49
#    D           75.51
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.000295            0.03
#         Developed Markets - Equities 0.746181           74.62
# Emerging Markets State - Obligations 0.004583            0.46
#       High Yield Bonds - Obligations 0.003541            0.35
# Investment Grade Bonds - Obligations 0.003534            0.35
#    Government ZC Bonds - Obligations 0.241866           24.19
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = N
# Match found at row 21. Updating status to 'Y'.
# Status updated successfully.
# 2044 20 44 59
# Starting Year: 2025
# Current Year: 2044
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -9, 'GOAL B': -4, 'GOAL C': 1, 'GOAL D': 16}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C           21.21
#    D           78.79
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.000400            0.04
#         Developed Markets - Equities 0.782488           78.25
# Emerging Markets State - Obligations 0.001757            0.18
#       High Yield Bonds - Obligations 0.000696            0.07
# Investment Grade Bonds - Obligations 0.001371            0.14
#    Government ZC Bonds - Obligations 0.213289           21.33
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = N
# Match found at row 22. Updating status to 'Y'.
# Status updated successfully.
# 2045 21 45 60
# Starting Year: 2025
# Current Year: 2045
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -10, 'GOAL B': -5, 'GOAL C': 0, 'GOAL D': 15}
# C:\Users\admin\AppData\Local\Temp\ipykernel_19344\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.967686           96.77
#         Developed Markets - Equities 0.002498            0.25
# Emerging Markets State - Obligations 0.010514            1.05
#       High Yield Bonds - Obligations 0.011485            1.15
# Investment Grade Bonds - Obligations 0.001881            0.19
#    Government ZC Bonds - Obligations 0.005936            0.59
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = N
# Match found at row 23. Updating status to 'Y'.
# Status updated successfully.
# 2046 22 46 61
# Starting Year: 2025
# Current Year: 2046
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -11, 'GOAL B': -6, 'GOAL C': -1, 'GOAL D': 14}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.986420           98.64
#         Developed Markets - Equities 0.001876            0.19
# Emerging Markets State - Obligations 0.005489            0.55
#       High Yield Bonds - Obligations 0.002317            0.23
# Investment Grade Bonds - Obligations 0.002587            0.26
#    Government ZC Bonds - Obligations 0.001310            0.13
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = N
# Match found at row 24. Updating status to 'Y'.
# Status updated successfully.
# 2047 23 47 62
# Starting Year: 2025
# Current Year: 2047
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -12, 'GOAL B': -7, 'GOAL C': -2, 'GOAL D': 13}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.941991           94.20
#         Developed Markets - Equities 0.000904            0.09
# Emerging Markets State - Obligations 0.002007            0.20
#       High Yield Bonds - Obligations 0.002022            0.20
# Investment Grade Bonds - Obligations 0.001247            0.12
#    Government ZC Bonds - Obligations 0.051829            5.18
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = N
# Match found at row 25. Updating status to 'Y'.
# Status updated successfully.
# 2048 24 48 63
# Starting Year: 2025
# Current Year: 2048
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -13, 'GOAL B': -8, 'GOAL C': -3, 'GOAL D': 12}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Allocation (%)
#          Emerging Markets - Equities 9.328420e-01           93.28
#         Developed Markets - Equities 1.137221e-18            0.00
# Emerging Markets State - Obligations 2.767462e-14            0.00
#       High Yield Bonds - Obligations 9.982449e-04            0.10
# Investment Grade Bonds - Obligations 2.441034e-02            2.44
#    Government ZC Bonds - Obligations 4.174939e-02            4.17
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = N
# Match found at row 26. Updating status to 'Y'.
# Status updated successfully.
# 2049 25 49 64
# Starting Year: 2025
# Current Year: 2049
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -14, 'GOAL B': -9, 'GOAL C': -4, 'GOAL D': 11}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.949221           95.88
#         Developed Markets - Equities 0.008848            0.89
# Emerging Markets State - Obligations 0.000959            0.10
#       High Yield Bonds - Obligations 0.008104            0.82
# Investment Grade Bonds - Obligations 0.004655            0.47
#    Government ZC Bonds - Obligations 0.018213            1.84
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = N
# Match found at row 27. Updating status to 'Y'.
# Status updated successfully.
# 2050 26 50 65
# Starting Year: 2025
# Current Year: 2050
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -15, 'GOAL B': -10, 'GOAL C': -5, 'GOAL D': 10}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.961842           97.16
#         Developed Markets - Equities 0.007704            0.78
# Emerging Markets State - Obligations 0.003035            0.31
#       High Yield Bonds - Obligations 0.007430            0.75
# Investment Grade Bonds - Obligations 0.007836            0.79
#    Government ZC Bonds - Obligations 0.002152            0.22
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = N
# Match found at row 28. Updating status to 'Y'.
# Status updated successfully.
# 2051 27 51 66
# Starting Year: 2025
# Current Year: 2051
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -16, 'GOAL B': -11, 'GOAL C': -6, 'GOAL D': 9}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.954527           95.45
#         Developed Markets - Equities 0.002572            0.26
# Emerging Markets State - Obligations 0.005122            0.51
#       High Yield Bonds - Obligations 0.009712            0.97
# Investment Grade Bonds - Obligations 0.009031            0.90
#    Government ZC Bonds - Obligations 0.019036            1.90
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = N
# Match found at row 29. Updating status to 'Y'.
# Status updated successfully.
# 2052 28 52 67
# Starting Year: 2025
# Current Year: 2052
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -17, 'GOAL B': -12, 'GOAL C': -7, 'GOAL D': 8}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.967123           97.69
#         Developed Markets - Equities 0.004507            0.46
# Emerging Markets State - Obligations 0.000039            0.00
#       High Yield Bonds - Obligations 0.004657            0.47
# Investment Grade Bonds - Obligations 0.005057            0.51
#    Government ZC Bonds - Obligations 0.008617            0.87
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = N
# Match found at row 30. Updating status to 'Y'.
# Status updated successfully.
# 2053 29 53 68
# Starting Year: 2025
# Current Year: 2053
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -18, 'GOAL B': -13, 'GOAL C': -8, 'GOAL D': 7}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.956958           95.70
#         Developed Markets - Equities 0.002305            0.23
# Emerging Markets State - Obligations 0.001059            0.11
#       High Yield Bonds - Obligations 0.003684            0.37
# Investment Grade Bonds - Obligations 0.016286            1.63
#    Government ZC Bonds - Obligations 0.019708            1.97
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = N
# Match found at row 31. Updating status to 'Y'.
# Status updated successfully.
# 2054 30 54 69
# Starting Year: 2025
# Current Year: 2054
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -19, 'GOAL B': -14, 'GOAL C': -9, 'GOAL D': 6}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.955293           96.49
#         Developed Markets - Equities 0.001272            0.13
# Emerging Markets State - Obligations 0.000111            0.01
#       High Yield Bonds - Obligations 0.000414            0.04
# Investment Grade Bonds - Obligations 0.014532            1.47
#    Government ZC Bonds - Obligations 0.018378            1.86
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = N
# ...
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.010494            1.05
#         Developed Markets - Equities 0.002577            0.26
# Emerging Markets State - Obligations 0.002427            0.24
#       High Yield Bonds - Obligations 0.004574            0.46
# Investment Grade Bonds - Obligations 0.007987            0.80
#    Government ZC Bonds - Obligations 0.971941           97.19
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = N
# Match found at row 48. Updating status to 'Y'.
# Status updated successfully.
# 2071 47 71 86
# Starting Year: 2025
# Current Year: 2071
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -36, 'GOAL B': -31, 'GOAL C': -26, 'GOAL D': -11}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.001876            0.19
#         Developed Markets - Equities 0.003687            0.37
# Emerging Markets State - Obligations 0.002348            0.23
#       High Yield Bonds - Obligations 0.001138            0.11
# Investment Grade Bonds - Obligations 0.000881            0.09
#    Government ZC Bonds - Obligations 0.990069           99.01
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = N
# Match found at row 49. Updating status to 'Y'.
# Status updated successfully.
# 2072 48 72 87
# Starting Year: 2025
# Current Year: 2072
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -37, 'GOAL B': -32, 'GOAL C': -27, 'GOAL D': -12}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.001404            0.14
#         Developed Markets - Equities 0.002315            0.23
# Emerging Markets State - Obligations 0.000581            0.06
#       High Yield Bonds - Obligations 0.001878            0.19
# Investment Grade Bonds - Obligations 0.001505            0.15
#    Government ZC Bonds - Obligations 0.992316           99.23
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = N
# Match found at row 50. Updating status to 'Y'.
# Status updated successfully.
# 2073 49 73 88
# Starting Year: 2025
# Current Year: 2073
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -38, 'GOAL B': -33, 'GOAL C': -28, 'GOAL D': -13}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.001257            0.13
#         Developed Markets - Equities 0.002553            0.26
# Emerging Markets State - Obligations 0.000948            0.09
#       High Yield Bonds - Obligations 0.002309            0.23
# Investment Grade Bonds - Obligations 0.001487            0.15
#    Government ZC Bonds - Obligations 0.991446           99.14
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = N
# Match found at row 51. Updating status to 'Y'.
# Status updated successfully.
# 2074 50 74 89
# Starting Year: 2025
# Current Year: 2074
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -39, 'GOAL B': -34, 'GOAL C': -29, 'GOAL D': -14}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.000713            0.07
#         Developed Markets - Equities 0.003716            0.37
# Emerging Markets State - Obligations 0.000699            0.07
#       High Yield Bonds - Obligations 0.001813            0.18
# Investment Grade Bonds - Obligations 0.000793            0.08
#    Government ZC Bonds - Obligations 0.992266           99.23
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = Y
# Row 52: Year = 2074.0, Status = N
# Match found at row 52. Updating status to 'Y'.
# Status updated successfully.
# 2075 51 75 90
# Starting Year: 2025
# Current Year: 2075
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2060}
# Adjusted Horizons: {'GOAL A': -40, 'GOAL B': -35, 'GOAL C': -30, 'GOAL D': -15}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.002142            0.21
#         Developed Markets - Equities 0.000916            0.09
# Emerging Markets State - Obligations 0.002418            0.24
#       High Yield Bonds - Obligations 0.001448            0.14
# Investment Grade Bonds - Obligations 0.002840            0.28
#    Government ZC Bonds - Obligations 0.990237           99.02
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = Y
# Row 52: Year = 2074.0, Status = Y
# Row 53: Year = 2075.0, Status = N
# Match found at row 53. Updating status to 'Y'.
# Status updated successfully.
# All loops completed

# %%
if infeasible_goals_log:
    print("\n⚠️ Infeasible goal scenarios encountered:")
    for year, goal, reason in infeasible_goals_log:
        print(f" - Year {year}, Goal {goal}: {reason}")

    # Optional: write to CSV
    pd.DataFrame(infeasible_goals_log, columns=["Year", "Goal", "Reason"]).to_csv(
        os.path.join(output_folder, "infeasible_goals_log.csv"), index=False)
else:
    print("\n✅ No infeasible goals encountered.")
# Out:
# ⚠️ Infeasible goal scenarios encountered:
#  - Year 2028, Goal Goal A: Required return > 100% (109.68%)
#  - Year 2029, Goal Goal A: Required return > 100% (128.01%)
#  - Year 2029, Goal Goal A: Required return > 100% (103.14%)
#  - Year 2030, Goal Goal A: Required return > 100% (158.66%)
#  - Year 2030, Goal Goal A: Required return > 100% (125.18%)
#  - Year 2030, Goal Goal A: Required return > 100% (107.64%)
#  - Year 2031, Goal Goal A: Required return > 100% (213.72%)
#  - Year 2031, Goal Goal A: Required return > 100% (163.80%)
#  - Year 2031, Goal Goal A: Required return > 100% (138.37%)
#  - Year 2031, Goal Goal A: Required return > 100% (121.83%)
#  - Year 2031, Goal Goal A: Required return > 100% (109.79%)
#  - Year 2031, Goal Goal A: Required return > 100% (100.45%)
#  - Year 2032, Goal Goal A: Required return > 100% (336.45%)
#  - Year 2032, Goal Goal A: Required return > 100% (246.41%)
#  - Year 2032, Goal Goal A: Required return > 100% (202.62%)
#  - Year 2032, Goal Goal A: Required return > 100% (174.94%)
#  - Year 2032, Goal Goal A: Required return > 100% (155.24%)
#  - Year 2032, Goal Goal A: Required return > 100% (140.19%)
#  - Year 2032, Goal Goal A: Required return > 100% (128.16%)
#  - Year 2032, Goal Goal A: Required return > 100% (118.22%)
#  - Year 2032, Goal Goal A: Required return > 100% (109.82%)
#  - Year 2032, Goal Goal A: Required return > 100% (102.58%)
#  - Year 2033, Goal Goal A: Required return > 100% (752.81%)
#  - Year 2033, Goal Goal A: Required return > 100% (503.03%)
#  - Year 2033, Goal Goal A: Required return > 100% (392.37%)
#  - Year 2033, Goal Goal A: Required return > 100% (326.41%)
#  - Year 2033, Goal Goal A: Required return > 100% (281.39%)
#  - Year 2033, Goal Goal A: Required return > 100% (248.16%)
#  - Year 2033, Goal Goal A: Required return > 100% (222.33%)
#  - Year 2033, Goal Goal A: Required return > 100% (201.51%)
#  - Year 2033, Goal Goal A: Required return > 100% (184.27%)
#  - Year 2033, Goal Goal A: Required return > 100% (169.68%)
#  - Year 2033, Goal Goal A: Required return > 100% (157.13%)
#  - Year 2033, Goal Goal A: Required return > 100% (146.19%)
#  - Year 2033, Goal Goal A: Required return > 100% (136.53%)
#  - Year 2033, Goal Goal A: Required return > 100% (127.92%)
#  - Year 2033, Goal Goal A: Required return > 100% (120.19%)
#  - Year 2033, Goal Goal A: Required return > 100% (113.20%)
#  - Year 2033, Goal Goal A: Required return > 100% (106.84%)
#  - Year 2033, Goal Goal A: Required return > 100% (101.01%)
#  - Year 2034, Goal Goal A: Required return > 100% (6356.48%)
#  - Year 2034, Goal Goal A: Required return > 100% (3128.24%)
#  - Year 2034, Goal Goal A: Required return > 100% (2052.16%)
#  - Year 2034, Goal Goal A: Required return > 100% (1514.12%)
#  - Year 2034, Goal Goal A: Required return > 100% (1191.30%)
#  - Year 2034, Goal Goal A: Required return > 100% (976.08%)
#  - Year 2034, Goal Goal A: Required return > 100% (822.35%)
#  - Year 2034, Goal Goal A: Required return > 100% (707.06%)
#  - Year 2034, Goal Goal A: Required return > 100% (617.39%)
#  - Year 2034, Goal Goal A: Required return > 100% (545.65%)
#  - Year 2034, Goal Goal A: Required return > 100% (486.95%)
#  - Year 2034, Goal Goal A: Required return > 100% (438.04%)
#  - Year 2034, Goal Goal A: Required return > 100% (396.65%)
#  - Year 2034, Goal Goal A: Required return > 100% (361.18%)
#  - Year 2034, Goal Goal A: Required return > 100% (330.43%)
#  - Year 2034, Goal Goal A: Required return > 100% (303.53%)
#  - Year 2034, Goal Goal A: Required return > 100% (279.79%)
#  - Year 2034, Goal Goal A: Required return > 100% (258.69%)
#  - Year 2034, Goal Goal A: Required return > 100% (239.81%)
#  - Year 2034, Goal Goal A: Required return > 100% (222.82%)
#  - Year 2034, Goal Goal A: Required return > 100% (207.45%)
#  - Year 2034, Goal Goal A: Required return > 100% (193.48%)
#  - Year 2034, Goal Goal A: Required return > 100% (180.72%)
#  - Year 2034, Goal Goal A: Required return > 100% (169.02%)
#  - Year 2034, Goal Goal A: Required return > 100% (158.26%)
#  - Year 2034, Goal Goal A: Required return > 100% (148.33%)
#  - Year 2034, Goal Goal A: Required return > 100% (139.13%)
#  - Year 2034, Goal Goal A: Required return > 100% (130.59%)
#  - Year 2034, Goal Goal A: Required return > 100% (122.64%)
#  - Year 2034, Goal Goal A: Required return > 100% (115.22%)
#  - Year 2034, Goal Goal A: Required return > 100% (108.27%)
#  - Year 2034, Goal Goal A: Required return > 100% (101.77%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2037, Goal Goal B: Required return > 100% (106.36%)
#  - Year 2038, Goal Goal B: Required return > 100% (183.53%)
#  - Year 2038, Goal Goal B: Required return > 100% (100.49%)
#  - Year 2039, Goal Goal B: Required return > 100% (634.40%)
#  - Year 2039, Goal Goal B: Required return > 100% (267.20%)
#  - Year 2039, Goal Goal B: Required return > 100% (144.80%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2041, Goal Goal C: Required return > 100% (123.59%)
#  - Year 2041, Goal Goal B: Required return > 100% (108.08%)
#  - Year 2041, Goal Goal B: Required return > 100% (124.09%)
#  - Year 2041, Goal Goal B: Required return > 100% (140.09%)
#  - Year 2041, Goal Goal B: Required return > 100% (156.10%)
#  - Year 2041, Goal Goal B: Required return > 100% (172.11%)
#  - Year 2041, Goal Goal B: Required return > 100% (188.11%)
#  - Year 2041, Goal Goal B: Required return > 100% (204.12%)
#  - Year 2041, Goal Goal B: Required return > 100% (220.12%)
#  - Year 2041, Goal Goal B: Required return > 100% (236.13%)
#  - Year 2041, Goal Goal B: Required return > 100% (252.14%)
#  - Year 2041, Goal Goal B: Required return > 100% (268.14%)
#  - Year 2041, Goal Goal B: Required return > 100% (284.15%)
#  - Year 2041, Goal Goal B: Required return > 100% (300.16%)
#  - Year 2041, Goal Goal B: Required return > 100% (316.16%)
#  - Year 2041, Goal Goal B: Required return > 100% (332.17%)
#  - Year 2041, Goal Goal B: Required return > 100% (348.17%)
#  - Year 2041, Goal Goal B: Required return > 100% (364.18%)
#  - Year 2041, Goal Goal B: Required return > 100% (380.19%)
#  - Year 2041, Goal Goal B: Required return > 100% (396.19%)
#  - Year 2041, Goal Goal B: Required return > 100% (412.20%)
#  - Year 2041, Goal Goal B: Required return > 100% (428.20%)
#  - Year 2041, Goal Goal B: Required return > 100% (444.21%)
#  - Year 2041, Goal Goal B: Required return > 100% (460.22%)
#  - Year 2041, Goal Goal B: Required return > 100% (476.22%)
#  - Year 2041, Goal Goal B: Required return > 100% (492.23%)
#  - Year 2041, Goal Goal B: Required return > 100% (508.24%)
#  - Year 2041, Goal Goal B: Required return > 100% (524.24%)
#  - Year 2041, Goal Goal B: Required return > 100% (540.25%)
#  - Year 2041, Goal Goal B: Required return > 100% (556.25%)
#  - Year 2041, Goal Goal B: Required return > 100% (572.26%)
#  - Year 2041, Goal Goal B: Required return > 100% (588.27%)
#  - Year 2041, Goal Goal B: Required return > 100% (604.27%)
#  - Year 2041, Goal Goal B: Required return > 100% (620.28%)
#  - Year 2041, Goal Goal B: Required return > 100% (636.29%)
#  - Year 2041, Goal Goal B: Required return > 100% (652.29%)
#  - Year 2041, Goal Goal B: Required return > 100% (668.30%)
#  - Year 2041, Goal Goal B: Required return > 100% (684.30%)
#  - Year 2041, Goal Goal B: Required return > 100% (700.31%)
#  - Year 2041, Goal Goal B: Required return > 100% (716.32%)
#  - Year 2041, Goal Goal B: Required return > 100% (732.32%)
#  - Year 2041, Goal Goal B: Required return > 100% (748.33%)
#  - Year 2041, Goal Goal B: Required return > 100% (764.33%)
#  - Year 2041, Goal Goal B: Required return > 100% (780.34%)
#  - Year 2041, Goal Goal B: Required return > 100% (796.35%)
#  - Year 2041, Goal Goal B: Required return > 100% (812.35%)
#  - Year 2041, Goal Goal B: Required return > 100% (828.36%)
#  - Year 2041, Goal Goal B: Required return > 100% (844.37%)
#  - Year 2041, Goal Goal B: Required return > 100% (860.37%)
#  - Year 2041, Goal Goal B: Required return > 100% (876.38%)
#  - Year 2041, Goal Goal B: Required return > 100% (892.38%)
#  - Year 2041, Goal Goal B: Required return > 100% (908.39%)
#  - Year 2041, Goal Goal B: Required return > 100% (924.40%)
#  - Year 2041, Goal Goal B: Required return > 100% (940.40%)
#  - Year 2041, Goal Goal B: Required return > 100% (956.41%)
#  - Year 2041, Goal Goal B: Required return > 100% (972.42%)
#  - Year 2041, Goal Goal B: Required return > 100% (988.42%)
#  - Year 2041, Goal Goal B: Required return > 100% (1004.43%)
#  - Year 2041, Goal Goal B: Required return > 100% (1020.43%)
#  - Year 2041, Goal Goal B: Required return > 100% (1036.44%)
#  - Year 2041, Goal Goal B: Required return > 100% (1052.45%)
#  - Year 2041, Goal Goal B: Required return > 100% (1068.45%)
#  - Year 2041, Goal Goal B: Required return > 100% (1084.46%)
#  - Year 2041, Goal Goal B: Required return > 100% (1100.47%)
#  - Year 2041, Goal Goal B: Required return > 100% (1116.47%)
#  - Year 2041, Goal Goal B: Required return > 100% (1132.48%)
#  - Year 2041, Goal Goal B: Required return > 100% (1148.48%)
#  - Year 2041, Goal Goal B: Required return > 100% (1164.49%)
#  - Year 2041, Goal Goal B: Required return > 100% (1180.50%)
#  - Year 2041, Goal Goal B: Required return > 100% (1196.50%)
#  - Year 2041, Goal Goal B: Required return > 100% (1212.51%)
#  - Year 2041, Goal Goal B: Required return > 100% (1228.51%)
#  - Year 2041, Goal Goal B: Required return > 100% (1244.52%)
#  - Year 2041, Goal Goal B: Required return > 100% (1260.53%)
#  - Year 2041, Goal Goal B: Required return > 100% (1276.53%)
#  - Year 2041, Goal Goal B: Required return > 100% (1292.54%)
#  - Year 2041, Goal Goal B: Required return > 100% (1308.55%)
#  - Year 2041, Goal Goal B: Required return > 100% (1324.55%)
#  - Year 2041, Goal Goal B: Required return > 100% (1340.56%)
#  - Year 2041, Goal Goal B: Required return > 100% (1356.56%)
#  - Year 2041, Goal Goal B: Required return > 100% (1372.57%)
#  - Year 2041, Goal Goal B: Required return > 100% (1388.58%)
#  - Year 2041, Goal Goal B: Required return > 100% (1404.58%)
#  - Year 2041, Goal Goal B: Required return > 100% (1420.59%)
#  - Year 2041, Goal Goal B: Required return > 100% (1436.60%)
#  - Year 2041, Goal Goal B: Required return > 100% (1452.60%)
#  - Year 2041, Goal Goal B: Required return > 100% (1468.61%)
#  - Year 2041, Goal Goal B: Required return > 100% (1484.61%)
#  - Year 2041, Goal Goal B: Required return > 100% (1500.62%)
#  - Year 2042, Goal Goal C: Required return > 100% (185.33%)
#  - Year 2042, Goal Goal C: Required return > 100% (126.47%)
#  - Year 2042, Goal Goal B: Required return > 100% (103.29%)
#  - Year 2042, Goal Goal B: Required return > 100% (107.48%)
#  - Year 2042, Goal Goal B: Required return > 100% (111.59%)
#  - Year 2042, Goal Goal B: Required return > 100% (115.62%)
#  - Year 2042, Goal Goal B: Required return > 100% (119.57%)
#  - Year 2042, Goal Goal B: Required return > 100% (123.46%)
#  - Year 2042, Goal Goal B: Required return > 100% (127.28%)
#  - Year 2042, Goal Goal B: Required return > 100% (131.04%)
#  - Year 2042, Goal Goal B: Required return > 100% (134.74%)
#  - Year 2042, Goal Goal B: Required return > 100% (138.37%)
#  - Year 2042, Goal Goal B: Required return > 100% (141.96%)
#  - Year 2042, Goal Goal B: Required return > 100% (145.49%)
#  - Year 2042, Goal Goal B: Required return > 100% (148.97%)
#  - Year 2042, Goal Goal B: Required return > 100% (152.41%)
#  - Year 2042, Goal Goal B: Required return > 100% (155.80%)
#  - Year 2042, Goal Goal B: Required return > 100% (159.14%)
#  - Year 2042, Goal Goal B: Required return > 100% (162.44%)
#  - Year 2042, Goal Goal B: Required return > 100% (165.70%)
#  - Year 2042, Goal Goal B: Required return > 100% (168.92%)
#  - Year 2042, Goal Goal B: Required return > 100% (172.11%)
#  - Year 2042, Goal Goal B: Required return > 100% (175.25%)
#  - Year 2042, Goal Goal B: Required return > 100% (178.36%)
#  - Year 2042, Goal Goal B: Required return > 100% (181.44%)
#  - Year 2042, Goal Goal B: Required return > 100% (184.48%)
#  - Year 2042, Goal Goal B: Required return > 100% (187.49%)
#  - Year 2042, Goal Goal B: Required return > 100% (190.47%)
#  - Year 2042, Goal Goal B: Required return > 100% (193.42%)
#  - Year 2042, Goal Goal B: Required return > 100% (196.34%)
#  - Year 2042, Goal Goal B: Required return > 100% (199.23%)
#  - Year 2042, Goal Goal B: Required return > 100% (202.09%)
#  - Year 2042, Goal Goal B: Required return > 100% (204.93%)
#  - Year 2042, Goal Goal B: Required return > 100% (207.74%)
#  - Year 2042, Goal Goal B: Required return > 100% (210.53%)
#  - Year 2042, Goal Goal B: Required return > 100% (213.29%)
#  - Year 2042, Goal Goal B: Required return > 100% (216.02%)
#  - Year 2042, Goal Goal B: Required return > 100% (218.73%)
#  - Year 2042, Goal Goal B: Required return > 100% (221.42%)
#  - Year 2042, Goal Goal B: Required return > 100% (224.09%)
#  - Year 2042, Goal Goal B: Required return > 100% (226.74%)
#  - Year 2042, Goal Goal B: Required return > 100% (229.36%)
#  - Year 2042, Goal Goal B: Required return > 100% (231.97%)
#  - Year 2042, Goal Goal B: Required return > 100% (234.55%)
#  - Year 2042, Goal Goal B: Required return > 100% (237.11%)
#  - Year 2042, Goal Goal B: Required return > 100% (239.66%)
#  - Year 2042, Goal Goal B: Required return > 100% (242.18%)
#  - Year 2042, Goal Goal B: Required return > 100% (244.69%)
#  - Year 2042, Goal Goal B: Required return > 100% (247.18%)
#  - Year 2042, Goal Goal B: Required return > 100% (249.65%)
#  - Year 2042, Goal Goal B: Required return > 100% (252.10%)
#  - Year 2042, Goal Goal B: Required return > 100% (254.54%)
#  - Year 2042, Goal Goal B: Required return > 100% (256.96%)
#  - Year 2042, Goal Goal B: Required return > 100% (259.36%)
#  - Year 2042, Goal Goal B: Required return > 100% (261.75%)
#  - Year 2042, Goal Goal B: Required return > 100% (264.12%)
#  - Year 2042, Goal Goal B: Required return > 100% (266.48%)
#  - Year 2042, Goal Goal B: Required return > 100% (268.82%)
#  - Year 2042, Goal Goal B: Required return > 100% (271.15%)
#  - Year 2042, Goal Goal B: Required return > 100% (273.46%)
#  - Year 2042, Goal Goal B: Required return > 100% (275.76%)
#  - Year 2042, Goal Goal B: Required return > 100% (278.04%)
#  - Year 2042, Goal Goal B: Required return > 100% (280.31%)
#  - Year 2042, Goal Goal B: Required return > 100% (282.57%)
#  - Year 2042, Goal Goal B: Required return > 100% (284.82%)
#  - Year 2042, Goal Goal B: Required return > 100% (287.05%)
#  - Year 2042, Goal Goal B: Required return > 100% (289.26%)
#  - Year 2042, Goal Goal B: Required return > 100% (291.47%)
#  - Year 2042, Goal Goal B: Required return > 100% (293.66%)
#  - Year 2042, Goal Goal B: Required return > 100% (295.84%)
#  - Year 2042, Goal Goal B: Required return > 100% (298.01%)
#  - Year 2042, Goal Goal B: Required return > 100% (300.17%)
#  - Year 2042, Goal Goal B: Required return > 100% (302.32%)
#  - Year 2042, Goal Goal B: Required return > 100% (304.45%)
#  - Year 2042, Goal Goal B: Required return > 100% (306.57%)
#  - Year 2042, Goal Goal B: Required return > 100% (308.69%)
#  - Year 2042, Goal Goal B: Required return > 100% (310.79%)
#  - Year 2042, Goal Goal B: Required return > 100% (312.88%)
#  - Year 2042, Goal Goal B: Required return > 100% (314.96%)
#  - Year 2043, Goal Goal C: Required return > 100% (364.17%)
#  - Year 2043, Goal Goal C: Required return > 100% (228.22%)
#  - Year 2043, Goal Goal C: Required return > 100% (167.99%)
#  - Year 2043, Goal Goal C: Required return > 100% (132.09%)
#  - Year 2043, Goal Goal C: Required return > 100% (107.59%)
#  - Year 2043, Goal Goal B: Required return > 100% (101.40%)
#  - Year 2043, Goal Goal B: Required return > 100% (102.91%)
#  - Year 2043, Goal Goal B: Required return > 100% (104.40%)
#  - Year 2043, Goal Goal B: Required return > 100% (105.87%)
#  - Year 2043, Goal Goal B: Required return > 100% (107.32%)
#  - Year 2043, Goal Goal B: Required return > 100% (108.75%)
#  - Year 2043, Goal Goal B: Required return > 100% (110.16%)
#  - Year 2043, Goal Goal B: Required return > 100% (111.55%)
#  - Year 2043, Goal Goal B: Required return > 100% (112.93%)
#  - Year 2043, Goal Goal B: Required return > 100% (114.28%)
#  - Year 2043, Goal Goal B: Required return > 100% (115.62%)
#  - Year 2043, Goal Goal B: Required return > 100% (116.95%)
#  - Year 2043, Goal Goal B: Required return > 100% (118.25%)
#  - Year 2043, Goal Goal B: Required return > 100% (119.55%)
#  - Year 2043, Goal Goal B: Required return > 100% (120.82%)
#  - Year 2043, Goal Goal B: Required return > 100% (122.08%)
#  - Year 2043, Goal Goal B: Required return > 100% (123.33%)
#  - Year 2043, Goal Goal B: Required return > 100% (124.57%)
#  - Year 2043, Goal Goal B: Required return > 100% (125.79%)
#  - Year 2043, Goal Goal B: Required return > 100% (126.99%)
#  - Year 2043, Goal Goal B: Required return > 100% (128.19%)
#  - Year 2043, Goal Goal B: Required return > 100% (129.37%)
#  - Year 2043, Goal Goal B: Required return > 100% (130.54%)
#  - Year 2043, Goal Goal B: Required return > 100% (131.70%)
#  - Year 2043, Goal Goal B: Required return > 100% (132.85%)
#  - Year 2043, Goal Goal B: Required return > 100% (133.98%)
#  - Year 2043, Goal Goal B: Required return > 100% (135.11%)
#  - Year 2043, Goal Goal B: Required return > 100% (136.22%)
#  - Year 2043, Goal Goal B: Required return > 100% (137.32%)
#  - Year 2043, Goal Goal B: Required return > 100% (138.42%)
#  - Year 2043, Goal Goal B: Required return > 100% (139.50%)
#  - Year 2043, Goal Goal B: Required return > 100% (140.58%)
#  - Year 2043, Goal Goal B: Required return > 100% (141.64%)
#  - Year 2043, Goal Goal B: Required return > 100% (142.70%)
#  - Year 2043, Goal Goal B: Required return > 100% (143.74%)
#  - Year 2043, Goal Goal B: Required return > 100% (144.78%)
#  - Year 2043, Goal Goal B: Required return > 100% (145.81%)
#  - Year 2043, Goal Goal B: Required return > 100% (146.83%)
#  - Year 2043, Goal Goal B: Required return > 100% (147.84%)
#  - Year 2043, Goal Goal B: Required return > 100% (148.84%)
#  - Year 2043, Goal Goal B: Required return > 100% (149.84%)
#  - Year 2043, Goal Goal B: Required return > 100% (150.83%)
#  - Year 2043, Goal Goal B: Required return > 100% (151.81%)
#  - Year 2043, Goal Goal B: Required return > 100% (152.78%)
#  - Year 2043, Goal Goal B: Required return > 100% (153.74%)
#  - Year 2043, Goal Goal B: Required return > 100% (154.70%)
#  - Year 2043, Goal Goal B: Required return > 100% (155.65%)
#  - Year 2043, Goal Goal B: Required return > 100% (156.59%)
#  - Year 2043, Goal Goal B: Required return > 100% (157.53%)
#  - Year 2043, Goal Goal B: Required return > 100% (158.46%)
#  - Year 2043, Goal Goal B: Required return > 100% (159.38%)
#  - Year 2043, Goal Goal B: Required return > 100% (160.30%)
#  - Year 2043, Goal Goal B: Required return > 100% (161.21%)
#  - Year 2043, Goal Goal B: Required return > 100% (162.11%)
#  - Year 2043, Goal Goal B: Required return > 100% (163.01%)
#  - Year 2043, Goal Goal B: Required return > 100% (163.90%)
#  - Year 2043, Goal Goal B: Required return > 100% (164.79%)
#  - Year 2044, Goal Goal C: Required return > 100% (1907.56%)
#  - Year 2044, Goal Goal C: Required return > 100% (903.78%)
#  - Year 2044, Goal Goal C: Required return > 100% (569.19%)
#  - Year 2044, Goal Goal C: Required return > 100% (401.89%)
#  - Year 2044, Goal Goal C: Required return > 100% (301.51%)
#  - Year 2044, Goal Goal C: Required return > 100% (234.59%)
#  - Year 2044, Goal Goal C: Required return > 100% (186.79%)
#  - Year 2044, Goal Goal C: Required return > 100% (150.95%)
#  - Year 2044, Goal Goal C: Required return > 100% (123.06%)
#  - Year 2044, Goal Goal C: Required return > 100% (100.76%)
#  - Year 2044, Goal Goal B: Required return > 100% (100.43%)
#  - Year 2044, Goal Goal B: Required return > 100% (101.05%)
#  - Year 2044, Goal Goal B: Required return > 100% (101.66%)
#  - Year 2044, Goal Goal B: Required return > 100% (102.26%)
#  - Year 2044, Goal Goal B: Required return > 100% (102.86%)
#  - Year 2044, Goal Goal B: Required return > 100% (103.46%)
#  - Year 2044, Goal Goal B: Required return > 100% (104.05%)
#  - Year 2044, Goal Goal B: Required return > 100% (104.63%)
#  - Year 2044, Goal Goal B: Required return > 100% (105.21%)
#  - Year 2044, Goal Goal B: Required return > 100% (105.78%)
#  - Year 2044, Goal Goal B: Required return > 100% (106.35%)
#  - Year 2044, Goal Goal B: Required return > 100% (106.92%)
#  - Year 2044, Goal Goal B: Required return > 100% (107.48%)
#  - Year 2044, Goal Goal B: Required return > 100% (108.03%)
#  - Year 2044, Goal Goal B: Required return > 100% (108.58%)
#  - Year 2044, Goal Goal B: Required return > 100% (109.13%)
#  - Year 2044, Goal Goal B: Required return > 100% (109.67%)
#  - Year 2044, Goal Goal B: Required return > 100% (110.21%)
#  - Year 2044, Goal Goal B: Required return > 100% (110.74%)
#  - Year 2044, Goal Goal B: Required return > 100% (111.27%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2046, Goal Goal C: Required return > 100% (104.16%)
#  - Year 2046, Goal Goal C: Required return > 100% (109.83%)
#  - Year 2046, Goal Goal C: Required return > 100% (115.51%)
#  - Year 2046, Goal Goal C: Required return > 100% (121.18%)
#  - Year 2046, Goal Goal C: Required return > 100% (126.85%)
#  - Year 2046, Goal Goal C: Required return > 100% (132.52%)
#  - Year 2046, Goal Goal C: Required return > 100% (138.19%)
#  - Year 2046, Goal Goal C: Required return > 100% (143.86%)
#  - Year 2046, Goal Goal C: Required return > 100% (149.53%)
#  - Year 2046, Goal Goal C: Required return > 100% (155.20%)
#  - Year 2046, Goal Goal C: Required return > 100% (160.88%)
#  - Year 2046, Goal Goal C: Required return > 100% (166.55%)
#  - Year 2046, Goal Goal C: Required return > 100% (172.22%)
#  - Year 2046, Goal Goal C: Required return > 100% (177.89%)
#  - Year 2046, Goal Goal C: Required return > 100% (183.56%)
#  - Year 2046, Goal Goal C: Required return > 100% (189.23%)
#  - Year 2046, Goal Goal C: Required return > 100% (194.90%)
#  - Year 2046, Goal Goal C: Required return > 100% (200.57%)
#  - Year 2046, Goal Goal C: Required return > 100% (206.24%)
#  - Year 2046, Goal Goal C: Required return > 100% (211.92%)
#  - Year 2046, Goal Goal C: Required return > 100% (217.59%)
#  - Year 2046, Goal Goal C: Required return > 100% (223.26%)
#  - Year 2046, Goal Goal C: Required return > 100% (228.93%)
#  - Year 2046, Goal Goal C: Required return > 100% (234.60%)
#  - Year 2046, Goal Goal C: Required return > 100% (240.27%)
#  - Year 2046, Goal Goal C: Required return > 100% (245.94%)
#  - Year 2046, Goal Goal C: Required return > 100% (251.61%)
#  - Year 2046, Goal Goal C: Required return > 100% (257.29%)
#  - Year 2046, Goal Goal C: Required return > 100% (262.96%)
#  - Year 2046, Goal Goal C: Required return > 100% (268.63%)
#  - Year 2046, Goal Goal C: Required return > 100% (274.30%)
#  - Year 2046, Goal Goal C: Required return > 100% (279.97%)
#  - Year 2046, Goal Goal C: Required return > 100% (285.64%)
#  - Year 2046, Goal Goal C: Required return > 100% (291.31%)
#  - Year 2046, Goal Goal C: Required return > 100% (296.98%)
#  - Year 2046, Goal Goal C: Required return > 100% (302.66%)
#  - Year 2046, Goal Goal C: Required return > 100% (308.33%)
#  - Year 2046, Goal Goal C: Required return > 100% (314.00%)
#  - Year 2046, Goal Goal C: Required return > 100% (319.67%)
#  - Year 2046, Goal Goal C: Required return > 100% (325.34%)
#  - Year 2046, Goal Goal C: Required return > 100% (331.01%)
#  - Year 2046, Goal Goal C: Required return > 100% (336.68%)
#  - Year 2046, Goal Goal C: Required return > 100% (342.35%)
#  - Year 2046, Goal Goal C: Required return > 100% (348.02%)
#  - Year 2046, Goal Goal C: Required return > 100% (353.70%)
#  - Year 2046, Goal Goal C: Required return > 100% (359.37%)
#  - Year 2046, Goal Goal C: Required return > 100% (365.04%)
#  - Year 2046, Goal Goal C: Required return > 100% (370.71%)
#  - Year 2046, Goal Goal C: Required return > 100% (376.38%)
#  - Year 2046, Goal Goal C: Required return > 100% (382.05%)
#  - Year 2046, Goal Goal C: Required return > 100% (387.72%)
#  - Year 2046, Goal Goal C: Required return > 100% (393.39%)
#  - Year 2046, Goal Goal C: Required return > 100% (399.07%)
#  - Year 2046, Goal Goal C: Required return > 100% (404.74%)
#  - Year 2046, Goal Goal C: Required return > 100% (410.41%)
#  - Year 2046, Goal Goal C: Required return > 100% (416.08%)
#  - Year 2046, Goal Goal C: Required return > 100% (421.75%)
#  - Year 2046, Goal Goal C: Required return > 100% (427.42%)
#  - Year 2046, Goal Goal C: Required return > 100% (433.09%)
#  - Year 2046, Goal Goal C: Required return > 100% (438.76%)
#  - Year 2046, Goal Goal C: Required return > 100% (444.44%)
#  - Year 2046, Goal Goal C: Required return > 100% (450.11%)
#  - Year 2046, Goal Goal C: Required return > 100% (455.78%)
#  - Year 2046, Goal Goal C: Required return > 100% (461.45%)
#  - Year 2046, Goal Goal C: Required return > 100% (467.12%)
#  - Year 2047, Goal Goal C: Required return > 100% (101.43%)
#  - Year 2047, Goal Goal C: Required return > 100% (102.93%)
#  - Year 2047, Goal Goal C: Required return > 100% (104.42%)
#  - Year 2047, Goal Goal C: Required return > 100% (105.89%)
#  - Year 2047, Goal Goal C: Required return > 100% (107.36%)
#  - Year 2047, Goal Goal C: Required return > 100% (108.82%)
#  - Year 2047, Goal Goal C: Required return > 100% (110.26%)
#  - Year 2047, Goal Goal C: Required return > 100% (111.70%)
#  - Year 2047, Goal Goal C: Required return > 100% (113.12%)
#  - Year 2047, Goal Goal C: Required return > 100% (114.54%)
#  - Year 2047, Goal Goal C: Required return > 100% (115.94%)
#  - Year 2047, Goal Goal C: Required return > 100% (117.34%)
#  - Year 2047, Goal Goal C: Required return > 100% (118.73%)
#  - Year 2047, Goal Goal C: Required return > 100% (120.11%)
#  - Year 2047, Goal Goal C: Required return > 100% (121.48%)
#  - Year 2047, Goal Goal C: Required return > 100% (122.84%)
#  - Year 2047, Goal Goal C: Required return > 100% (124.20%)
#  - Year 2047, Goal Goal C: Required return > 100% (125.55%)
#  - Year 2047, Goal Goal C: Required return > 100% (126.88%)
#  - Year 2047, Goal Goal C: Required return > 100% (128.22%)
#  - Year 2047, Goal Goal C: Required return > 100% (129.54%)
#  - Year 2047, Goal Goal C: Required return > 100% (130.85%)
#  - Year 2047, Goal Goal C: Required return > 100% (132.16%)
#  - Year 2047, Goal Goal C: Required return > 100% (133.46%)
#  - Year 2047, Goal Goal C: Required return > 100% (134.76%)
#  - Year 2047, Goal Goal C: Required return > 100% (136.04%)
#  - Year 2047, Goal Goal C: Required return > 100% (137.32%)
#  - Year 2047, Goal Goal C: Required return > 100% (138.59%)
#  - Year 2047, Goal Goal C: Required return > 100% (139.86%)
#  - Year 2047, Goal Goal C: Required return > 100% (141.12%)
#  - Year 2047, Goal Goal C: Required return > 100% (142.37%)
#  - Year 2047, Goal Goal C: Required return > 100% (143.62%)
#  - Year 2047, Goal Goal C: Required return > 100% (144.86%)
#  - Year 2047, Goal Goal C: Required return > 100% (146.09%)
#  - Year 2052, Goal Goal D: Required return > 100% (104.92%)
#  - Year 2053, Goal Goal D: Required return > 100% (125.44%)
#  - Year 2053, Goal Goal D: Required return > 100% (104.19%)
#  - Year 2054, Goal Goal D: Required return > 100% (156.10%)
#  - Year 2054, Goal Goal D: Required return > 100% (128.16%)
#  - Year 2054, Goal Goal D: Required return > 100% (113.25%)
#  - Year 2054, Goal Goal D: Required return > 100% (103.27%)
#  - Year 2055, Goal Goal D: Required return > 100% (206.27%)
#  - Year 2055, Goal Goal D: Required return > 100% (166.63%)
#  - Year 2055, Goal Goal D: Required return > 100% (145.86%)
#  - Year 2055, Goal Goal D: Required return > 100% (132.11%)
#  - Year 2055, Goal Goal D: Required return > 100% (121.98%)
#  - Year 2055, Goal Goal D: Required return > 100% (114.03%)
#  - Year 2055, Goal Goal D: Required return > 100% (107.53%)
#  - Year 2055, Goal Goal D: Required return > 100% (102.06%)
#  - Year 2056, Goal Goal D: Required return > 100% (300.70%)
#  - Year 2056, Goal Goal D: Required return > 100% (236.94%)
#  - Year 2056, Goal Goal D: Required return > 100% (204.46%)
#  - Year 2056, Goal Goal D: Required return > 100% (183.34%)
#  - Year 2056, Goal Goal D: Required return > 100% (167.96%)
#  - Year 2056, Goal Goal D: Required return > 100% (156.02%)
#  - Year 2056, Goal Goal D: Required return > 100% (146.34%)
#  - Year 2056, Goal Goal D: Required return > 100% (138.26%)
#  - Year 2056, Goal Goal D: Required return > 100% (131.34%)
#  - Year 2056, Goal Goal D: Required return > 100% (125.33%)
#  - Year 2056, Goal Goal D: Required return > 100% (120.02%)
#  - Year 2056, Goal Goal D: Required return > 100% (115.29%)
#  - Year 2056, Goal Goal D: Required return > 100% (111.02%)
#  - Year 2056, Goal Goal D: Required return > 100% (107.15%)
#  - Year 2056, Goal Goal D: Required return > 100% (103.61%)
#  - Year 2056, Goal Goal D: Required return > 100% (100.35%)
#  - Year 2057, Goal Goal D: Required return > 100% (527.40%)
#  - Year 2057, Goal Goal D: Required return > 100% (397.97%)
#  - Year 2057, Goal Goal D: Required return > 100% (335.01%)
#  - Year 2057, Goal Goal D: Required return > 100% (295.24%)
#  - Year 2057, Goal Goal D: Required return > 100% (266.91%)
#  - Year 2057, Goal Goal D: Required return > 100% (245.27%)
#  - Year 2057, Goal Goal D: Required return > 100% (227.98%)
#  - Year 2057, Goal Goal D: Required return > 100% (213.70%)
#  - Year 2057, Goal Goal D: Required return > 100% (201.62%)
#  - Year 2057, Goal Goal D: Required return > 100% (191.21%)
#  - Year 2057, Goal Goal D: Required return > 100% (182.11%)
#  - Year 2057, Goal Goal D: Required return > 100% (174.04%)
#  - Year 2057, Goal Goal D: Required return > 100% (166.83%)
#  - Year 2057, Goal Goal D: Required return > 100% (160.32%)
#  - Year 2057, Goal Goal D: Required return > 100% (154.40%)
#  - Year 2057, Goal Goal D: Required return > 100% (148.98%)
#  - Year 2057, Goal Goal D: Required return > 100% (144.00%)
#  - Year 2057, Goal Goal D: Required return > 100% (139.40%)
#  - Year 2057, Goal Goal D: Required return > 100% (135.12%)
#  - Year 2057, Goal Goal D: Required return > 100% (131.14%)
#  - Year 2057, Goal Goal D: Required return > 100% (127.41%)
#  - Year 2057, Goal Goal D: Required return > 100% (123.91%)
#  - Year 2057, Goal Goal D: Required return > 100% (120.61%)
#  - Year 2057, Goal Goal D: Required return > 100% (117.51%)
#  - Year 2057, Goal Goal D: Required return > 100% (114.57%)
#  - Year 2057, Goal Goal D: Required return > 100% (111.78%)
#  - Year 2057, Goal Goal D: Required return > 100% (109.13%)
#  - Year 2057, Goal Goal D: Required return > 100% (106.61%)
#  - Year 2057, Goal Goal D: Required return > 100% (104.21%)
#  - Year 2057, Goal Goal D: Required return > 100% (101.92%)
#  - Year 2058, Goal Goal D: Required return > 100% (1439.20%)
#  - Year 2058, Goal Goal D: Required return > 100% (988.38%)
#  - Year 2058, Goal Goal D: Required return > 100% (788.66%)
#  - Year 2058, Goal Goal D: Required return > 100% (669.60%)
#  - Year 2058, Goal Goal D: Required return > 100% (588.35%)
#  - Year 2058, Goal Goal D: Required return > 100% (528.38%)
#  - Year 2058, Goal Goal D: Required return > 100% (481.76%)
#  - Year 2058, Goal Goal D: Required return > 100% (444.19%)
#  - Year 2058, Goal Goal D: Required return > 100% (413.07%)
#  - Year 2058, Goal Goal D: Required return > 100% (386.74%)
#  - Year 2058, Goal Goal D: Required return > 100% (364.09%)
#  - Year 2058, Goal Goal D: Required return > 100% (344.33%)
#  - Year 2058, Goal Goal D: Required return > 100% (326.90%)
#  - Year 2058, Goal Goal D: Required return > 100% (311.37%)
#  - Year 2058, Goal Goal D: Required return > 100% (297.42%)
#  - Year 2058, Goal Goal D: Required return > 100% (284.80%)
#  - Year 2058, Goal Goal D: Required return > 100% (273.31%)
#  - Year 2058, Goal Goal D: Required return > 100% (262.79%)
#  - Year 2058, Goal Goal D: Required return > 100% (253.12%)
#  - Year 2058, Goal Goal D: Required return > 100% (244.18%)
#  - Year 2058, Goal Goal D: Required return > 100% (235.88%)
#  - Year 2058, Goal Goal D: Required return > 100% (228.16%)
#  - Year 2058, Goal Goal D: Required return > 100% (220.95%)
#  - Year 2058, Goal Goal D: Required return > 100% (214.19%)
#  - Year 2058, Goal Goal D: Required return > 100% (207.84%)
#  - Year 2058, Goal Goal D: Required return > 100% (201.86%)
#  - Year 2058, Goal Goal D: Required return > 100% (196.22%)
#  - Year 2058, Goal Goal D: Required return > 100% (190.88%)
#  - Year 2058, Goal Goal D: Required return > 100% (185.82%)
#  - Year 2058, Goal Goal D: Required return > 100% (181.02%)
#  - Year 2058, Goal Goal D: Required return > 100% (176.45%)
#  - Year 2058, Goal Goal D: Required return > 100% (172.09%)
#  - Year 2058, Goal Goal D: Required return > 100% (167.94%)
#  - Year 2058, Goal Goal D: Required return > 100% (163.97%)
#  - Year 2058, Goal Goal D: Required return > 100% (160.17%)
#  - Year 2058, Goal Goal D: Required return > 100% (156.53%)
#  - Year 2058, Goal Goal D: Required return > 100% (153.04%)
#  - Year 2058, Goal Goal D: Required return > 100% (149.69%)
#  - Year 2058, Goal Goal D: Required return > 100% (146.47%)
#  - Year 2058, Goal Goal D: Required return > 100% (143.37%)
#  - Year 2058, Goal Goal D: Required return > 100% (140.38%)
#  - Year 2058, Goal Goal D: Required return > 100% (137.50%)
#  - Year 2058, Goal Goal D: Required return > 100% (134.73%)
#  - Year 2058, Goal Goal D: Required return > 100% (132.04%)
#  - Year 2058, Goal Goal D: Required return > 100% (129.45%)
#  - Year 2058, Goal Goal D: Required return > 100% (126.94%)
#  - Year 2058, Goal Goal D: Required return > 100% (124.52%)
#  - Year 2058, Goal Goal D: Required return > 100% (122.16%)
#  - Year 2058, Goal Goal D: Required return > 100% (119.89%)
#  - Year 2058, Goal Goal D: Required return > 100% (117.68%)
#  - Year 2058, Goal Goal D: Required return > 100% (115.53%)
#  - Year 2058, Goal Goal D: Required return > 100% (113.45%)
#  - Year 2058, Goal Goal D: Required return > 100% (111.43%)
#  - Year 2058, Goal Goal D: Required return > 100% (109.46%)
#  - Year 2058, Goal Goal D: Required return > 100% (107.55%)
#  - Year 2058, Goal Goal D: Required return > 100% (105.68%)
#  - Year 2058, Goal Goal D: Required return > 100% (103.87%)
#  - Year 2058, Goal Goal D: Required return > 100% (102.11%)
#  - Year 2058, Goal Goal D: Required return > 100% (100.39%)
#  - Year 2059, Goal Goal D: Required return > 100% (22656.15%)
#  - Year 2059, Goal Goal D: Required return > 100% (11278.08%)
#  - Year 2059, Goal Goal D: Required return > 100% (7485.38%)
#  - Year 2059, Goal Goal D: Required return > 100% (5589.04%)
#  - Year 2059, Goal Goal D: Required return > 100% (4451.23%)
#  - Year 2059, Goal Goal D: Required return > 100% (3692.69%)
#  - Year 2059, Goal Goal D: Required return > 100% (3150.88%)
#  - Year 2059, Goal Goal D: Required return > 100% (2744.52%)
#  - Year 2059, Goal Goal D: Required return > 100% (2428.46%)
#  - Year 2059, Goal Goal D: Required return > 100% (2175.62%)
#  - Year 2059, Goal Goal D: Required return > 100% (1968.74%)
#  - Year 2059, Goal Goal D: Required return > 100% (1796.35%)
#  - Year 2059, Goal Goal D: Required return > 100% (1650.47%)
#  - Year 2059, Goal Goal D: Required return > 100% (1525.44%)
#  - Year 2059, Goal Goal D: Required return > 100% (1417.08%)
#  - Year 2059, Goal Goal D: Required return > 100% (1322.26%)
#  - Year 2059, Goal Goal D: Required return > 100% (1238.60%)
#  - Year 2059, Goal Goal D: Required return > 100% (1164.23%)
#  - Year 2059, Goal Goal D: Required return > 100% (1097.69%)
#  - Year 2059, Goal Goal D: Required return > 100% (1037.81%)
#  - Year 2059, Goal Goal D: Required return > 100% (983.63%)
#  - Year 2059, Goal Goal D: Required return > 100% (934.37%)
#  - Year 2059, Goal Goal D: Required return > 100% (889.40%)
#  - Year 2059, Goal Goal D: Required return > 100% (848.17%)
#  - Year 2059, Goal Goal D: Required return > 100% (810.25%)
#  - Year 2059, Goal Goal D: Required return > 100% (775.24%)
#  - Year 2059, Goal Goal D: Required return > 100% (742.82%)
#  - Year 2059, Goal Goal D: Required return > 100% (712.72%)
#  - Year 2059, Goal Goal D: Required return > 100% (684.69%)
#  - Year 2059, Goal Goal D: Required return > 100% (658.54%)
#  - Year 2059, Goal Goal D: Required return > 100% (634.07%)
#  - Year 2059, Goal Goal D: Required return > 100% (611.13%)
#  - Year 2059, Goal Goal D: Required return > 100% (589.58%)
#  - Year 2059, Goal Goal D: Required return > 100% (569.30%)
#  - Year 2059, Goal Goal D: Required return > 100% (550.18%)
#  - Year 2059, Goal Goal D: Required return > 100% (532.12%)
#  - Year 2059, Goal Goal D: Required return > 100% (515.03%)
#  - Year 2059, Goal Goal D: Required return > 100% (498.85%)
#  - Year 2059, Goal Goal D: Required return > 100% (483.49%)
#  - Year 2059, Goal Goal D: Required return > 100% (468.90%)
#  - Year 2059, Goal Goal D: Required return > 100% (455.03%)
#  - Year 2059, Goal Goal D: Required return > 100% (441.81%)
#  - Year 2059, Goal Goal D: Required return > 100% (429.21%)
#  - Year 2059, Goal Goal D: Required return > 100% (417.19%)
#  - Year 2059, Goal Goal D: Required return > 100% (405.69%)
#  - Year 2059, Goal Goal D: Required return > 100% (394.70%)
#  - Year 2059, Goal Goal D: Required return > 100% (384.17%)
#  - Year 2059, Goal Goal D: Required return > 100% (374.09%)
#  - Year 2059, Goal Goal D: Required return > 100% (364.41%)
#  - Year 2059, Goal Goal D: Required return > 100% (355.12%)
#  - Year 2059, Goal Goal D: Required return > 100% (346.20%)
#  - Year 2059, Goal Goal D: Required return > 100% (337.62%)
#  - Year 2059, Goal Goal D: Required return > 100% (329.36%)
#  - Year 2059, Goal Goal D: Required return > 100% (321.41%)
#  - Year 2059, Goal Goal D: Required return > 100% (313.75%)
#  - Year 2059, Goal Goal D: Required return > 100% (306.36%)
#  - Year 2059, Goal Goal D: Required return > 100% (299.23%)
#  - Year 2059, Goal Goal D: Required return > 100% (292.35%)
#  - Year 2059, Goal Goal D: Required return > 100% (285.70%)
#  - Year 2059, Goal Goal D: Required return > 100% (279.27%)
#  - Year 2059, Goal Goal D: Required return > 100% (273.05%)
#  - Year 2059, Goal Goal D: Required return > 100% (267.03%)
#  - Year 2059, Goal Goal D: Required return > 100% (261.21%)
#  - Year 2059, Goal Goal D: Required return > 100% (255.56%)
#  - Year 2059, Goal Goal D: Required return > 100% (250.09%)
#  - Year 2059, Goal Goal D: Required return > 100% (244.79%)
#  - Year 2059, Goal Goal D: Required return > 100% (239.64%)
#  - Year 2059, Goal Goal D: Required return > 100% (234.65%)
#  - Year 2059, Goal Goal D: Required return > 100% (229.80%)
#  - Year 2059, Goal Goal D: Required return > 100% (225.09%)
#  - Year 2059, Goal Goal D: Required return > 100% (220.51%)
#  - Year 2059, Goal Goal D: Required return > 100% (216.06%)
#  - Year 2059, Goal Goal D: Required return > 100% (211.73%)
#  - Year 2059, Goal Goal D: Required return > 100% (207.52%)
#  - Year 2059, Goal Goal D: Required return > 100% (203.42%)
#  - Year 2059, Goal Goal D: Required return > 100% (199.42%)
#  - Year 2059, Goal Goal D: Required return > 100% (195.53%)
#  - Year 2059, Goal Goal D: Required return > 100% (191.75%)
#  - Year 2059, Goal Goal D: Required return > 100% (188.05%)
#  - Year 2059, Goal Goal D: Required return > 100% (184.45%)
#  - Year 2059, Goal Goal D: Required return > 100% (180.94%)
#  - Year 2059, Goal Goal D: Required return > 100% (177.51%)
#  - Year 2059, Goal Goal D: Required return > 100% (174.17%)
#  - Year 2059, Goal Goal D: Required return > 100% (170.91%)
#  - Year 2059, Goal Goal D: Required return > 100% (167.72%)
#  - Year 2059, Goal Goal D: Required return > 100% (164.61%)
#  - Year 2059, Goal Goal D: Required return > 100% (161.56%)
#  - Year 2059, Goal Goal D: Required return > 100% (158.59%)
#  - Year 2059, Goal Goal D: Required return > 100% (155.69%)
#  - Year 2059, Goal Goal D: Required return > 100% (152.85%)
#  - Year 2059, Goal Goal D: Required return > 100% (150.07%)
#  - Year 2059, Goal Goal D: Required return > 100% (147.35%)
#  - Year 2059, Goal Goal D: Required return > 100% (144.69%)
#  - Year 2059, Goal Goal D: Required return > 100% (142.09%)
#  - Year 2059, Goal Goal D: Required return > 100% (139.54%)
#  - Year 2059, Goal Goal D: Required return > 100% (137.04%)
#  - Year 2059, Goal Goal D: Required return > 100% (134.60%)
#  - Year 2059, Goal Goal D: Required return > 100% (132.21%)
#  - Year 2059, Goal Goal D: Required return > 100% (129.86%)
#  - Year 2059, Goal Goal D: Required return > 100% (127.56%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
#  - Year 2060, Goal Goal D: Required return > 100% (inf%)
