# %% [markdown]
# V1 (02 11 2025): Translated from R to Python and added the visualizations for goals B to D
#
#
# V2 (04 01 2025): Loop system implemented
#
# V2.5 (04 02 2025): Loops system tweaks. Removed openpyxl as it was corrupting files and replaced it with xlwings
#
# V3 & V4 finalize the loop except for the tax and asset channel
#
# V 5,6,7 add tax shenanigans. V7C added the fully functioning inflow and outflow of wealth with the returns and taxes in it.
#
# V8 modifies the aktiesparekonto pool so that it is increased when taxes are payed.
#
# V9 substracts from the wealth pool the amount for the goals reached. It does not just substract the full amount of the goal, but rather the % from the allocation of the year prior to the goal being handed.
#
# V10 Corrects returns to be inflation adjusted
#
# V11 Opportunity cost calculation to redeem goal
#
# V12 FinalWealth works without excel
#
# V13 Loop check works without excel

# %%
#!pip install numpy pandas scipy matplotlib xlwings

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import subprocess

# %%
# -- Variable Setup -- ##

#Monte Carlo Trials
n_trials = 10**5

# -V10 - Static Inflation
inflation_rate = 0.02  # 2%
#Case Study Profile Selection
Profile = "P1" #Either P1 or P2

#Excel worksheets - Master
excel_returns = "Returns"
excel_volatilities = "Volatilities"
excel_correlation = "Correlation"
excel_income = "Salary"
excel_real_returns = "Real Returns"

#Excel worksheets - Montecarlo Returns
excel_obligations_zc = "Government ZC Bonds - Obli"
excel_obligations_igb = "Investment Grade Bonds - Obli"
excel_obligations_hyb = "High Yield Bonds - Obli"
excel_obligations_ems = "Emerging Markets State - Obli"
excel_equities_dm = "Developed Markets - Equities"
excel_equities_em = "Emerging Markets - Equities"

# %% [markdown]
# # Define Functions
# This section defines the functions used for calculating portfolio volatility, expected return,
# goal achievement probability, and the objective (failure probability) to minimize.

# %%
def sd_f(weight_vector, covar_table):
    covar_vector = np.zeros(len(weight_vector))
    for z in range(len(weight_vector)):
        covar_vector[z] = np.sum(weight_vector * covar_table[:, z])
    return np.sqrt(np.sum(weight_vector * covar_vector))

# %%
def mean_f(weight_vector, return_vector):
    return np.sum(weight_vector * return_vector)

# %%
"""
Disabled because due to the dynamic model some phis are nan instead of 0
def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    # goal_vector is [value ratio, funding requirement, time horizon]
    required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
    if goal_allocation * pool >= goal_vector[1]:
        return 1
    else:
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)"""

def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    try:
        if goal_allocation <= 0 or pool <= 0 or goal_vector[2] <= 0 or sd <= 0:
            return 0  # invalid case
        required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
        if goal_allocation * pool >= goal_vector[1]:
            return 1
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)
    except:
        return 0  # fallback for any numerical error

# %%
def optim_function(weights):
    # Uses the current global variables: goal_vector, allocation, pool, return_vector, covar_table
    return 1 - phi_f(
        goal_vector,
        allocation,
        pool,
        mean_f(weights, return_vector),
        sd_f(weights, covar_table)
    )

# %%
def constraint_function(weights):
    # For SciPy equality constraints, we require constraint_function(weights) == 0.
        return np.sum(weights) - 1

# %%
def mvu_f(weights):
    # mvu_f is defined for mean-variance optimization (not used below).
    return -(mean_f(weights, return_vector) - 0.5 * gamma * sd_f(weights, covariances)**2)

# %%
def r_req_f(goal_vector, goal_allocation, pool):
    return (goal_vector[1] / (goal_allocation * pool))**(1 / goal_vector[2]) - 1

# %%
def get_goal_data(master_excel_path, plan=Profile):
    """
    Returns a DataFrame of the specified goal table (P1 or P2).
    P1 => B2:F5
    P2 => B7:F10
    """
    if plan == "P1":
        skip = 1  # start reading at row 2
    elif plan == "P2":
        skip = 6  # start reading at row 7
    else:
        raise ValueError("Plan not recognized. Use 'P1' or 'P2'.")

    df_goals = pd.read_excel(master_excel_path,sheet_name="Goals",skiprows=skip,nrows=4,usecols="B:F",header=0)
    # First column is "Goal Info", so make that the index
    df_goals.set_index(df_goals.columns[0], inplace=True)
    return df_goals

# %% [markdown]
# # Load & Parse Data

# %%
## -- Repo Root and Folders -- ##

# Get repo root and set folders
root = subprocess.run(["git", "rev-parse", "--show-toplevel"], capture_output=True, text=True).stdout.strip()
data_folder = os.path.join(root, "GBI Optimisation", "data")
output_folder = os.path.join(root, "GBI Optimisation")

# Get excel file and sheets
master_excel_path = os.path.join(data_folder, "Master.xlsx")
montecarlo_excel_path = os.path.join(data_folder, "Montecarlo Returns.xlsx")

df_returns = pd.read_excel(master_excel_path, sheet_name=excel_returns)
df_vols = pd.read_excel(master_excel_path, sheet_name=excel_volatilities)

df_returns.set_index(df_returns.columns[0], inplace=True)
df_vols.set_index(df_vols.columns[0], inplace=True)

df_corr = pd.read_excel(master_excel_path, sheet_name=excel_correlation)
df_corr.set_index(df_corr.columns[0], inplace=True)

df_real_returns = pd.read_excel(master_excel_path, sheet_name=excel_real_returns)
df_real_returns.set_index(df_real_returns.columns[0], inplace=True)

#Montecarlo Excel File DFs
df_zc = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_zc)
df_igb = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_igb)
df_hyb = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_hyb)
df_ems = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_ems)
df_dm = pd.read_excel(montecarlo_excel_path, sheet_name=excel_equities_dm)
df_em = pd.read_excel(montecarlo_excel_path, sheet_name=excel_equities_em)

# %%
sheet_map = {
    "Government ZC Bonds - Obligations": df_zc,
    "Investment Grade Bonds - Obligations": df_igb,
    "High Yield Bonds - Obligations": df_hyb,
    "Emerging Markets State - Obligations": df_ems,
    "Developed Markets - Equities": df_dm,
    "Emerging Markets - Equities": df_em,
}

# Stack into a long format with asset label and path number
all_paths = []

for sheet_name, df in sheet_map.items():
    df = df.drop(columns=df.columns[0])  # Drop the unnamed column
    df["Asset"] = sheet_name
    df["Path"] = range(len(df))
    all_paths.append(df)

df_montecarlo_returns = pd.concat(all_paths, ignore_index=True)
df_montecarlo_returns = df_montecarlo_returns.set_index(["Asset", "Path"])  # Multi-index for looping per asset/path

# %%
print(df_montecarlo_returns)
# Out:
#                                             2025      2026      2027  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.979959 -0.988946 -0.992397
#                                   1     0.032139 -0.032694 -0.024736
#                                   2    -0.062414 -0.039767 -0.038905
#                                   3    -0.005755 -0.027977 -0.019411
#                                   4     0.050316  0.025197  0.035256
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9994 -0.284966 -0.512681 -0.684569
#                                   9995  0.581717  0.650537  1.259412
#                                   9996 -0.116502 -0.318915 -0.128478
#                                   9997 -0.110199 -0.012209 -0.346583
#                                   9998 -0.264493 -0.138363  0.210876
#
#                                             2028      2029      2030  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.994155 -0.995233 -0.995988
#                                   1    -0.026872 -0.042744 -0.003861
#                                   2    -0.010012  0.041549 -0.022640
#                                   3    -0.027684 -0.047178 -0.005487
#                                   4     0.035039 -0.006451 -0.001372
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9994 -0.704879 -0.686145 -0.494765
#                                   9995  1.648085  0.769272  0.325218
#                                   9996 -0.101703  0.080899  0.062284
#                                   9997 -0.550211 -0.429595 -0.418652
#                                   9998  0.930641  1.024086  1.549291
#
#                                             2031      2032      2033  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.996391 -0.996874 -0.997111
#                                   1    -0.065594 -0.017815 -0.007954
#                                   2     0.041921  0.012096 -0.007562
#                                   3    -0.053832 -0.046436 -0.042238
#                                   4    -0.030500 -0.032701 -0.091766
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9994 -0.372757 -0.359987 -0.090492
#                                   9995  0.672086  1.256190  0.511955
#                                   9996  0.079858 -0.060011  0.805057
#                                   9997 -0.483616 -0.630412 -0.751563
#                                   9998  0.882310  0.980099  0.754575
#
#                                             2034  ...      2066      2067  \
# Asset                             Path            ...
# Government ZC Bonds - Obligations 0    -0.997396  ... -0.998277 -0.998297
#                                   1     0.003208  ... -0.170764 -0.129836
#                                   2     0.022008  ... -0.161234 -0.178104
#                                   3    -0.080377  ... -0.192875 -0.278886
#                                   4    -0.071732  ...  0.403485  0.510147
# ...                                          ...  ...       ...       ...
# Emerging Markets - Equities       9994  0.349562  ... -0.451356 -0.470983
#                                   9995 -0.070068  ...  3.993465  3.530246
#                                   9996  0.962554  ... -0.075976  0.042981
#                                   9997 -0.785312  ... -0.866474 -0.898618
#                                   9998  1.216452  ...  4.393417  4.390043
#
#                                             2068      2069      2070  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.998236 -0.998240 -0.998232
#                                   1    -0.090440 -0.125203 -0.096389
#                                   2    -0.255039 -0.266282 -0.289747
#                                   3    -0.271308 -0.216676 -0.201973
#                                   4     0.493041  0.467672  0.398871
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9994 -0.468602 -0.315570 -0.369840
#                                   9995  3.247756  3.459559  6.933328
#                                   9996  0.201124 -0.002405 -0.166012
#                                   9997 -0.923496 -0.930558 -0.942610
#                                   9998  4.332002  7.070071  5.768976
#
#                                             2071      2072      2073  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.998214 -0.998190 -0.998213
#                                   1    -0.120958 -0.130930 -0.165743
#                                   2    -0.268874 -0.267865 -0.221856
#                                   3    -0.245147 -0.238304 -0.242379
#                                   4     0.424675  0.450363  0.498839
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9994 -0.088770 -0.459858 -0.371491
#                                   9995  6.091636  9.763465  8.524677
#                                   9996 -0.248070 -0.510899 -0.627931
#                                   9997 -0.946907 -0.929561 -0.877555
#                                   9998  5.519892  3.916971  4.441648
#
#                                             2074  2075
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.998205   NaN
#                                   1    -0.117130   NaN
#                                   2    -0.246270   NaN
#                                   3    -0.224126   NaN
#                                   4     0.426973   NaN
# ...                                          ...   ...
# Emerging Markets - Equities       9994 -0.316325   NaN
#                                   9995  9.681887   NaN
#                                   9996 -0.621759   NaN
#                                   9997 -0.898874   NaN
#                                   9998  6.259082   NaN
#
# [59994 rows x 51 columns]

# %%
print(df_real_returns)
# Out:
#                                        2025   2026   2027   2028   2029  \
# Unnamed: 0
# Emerging Markets - Equities           0.001  0.001  0.001  0.001  0.001
# Developed Markets - Equities          0.001  0.001  0.001  0.001  0.001
# Emerging Markets State - Obligations  0.001  0.001  0.001  0.001  0.001
# High Yield Bonds - Obligations        0.001  0.001  0.001  0.001  0.001
# Investment Grade Bonds - Obligations  0.001  0.001  0.001  0.001  0.001
# Government ZC Bonds - Obligations     0.001  0.001  0.001  0.001  0.001
#
#                                        2030   2031   2032   2033   2034  ...  \
# Unnamed: 0                                                               ...
# Emerging Markets - Equities           0.001  0.001  0.001  0.001  0.001  ...
# Developed Markets - Equities          0.001  0.001  0.001  0.001  0.001  ...
# Emerging Markets State - Obligations  0.001  0.001  0.001  0.001  0.001  ...
# High Yield Bonds - Obligations        0.001  0.001  0.001  0.001  0.001  ...
# Investment Grade Bonds - Obligations  0.001  0.001  0.001  0.001  0.001  ...
# Government ZC Bonds - Obligations     0.001  0.001  0.001  0.001  0.001  ...
#
#                                       2066  2067  2068  2069  2070  2071  \
# Unnamed: 0
# Emerging Markets - Equities           0.04  0.04  0.04  0.04  0.04  0.04
# Developed Markets - Equities          0.04  0.04  0.04  0.04  0.04  0.04
# Emerging Markets State - Obligations  0.04  0.04  0.04  0.04  0.04  0.04
# High Yield Bonds - Obligations        0.04  0.04  0.04  0.04  0.04  0.04
# Investment Grade Bonds - Obligations  0.04  0.04  0.04  0.04  0.04  0.04
# Government ZC Bonds - Obligations     0.04  0.04  0.04  0.04  0.04  0.04
#
#                                       2072  2073  2074  2075
# Unnamed: 0
# Emerging Markets - Equities           0.04  0.04  0.04  0.04
# Developed Markets - Equities          0.04  0.04  0.04  0.04
# Emerging Markets State - Obligations  0.04  0.04  0.04  0.04
# High Yield Bonds - Obligations        0.04  0.04  0.04  0.04
# Investment Grade Bonds - Obligations  0.04  0.04  0.04  0.04
# Government ZC Bonds - Obligations     0.04  0.04  0.04  0.04
#
# [6 rows x 51 columns]

# %%
# - NEW V8 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #

# Initial cap in 2025
initial_ask_cap = 166200
growth_rate = 0.1265  # 12.65% annual increase
aktiesparekonto_used_total = 0

# %%
# V 13 - Year Loop table
# -- Replaces Excel loop sheet with in-code structure -- #
start_year = 2025
end_year = 2075
N_max = end_year - start_year + 1

age_p1_start = 25
age_p2_start = 40

loop_df = pd.DataFrame({
    "N": range(1, N_max + 1),
    "Year": list(range(start_year, end_year + 1)),
    "AgeP1": [age_p1_start + i for i in range(N_max)],
    "AgeP2": [age_p2_start + i for i in range(N_max)],
    "LoopStatus": ['N'] * N_max
})

# %%
# V14 - Load salary data for all years
df_salary = pd.read_excel(master_excel_path, sheet_name=excel_income)
df_salary.set_index(df_salary.columns[0], inplace=True)

# %%
path_results = {}
goal_reached = {g: [] for g in ["A", "B", "C", "D"]}

n_paths = 3  # Assuming you want to simulate all 9999 paths
for path_id in range(n_paths):
    loop_df["LoopStatus"] = "N"
    asset_level_log = []  # NEW: Log each asset's return pre- and post-tax by account
    #V12 moved finalwealth to python
    final_wealth_tracker = {}

    #V15 goal info stored in python instead of excel
    goal_weights_tracker = []          # Stores goal weights for each year
    aggregate_portfolio_tracker = []   # Stores aggregate portfolio for each year

    # V15: Store all optimal weight matrices by year
    goal_optimal_weights_A = {}
    goal_optimal_weights_B = {}
    goal_optimal_weights_C = {}
    goal_optimal_weights_D = {}
    print(f"🧪 Running simulation for path {path_id}")

    while True:
        pending_rows = loop_df[loop_df["LoopStatus"] == "N"]

        # If we find any rows, get the row with the lowest Year
        if pending_rows.empty:
            print("All loops completed")
            break


        chosen_row = pending_rows.loc[pending_rows["Year"].idxmin()]
        loop_year = chosen_row["Year"]
        loop_number = chosen_row["N"]
        loop_age1 = chosen_row["AgeP1"]
        loop_age2 = chosen_row["AgeP2"]

        print(loop_year, loop_number, loop_age1, loop_age2)

        # - Wealth - #

        # Get salary for current year
        salary = df_salary.loc[Profile, str(loop_year)]


        # - Dynamic time horizon based on current year - #

        # Step 1: Get Starting Year (minimum year in Loop sheet)
        starting_year = start_year
        prev_year = str(loop_year - 1)

        # If first loop year, no previous wealth exists
        if loop_year == starting_year:
            prev_wealth = 0
            pool = salary
        else:
            try:
                prev_wealth = final_wealth_tracker[int(prev_year)]
            except KeyError:
                raise KeyError(f"Previous wealth not found for {Profile} in {prev_year}")
            pool = salary + prev_wealth

        capital_market_expectations_raw = {}
        for asset in df_returns.index:
            expected_return = df_returns.loc[asset, str(loop_year)]
            volatility = df_vols.loc[asset, 'volatility']
            capital_market_expectations_raw[asset] = {
                'Return Forecast': expected_return,
                'Volatility Forecast': volatility
            }

        capital_market_expectations_raw = pd.DataFrame.from_dict(capital_market_expectations_raw, orient='index')

        capital_market_expectations_raw = capital_market_expectations_raw.reset_index()
        capital_market_expectations_raw.rename(columns={'index': 'Unnamed: 0'}, inplace=True)

        # Rearrange columns to match your old format (optional):
        capital_market_expectations_raw = capital_market_expectations_raw[['Unnamed: 0', 'Return Forecast', 'Volatility Forecast']]

        goal_data_raw = get_goal_data(master_excel_path, plan="P1")

        # - Dynamic time horizon based on current year - #


        # Step 2: Compute Goal Years = starting_year + time_horizon
        goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
        goal_years = starting_year + goal_horizons

        # Step 3: Recalculate Time Horizons = goal_years - current loop_year
        adjusted_horizons = goal_years - loop_year

        # Step 4: Replace the "Time Horizon" row in goal_data_raw
        goal_data_raw.loc["Time Horizon"] = adjusted_horizons


        # - V8 - Dynamically compute ASK cap per year
        aktiesparekonto_cap = initial_ask_cap * ((1 + growth_rate) ** (loop_year - starting_year))

        goals = ["A", "B", "C", "D"]
        active_goal_mask = np.array([adjusted_horizons[f"GOAL {g}"] > 0 for g in goals])

        # Optional: print to confirm
        print("Starting Year:", starting_year)
        print("Current Year:", loop_year)
        print("Goal Years:", goal_years.to_dict())
        print("Adjusted Horizons:", adjusted_horizons.to_dict())



        # Record number of potential investments and goals
        num_assets = capital_market_expectations_raw.shape[0]
        num_goals = goal_data_raw.shape[1]

        # Create vector of expected returns
        return_vector = (capital_market_expectations_raw["Return Forecast"] - inflation_rate).to_numpy()

        # Get the correlations as a numeric DataFrame (just a num_assets × num_assets block)
        correlations = df_corr.iloc[:num_assets, :num_assets].astype(float)

        # Build the covariance matrix: stdev_i * stdev_j * correlation_ij
        stdevs = capital_market_expectations_raw["Volatility Forecast"].to_numpy()
        covariances = np.zeros((num_assets, num_assets))
        for i in range(num_assets):
            for j in range(num_assets):
                covariances[i, j] = stdevs[i] * stdevs[j] * correlations.iloc[i, j]

        goal_A = goal_data_raw["GOAL A"].values
        goal_B = goal_data_raw["GOAL B"].values
        goal_C = goal_data_raw["GOAL C"].values
        goal_D = goal_data_raw["GOAL D"].values

        # - Optimal Goal Allocation - #


        goal_allocation = np.arange(0.01, 1.01, 0.01)

        # Starting weights (random initialization normalized to sum to 1)
        starting_weights = np.random.uniform(0, 1, num_assets)
        starting_weights /= np.sum(starting_weights)

        # Initialize matrices to store the optimal weights for each goal
        optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
        optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
        optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
        optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

        goal_allocation = np.arange(0.01, 1.01, 0.01)

        # Set SLSQP options to be more stringent, mimicking solnp's behavior.
        slsqp_opts = {
            'ftol': 1e-12,     # function tolerance
            'eps': 1e-12,      # finite-difference step size for gradient estimation
            'maxiter': 10000,  # maximum iterations
            'disp': False     # do not display convergence messages
        }

        for i, alloc in enumerate(goal_allocation):
            allocation = alloc      # Global variable used in optim_function
            covar_table = covariances

            # Goal A Optimization
            goal_vector = goal_A   # Global variable used in optim_function
            if goal_A[1] <= pool * allocation:
                optimal_weights_A[i, :] = [0]*(num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_A[i, :] = result.x

            # Goal B Optimization
            goal_vector = goal_B
            if goal_B[1] <= pool * allocation:
                optimal_weights_B[i, :] = [0]*(num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_B[i, :] = result.x

            # Goal C Optimization
            goal_vector = goal_C
            if goal_C[1] <= pool * allocation:
                optimal_weights_C[i, :] = [0]*(num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_C[i, :] = result.x

            # Goal D Optimization
            goal_vector = goal_D
            if goal_D[1] <= pool * allocation:
                optimal_weights_D[i, :] = [0]*(num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_D[i, :] = result.x

        goal_optimal_weights_A[loop_year] = optimal_weights_A
        goal_optimal_weights_B[loop_year] = optimal_weights_B
        goal_optimal_weights_C[loop_year] = optimal_weights_C
        goal_optimal_weights_D[loop_year] = optimal_weights_D

        # Calculate the best probability (phi) for each allocation level for every goal
        phi_A = np.zeros(len(goal_allocation))
        phi_B = np.zeros(len(goal_allocation))
        phi_C = np.zeros(len(goal_allocation))
        phi_D = np.zeros(len(goal_allocation))

        for i, alloc in enumerate(goal_allocation):
            phi_A[i] = phi_f(goal_A, alloc, pool,
                             mean_f(optimal_weights_A[i, :], return_vector),
                             sd_f(optimal_weights_A[i, :], covariances))
            phi_B[i] = phi_f(goal_B, alloc, pool,
                             mean_f(optimal_weights_B[i, :], return_vector),
                             sd_f(optimal_weights_B[i, :], covariances))
            phi_C[i] = phi_f(goal_C, alloc, pool,
                             mean_f(optimal_weights_C[i, :], return_vector),
                             sd_f(optimal_weights_C[i, :], covariances))
            phi_D[i] = phi_f(goal_D, alloc, pool,
                             mean_f(optimal_weights_D[i, :], return_vector),
                             sd_f(optimal_weights_D[i, :], covariances))

        # Simulate goal weights: each row is a simulated allocation (in percentages)
        sim_goal_weights = np.random.multinomial(100, [1/num_goals]*num_goals, size=n_trials) #this one sums to 100 so its good
        for i in range(n_trials):
            rand_vector = np.random.uniform(0, 1, num_goals)
            normalizer = np.sum(rand_vector)
            percents = np.round((rand_vector / normalizer) * 100, 0)

            # Only enforce floor for active goals
            floor_applied = np.where(active_goal_mask, np.maximum(percents, 1), percents)
            sim_goal_weights[i, :] = floor_applied


        # Calculate utility for each simulated portfolio.
        # Note: subtract 1 from simulated weights for 0-indexing.
        utility = (
            goal_A[0] * phi_A[sim_goal_weights[:, 0] - 1] +
            goal_A[0] * goal_B[0] * phi_B[sim_goal_weights[:, 1] - 1] +
            goal_A[0] * goal_B[0] * goal_C[0] * phi_C[sim_goal_weights[:, 2] - 1] +
            goal_A[0] * goal_B[0] * goal_C[0] * goal_D[0] * phi_D[sim_goal_weights[:, 3] - 1]
        )

        # Find the index of the portfolio with the highest utility
        index = np.argmax(utility)
        optimal_goal_weights = sim_goal_weights[index, :]

        # - Optimal Subportfolio Allocation - #

        # Retrieve optimal subportfolio allocations
        optimal_subportfolios = np.zeros((num_goals, num_assets))

        # For each goal, use the simulated percentage to select the corresponding row
        # from the optimal weights matrix (adjust for zero-indexing)
        for i in range(num_goals):
            optimal_subportfolios[i, :] = eval(f"optimal_weights_{goals[i]}")[optimal_goal_weights[i] - 1, :]

        # Compute the optimal aggregate investment portfolio.
        optimal_aggregate_portfolio = (optimal_goal_weights / 100) @ optimal_subportfolios

        #Define asset names
        asset_names = capital_market_expectations_raw.iloc[:, 0].astype(str).tolist()

        # - Storing and exporting results - #

        # Create a DataFrame for the aggregate portfolio.
        # First calculate unrounded percentages
        raw_alloc = optimal_aggregate_portfolio * 100

        # Normalize to force sum = 100 after rounding
        normalized_alloc = raw_alloc / raw_alloc.sum() * 100
        normalized_goal_alloc = np.zeros_like(optimal_goal_weights, dtype=float)
        active_sum = np.sum(optimal_goal_weights[active_goal_mask])
        normalized_goal_alloc[active_goal_mask] = (optimal_goal_weights[active_goal_mask] / active_sum) * 100

        normalized_weights = normalized_alloc / 100  # convert back to decimal weights

        # Create a DataFrame for the across-goal allocation.
        df_across_goal = pd.DataFrame({
            "Goal": goals,
            "Allocation (%)": np.round(normalized_goal_alloc, 2) # Keep raw percentages
        })

        # Round after normalization
        df_aggregate = pd.DataFrame({
            "Asset": asset_names,
            "Weight": normalized_weights,
            "Invested Amt (DKK)": normalized_weights * pool,
            "Allocation (%)": np.round(normalized_alloc, 2)  # keep for display only
        })


        # - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #
        # --- NEW: Exact and Proportional ASK Logic ---
        account_allocations = []
        equity_rows = []
        non_equity_rows = []

        # First pass: split equity and non-equity rows
        for i, row in df_aggregate.iterrows():
            asset_name = row["Asset"]
            invested = row["Invested Amt (DKK)"]
            weight = row["Weight"]

            row_dict = {
                "Year": loop_year,
                "Asset": asset_name,
                "Invested": invested,
                "Weight": weight,
                "ASK (DKK)": 0,
                "Normal (DKK)": 0,
            }

            if "Equities" in asset_name:
                equity_rows.append(row_dict)
            else:
                row_dict["Normal (DKK)"] = invested
                non_equity_rows.append(row_dict)

        # Determine total equity to allocate proportionally if ASK cap remains
        total_equity = sum(row["Invested"] for row in equity_rows)
        remaining_ask_cap = max(0, aktiesparekonto_cap - aktiesparekonto_used_total)
        ask_fraction = min(1, remaining_ask_cap / total_equity) if total_equity > 0 else 0

        # Apply proportional ASK allocation to equities
        for row in equity_rows:
            ask_part = row["Invested"] * ask_fraction
            normal_part = row["Invested"] - ask_part
            row["ASK (DKK)"] = round(ask_part, 2)
            row["Normal (DKK)"] = round(normal_part, 2)
            aktiesparekonto_used_total += ask_part

        # Combine and finalize
        account_allocations = equity_rows + non_equity_rows


        df_accounts = pd.DataFrame(account_allocations)
        print(f"[DEBUG] Final weight sum: {sum(row['Weight'] for row in account_allocations):.10f}")
        # - V5 END - #


        # - NEW V6 CONTENT REGARDING GAINS & TAXES - #


        share_income_normal = 0  # for progressive tax
        tax_ask = 0  # Track ASK tax separately

        # Update portfolio and compute gains
        for row in account_allocations:
            asset = row["Asset"]
            ask = row["ASK (DKK)"]
            normal = row["Normal (DKK)"]
            weight = row["Weight"]
            expected_return_nominal = df_montecarlo_returns.loc[(asset, path_id), str(loop_year)]
            expected_return_inflation_adj = expected_return_nominal - inflation_rate


            # V7C -LOG ASSET RETURNS BY ACCOUNT
            if ask > 0:
                new_val = ask * (1 + expected_return_inflation_adj)
                gain = new_val - ask
                tax = 0.17 * gain
                asset_level_log.append({
                    "Year": loop_year,
                    "Account": "ASK",
                    "Asset": asset,
                    "Invested": ask,
                    "Weight": ask / pool,
                    "Return (Nominal)": expected_return_nominal,
                    "Inflation Rate": inflation_rate,
                    "Return (Inflation Adjusted)": expected_return_inflation_adj,
                    "Gross Gain": gain,
                    "Tax": tax,
                    "Net Gain": gain - tax,
                    "End Value": ask + gain - tax,
                    "TOTAL ASK Cap (DKK)": aktiesparekonto_cap
                })

            if normal > 0:
                new_val = normal * (1 + expected_return_inflation_adj)
                gain = new_val - normal
                share_income_normal += gain
                asset_level_log.append({
                    "Year": loop_year,
                    "Account": "NORMAL",
                    "Asset": asset,
                    "Invested": normal,
                    "Weight": normal / pool,
                    "Return (Nominal)": expected_return_nominal,
                    "Inflation Rate": inflation_rate,
                    "Return (Inflation Adjusted)": expected_return_inflation_adj,
                    "Gross Gain": gain,
                    "Tax": None,  # progressive tax logged later
                    "Net Gain": None,
                    "End Value": None,
                    "TOTAL ASK Cap (DKK)": aktiesparekonto_cap
                })

                #V7C END

        # Tax on Normal Account (progressive)
        cap = 67500
        if share_income_normal <= cap:
            tax_normal = 0.27 * share_income_normal
        else:
            tax_normal = 0.27 * cap + 0.42 * (share_income_normal - cap)

        # Distribute tax proportionally across NORMAL assets
        normal_log_rows = [
            row for row in asset_level_log
            if "Account" in row and row["Account"] == "NORMAL" and row["Year"] == loop_year
        ]

        total_normal_gain = sum(row["Gross Gain"] for row in normal_log_rows)

        print(f"[DEBUG] Year: {loop_year}")
        print(f"[DEBUG] Gross Gains (Normal account): {share_income_normal:.2f}")
        print(f"[DEBUG] Tax Calculated (Normal account): {tax_normal:.2f}")

        for row in normal_log_rows:
            if total_normal_gain > 0:
                share = row["Gross Gain"] / total_normal_gain
                tax = share * tax_normal
            else:
                tax = 0

            row["Tax"] = tax
            row["Net Gain"] = row["Gross Gain"] - tax
            row["End Value"] = row["Invested"] + row["Net Gain"]

        total_gains_normal = share_income_normal - tax_normal


        print("Optimal Across-Goal Allocation:")
        print(df_across_goal.to_string(index=False))

        print("\nOptimal Aggregate Investment Allocation:")
        print(df_aggregate.to_string(index=False))

        print("\nUtility:")
        print(utility)

        print("\nProbability of Achieving Each Goal at Optimal Allocation:")
        print(f"Goal A: {phi_A[optimal_goal_weights[0] - 1]:.4f}")
        print(f"Goal B: {phi_B[optimal_goal_weights[1] - 1]:.4f}")
        print(f"Goal C: {phi_C[optimal_goal_weights[2] - 1]:.4f}")
        print(f"Goal D: {phi_D[optimal_goal_weights[3] - 1]:.4f}")

        # -- V15 Goal weights -- #


        # Store current year's across-goal allocation
        goal_weights_tracker.append({
            "Year": loop_year,
            **{f"Goal {goals[i]} (%)": normalized_goal_alloc[i] for i in range(num_goals)}
        })

        # Store current year's aggregate portfolio
        for i in range(num_assets):
            aggregate_portfolio_tracker.append({
                "Year": loop_year,
                "Asset": asset_names[i],
                "Weight": normalized_weights[i],
                "Allocation (%)": np.round(normalized_alloc[i], 2),
                "Invested Amt (DKK)": normalized_weights[i] * pool
            })


        # -- V13 - Modify Loop Check -- #
        print("Starting loop status check (in-memory)...")

        # Show up to 10 rows (adjust as needed) of the current loop status
        preview_rows = loop_df.tail(10)
        for i, row in preview_rows.iterrows():
            print(f"Row {i+2}: Year = {row['Year']}, Status = {row['LoopStatus']}")

        # Update the current year's loop status
        loop_df.loc[loop_df["Year"] == loop_year, "LoopStatus"] = "Y"
        print(f"✅ LoopStatus updated to 'Y' for Year {loop_year}")

        this_year_rows = [row for row in asset_level_log if row["Year"] == loop_year]
        end_value_sum = sum(row["End Value"] for row in this_year_rows)

        # - V9 END -

        # --- V11: Opportunity Cost Check for Goal Redemption --- #
        for idx, g in enumerate(goals):
            horizon = adjusted_horizons[f"GOAL {g}"]
            if horizon == 1:
                goal_vec = goal_data_raw[f"GOAL {g}"].values.copy()
                goal_value = goal_vec[1]

                # Step 1: Prepare inputs
                phi_array = [None] * num_goals
                goal_ratios = [goal_data_raw[f"GOAL {goals[i]}"].values[0] for i in range(num_goals)]
                allocs = [normalized_goal_alloc[i] / 100 for i in range(num_goals)]

                # Step 2: Case 1 - Keep goal (phi = 0 for this goal)
                for j in range(num_goals):
                    if j == idx:
                        phi_array[j] = 0
                    else:
                        phi_array[j] = phi_f(
                            goal_data_raw[f"GOAL {goals[j]}"].values,
                            allocs[j],
                            pool,
                            mean_f(optimal_subportfolios[j], return_vector),
                            sd_f(optimal_subportfolios[j], covariances)
                        )

                utility_keep = (
                    goal_ratios[0] * phi_array[0] +
                    goal_ratios[0] * goal_ratios[1] * phi_array[1] +
                    goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * phi_array[2] +
                    goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * goal_ratios[3] * phi_array[3]
                )

                # Step 3: Case 2 - Redeem goal (phi = 1, pool reduced)
                pool_reduced = pool - goal_value
                for j in range(num_goals):
                    if j == idx:
                        phi_array[j] = 1
                    else:
                        phi_array[j] = phi_f(
                            goal_data_raw[f"GOAL {goals[j]}"].values,
                            allocs[j],
                            pool_reduced,
                            mean_f(optimal_subportfolios[j], return_vector),
                            sd_f(optimal_subportfolios[j], covariances)
                        )

                utility_redeem = (
                    goal_ratios[0] * phi_array[0] +
                    goal_ratios[0] * goal_ratios[1] * phi_array[1] +
                    goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * phi_array[2] +
                    goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * goal_ratios[3] * phi_array[3]
                )

                # Step 4: Compare & apply
                utility_diff = utility_redeem - utility_keep
                redeem = utility_diff > 0

                if redeem:
                    allocated_value = allocs[idx] * end_value_sum
                    redeemed_amount = min(goal_value, allocated_value)
                    end_value_sum -= redeemed_amount
                    goal_reached[g].append({"path_id": path_id, "success": True})
                if not redeem:
                    goal_reached[g].append({"path_id": path_id, "success": False})

                asset_level_log.append({
                    "Year": loop_year,
                    "Goal": f"GOAL {g}",
                    "Redeemed Amount": redeemed_amount,
                    "Allocated Value": allocated_value,
                    "Goal Value": goal_value,
                    "Utility (Keep)": utility_keep,
                    "Utility (Redeem)": utility_redeem,
                    "Utility Δ": utility_diff,
                    "Redeemed": True
                })


        final_wealth_tracker[loop_year] = end_value_sum

        print(f"\n--- Year {loop_year} Summary ---")
        print(f"Income (Salary): {salary:.2f}")
        if loop_year != starting_year:
            print(f"Previous Wealth Carried: {prev_wealth:.2f}")
        print(f"Post-Tax Wealth (New Final Wealth): {pool:.2f}")
        print("------------------------------\n")
    # Create subfolder for each path (optional but cleaner)
    path_folder = os.path.join(output_folder, f"path_{path_id}")
    os.makedirs(path_folder, exist_ok=True)

    # Export asset-level log
    pd.DataFrame(asset_level_log).to_csv(os.path.join(path_folder, "asset_returns_log.csv"), index=False)

    # Export final wealth
    pd.DataFrame.from_dict(final_wealth_tracker, orient='index', columns=['Final Wealth']).to_csv(
        os.path.join(path_folder, "final_wealth_by_year.csv")
    )

    # Export goal weights
    pd.DataFrame(goal_weights_tracker).to_csv(
        os.path.join(path_folder, "goal_weights_by_year.csv"), index=False
    )

    # Export aggregate portfolio
    pd.DataFrame(aggregate_portfolio_tracker).to_csv(
        os.path.join(path_folder, "aggregate_portfolio_by_year.csv"), index=False
    )

    # Export optimal weights for each goal
    for goal_letter, matrix_dict in zip(
        ["A", "B", "C", "D"],
        [goal_optimal_weights_A, goal_optimal_weights_B, goal_optimal_weights_C, goal_optimal_weights_D]
    ):
        all_dfs = []
        for year, mat in matrix_dict.items():
            df = pd.DataFrame(mat)
            df.insert(0, "Year", year)
            df.insert(1, "Allocation Level", np.arange(0.01, 1.01, 0.01))
            all_dfs.append(df)

        df_all = pd.concat(all_dfs, ignore_index=True)
        df_all.to_csv(os.path.join(path_folder, f"optimal_weights_goal_{goal_letter}.csv"), index=False)

    path_results[path_id] = {
        "final_wealth": final_wealth_tracker.copy(),
        "goal_weights": goal_weights_tracker.copy(),
        "aggregate_portfolio": aggregate_portfolio_tracker.copy()
    }
# Out:
# 🧪 Running simulation for path 0
# 2025 1 25 40
# Starting Year: 2025
# Current Year: 2025
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 50, 'GOAL B': 5, 'GOAL C': 10, 'GOAL D': 15}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2025
# [DEBUG] Gross Gains (Normal account): 0.00
# [DEBUG] Tax Calculated (Normal account): 0.00
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            35.0
#    B             5.0
#    C            23.0
#    D            37.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.136614                 0.0           13.66
#         Developed Markets - Equities 0.166915                 0.0           16.69
# Emerging Markets State - Obligations 0.110640                 0.0           11.06
#       High Yield Bonds - Obligations 0.317397                 0.0           31.74
# Investment Grade Bonds - Obligations 0.069041                 0.0            6.90
#    Government ZC Bonds - Obligations 0.199393                 0.0           19.94
#
# Utility:
# [0. 0. 0. ... 0. 0. 0.]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2025
#
# --- Year 2025 Summary ---
# Income (Salary): 0.00
# Post-Tax Wealth (New Final Wealth): 0.00
# ------------------------------
#
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 49, 'GOAL B': 4, 'GOAL C': 9, 'GOAL D': 14}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2026
# [DEBUG] Gross Gains (Normal account): -2044.60
# [DEBUG] Tax Calculated (Normal account): -552.04
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            94.0
#    B             1.0
#    C             2.0
#    D             3.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.949273        49974.661247           94.93
#         Developed Markets - Equities 0.012226          643.629230            1.22
# Emerging Markets State - Obligations 0.012373          651.381772            1.24
#       High Yield Bonds - Obligations 0.007028          369.988633            0.70
# Investment Grade Bonds - Obligations 0.014848          781.685868            1.48
#    Government ZC Bonds - Obligations 0.004252          223.853250            0.43
#
# Utility:
# [0.1862142  0.15813623 0.2253119  ... 0.22060619 0.16582179 0.15329818]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3112
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2026
#
# --- Year 2026 Summary ---
# Income (Salary): 52645.20
# Previous Wealth Carried: 0.00
# Post-Tax Wealth (New Final Wealth): 52645.20
# ------------------------------
#
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 48, 'GOAL B': 3, 'GOAL C': 8, 'GOAL D': 13}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2027
# [DEBUG] Gross Gains (Normal account): -2841.35
# [DEBUG] Tax Calculated (Normal account): -767.16
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            92.0
#    B             1.0
#    C             4.0
#    D             3.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.934495        57378.813102           93.45
#         Developed Markets - Equities 0.019798         1215.603552            1.98
# Emerging Markets State - Obligations 0.021248         1304.622855            2.12
#       High Yield Bonds - Obligations 0.007005          430.094461            0.70
# Investment Grade Bonds - Obligations 0.006074          372.960511            0.61
#    Government ZC Bonds - Obligations 0.011381          698.806413            1.14
#
# Utility:
# [0.12403289 0.23915757 0.21407419 ... 0.20708772 0.0447902  0.21274054]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3142
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2027
#
# --- Year 2027 Summary ---
# Income (Salary): 53171.65
# Previous Wealth Carried: 8229.25
# Post-Tax Wealth (New Final Wealth): 61400.90
# ------------------------------
#
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 47, 'GOAL B': 2, 'GOAL C': 7, 'GOAL D': 12}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2028
# [DEBUG] Gross Gains (Normal account): -1656.61
# [DEBUG] Tax Calculated (Normal account): -447.28
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            95.0
#    B             1.0
#    C             1.0
#    D             3.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.964868        66035.471101           96.49
#         Developed Markets - Equities 0.011273          771.501978            1.13
# Emerging Markets State - Obligations 0.003147          215.362396            0.31
#       High Yield Bonds - Obligations 0.007140          488.655989            0.71
# Investment Grade Bonds - Obligations 0.009651          660.547724            0.97
#    Government ZC Bonds - Obligations 0.003922          268.395734            0.39
#
# Utility:
# [0.08846049 0.17055801 0.20638665 ... 0.19309612 0.21420567 0.20861072]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3181
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2028
#
# --- Year 2028 Summary ---
# Income (Salary): 59020.53
# Previous Wealth Carried: 9419.40
# Post-Tax Wealth (New Final Wealth): 68439.93
# ------------------------------
#
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 46, 'GOAL B': 1, 'GOAL C': 6, 'GOAL D': 11}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2029
# [DEBUG] Gross Gains (Normal account): -1384.02
# [DEBUG] Tax Calculated (Normal account): -373.69
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            94.0
#    B             3.0
#    C             1.0
#    D             2.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.960711        67452.594699           96.07
#         Developed Markets - Equities 0.019881         1395.890299            1.99
# Emerging Markets State - Obligations 0.001907          133.903889            0.19
#       High Yield Bonds - Obligations 0.009595          673.665760            0.96
# Investment Grade Bonds - Obligations 0.007078          496.965114            0.71
#    Government ZC Bonds - Obligations 0.000827           58.067503            0.08
#
# Utility:
# [0.19755405 0.26032328 0.12326367 ... 0.13883785 0.26355477 0.19892346]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3097
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2029
#
# --- Year 2029 Summary ---
# Income (Salary): 59610.74
# Previous Wealth Carried: 10600.35
# Post-Tax Wealth (New Final Wealth): 70211.09
# ------------------------------
#
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 45, 'GOAL B': 0, 'GOAL C': 5, 'GOAL D': 10}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2030
# [DEBUG] Gross Gains (Normal account): -14395.67
# [DEBUG] Tax Calculated (Normal account): -3886.83
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           95.96
#    B            0.00
#    C            3.03
#    D            1.01
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.963251        68246.709564           96.33
#         Developed Markets - Equities 0.002732          193.545247            0.27
# Emerging Markets State - Obligations 0.014498         1027.180781            1.45
#       High Yield Bonds - Obligations 0.002681          189.983054            0.27
# Investment Grade Bonds - Obligations 0.005371          380.549322            0.54
#    Government ZC Bonds - Obligations 0.011467          812.447223            1.15
#
# Utility:
# [0.2067378  0.11252969 0.11252969 ... 0.21387975 0.22482419 0.17544666]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3015
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2030
#
# --- Year 2030 Summary ---
# Income (Salary): 60206.85
# Previous Wealth Carried: 10643.57
# Post-Tax Wealth (New Final Wealth): 70850.42
# ------------------------------
#
# 2031 7 31 46
# Starting Year: 2025
# Current Year: 2031
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 44, 'GOAL B': -1, 'GOAL C': 4, 'GOAL D': 9}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2031
# [DEBUG] Gross Gains (Normal account): -31971.12
# [DEBUG] Tax Calculated (Normal account): -8632.20
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           96.97
#    B            0.00
#    C            1.01
#    D            2.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.964074        67205.812052           96.41
#         Developed Markets - Equities 0.012853          895.967207            1.29
# Emerging Markets State - Obligations 0.010195          710.662962            1.02
#       High Yield Bonds - Obligations 0.004685          326.589343            0.47
# Investment Grade Bonds - Obligations 0.003576          249.298670            0.36
#    Government ZC Bonds - Obligations 0.004617          321.884983            0.46
#
# Utility:
# [0.02472532 0.23679554 0.10269698 ... 0.12449079 0.2432829  0.1571564 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.2905
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2031
#
# --- Year 2031 Summary ---
# Income (Salary): 60808.91
# Previous Wealth Carried: 8901.30
# Post-Tax Wealth (New Final Wealth): 69710.22
# ------------------------------
#
# 2032 8 32 47
# Starting Year: 2025
# Current Year: 2032
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 43, 'GOAL B': -2, 'GOAL C': 3, 'GOAL D': 8}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2032
# [DEBUG] Gross Gains (Normal account): -30631.00
# [DEBUG] Tax Calculated (Normal account): -8270.37
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           96.84
#    B            0.00
#    C            2.11
#    D            1.05
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.913988        66891.240410           91.40
#         Developed Markets - Equities 0.008324          609.217314            0.83
# Emerging Markets State - Obligations 0.034318         2511.625760            3.43
#       High Yield Bonds - Obligations 0.025210         1845.014137            2.52
# Investment Grade Bonds - Obligations 0.009271          678.517413            0.93
#    Government ZC Bonds - Obligations 0.008888          650.479934            0.89
#
# Utility:
# [1.85514366e-01 2.30294528e-01 1.90404513e-01 ... 2.04455151e-06
#  2.03907000e-01 1.77746702e-01]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.2803
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2032
#
# --- Year 2032 Summary ---
# Income (Salary): 67497.90
# Previous Wealth Carried: 5688.20
# Post-Tax Wealth (New Final Wealth): 73186.09
# ------------------------------
#
# 2033 9 33 48
# Starting Year: 2025
# Current Year: 2033
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 42, 'GOAL B': -3, 'GOAL C': 2, 'GOAL D': 7}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2033
# [DEBUG] Gross Gains (Normal account): -26560.90
# [DEBUG] Tax Calculated (Normal account): -7171.44
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           95.92
#    B            0.00
#    C            1.02
#    D            3.06
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.957269        71425.968177           95.73
#         Developed Markets - Equities 0.012504          932.977248            1.25
# Emerging Markets State - Obligations 0.006893          514.335557            0.69
#       High Yield Bonds - Obligations 0.021786         1625.567321            2.18
# Investment Grade Bonds - Obligations 0.000095            7.070573            0.01
#    Government ZC Bonds - Obligations 0.001452          108.376352            0.15
#
# Utility:
# [0.05309496 0.17860736 0.15425351 ... 0.19015295 0.16014905 0.20458403]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.2734
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2033
#
# --- Year 2033 Summary ---
# Income (Salary): 68172.87
# Previous Wealth Carried: 6441.42
# Post-Tax Wealth (New Final Wealth): 74614.30
# ------------------------------
#
# 2034 10 34 49
# Starting Year: 2025
# Current Year: 2034
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 41, 'GOAL B': -4, 'GOAL C': 1, 'GOAL D': 6}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2034
# [DEBUG] Gross Gains (Normal account): -21989.67
# [DEBUG] Tax Calculated (Normal account): -5937.21
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           96.94
#    B            0.00
#    C            1.02
#    D            2.04
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.955565        72835.306224           95.56
#         Developed Markets - Equities 0.008394          639.807056            0.84
# Emerging Markets State - Obligations 0.006921          527.515319            0.69
#       High Yield Bonds - Obligations 0.014551         1109.077072            1.46
# Investment Grade Bonds - Obligations 0.011824          901.274050            1.18
#    Government ZC Bonds - Obligations 0.002746          209.274175            0.27
#
# Utility:
# [0.12553769 0.14210149 0.15095122 ... 0.19508883 0.0383373  0.14513092]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.2652
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2034
#
# --- Year 2034 Summary ---
# Income (Salary): 68854.60
# Previous Wealth Carried: 7367.65
# Post-Tax Wealth (New Final Wealth): 76222.25
# ------------------------------
#
# 2035 11 35 50
# Starting Year: 2025
# Current Year: 2035
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 40, 'GOAL B': -5, 'GOAL C': 0, 'GOAL D': 5}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2035
# [DEBUG] Gross Gains (Normal account): -16743.68
# [DEBUG] Tax Calculated (Normal account): -4520.79
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            99.0
#    B             0.0
#    C             0.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.984922        76772.181737           98.49
#         Developed Markets - Equities 0.002917          227.334018            0.29
# Emerging Markets State - Obligations 0.002287          178.290971            0.23
#       High Yield Bonds - Obligations 0.001694          132.067924            0.17
# Investment Grade Bonds - Obligations 0.001117           87.061126            0.11
#    Government ZC Bonds - Obligations 0.007063          550.519171            0.71
#
# Utility:
# [0.06186178 0.12118893 0.08969318 ... 0.10758129 0.12277132 0.13878754]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1875
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2035
#
# --- Year 2035 Summary ---
# Income (Salary): 69543.15
# Previous Wealth Carried: 8404.31
# Post-Tax Wealth (New Final Wealth): 77947.45
# ------------------------------
#
# 2036 12 36 51
# Starting Year: 2025
# Current Year: 2036
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 39, 'GOAL B': -6, 'GOAL C': -1, 'GOAL D': 4}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2036
# [DEBUG] Gross Gains (Normal account): -17809.26
# [DEBUG] Tax Calculated (Normal account): -4808.50
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           98.96
#    B            0.00
#    C            0.00
#    D            1.04
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.956728        83014.500721           95.67
#         Developed Markets - Equities 0.015167         1316.068581            1.52
# Emerging Markets State - Obligations 0.015926         1381.877621            1.59
#       High Yield Bonds - Obligations 0.004460          387.013382            0.45
# Investment Grade Bonds - Obligations 0.006210          538.853796            0.62
#    Government ZC Bonds - Obligations 0.001508          130.842561            0.15
#
# Utility:
# [0.10737799 0.07581431 0.08065187 ... 0.12254051 0.11093729 0.09591068]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1834
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2036
#
# --- Year 2036 Summary ---
# Income (Salary): 77192.90
# Previous Wealth Carried: 9576.26
# Post-Tax Wealth (New Final Wealth): 86769.16
# ------------------------------
#
# 2037 13 37 52
# Starting Year: 2025
# Current Year: 2037
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 38, 'GOAL B': -7, 'GOAL C': -2, 'GOAL D': 3}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2037
# [DEBUG] Gross Gains (Normal account): -11006.33
# [DEBUG] Tax Calculated (Normal account): -2971.71
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           98.96
#    B            0.00
#    C            0.00
#    D            1.04
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.953344        84648.269217           95.33
#         Developed Markets - Equities 0.011315         1004.651710            1.13
# Emerging Markets State - Obligations 0.017472         1551.347398            1.75
#       High Yield Bonds - Obligations 0.008163          724.835333            0.82
# Investment Grade Bonds - Obligations 0.005983          531.213998            0.60
#    Government ZC Bonds - Obligations 0.003723          330.534558            0.37
#
# Utility:
# [8.06235045e-02 8.06235045e-02 8.06235045e-02 ... 2.66762353e-06
#  9.07525694e-02 9.45430682e-02]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1752
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2037
#
# --- Year 2037 Summary ---
# Income (Salary): 77964.82
# Previous Wealth Carried: 10826.03
# Post-Tax Wealth (New Final Wealth): 88790.85
# ------------------------------
#
# 2038 14 38 53
# Starting Year: 2025
# Current Year: 2038
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 37, 'GOAL B': -8, 'GOAL C': -3, 'GOAL D': 2}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2038
# [DEBUG] Gross Gains (Normal account): -7389.27
# [DEBUG] Tax Calculated (Normal account): -1995.10
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           98.92
#    B            0.00
#    C            0.00
#    D            1.08
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.916279        83371.290557           91.63
#         Developed Markets - Equities 0.003927          357.357458            0.39
# Emerging Markets State - Obligations 0.035629         3241.835494            3.56
#       High Yield Bonds - Obligations 0.006419          584.047999            0.64
# Investment Grade Bonds - Obligations 0.004049          368.422944            0.40
#    Government ZC Bonds - Obligations 0.033696         3065.997407            3.37
#
# Utility:
# [8.73716251e-02 1.10193180e-01 7.37126349e-07 ... 8.73716251e-02
#  7.79227922e-02 7.98807304e-02]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1641
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2038
#
# --- Year 2038 Summary ---
# Income (Salary): 78744.47
# Previous Wealth Carried: 12244.48
# Post-Tax Wealth (New Final Wealth): 90988.95
# ------------------------------
#
# 2039 15 39 54
# Starting Year: 2025
# Current Year: 2039
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 36, 'GOAL B': -9, 'GOAL C': -4, 'GOAL D': 1}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2039
# [DEBUG] Gross Gains (Normal account): -2199.13
# [DEBUG] Tax Calculated (Normal account): -593.76
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           98.98
#    B            0.00
#    C            0.00
#    D            1.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.972450        90126.585286           97.25
#         Developed Markets - Equities 0.004235          392.541174            0.42
# Emerging Markets State - Obligations 0.008538          791.283173            0.85
#       High Yield Bonds - Obligations 0.008158          756.048983            0.82
# Investment Grade Bonds - Obligations 0.001547          143.376042            0.15
#    Government ZC Bonds - Obligations 0.005072          470.049841            0.51
#
# Utility:
# [1.02030107e-01 5.44438100e-02 8.66611193e-02 ... 9.62962610e-08
#  8.82927370e-02 6.08822926e-02]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1598
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2039
#
# --- Year 2039 Summary ---
# Income (Salary): 79531.92
# Previous Wealth Carried: 13147.97
# Post-Tax Wealth (New Final Wealth): 92679.88
# ------------------------------
#
# 2040 16 40 55
# Starting Year: 2025
# Current Year: 2040
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 35, 'GOAL B': -10, 'GOAL C': -5, 'GOAL D': 0}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2040
# [DEBUG] Gross Gains (Normal account): -4022.31
# [DEBUG] Tax Calculated (Normal account): -1086.02
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.000245           25.117781            0.02
#         Developed Markets - Equities 0.961222        98574.803256           96.12
# Emerging Markets State - Obligations 0.011335         1162.374855            1.13
#       High Yield Bonds - Obligations 0.009410          965.028525            0.94
# Investment Grade Bonds - Obligations 0.009062          929.339496            0.91
#    Government ZC Bonds - Obligations 0.008726          894.899297            0.87
#
# Utility:
# [2.52796207e-06 5.59432184e-02 2.94722608e-02 ... 1.44338533e-02
#  3.21383071e-02 1.08730111e-06]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1072
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2040
#
# --- Year 2040 Summary ---
# Income (Salary): 88280.43
# Previous Wealth Carried: 14271.13
# Post-Tax Wealth (New Final Wealth): 102551.56
# ------------------------------
#
# 2041 17 41 56
# Starting Year: 2025
# Current Year: 2041
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 34, 'GOAL B': -11, 'GOAL C': -6, 'GOAL D': -1}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2041
# [DEBUG] Gross Gains (Normal account): -4600.57
# [DEBUG] Tax Calculated (Normal account): -1242.15
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.950369        99193.370178           95.04
#         Developed Markets - Equities 0.006327          660.367413            0.63
# Emerging Markets State - Obligations 0.009395          980.538733            0.94
#       High Yield Bonds - Obligations 0.025688         2681.164028            2.57
# Investment Grade Bonds - Obligations 0.002218          231.549324            0.22
#    Government ZC Bonds - Obligations 0.006003          626.510915            0.60
#
# Utility:
# [5.15155844e-02 3.25279249e-02 7.11561824e-02 ... 2.05486184e-10
#  4.75631876e-02 6.08459430e-02]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1457
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2041
#
# --- Year 2041 Summary ---
# Income (Salary): 89163.23
# Previous Wealth Carried: 15210.27
# Post-Tax Wealth (New Final Wealth): 104373.50
# ------------------------------
#
# 2042 18 42 57
# Starting Year: 2025
# Current Year: 2042
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 33, 'GOAL B': -12, 'GOAL C': -7, 'GOAL D': -2}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2042
# [DEBUG] Gross Gains (Normal account): -1870.62
# [DEBUG] Tax Calculated (Normal account): -505.07
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.000265           28.047217            0.03
#         Developed Markets - Equities 0.982356       103876.978441           98.24
# Emerging Markets State - Obligations 0.003777          399.413540            0.38
#       High Yield Bonds - Obligations 0.005109          540.236130            0.51
# Investment Grade Bonds - Obligations 0.002802          296.324671            0.28
#    Government ZC Bonds - Obligations 0.005690          601.675415            0.57
#
# Utility:
# [4.91811899e-07 2.29175777e-02 6.18868997e-02 ... 1.09718771e-06
#  3.15813455e-06 3.24903642e-02]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0908
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2042
#
# --- Year 2042 Summary ---
# Income (Salary): 90054.87
# Previous Wealth Carried: 15687.81
# Post-Tax Wealth (New Final Wealth): 105742.68
# ------------------------------
#
# 2043 19 43 58
# Starting Year: 2025
# Current Year: 2043
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 32, 'GOAL B': -13, 'GOAL C': -8, 'GOAL D': -3}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2043
# [DEBUG] Gross Gains (Normal account): -1885.51
# [DEBUG] Tax Calculated (Normal account): -509.09
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.977496       104628.059025           97.75
#         Developed Markets - Equities 0.005196          556.118225            0.52
# Emerging Markets State - Obligations 0.004309          461.184629            0.43
#       High Yield Bonds - Obligations 0.004026          430.895884            0.40
# Investment Grade Bonds - Obligations 0.005124          548.430099            0.51
#    Government ZC Bonds - Obligations 0.003851          412.176020            0.39
#
# Utility:
# [3.08382632e-07 5.44576155e-02 4.36862480e-02 ... 2.84708792e-02
#  3.02453764e-02 3.54395029e-02]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1281
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2043
#
# --- Year 2043 Summary ---
# Income (Salary): 90955.41
# Previous Wealth Carried: 16081.45
# Post-Tax Wealth (New Final Wealth): 107036.86
# ------------------------------
#
# 2044 20 44 59
# Starting Year: 2025
# Current Year: 2044
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 31, 'GOAL B': -14, 'GOAL C': -9, 'GOAL D': -4}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2044
# [DEBUG] Gross Gains (Normal account): -1702.10
# [DEBUG] Tax Calculated (Normal account): -459.57
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.971732       114282.293813           97.17
#         Developed Markets - Equities 0.014047         1652.024002            1.40
# Emerging Markets State - Obligations 0.003162          371.837203            0.32
#       High Yield Bonds - Obligations 0.001819          213.977687            0.18
# Investment Grade Bonds - Obligations 0.002655          312.213952            0.27
#    Government ZC Bonds - Obligations 0.006585          774.471070            0.66
#
# Utility:
# [0.00999289 0.0450889  0.0450889  ... 0.05532013 0.01887926 0.03412671]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1248
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2044
#
# --- Year 2044 Summary ---
# Income (Salary): 100960.51
# Previous Wealth Carried: 16646.31
# Post-Tax Wealth (New Final Wealth): 117606.82
# ------------------------------
#
# 2045 21 45 60
# Starting Year: 2025
# Current Year: 2045
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 30, 'GOAL B': -15, 'GOAL C': -10, 'GOAL D': -5}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2045
# [DEBUG] Gross Gains (Normal account): -2745.43
# [DEBUG] Tax Calculated (Normal account): -741.27
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.968179       116693.703264           96.82
#         Developed Markets - Equities 0.009435         1137.168976            0.94
# Emerging Markets State - Obligations 0.005703          687.389528            0.57
#       High Yield Bonds - Obligations 0.007144          861.010373            0.71
# Investment Grade Bonds - Obligations 0.006083          733.214459            0.61
#    Government ZC Bonds - Obligations 0.003457          416.628391            0.35
#
# Utility:
# [3.18440676e-02 1.84143108e-02 2.04529627e-09 ... 3.03901713e-02
#  5.36562650e-02 2.48410003e-06]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1143
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2045
#
# --- Year 2045 Summary ---
# Income (Salary): 101970.11
# Previous Wealth Carried: 18559.00
# Post-Tax Wealth (New Final Wealth): 120529.11
# ------------------------------
#
# 2046 22 46 61
# Starting Year: 2025
# Current Year: 2046
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 29, 'GOAL B': -16, 'GOAL C': -11, 'GOAL D': -6}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2046
# [DEBUG] Gross Gains (Normal account): -1765.77
# [DEBUG] Tax Calculated (Normal account): -476.76
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.978597       119076.917917           97.86
#         Developed Markets - Equities 0.007142          869.051716            0.71
# Emerging Markets State - Obligations 0.004994          607.627864            0.50
#       High Yield Bonds - Obligations 0.002336          284.299551            0.23
# Investment Grade Bonds - Obligations 0.005529          672.722815            0.55
#    Government ZC Bonds - Obligations 0.001403          170.664657            0.14
#
# Utility:
# [4.00073647e-02 4.83270568e-02 2.75368388e-02 ... 5.88871285e-10
#  8.80362137e-07 9.22602904e-08]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1034
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2046
#
# --- Year 2046 Summary ---
# Income (Salary): 102989.82
# Previous Wealth Carried: 18691.47
# Post-Tax Wealth (New Final Wealth): 121681.28
# ------------------------------
#
# 2047 23 47 62
# Starting Year: 2025
# Current Year: 2047
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 28, 'GOAL B': -17, 'GOAL C': -12, 'GOAL D': -7}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2047
# [DEBUG] Gross Gains (Normal account): -4244.99
# [DEBUG] Tax Calculated (Normal account): -1146.15
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.956421       117746.475833           95.64
#         Developed Markets - Equities 0.009698         1193.931634            0.97
# Emerging Markets State - Obligations 0.013066         1608.593522            1.31
#       High Yield Bonds - Obligations 0.005458          671.949546            0.55
# Investment Grade Bonds - Obligations 0.011573         1424.829967            1.16
#    Government ZC Bonds - Obligations 0.003783          465.722913            0.38
#
# Utility:
# [2.50282985e-07 3.23270508e-02 6.76729339e-10 ... 1.11015641e-11
#  3.17828027e-06 3.55937090e-02]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0918
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2047
#
# --- Year 2047 Summary ---
# Income (Salary): 104019.71
# Previous Wealth Carried: 19091.79
# Post-Tax Wealth (New Final Wealth): 123111.50
# ------------------------------
#
# 2048 24 48 63
# Starting Year: 2025
# Current Year: 2048
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 27, 'GOAL B': -18, 'GOAL C': -13, 'GOAL D': -8}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2048
# [DEBUG] Gross Gains (Normal account): -4369.40
# [DEBUG] Tax Calculated (Normal account): -1179.74
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.960825       128960.785312           96.08
#         Developed Markets - Equities 0.007194          965.567927            0.72
# Emerging Markets State - Obligations 0.012524         1681.014561            1.25
#       High Yield Bonds - Obligations 0.008912         1196.102288            0.89
# Investment Grade Bonds - Obligations 0.002255          302.679816            0.23
#    Government ZC Bonds - Obligations 0.008290         1112.623713            0.83
#
# Utility:
# [4.44111724e-08 3.70575881e-02 2.51600962e-11 ... 6.42271105e-02
#  2.36376803e-02 2.37158556e-07]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0870
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2048
#
# --- Year 2048 Summary ---
# Income (Salary): 115461.88
# Previous Wealth Carried: 18756.89
# Post-Tax Wealth (New Final Wealth): 134218.77
# ------------------------------
#
# 2049 25 49 64
# Starting Year: 2025
# Current Year: 2049
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 26, 'GOAL B': -19, 'GOAL C': -14, 'GOAL D': -9}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2049
# [DEBUG] Gross Gains (Normal account): -5974.85
# [DEBUG] Tax Calculated (Normal account): -1613.21
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.938927       128654.870375           93.89
#         Developed Markets - Equities 0.018247         2500.255375            1.82
# Emerging Markets State - Obligations 0.019143         2623.076664            1.91
#       High Yield Bonds - Obligations 0.002525          345.927934            0.25
# Investment Grade Bonds - Obligations 0.000076           10.417725            0.01
#    Government ZC Bonds - Obligations 0.021083         2888.800284            2.11
#
# Utility:
# [9.88888689e-08 3.15653598e-07 8.47544257e-13 ... 2.06377684e-06
#  7.04868539e-08 2.58581071e-06]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0754
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = N
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2049
#
# --- Year 2049 Summary ---
# Income (Salary): 116616.50
# Previous Wealth Carried: 20406.85
# Post-Tax Wealth (New Final Wealth): 137023.35
# ------------------------------
#
# 2050 26 50 65
# Starting Year: 2025
# Current Year: 2050
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 25, 'GOAL B': -20, 'GOAL C': -15, 'GOAL D': -10}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2050
# [DEBUG] Gross Gains (Normal account): -2438.01
# [DEBUG] Tax Calculated (Normal account): -658.26
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
# ...
# [1.91463420e-06 0.00000000e+00 1.73914882e-10 ... 1.15001911e-01
#  3.44645280e-02 2.22150809e-01]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = N
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2067
#
# --- Year 2067 Summary ---
# Income (Salary): 153301.48
# Previous Wealth Carried: 10060701.75
# Post-Tax Wealth (New Final Wealth): 10214003.23
# ------------------------------
#
# 2068 44 68 83
# Starting Year: 2025
# Current Year: 2068
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 7, 'GOAL B': -38, 'GOAL C': -33, 'GOAL D': -28}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2068
# [DEBUG] Gross Gains (Normal account): 5602277.83
# [DEBUG] Tax Calculated (Normal account): 2342831.69
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.060983        7.619168e+05            6.10
#         Developed Markets - Equities 0.013378        1.671431e+05            1.34
# Emerging Markets State - Obligations 0.028708        3.586710e+05            2.87
#       High Yield Bonds - Obligations 0.063605        7.946657e+05            6.36
# Investment Grade Bonds - Obligations 0.000638        7.973917e+03            0.06
#    Government ZC Bonds - Obligations 0.832688        1.040347e+07           83.27
#
# Utility:
# [3.98021541e-01 3.78881473e-01 0.00000000e+00 ... 4.34948465e-08
#  2.18247677e-01 5.46353931e-01]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = N
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2068
#
# --- Year 2068 Summary ---
# Income (Salary): 154834.49
# Previous Wealth Carried: 12339006.39
# Post-Tax Wealth (New Final Wealth): 12493840.88
# ------------------------------
#
# 2069 45 69 84
# Starting Year: 2025
# Current Year: 2069
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 6, 'GOAL B': -39, 'GOAL C': -34, 'GOAL D': -29}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2069
# [DEBUG] Gross Gains (Normal account): -2877470.53
# [DEBUG] Tax Calculated (Normal account): -776917.04
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.003705        5.893924e+04            0.37
#         Developed Markets - Equities 0.012206        1.941918e+05            1.22
# Emerging Markets State - Obligations 0.017791        2.830543e+05            1.78
#       High Yield Bonds - Obligations 0.012903        2.052772e+05            1.29
# Investment Grade Bonds - Obligations 0.009267        1.474367e+05            0.93
#    Government ZC Bonds - Obligations 0.944128        1.502077e+07           94.41
#
# Utility:
# [6.71993716e-02 0.00000000e+00 8.56874906e-02 ... 1.00000000e+00
#  1.09306894e-07 4.71686382e-01]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = N
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2069
#
# --- Year 2069 Summary ---
# Income (Salary): 156382.84
# Previous Wealth Carried: 15753287.02
# Post-Tax Wealth (New Final Wealth): 15909669.86
# ------------------------------
#
# 2070 46 70 85
# Starting Year: 2025
# Current Year: 2070
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 5, 'GOAL B': -40, 'GOAL C': -35, 'GOAL D': -30}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2070
# [DEBUG] Gross Gains (Normal account): -259182.87
# [DEBUG] Tax Calculated (Normal account): -69979.37
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.024018        3.167999e+05            2.40
#         Developed Markets - Equities 0.034329        4.528054e+05            3.43
# Emerging Markets State - Obligations 0.053800        7.096308e+05            5.38
#       High Yield Bonds - Obligations 0.061037        8.050879e+05            6.10
# Investment Grade Bonds - Obligations 0.015564        2.052943e+05            1.56
#    Government ZC Bonds - Obligations 0.811252        1.070053e+07           81.13
#
# Utility:
# [0.00000000e+00 0.00000000e+00 2.79957364e-01 ... 0.00000000e+00
#  2.54920068e-01 3.14193116e-14]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = N
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2070
#
# --- Year 2070 Summary ---
# Income (Salary): 157946.67
# Previous Wealth Carried: 13032199.33
# Post-Tax Wealth (New Final Wealth): 13190145.99
# ------------------------------
#
# 2071 47 71 86
# Starting Year: 2025
# Current Year: 2071
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 4, 'GOAL B': -41, 'GOAL C': -36, 'GOAL D': -31}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2071
# [DEBUG] Gross Gains (Normal account): -2156379.42
# [DEBUG] Tax Calculated (Normal account): -582222.44
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.070539        9.121318e+05            7.05
#         Developed Markets - Equities 0.041574        5.375961e+05            4.16
# Emerging Markets State - Obligations 0.035230        4.555582e+05            3.52
#       High Yield Bonds - Obligations 0.022880        2.958615e+05            2.29
# Investment Grade Bonds - Obligations 0.050117        6.480668e+05            5.01
#    Government ZC Bonds - Obligations 0.779660        1.008175e+07           77.97
#
# Utility:
# [3.28990675e-02 7.63980428e-01 2.54452713e-01 ... 3.28990675e-02
#  6.38942564e-08 9.23670218e-09]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = N
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2071
#
# --- Year 2071 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 12930963.13
# Post-Tax Wealth (New Final Wealth): 12930963.13
# ------------------------------
#
# 2072 48 72 87
# Starting Year: 2025
# Current Year: 2072
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 3, 'GOAL B': -42, 'GOAL C': -37, 'GOAL D': -32}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2072
# [DEBUG] Gross Gains (Normal account): -2461146.39
# [DEBUG] Tax Calculated (Normal account): -664509.53
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.027695        3.965895e+05            2.77
#         Developed Markets - Equities 0.022815        3.267076e+05            2.28
# Emerging Markets State - Obligations 0.013370        1.914525e+05            1.34
#       High Yield Bonds - Obligations 0.028355        4.060472e+05            2.84
# Investment Grade Bonds - Obligations 0.026217        3.754262e+05            2.62
#    Government ZC Bonds - Obligations 0.881548        1.262375e+07           88.15
#
# Utility:
# [0.00000000e+00 1.78713266e-10 1.03146050e-01 ... 0.00000000e+00
#  0.00000000e+00 2.79267380e-08]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = N
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2072
#
# --- Year 2072 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 14319975.00
# Post-Tax Wealth (New Final Wealth): 14319975.00
# ------------------------------
#
# 2073 49 73 88
# Starting Year: 2025
# Current Year: 2073
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 2, 'GOAL B': -43, 'GOAL C': -38, 'GOAL D': -33}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2073
# [DEBUG] Gross Gains (Normal account): -1982395.80
# [DEBUG] Tax Calculated (Normal account): -535246.87
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.019774        2.749565e+05            1.98
#         Developed Markets - Equities 0.039795        5.533640e+05            3.98
# Emerging Markets State - Obligations 0.050574        7.032398e+05            5.06
#       High Yield Bonds - Obligations 0.026867        3.735911e+05            2.69
# Investment Grade Bonds - Obligations 0.011614        1.614986e+05            1.16
#    Government ZC Bonds - Obligations 0.851376        1.183856e+07           85.14
#
# Utility:
# [0.00000000e+00 7.66857799e-09 1.04678488e-11 ... 2.73471352e-01
#  1.15946902e-07 0.00000000e+00]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = Y
# Row 50: Year = 2073, Status = N
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2073
#
# --- Year 2073 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 13905213.52
# Post-Tax Wealth (New Final Wealth): 13905213.52
# ------------------------------
#
# 2074 50 74 89
# Starting Year: 2025
# Current Year: 2074
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 1, 'GOAL B': -44, 'GOAL C': -39, 'GOAL D': -34}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2074
# [DEBUG] Gross Gains (Normal account): -2718606.60
# [DEBUG] Tax Calculated (Normal account): -734023.78
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.020134        2.703531e+05            2.01
#         Developed Markets - Equities 0.010914        1.465448e+05            1.09
# Emerging Markets State - Obligations 0.009495        1.274942e+05            0.95
#       High Yield Bonds - Obligations 0.019573        2.628265e+05            1.96
# Investment Grade Bonds - Obligations 0.017460        2.344510e+05            1.75
#    Government ZC Bonds - Obligations 0.922424        1.238604e+07           92.24
#
# Utility:
# [1. 0. 0. ... 0. 0. 0.]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = Y
# Row 50: Year = 2073, Status = Y
# Row 51: Year = 2074, Status = N
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2074
#
# --- Year 2074 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 13427705.12
# Post-Tax Wealth (New Final Wealth): 13427705.12
# ------------------------------
#
# 2075 51 75 90
# Starting Year: 2025
# Current Year: 2075
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 0, 'GOAL B': -45, 'GOAL C': -40, 'GOAL D': -35}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2075
# [DEBUG] Gross Gains (Normal account): nan
# [DEBUG] Tax Calculated (Normal account): nan
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.110836        5.322364e+05           11.08
#         Developed Markets - Equities 0.059842        2.873618e+05            5.98
# Emerging Markets State - Obligations 0.016669        8.004339e+04            1.67
#       High Yield Bonds - Obligations 0.035668        1.712760e+05            3.57
# Investment Grade Bonds - Obligations 0.033458        1.606667e+05            3.35
#    Government ZC Bonds - Obligations 0.743527        3.570427e+06           74.35
#
# Utility:
# [0. 0. 0. ... 0. 0. 0.]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 43: Year = 2066, Status = Y
# Row 44: Year = 2067, Status = Y
# Row 45: Year = 2068, Status = Y
# Row 46: Year = 2069, Status = Y
# Row 47: Year = 2070, Status = Y
# Row 48: Year = 2071, Status = Y
# Row 49: Year = 2072, Status = Y
# Row 50: Year = 2073, Status = Y
# Row 51: Year = 2074, Status = Y
# Row 52: Year = 2075, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2075
#
# --- Year 2075 Summary ---
# Income (Salary): 0.00
# Previous Wealth Carried: 4802011.09
# Post-Tax Wealth (New Final Wealth): 4802011.09
# ------------------------------
#
# All loops completed

# %%
# V7C: Export new asset-level log for debugging
pd.DataFrame(asset_level_log).to_csv(os.path.join(output_folder, "asset_returns_log.csv"), index=False)

#V12 moved finalwealth to python
pd.DataFrame.from_dict(final_wealth_tracker, orient='index', columns=['Final Wealth']).to_csv(
    os.path.join(output_folder, "final_wealth_by_year.csv")
)

#V15
pd.DataFrame(goal_weights_tracker).to_csv(
    os.path.join(output_folder, "goal_weights_by_year.csv"), index=False
)

pd.DataFrame(aggregate_portfolio_tracker).to_csv(
    os.path.join(output_folder, "aggregate_portfolio_by_year.csv"), index=False
)

# V15: Save optimal_weights for Goals A–D
for goal_letter, matrix_dict in zip(
    ["A", "B", "C", "D"],
    [goal_optimal_weights_A, goal_optimal_weights_B, goal_optimal_weights_C, goal_optimal_weights_D]
):
    all_dfs = []
    for year, mat in matrix_dict.items():
        df = pd.DataFrame(mat)
        df.insert(0, "Year", year)
        df.insert(1, "Allocation Level", np.arange(0.01, 1.01, 0.01))
        all_dfs.append(df)

    df_all = pd.concat(all_dfs, ignore_index=True)
    df_all.to_csv(os.path.join(output_folder, f"optimal_weights_goal_{goal_letter}.csv"), index=False)

# %%
# V17 - Store if goal was reached or not
records = []

for g in ["A", "B", "C", "D"]:
    for entry in goal_reached[g]:
        records.append({
            "Goal": g,
            "Path_ID": entry["path_id"],
            "Success": entry["success"]
        })

df_goal_distribution = pd.DataFrame(records)

# Quick summary if needed
summary = df_goal_distribution.groupby("Goal")["Success"].agg(["sum", "count"])
summary.rename(columns={"sum": "Successes", "count": "Total"}, inplace=True)
summary["Failures"] = summary["Total"] - summary["Successes"]
summary = summary[["Successes", "Failures"]]

print("\n--- Goal Success/Failure Distribution ---")
print(summary)

# Save detailed data and summary if you want
df_goal_distribution.to_csv(os.path.join(output_folder, "goal_success_detailed.csv"), index=False)
summary.to_csv(os.path.join(output_folder, "goal_success_summary.csv"))
# Out:
# --- Goal Success/Failure Distribution ---
#       Successes  Failures
# Goal
# A             3         0
# B             3         0
# C             0         3
# D             1         2
