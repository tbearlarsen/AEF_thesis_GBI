# %% [markdown]
# V1 (02 11 2025): Translated from R to Python and added the visualizations for goals B to D
#
#
# V2 (04 01 2025): Loop system implemented
#
# V2.5 (04 02 2025): Loops system tweaks. Removed openpyxl as it was corrupting files and replaced it with xlwings
#
# V3 & V4 finalize the loop except for the tax and asset channel
#
# V 5,6,7 add tax shenanigans. V7C added the fully functioning inflow and outflow of wealth with the returns and taxes in it.
#
# V8 modifies the aktiesparekonto pool so that it is increased when taxes are payed.
#
# V9 substracts from the wealth pool the amount for the goals reached. It does not just substract the full amount of the goal, but rather the % from the allocation of the year prior to the goal being handed.
#
# V10 Corrects returns to be inflation adjusted
#
# V11 Opportunity cost calculation to redeem goal
#
# V12 FinalWealth works without excel
#
# V13 Loop check works without excel

# %%
#!pip install numpy pandas scipy matplotlib xlwings

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import subprocess

# %%
# -- Variable Setup -- ##

#Monte Carlo Trials
n_trials = 10**5

# -V10 - Static Inflation
inflation_rate = 0.02  # 2%
#Case Study Profile Selection
Profile = "P1" #Either P1 or P2

#Excel worksheets - Master
excel_returns = "Returns"
excel_volatilities = "Volatilities"
excel_correlation = "Correlation"
excel_income = "Salary"
excel_real_returns = "Real Returns"

#Excel worksheets - Montecarlo Returns
excel_obligations_zc = "Government ZC Bonds - Obli"
excel_obligations_igb = "Investment Grade Bonds - Obli"
excel_obligations_hyb = "High Yield Bonds - Obli"
excel_obligations_ems = "Emerging Markets State - Obli"
excel_equities_dm = "Developed Markets - Equities"
excel_equities_em = "Emerging Markets - Equities"

# %% [markdown]
# # Define Functions
# This section defines the functions used for calculating portfolio volatility, expected return,
# goal achievement probability, and the objective (failure probability) to minimize.

# %%
def sd_f(weight_vector, covar_table):
    covar_vector = np.zeros(len(weight_vector))
    for z in range(len(weight_vector)):
        covar_vector[z] = np.sum(weight_vector * covar_table[:, z])
    return np.sqrt(np.sum(weight_vector * covar_vector))

# %%
def mean_f(weight_vector, return_vector):
    return np.sum(weight_vector * return_vector)

# %%
"""
Disabled because due to the dynamic model some phis are nan instead of 0
def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    # goal_vector is [value ratio, funding requirement, time horizon]
    required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
    if goal_allocation * pool >= goal_vector[1]:
        return 1
    else:
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)"""

def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    try:
        if goal_allocation <= 0 or pool <= 0 or goal_vector[2] <= 0 or sd <= 0:
            return 0  # invalid case
        required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
        if goal_allocation * pool >= goal_vector[1]:
            return 1
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)
    except:
        return 0  # fallback for any numerical error

# %%
def optim_function(weights):
    # Uses the current global variables: goal_vector, allocation, pool, return_vector, covar_table
    return 1 - phi_f(
        goal_vector,
        allocation,
        pool,
        mean_f(weights, return_vector),
        sd_f(weights, covar_table)
    )

# %%
def constraint_function(weights):
    # For SciPy equality constraints, we require constraint_function(weights) == 0.
        return np.sum(weights) - 1

# %%
def mvu_f(weights):
    # mvu_f is defined for mean-variance optimization (not used below).
    return -(mean_f(weights, return_vector) - 0.5 * gamma * sd_f(weights, covariances)**2)

# %%
def r_req_f(goal_vector, goal_allocation, pool):
    return (goal_vector[1] / (goal_allocation * pool))**(1 / goal_vector[2]) - 1

# %%
def get_goal_data(master_excel_path, plan=Profile):
    """
    Returns a DataFrame of the specified goal table (P1 or P2).
    P1 => B2:F5
    P2 => B7:F10
    """
    if plan == "P1":
        skip = 1  # start reading at row 2
    elif plan == "P2":
        skip = 6  # start reading at row 7
    else:
        raise ValueError("Plan not recognized. Use 'P1' or 'P2'.")

    df_goals = pd.read_excel(master_excel_path,sheet_name="Goals",skiprows=skip,nrows=4,usecols="B:F",header=0)
    # First column is "Goal Info", so make that the index
    df_goals.set_index(df_goals.columns[0], inplace=True)
    return df_goals

# %% [markdown]
# # Load & Parse Data

# %%
## -- Repo Root and Folders -- ##

# Get repo root and set folders
root = subprocess.run(["git", "rev-parse", "--show-toplevel"], capture_output=True, text=True).stdout.strip()
data_folder = os.path.join(root, "GBI Optimisation", "data")
output_folder = os.path.join(root, "GBI Optimisation")

# Get excel file and sheets
master_excel_path = os.path.join(data_folder, "Master.xlsx")
montecarlo_excel_path = os.path.join(data_folder, "Montecarlo Returns.xlsx")

df_returns = pd.read_excel(master_excel_path, sheet_name=excel_returns)
df_vols = pd.read_excel(master_excel_path, sheet_name=excel_volatilities)

df_returns.set_index(df_returns.columns[0], inplace=True)
df_vols.set_index(df_vols.columns[0], inplace=True)

df_corr = pd.read_excel(master_excel_path, sheet_name=excel_correlation)
df_corr.set_index(df_corr.columns[0], inplace=True)

df_real_returns = pd.read_excel(master_excel_path, sheet_name=excel_real_returns)
df_real_returns.set_index(df_real_returns.columns[0], inplace=True)

#Montecarlo Excel File DFs
df_zc = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_zc)
df_igb = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_igb)
df_hyb = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_hyb)
df_ems = pd.read_excel(montecarlo_excel_path, sheet_name=excel_obligations_ems)
df_dm = pd.read_excel(montecarlo_excel_path, sheet_name=excel_equities_dm)
df_em = pd.read_excel(montecarlo_excel_path, sheet_name=excel_equities_em)

# %%
sheet_map = {
    "Government ZC Bonds - Obligations": df_zc,
    "Investment Grade Bonds - Obligations": df_igb,
    "High Yield Bonds - Obligations": df_hyb,
    "Emerging Markets State - Obligations": df_ems,
    "Developed Markets - Equities": df_dm,
    "Emerging Markets - Equities": df_em,
}

# Stack into a long format with asset label and path number
all_paths = []

for sheet_name, df in sheet_map.items():
    df = df.drop(columns=df.columns[0])  # Drop the unnamed column
    df["Asset"] = sheet_name
    df["Path"] = range(len(df))
    all_paths.append(df)

df_montecarlo_returns = pd.concat(all_paths, ignore_index=True)
df_montecarlo_returns = df_montecarlo_returns.set_index(["Asset", "Path"])  # Multi-index for looping per asset/path

# %%
print(df_montecarlo_returns)
# Out:
#                                             2025      2026      2027  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.979959 -0.988946 -0.992397
#                                   1     0.032139 -0.032694 -0.024736
#                                   2    -0.062414 -0.039767 -0.038905
#                                   3    -0.005755 -0.027977 -0.019411
#                                   4     0.050316  0.025197  0.035256
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9994 -0.284966 -0.512681 -0.684569
#                                   9995  0.581717  0.650537  1.259412
#                                   9996 -0.116502 -0.318915 -0.128478
#                                   9997 -0.110199 -0.012209 -0.346583
#                                   9998 -0.264493 -0.138363  0.210876
#
#                                             2028      2029      2030  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.994155 -0.995233 -0.995988
#                                   1    -0.026872 -0.042744 -0.003861
#                                   2    -0.010012  0.041549 -0.022640
#                                   3    -0.027684 -0.047178 -0.005487
#                                   4     0.035039 -0.006451 -0.001372
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9994 -0.704879 -0.686145 -0.494765
#                                   9995  1.648085  0.769272  0.325218
#                                   9996 -0.101703  0.080899  0.062284
#                                   9997 -0.550211 -0.429595 -0.418652
#                                   9998  0.930641  1.024086  1.549291
#
#                                             2031      2032      2033  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.996391 -0.996874 -0.997111
#                                   1    -0.065594 -0.017815 -0.007954
#                                   2     0.041921  0.012096 -0.007562
#                                   3    -0.053832 -0.046436 -0.042238
#                                   4    -0.030500 -0.032701 -0.091766
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9994 -0.372757 -0.359987 -0.090492
#                                   9995  0.672086  1.256190  0.511955
#                                   9996  0.079858 -0.060011  0.805057
#                                   9997 -0.483616 -0.630412 -0.751563
#                                   9998  0.882310  0.980099  0.754575
#
#                                             2034  ...      2066      2067  \
# Asset                             Path            ...
# Government ZC Bonds - Obligations 0    -0.997396  ... -0.998277 -0.998297
#                                   1     0.003208  ... -0.170764 -0.129836
#                                   2     0.022008  ... -0.161234 -0.178104
#                                   3    -0.080377  ... -0.192875 -0.278886
#                                   4    -0.071732  ...  0.403485  0.510147
# ...                                          ...  ...       ...       ...
# Emerging Markets - Equities       9994  0.349562  ... -0.451356 -0.470983
#                                   9995 -0.070068  ...  3.993465  3.530246
#                                   9996  0.962554  ... -0.075976  0.042981
#                                   9997 -0.785312  ... -0.866474 -0.898618
#                                   9998  1.216452  ...  4.393417  4.390043
#
#                                             2068      2069      2070  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.998236 -0.998240 -0.998232
#                                   1    -0.090440 -0.125203 -0.096389
#                                   2    -0.255039 -0.266282 -0.289747
#                                   3    -0.271308 -0.216676 -0.201973
#                                   4     0.493041  0.467672  0.398871
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9994 -0.468602 -0.315570 -0.369840
#                                   9995  3.247756  3.459559  6.933328
#                                   9996  0.201124 -0.002405 -0.166012
#                                   9997 -0.923496 -0.930558 -0.942610
#                                   9998  4.332002  7.070071  5.768976
#
#                                             2071      2072      2073  \
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.998214 -0.998190 -0.998213
#                                   1    -0.120958 -0.130930 -0.165743
#                                   2    -0.268874 -0.267865 -0.221856
#                                   3    -0.245147 -0.238304 -0.242379
#                                   4     0.424675  0.450363  0.498839
# ...                                          ...       ...       ...
# Emerging Markets - Equities       9994 -0.088770 -0.459858 -0.371491
#                                   9995  6.091636  9.763465  8.524677
#                                   9996 -0.248070 -0.510899 -0.627931
#                                   9997 -0.946907 -0.929561 -0.877555
#                                   9998  5.519892  3.916971  4.441648
#
#                                             2074  2075
# Asset                             Path
# Government ZC Bonds - Obligations 0    -0.998205   NaN
#                                   1    -0.117130   NaN
#                                   2    -0.246270   NaN
#                                   3    -0.224126   NaN
#                                   4     0.426973   NaN
# ...                                          ...   ...
# Emerging Markets - Equities       9994 -0.316325   NaN
#                                   9995  9.681887   NaN
#                                   9996 -0.621759   NaN
#                                   9997 -0.898874   NaN
#                                   9998  6.259082   NaN
#
# [59994 rows x 51 columns]

# %%
print(df_real_returns)
# Out:
#                                        2025   2026   2027   2028   2029  \
# Unnamed: 0
# Emerging Markets - Equities           0.001  0.001  0.001  0.001  0.001
# Developed Markets - Equities          0.001  0.001  0.001  0.001  0.001
# Emerging Markets State - Obligations  0.001  0.001  0.001  0.001  0.001
# High Yield Bonds - Obligations        0.001  0.001  0.001  0.001  0.001
# Investment Grade Bonds - Obligations  0.001  0.001  0.001  0.001  0.001
# Government ZC Bonds - Obligations     0.001  0.001  0.001  0.001  0.001
#
#                                        2030   2031   2032   2033   2034  ...  \
# Unnamed: 0                                                               ...
# Emerging Markets - Equities           0.001  0.001  0.001  0.001  0.001  ...
# Developed Markets - Equities          0.001  0.001  0.001  0.001  0.001  ...
# Emerging Markets State - Obligations  0.001  0.001  0.001  0.001  0.001  ...
# High Yield Bonds - Obligations        0.001  0.001  0.001  0.001  0.001  ...
# Investment Grade Bonds - Obligations  0.001  0.001  0.001  0.001  0.001  ...
# Government ZC Bonds - Obligations     0.001  0.001  0.001  0.001  0.001  ...
#
#                                       2066  2067  2068  2069  2070  2071  \
# Unnamed: 0
# Emerging Markets - Equities           0.04  0.04  0.04  0.04  0.04  0.04
# Developed Markets - Equities          0.04  0.04  0.04  0.04  0.04  0.04
# Emerging Markets State - Obligations  0.04  0.04  0.04  0.04  0.04  0.04
# High Yield Bonds - Obligations        0.04  0.04  0.04  0.04  0.04  0.04
# Investment Grade Bonds - Obligations  0.04  0.04  0.04  0.04  0.04  0.04
# Government ZC Bonds - Obligations     0.04  0.04  0.04  0.04  0.04  0.04
#
#                                       2072  2073  2074  2075
# Unnamed: 0
# Emerging Markets - Equities           0.04  0.04  0.04  0.04
# Developed Markets - Equities          0.04  0.04  0.04  0.04
# Emerging Markets State - Obligations  0.04  0.04  0.04  0.04
# High Yield Bonds - Obligations        0.04  0.04  0.04  0.04
# Investment Grade Bonds - Obligations  0.04  0.04  0.04  0.04
# Government ZC Bonds - Obligations     0.04  0.04  0.04  0.04
#
# [6 rows x 51 columns]

# %%
# - NEW V8 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #

# Initial cap in 2025
initial_ask_cap = 166200
growth_rate = 0.1265  # 12.65% annual increase
aktiesparekonto_used_total = 0

# %%
# V 13 - Year Loop table
# -- Replaces Excel loop sheet with in-code structure -- #
start_year = 2025
end_year = 2040
N_max = end_year - start_year + 1

age_p1_start = 25
age_p2_start = 40

loop_df = pd.DataFrame({
    "N": range(1, N_max + 1),
    "Year": list(range(start_year, end_year + 1)),
    "AgeP1": [age_p1_start + i for i in range(N_max)],
    "AgeP2": [age_p2_start + i for i in range(N_max)],
    "LoopStatus": ['N'] * N_max
})

# %%
# V14 - Load salary data for all years
df_salary = pd.read_excel(master_excel_path, sheet_name=excel_income)
df_salary.set_index(df_salary.columns[0], inplace=True)

# %%
path_results = {}

n_paths = 3  # Assuming you want to simulate all 9999 paths
for path_id in range(n_paths):
    loop_df["LoopStatus"] = "N"
    asset_level_log = []  # NEW: Log each asset's return pre- and post-tax by account
    #V12 moved finalwealth to python
    final_wealth_tracker = {}

    #V15 goal info stored in python instead of excel
    goal_weights_tracker = []          # Stores goal weights for each year
    aggregate_portfolio_tracker = []   # Stores aggregate portfolio for each year

    # V15: Store all optimal weight matrices by year
    goal_optimal_weights_A = {}
    goal_optimal_weights_B = {}
    goal_optimal_weights_C = {}
    goal_optimal_weights_D = {}
    print(f"🧪 Running simulation for path {path_id}")

    while True:
        pending_rows = loop_df[loop_df["LoopStatus"] == "N"]

        # If we find any rows, get the row with the lowest Year
        if pending_rows.empty:
            print("All loops completed")
            break


        chosen_row = pending_rows.loc[pending_rows["Year"].idxmin()]
        loop_year = chosen_row["Year"]
        loop_number = chosen_row["N"]
        loop_age1 = chosen_row["AgeP1"]
        loop_age2 = chosen_row["AgeP2"]

        print(loop_year, loop_number, loop_age1, loop_age2)

        # - Wealth - #

        # Get salary for current year
        salary = df_salary.loc[Profile, str(loop_year)]


        # - Dynamic time horizon based on current year - #

        # Step 1: Get Starting Year (minimum year in Loop sheet)
        starting_year = start_year
        prev_year = str(loop_year - 1)

        # If first loop year, no previous wealth exists
        if loop_year == starting_year:
            prev_wealth = 0
            pool = salary
        else:
            try:
                prev_wealth = final_wealth_tracker[int(prev_year)]
            except KeyError:
                raise KeyError(f"Previous wealth not found for {Profile} in {prev_year}")
            pool = salary + prev_wealth

        capital_market_expectations_raw = {}
        for asset in df_returns.index:
            expected_return = df_returns.loc[asset, str(loop_year)]
            volatility = df_vols.loc[asset, 'volatility']
            capital_market_expectations_raw[asset] = {
                'Return Forecast': expected_return,
                'Volatility Forecast': volatility
            }

        capital_market_expectations_raw = pd.DataFrame.from_dict(capital_market_expectations_raw, orient='index')

        capital_market_expectations_raw = capital_market_expectations_raw.reset_index()
        capital_market_expectations_raw.rename(columns={'index': 'Unnamed: 0'}, inplace=True)

        # Rearrange columns to match your old format (optional):
        capital_market_expectations_raw = capital_market_expectations_raw[['Unnamed: 0', 'Return Forecast', 'Volatility Forecast']]

        goal_data_raw = get_goal_data(master_excel_path, plan="P1")

        # - Dynamic time horizon based on current year - #


        # Step 2: Compute Goal Years = starting_year + time_horizon
        goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
        goal_years = starting_year + goal_horizons

        # Step 3: Recalculate Time Horizons = goal_years - current loop_year
        adjusted_horizons = goal_years - loop_year

        # Step 4: Replace the "Time Horizon" row in goal_data_raw
        goal_data_raw.loc["Time Horizon"] = adjusted_horizons


        # - V8 - Dynamically compute ASK cap per year
        aktiesparekonto_cap = initial_ask_cap * ((1 + growth_rate) ** (loop_year - starting_year))

        goals = ["A", "B", "C", "D"]
        active_goal_mask = np.array([adjusted_horizons[f"GOAL {g}"] > 0 for g in goals])

        # Optional: print to confirm
        print("Starting Year:", starting_year)
        print("Current Year:", loop_year)
        print("Goal Years:", goal_years.to_dict())
        print("Adjusted Horizons:", adjusted_horizons.to_dict())



        # Record number of potential investments and goals
        num_assets = capital_market_expectations_raw.shape[0]
        num_goals = goal_data_raw.shape[1]

        # Create vector of expected returns
        return_vector = (capital_market_expectations_raw["Return Forecast"] - inflation_rate).to_numpy()

        # Get the correlations as a numeric DataFrame (just a num_assets × num_assets block)
        correlations = df_corr.iloc[:num_assets, :num_assets].astype(float)

        # Build the covariance matrix: stdev_i * stdev_j * correlation_ij
        stdevs = capital_market_expectations_raw["Volatility Forecast"].to_numpy()
        covariances = np.zeros((num_assets, num_assets))
        for i in range(num_assets):
            for j in range(num_assets):
                covariances[i, j] = stdevs[i] * stdevs[j] * correlations.iloc[i, j]

        goal_A = goal_data_raw["GOAL A"].values
        goal_B = goal_data_raw["GOAL B"].values
        goal_C = goal_data_raw["GOAL C"].values
        goal_D = goal_data_raw["GOAL D"].values

        # - Optimal Goal Allocation - #


        goal_allocation = np.arange(0.01, 1.01, 0.01)

        # Starting weights (random initialization normalized to sum to 1)
        starting_weights = np.random.uniform(0, 1, num_assets)
        starting_weights /= np.sum(starting_weights)

        # Initialize matrices to store the optimal weights for each goal
        optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
        optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
        optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
        optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

        goal_allocation = np.arange(0.01, 1.01, 0.01)

        # Set SLSQP options to be more stringent, mimicking solnp's behavior.
        slsqp_opts = {
            'ftol': 1e-12,     # function tolerance
            'eps': 1e-12,      # finite-difference step size for gradient estimation
            'maxiter': 10000,  # maximum iterations
            'disp': False     # do not display convergence messages
        }

        for i, alloc in enumerate(goal_allocation):
            allocation = alloc      # Global variable used in optim_function
            covar_table = covariances

            # Goal A Optimization
            goal_vector = goal_A   # Global variable used in optim_function
            if goal_A[1] <= pool * allocation:
                optimal_weights_A[i, :] = [0]*(num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_A[i, :] = result.x

            # Goal B Optimization
            goal_vector = goal_B
            if goal_B[1] <= pool * allocation:
                optimal_weights_B[i, :] = [0]*(num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_B[i, :] = result.x

            # Goal C Optimization
            goal_vector = goal_C
            if goal_C[1] <= pool * allocation:
                optimal_weights_C[i, :] = [0]*(num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_C[i, :] = result.x

            # Goal D Optimization
            goal_vector = goal_D
            if goal_D[1] <= pool * allocation:
                optimal_weights_D[i, :] = [0]*(num_assets - 1) + [1]
            else:
                result = minimize(
                    optim_function,
                    starting_weights,
                    constraints=[{'type': 'eq', 'fun': constraint_function}],
                    bounds=[(0, 1)] * num_assets,
                    method='SLSQP',
                    options=slsqp_opts
                )
                optimal_weights_D[i, :] = result.x

        goal_optimal_weights_A[loop_year] = optimal_weights_A
        goal_optimal_weights_B[loop_year] = optimal_weights_B
        goal_optimal_weights_C[loop_year] = optimal_weights_C
        goal_optimal_weights_D[loop_year] = optimal_weights_D

        # Calculate the best probability (phi) for each allocation level for every goal
        phi_A = np.zeros(len(goal_allocation))
        phi_B = np.zeros(len(goal_allocation))
        phi_C = np.zeros(len(goal_allocation))
        phi_D = np.zeros(len(goal_allocation))

        for i, alloc in enumerate(goal_allocation):
            phi_A[i] = phi_f(goal_A, alloc, pool,
                             mean_f(optimal_weights_A[i, :], return_vector),
                             sd_f(optimal_weights_A[i, :], covariances))
            phi_B[i] = phi_f(goal_B, alloc, pool,
                             mean_f(optimal_weights_B[i, :], return_vector),
                             sd_f(optimal_weights_B[i, :], covariances))
            phi_C[i] = phi_f(goal_C, alloc, pool,
                             mean_f(optimal_weights_C[i, :], return_vector),
                             sd_f(optimal_weights_C[i, :], covariances))
            phi_D[i] = phi_f(goal_D, alloc, pool,
                             mean_f(optimal_weights_D[i, :], return_vector),
                             sd_f(optimal_weights_D[i, :], covariances))

        # Simulate goal weights: each row is a simulated allocation (in percentages)
        sim_goal_weights = np.random.multinomial(100, [1/num_goals]*num_goals, size=n_trials) #this one sums to 100 so its good
        for i in range(n_trials):
            rand_vector = np.random.uniform(0, 1, num_goals)
            normalizer = np.sum(rand_vector)
            percents = np.round((rand_vector / normalizer) * 100, 0)

            # Only enforce floor for active goals
            floor_applied = np.where(active_goal_mask, np.maximum(percents, 1), percents)
            sim_goal_weights[i, :] = floor_applied


        # Calculate utility for each simulated portfolio.
        # Note: subtract 1 from simulated weights for 0-indexing.
        utility = (
            goal_A[0] * phi_A[sim_goal_weights[:, 0] - 1] +
            goal_A[0] * goal_B[0] * phi_B[sim_goal_weights[:, 1] - 1] +
            goal_A[0] * goal_B[0] * goal_C[0] * phi_C[sim_goal_weights[:, 2] - 1] +
            goal_A[0] * goal_B[0] * goal_C[0] * goal_D[0] * phi_D[sim_goal_weights[:, 3] - 1]
        )

        # Find the index of the portfolio with the highest utility
        index = np.argmax(utility)
        optimal_goal_weights = sim_goal_weights[index, :]

        # - Optimal Subportfolio Allocation - #

        # Retrieve optimal subportfolio allocations
        optimal_subportfolios = np.zeros((num_goals, num_assets))

        # For each goal, use the simulated percentage to select the corresponding row
        # from the optimal weights matrix (adjust for zero-indexing)
        for i in range(num_goals):
            optimal_subportfolios[i, :] = eval(f"optimal_weights_{goals[i]}")[optimal_goal_weights[i] - 1, :]

        # Compute the optimal aggregate investment portfolio.
        optimal_aggregate_portfolio = (optimal_goal_weights / 100) @ optimal_subportfolios

        #Define asset names
        asset_names = capital_market_expectations_raw.iloc[:, 0].astype(str).tolist()

        # - Storing and exporting results - #

        # Create a DataFrame for the aggregate portfolio.
        # First calculate unrounded percentages
        raw_alloc = optimal_aggregate_portfolio * 100

        # Normalize to force sum = 100 after rounding
        normalized_alloc = raw_alloc / raw_alloc.sum() * 100
        normalized_goal_alloc = np.zeros_like(optimal_goal_weights, dtype=float)
        active_sum = np.sum(optimal_goal_weights[active_goal_mask])
        normalized_goal_alloc[active_goal_mask] = (optimal_goal_weights[active_goal_mask] / active_sum) * 100

        normalized_weights = normalized_alloc / 100  # convert back to decimal weights

        # Create a DataFrame for the across-goal allocation.
        df_across_goal = pd.DataFrame({
            "Goal": goals,
            "Allocation (%)": np.round(normalized_goal_alloc, 2) # Keep raw percentages
        })

        # Round after normalization
        df_aggregate = pd.DataFrame({
            "Asset": asset_names,
            "Weight": normalized_weights,
            "Invested Amt (DKK)": normalized_weights * pool,
            "Allocation (%)": np.round(normalized_alloc, 2)  # keep for display only
        })


        # - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #
        # --- NEW: Exact and Proportional ASK Logic ---
        account_allocations = []
        equity_rows = []
        non_equity_rows = []

        # First pass: split equity and non-equity rows
        for i, row in df_aggregate.iterrows():
            asset_name = row["Asset"]
            invested = row["Invested Amt (DKK)"]
            weight = row["Weight"]

            row_dict = {
                "Year": loop_year,
                "Asset": asset_name,
                "Invested": invested,
                "Weight": weight,
                "ASK (DKK)": 0,
                "Normal (DKK)": 0,
            }

            if "Equities" in asset_name:
                equity_rows.append(row_dict)
            else:
                row_dict["Normal (DKK)"] = invested
                non_equity_rows.append(row_dict)

        # Determine total equity to allocate proportionally if ASK cap remains
        total_equity = sum(row["Invested"] for row in equity_rows)
        remaining_ask_cap = max(0, aktiesparekonto_cap - aktiesparekonto_used_total)
        ask_fraction = min(1, remaining_ask_cap / total_equity) if total_equity > 0 else 0

        # Apply proportional ASK allocation to equities
        for row in equity_rows:
            ask_part = row["Invested"] * ask_fraction
            normal_part = row["Invested"] - ask_part
            row["ASK (DKK)"] = round(ask_part, 2)
            row["Normal (DKK)"] = round(normal_part, 2)
            aktiesparekonto_used_total += ask_part

        # Combine and finalize
        account_allocations = equity_rows + non_equity_rows


        df_accounts = pd.DataFrame(account_allocations)
        print(f"[DEBUG] Final weight sum: {sum(row['Weight'] for row in account_allocations):.10f}")
        # - V5 END - #


        # - NEW V6 CONTENT REGARDING GAINS & TAXES - #


        share_income_normal = 0  # for progressive tax
        tax_ask = 0  # Track ASK tax separately

        # Update portfolio and compute gains
        for row in account_allocations:
            asset = row["Asset"]
            ask = row["ASK (DKK)"]
            normal = row["Normal (DKK)"]
            weight = row["Weight"]
            expected_return_nominal = df_montecarlo_returns.loc[(asset, path_id), str(loop_year)]
            expected_return_inflation_adj = expected_return_nominal - inflation_rate


            # V7C -LOG ASSET RETURNS BY ACCOUNT
            if ask > 0:
                new_val = ask * (1 + expected_return_inflation_adj)
                gain = new_val - ask
                tax = 0.17 * gain
                asset_level_log.append({
                    "Year": loop_year,
                    "Account": "ASK",
                    "Asset": asset,
                    "Invested": ask,
                    "Weight": ask / pool,
                    "Return (Nominal)": expected_return_nominal,
                    "Inflation Rate": inflation_rate,
                    "Return (Inflation Adjusted)": expected_return_inflation_adj,
                    "Gross Gain": gain,
                    "Tax": tax,
                    "Net Gain": gain - tax,
                    "End Value": ask + gain - tax,
                    "TOTAL ASK Cap (DKK)": aktiesparekonto_cap
                })

            if normal > 0:
                new_val = normal * (1 + expected_return_inflation_adj)
                gain = new_val - normal
                share_income_normal += gain
                asset_level_log.append({
                    "Year": loop_year,
                    "Account": "NORMAL",
                    "Asset": asset,
                    "Invested": normal,
                    "Weight": normal / pool,
                    "Return (Nominal)": expected_return_nominal,
                    "Inflation Rate": inflation_rate,
                    "Return (Inflation Adjusted)": expected_return_inflation_adj,
                    "Gross Gain": gain,
                    "Tax": None,  # progressive tax logged later
                    "Net Gain": None,
                    "End Value": None,
                    "TOTAL ASK Cap (DKK)": aktiesparekonto_cap
                })

                #V7C END

        # Tax on Normal Account (progressive)
        cap = 67500
        if share_income_normal <= cap:
            tax_normal = 0.27 * share_income_normal
        else:
            tax_normal = 0.27 * cap + 0.42 * (share_income_normal - cap)

        # Distribute tax proportionally across NORMAL assets
        normal_log_rows = [
            row for row in asset_level_log
            if "Account" in row and row["Account"] == "NORMAL" and row["Year"] == loop_year
        ]

        total_normal_gain = sum(row["Gross Gain"] for row in normal_log_rows)

        print(f"[DEBUG] Year: {loop_year}")
        print(f"[DEBUG] Gross Gains (Normal account): {share_income_normal:.2f}")
        print(f"[DEBUG] Tax Calculated (Normal account): {tax_normal:.2f}")

        for row in normal_log_rows:
            if total_normal_gain > 0:
                share = row["Gross Gain"] / total_normal_gain
                tax = share * tax_normal
            else:
                tax = 0

            row["Tax"] = tax
            row["Net Gain"] = row["Gross Gain"] - tax
            row["End Value"] = row["Invested"] + row["Net Gain"]

        total_gains_normal = share_income_normal - tax_normal


        print("Optimal Across-Goal Allocation:")
        print(df_across_goal.to_string(index=False))

        print("\nOptimal Aggregate Investment Allocation:")
        print(df_aggregate.to_string(index=False))

        print("\nUtility:")
        print(utility)

        print("\nProbability of Achieving Each Goal at Optimal Allocation:")
        print(f"Goal A: {phi_A[optimal_goal_weights[0] - 1]:.4f}")
        print(f"Goal B: {phi_B[optimal_goal_weights[1] - 1]:.4f}")
        print(f"Goal C: {phi_C[optimal_goal_weights[2] - 1]:.4f}")
        print(f"Goal D: {phi_D[optimal_goal_weights[3] - 1]:.4f}")

        # -- V15 Goal weights -- #


        # Store current year's across-goal allocation
        goal_weights_tracker.append({
            "Year": loop_year,
            **{f"Goal {goals[i]} (%)": normalized_goal_alloc[i] for i in range(num_goals)}
        })

        # Store current year's aggregate portfolio
        for i in range(num_assets):
            aggregate_portfolio_tracker.append({
                "Year": loop_year,
                "Asset": asset_names[i],
                "Weight": normalized_weights[i],
                "Allocation (%)": np.round(normalized_alloc[i], 2),
                "Invested Amt (DKK)": normalized_weights[i] * pool
            })


        # -- V13 - Modify Loop Check -- #
        print("Starting loop status check (in-memory)...")

        # Show up to 10 rows (adjust as needed) of the current loop status
        preview_rows = loop_df.tail(10)
        for i, row in preview_rows.iterrows():
            print(f"Row {i+2}: Year = {row['Year']}, Status = {row['LoopStatus']}")

        # Update the current year's loop status
        loop_df.loc[loop_df["Year"] == loop_year, "LoopStatus"] = "Y"
        print(f"✅ LoopStatus updated to 'Y' for Year {loop_year}")

        this_year_rows = [row for row in asset_level_log if row["Year"] == loop_year]
        end_value_sum = sum(row["End Value"] for row in this_year_rows)

        # - V9 END -

        # --- V11: Opportunity Cost Check for Goal Redemption --- #
        for idx, g in enumerate(goals):
            horizon = adjusted_horizons[f"GOAL {g}"]
            if horizon == 1:
                goal_vec = goal_data_raw[f"GOAL {g}"].values.copy()
                goal_value = goal_vec[1]

                # Step 1: Prepare inputs
                phi_array = [None] * num_goals
                goal_ratios = [goal_data_raw[f"GOAL {goals[i]}"].values[0] for i in range(num_goals)]
                allocs = [normalized_goal_alloc[i] / 100 for i in range(num_goals)]

                # Step 2: Case 1 - Keep goal (phi = 0 for this goal)
                for j in range(num_goals):
                    if j == idx:
                        phi_array[j] = 0
                    else:
                        phi_array[j] = phi_f(
                            goal_data_raw[f"GOAL {goals[j]}"].values,
                            allocs[j],
                            pool,
                            mean_f(optimal_subportfolios[j], return_vector),
                            sd_f(optimal_subportfolios[j], covariances)
                        )

                utility_keep = (
                    goal_ratios[0] * phi_array[0] +
                    goal_ratios[0] * goal_ratios[1] * phi_array[1] +
                    goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * phi_array[2] +
                    goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * goal_ratios[3] * phi_array[3]
                )

                # Step 3: Case 2 - Redeem goal (phi = 1, pool reduced)
                pool_reduced = pool - goal_value
                for j in range(num_goals):
                    if j == idx:
                        phi_array[j] = 1
                    else:
                        phi_array[j] = phi_f(
                            goal_data_raw[f"GOAL {goals[j]}"].values,
                            allocs[j],
                            pool_reduced,
                            mean_f(optimal_subportfolios[j], return_vector),
                            sd_f(optimal_subportfolios[j], covariances)
                        )

                utility_redeem = (
                    goal_ratios[0] * phi_array[0] +
                    goal_ratios[0] * goal_ratios[1] * phi_array[1] +
                    goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * phi_array[2] +
                    goal_ratios[0] * goal_ratios[1] * goal_ratios[2] * goal_ratios[3] * phi_array[3]
                )

                # Step 4: Compare & apply
                utility_diff = utility_redeem - utility_keep
                redeem = utility_diff > 0

                if redeem:
                    allocated_value = allocs[idx] * end_value_sum
                    redeemed_amount = min(goal_value, allocated_value)
                    end_value_sum -= redeemed_amount

                    asset_level_log.append({
                        "Year": loop_year,
                        "Goal": f"GOAL {g}",
                        "Redeemed Amount": redeemed_amount,
                        "Allocated Value": allocated_value,
                        "Goal Value": goal_value,
                        "Utility (Keep)": utility_keep,
                        "Utility (Redeem)": utility_redeem,
                        "Utility Δ": utility_diff,
                        "Redeemed": True
                    })


        final_wealth_tracker[loop_year] = end_value_sum

        print(f"\n--- Year {loop_year} Summary ---")
        print(f"Income (Salary): {salary:.2f}")
        if loop_year != starting_year:
            print(f"Previous Wealth Carried: {prev_wealth:.2f}")
        print(f"Post-Tax Wealth (New Final Wealth): {pool:.2f}")
        print("------------------------------\n")
    # Create subfolder for each path (optional but cleaner)
    path_folder = os.path.join(output_folder, f"path_{path_id}")
    os.makedirs(path_folder, exist_ok=True)

    # Export asset-level log
    pd.DataFrame(asset_level_log).to_csv(os.path.join(path_folder, "asset_returns_log.csv"), index=False)

    # Export final wealth
    pd.DataFrame.from_dict(final_wealth_tracker, orient='index', columns=['Final Wealth']).to_csv(
        os.path.join(path_folder, "final_wealth_by_year.csv")
    )

    # Export goal weights
    pd.DataFrame(goal_weights_tracker).to_csv(
        os.path.join(path_folder, "goal_weights_by_year.csv"), index=False
    )

    # Export aggregate portfolio
    pd.DataFrame(aggregate_portfolio_tracker).to_csv(
        os.path.join(path_folder, "aggregate_portfolio_by_year.csv"), index=False
    )

    # Export optimal weights for each goal
    for goal_letter, matrix_dict in zip(
        ["A", "B", "C", "D"],
        [goal_optimal_weights_A, goal_optimal_weights_B, goal_optimal_weights_C, goal_optimal_weights_D]
    ):
        all_dfs = []
        for year, mat in matrix_dict.items():
            df = pd.DataFrame(mat)
            df.insert(0, "Year", year)
            df.insert(1, "Allocation Level", np.arange(0.01, 1.01, 0.01))
            all_dfs.append(df)

        df_all = pd.concat(all_dfs, ignore_index=True)
        df_all.to_csv(os.path.join(path_folder, f"optimal_weights_goal_{goal_letter}.csv"), index=False)

    path_results[path_id] = {
        "final_wealth": final_wealth_tracker.copy(),
        "goal_weights": goal_weights_tracker.copy(),
        "aggregate_portfolio": aggregate_portfolio_tracker.copy()
    }
# Out:
# 🧪 Running simulation for path 0
# 2025 1 25 40
# Starting Year: 2025
# Current Year: 2025
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 50, 'GOAL B': 5, 'GOAL C': 10, 'GOAL D': 15}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2025
# [DEBUG] Gross Gains (Normal account): 0.00
# [DEBUG] Tax Calculated (Normal account): 0.00
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            33.0
#    B            19.0
#    C            14.0
#    D            34.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.174499                 0.0           17.45
#         Developed Markets - Equities 0.280128                 0.0           28.01
# Emerging Markets State - Obligations 0.051468                 0.0            5.15
#       High Yield Bonds - Obligations 0.086791                 0.0            8.68
# Investment Grade Bonds - Obligations 0.181768                 0.0           18.18
#    Government ZC Bonds - Obligations 0.225346                 0.0           22.53
#
# Utility:
# [0. 0. 0. ... 0. 0. 0.]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2025
#
# --- Year 2025 Summary ---
# Income (Salary): 0.00
# Post-Tax Wealth (New Final Wealth): 0.00
# ------------------------------
#
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 49, 'GOAL B': 4, 'GOAL C': 9, 'GOAL D': 14}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2026
# [DEBUG] Gross Gains (Normal account): -978.83
# [DEBUG] Tax Calculated (Normal account): -264.28
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           96.04
#    B            1.98
#    C            0.99
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.962716        50682.389223           96.27
#         Developed Markets - Equities 0.018851          992.433830            1.89
# Emerging Markets State - Obligations 0.002233          117.548537            0.22
#       High Yield Bonds - Obligations 0.010229          538.513929            1.02
# Investment Grade Bonds - Obligations 0.004827          254.141644            0.48
#    Government ZC Bonds - Obligations 0.001143           60.172837            0.11
#
# Utility:
# [0.28305211 0.23354143 0.22994694 ... 0.19074453 0.24348444 0.2533737 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3141
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2026
#
# --- Year 2026 Summary ---
# Income (Salary): 52645.20
# Previous Wealth Carried: 0.00
# Post-Tax Wealth (New Final Wealth): 52645.20
# ------------------------------
#
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 48, 'GOAL B': 3, 'GOAL C': 8, 'GOAL D': 13}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2027
# [DEBUG] Gross Gains (Normal account): -2604.89
# [DEBUG] Tax Calculated (Normal account): -703.32
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           94.06
#    B            2.97
#    C            0.99
#    D            1.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.956589        58908.838827           95.66
#         Developed Markets - Equities 0.001635          100.713696            0.16
# Emerging Markets State - Obligations 0.005764          354.973913            0.58
#       High Yield Bonds - Obligations 0.012133          747.199452            1.21
# Investment Grade Bonds - Obligations 0.006983          430.042741            0.70
#    Government ZC Bonds - Obligations 0.016894         1040.398640            1.69
#
# Utility:
# [0.17679987 0.12420305 0.12420305 ... 0.19363428 0.06050107 0.23057495]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3175
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2027
#
# --- Year 2027 Summary ---
# Income (Salary): 53171.65
# Previous Wealth Carried: 8410.52
# Post-Tax Wealth (New Final Wealth): 61582.17
# ------------------------------
#
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 47, 'GOAL B': 2, 'GOAL C': 7, 'GOAL D': 12}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2028
# [DEBUG] Gross Gains (Normal account): -1509.83
# [DEBUG] Tax Calculated (Normal account): -407.65
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           94.95
#    B            1.01
#    C            3.03
#    D            1.01
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.968922        66381.900153           96.89
#         Developed Markets - Equities 0.009353          640.761172            0.94
# Emerging Markets State - Obligations 0.000936           64.150433            0.09
#       High Yield Bonds - Obligations 0.005703          390.725200            0.57
# Investment Grade Bonds - Obligations 0.005965          408.670991            0.60
#    Government ZC Bonds - Obligations 0.009121          624.885722            0.91
#
# Utility:
# [0.17352876 0.11924233 0.14104259 ... 0.23627251 0.18728186 0.04022182]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3172
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2028
#
# --- Year 2028 Summary ---
# Income (Salary): 59020.53
# Previous Wealth Carried: 9490.56
# Post-Tax Wealth (New Final Wealth): 68511.09
# ------------------------------
#
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 46, 'GOAL B': 1, 'GOAL C': 6, 'GOAL D': 11}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2029
# [DEBUG] Gross Gains (Normal account): -3276.47
# [DEBUG] Tax Calculated (Normal account): -884.65
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           92.08
#    B            5.94
#    C            0.99
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.941916        66167.397130           94.19
#         Developed Markets - Equities 0.012152          853.654384            1.22
# Emerging Markets State - Obligations 0.022099         1552.388217            2.21
#       High Yield Bonds - Obligations 0.002266          159.167940            0.23
# Investment Grade Bonds - Obligations 0.013959          980.593450            1.40
#    Government ZC Bonds - Obligations 0.007608          534.463755            0.76
#
# Utility:
# [0.1210348  0.06717809 0.26360278 ... 0.2324782  0.20334952 0.17064125]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3087
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2029
#
# --- Year 2029 Summary ---
# Income (Salary): 59610.74
# Previous Wealth Carried: 10636.93
# Post-Tax Wealth (New Final Wealth): 70247.66
# ------------------------------
#
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 45, 'GOAL B': 0, 'GOAL C': 5, 'GOAL D': 10}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2030
# [DEBUG] Gross Gains (Normal account): -13620.15
# [DEBUG] Tax Calculated (Normal account): -3677.44
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            96.0
#    B             0.0
#    C             3.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.969755        68103.279830           96.98
#         Developed Markets - Equities 0.007801          547.808119            0.78
# Emerging Markets State - Obligations 0.002875          201.900915            0.29
#       High Yield Bonds - Obligations 0.011054          776.299253            1.11
# Investment Grade Bonds - Obligations 0.003233          227.013119            0.32
#    Government ZC Bonds - Obligations 0.005283          371.001433            0.53
#
# Utility:
# [0.15668972 0.243087   0.21080365 ... 0.17803225 0.21763051 0.20842832]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3017
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2030
#
# --- Year 2030 Summary ---
# Income (Salary): 60206.85
# Previous Wealth Carried: 10020.46
# Post-Tax Wealth (New Final Wealth): 70227.30
# ------------------------------
#
# 2031 7 31 46
# Starting Year: 2025
# Current Year: 2031
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 44, 'GOAL B': -1, 'GOAL C': 4, 'GOAL D': 9}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2031
# [DEBUG] Gross Gains (Normal account): -32018.79
# [DEBUG] Tax Calculated (Normal account): -8645.07
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           94.79
#    B            0.00
#    C            1.04
#    D            4.17
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.927988        64721.958237           92.80
#         Developed Markets - Equities 0.001520          106.001995            0.15
# Emerging Markets State - Obligations 0.009099          634.569349            0.91
#       High Yield Bonds - Obligations 0.033665         2347.968786            3.37
# Investment Grade Bonds - Obligations 0.013359          931.736283            1.34
#    Government ZC Bonds - Obligations 0.014369         1002.147732            1.44
#
# Utility:
# [0.17621906 0.1947949  0.1972051  ... 0.16393002 0.14616678 0.17025512]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.2852
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2031
#
# --- Year 2031 Summary ---
# Income (Salary): 60808.91
# Previous Wealth Carried: 8935.47
# Post-Tax Wealth (New Final Wealth): 69744.38
# ------------------------------
#
# 2032 8 32 47
# Starting Year: 2025
# Current Year: 2032
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 43, 'GOAL B': -2, 'GOAL C': 3, 'GOAL D': 8}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2032
# [DEBUG] Gross Gains (Normal account): -30598.71
# [DEBUG] Tax Calculated (Normal account): -8261.65
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           96.94
#    B            0.00
#    C            2.04
#    D            1.02
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.973130        71207.346177           97.31
#         Developed Markets - Equities 0.008887          650.271372            0.89
# Emerging Markets State - Obligations 0.003026          221.422400            0.30
#       High Yield Bonds - Obligations 0.000124            9.104414            0.01
# Investment Grade Bonds - Obligations 0.008880          649.766818            0.89
#    Government ZC Bonds - Obligations 0.005953          435.575773            0.60
#
# Utility:
# [0.18038351 0.15038428 0.1354848  ... 0.1354848  0.09027081 0.19734416]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.2835
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2032
#
# --- Year 2032 Summary ---
# Income (Salary): 67497.90
# Previous Wealth Carried: 5675.59
# Post-Tax Wealth (New Final Wealth): 73173.49
# ------------------------------
#
# 2033 9 33 48
# Starting Year: 2025
# Current Year: 2033
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 42, 'GOAL B': -3, 'GOAL C': 2, 'GOAL D': 7}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2033
# [DEBUG] Gross Gains (Normal account): -26577.58
# [DEBUG] Tax Calculated (Normal account): -7175.95
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           95.96
#    B            0.00
#    C            3.03
#    D            1.01
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.964670        71997.126510           96.47
#         Developed Markets - Equities 0.014224         1061.607440            1.42
# Emerging Markets State - Obligations 0.005732          427.803233            0.57
#       High Yield Bonds - Obligations 0.002324          173.472907            0.23
# Investment Grade Bonds - Obligations 0.005956          444.503083            0.60
#    Government ZC Bonds - Obligations 0.007094          529.459681            0.71
#
# Utility:
# [0.07631068 0.16845861 0.09981713 ... 0.19017554 0.16845861 0.01854093]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.2745
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2033
#
# --- Year 2033 Summary ---
# Income (Salary): 68172.87
# Previous Wealth Carried: 6461.10
# Post-Tax Wealth (New Final Wealth): 74633.97
# ------------------------------
#
# 2034 10 34 49
# Starting Year: 2025
# Current Year: 2034
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 41, 'GOAL B': -4, 'GOAL C': 1, 'GOAL D': 6}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2034
# [DEBUG] Gross Gains (Normal account): -22001.60
# [DEBUG] Tax Calculated (Normal account): -5940.43
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            92.0
#    B             0.0
#    C             4.0
#    D             4.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.924526        70472.001675           92.45
#         Developed Markets - Equities 0.015553         1185.497742            1.56
# Emerging Markets State - Obligations 0.016892         1287.604889            1.69
#       High Yield Bonds - Obligations 0.014855         1132.308344            1.49
# Investment Grade Bonds - Obligations 0.016046         1223.094876            1.60
#    Government ZC Bonds - Obligations 0.012128          924.484272            1.21
#
# Utility:
# [0.16679601 0.1451336  0.05533445 ... 0.1617576  0.16679601 0.06929817]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.2619
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2034
#
# --- Year 2034 Summary ---
# Income (Salary): 68854.60
# Previous Wealth Carried: 7370.39
# Post-Tax Wealth (New Final Wealth): 76224.99
# ------------------------------
#
# 2035 11 35 50
# Starting Year: 2025
# Current Year: 2035
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 40, 'GOAL B': -5, 'GOAL C': 0, 'GOAL D': 5}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2035
# [DEBUG] Gross Gains (Normal account): -16798.58
# [DEBUG] Tax Calculated (Normal account): -4535.62
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           97.92
#    B            0.00
#    C            0.00
#    D            2.08
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.002012          156.828070            0.20
#         Developed Markets - Equities 0.953678        74326.450658           95.37
# Emerging Markets State - Obligations 0.032709         2549.220031            3.27
#       High Yield Bonds - Obligations 0.003895          303.565496            0.39
# Investment Grade Bonds - Obligations 0.007238          564.110080            0.72
#    Government ZC Bonds - Obligations 0.000468           36.461053            0.05
#
# Utility:
# [0.05610909 0.07265848 0.07265848 ... 0.03323243 0.02522843 0.05285461]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1334
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2035
#
# --- Year 2035 Summary ---
# Income (Salary): 69543.15
# Previous Wealth Carried: 8393.49
# Post-Tax Wealth (New Final Wealth): 77936.64
# ------------------------------
#
# 2036 12 36 51
# Starting Year: 2025
# Current Year: 2036
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 39, 'GOAL B': -6, 'GOAL C': -1, 'GOAL D': 4}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2036
# [DEBUG] Gross Gains (Normal account): -17533.23
# [DEBUG] Tax Calculated (Normal account): -4733.97
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           97.94
#    B            0.00
#    C            0.00
#    D            2.06
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.952970        82422.333532           95.30
#         Developed Markets - Equities 0.002977          257.462719            0.30
# Emerging Markets State - Obligations 0.010241          885.754752            1.02
#       High Yield Bonds - Obligations 0.002854          246.800481            0.29
# Investment Grade Bonds - Obligations 0.019825         1714.685856            1.98
#    Government ZC Bonds - Obligations 0.011134          962.961469            1.11
#
# Utility:
# [0.117502   0.12541458 0.08947609 ... 0.097721   0.09160144 0.0756545 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1831
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = Y
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2036
#
# --- Year 2036 Summary ---
# Income (Salary): 77192.90
# Previous Wealth Carried: 9297.10
# Post-Tax Wealth (New Final Wealth): 86490.00
# ------------------------------
#
# 2037 13 37 52
# Starting Year: 2025
# Current Year: 2037
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 38, 'GOAL B': -7, 'GOAL C': -2, 'GOAL D': 3}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2037
# [DEBUG] Gross Gains (Normal account): -11005.18
# [DEBUG] Tax Calculated (Normal account): -2971.40
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           97.87
#    B            0.00
#    C            0.00
#    D            2.13
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.945036        83910.939596           94.50
#         Developed Markets - Equities 0.024687         2191.948218            2.47
# Emerging Markets State - Obligations 0.017904         1589.738813            1.79
#       High Yield Bonds - Obligations 0.011225          996.642599            1.12
# Investment Grade Bonds - Obligations 0.000291           25.843324            0.03
#    Government ZC Bonds - Obligations 0.000858           76.191638            0.09
#
# Utility:
# [0.0417195  0.00988572 0.08479599 ... 0.09638889 0.08880499 0.08681994]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1724
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = Y
# Row 13: Year = 2036, Status = Y
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2037
#
# --- Year 2037 Summary ---
# Income (Salary): 77964.82
# Previous Wealth Carried: 10826.48
# Post-Tax Wealth (New Final Wealth): 88791.30
# ------------------------------
#
# 2038 14 38 53
# Starting Year: 2025
# Current Year: 2038
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 37, 'GOAL B': -8, 'GOAL C': -3, 'GOAL D': 2}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2038
# [DEBUG] Gross Gains (Normal account): -3240.52
# [DEBUG] Tax Calculated (Normal account): -874.94
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           98.95
#    B            0.00
#    C            0.00
#    D            1.05
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.956470        87025.930078           95.65
#         Developed Markets - Equities 0.014594         1327.847685            1.46
# Emerging Markets State - Obligations 0.009438          858.712378            0.94
#       High Yield Bonds - Obligations 0.003758          341.913599            0.38
# Investment Grade Bonds - Obligations 0.012735         1158.669993            1.27
#    Government ZC Bonds - Obligations 0.003005          273.455763            0.30
#
# Utility:
# [0.03988817 0.09092966 0.11310876 ... 0.06970015 0.06753765 0.08554571]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1660
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = Y
# Row 13: Year = 2036, Status = Y
# Row 14: Year = 2037, Status = Y
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2038
#
# --- Year 2038 Summary ---
# Income (Salary): 78744.47
# Previous Wealth Carried: 12242.06
# Post-Tax Wealth (New Final Wealth): 90986.53
# ------------------------------
#
# 2039 15 39 54
# Starting Year: 2025
# Current Year: 2039
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 36, 'GOAL B': -9, 'GOAL C': -4, 'GOAL D': 1}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2039
# [DEBUG] Gross Gains (Normal account): -4145.61
# [DEBUG] Tax Calculated (Normal account): -1119.32
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           96.88
#    B            0.00
#    C            0.00
#    D            3.12
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.948567        88593.477729           94.86
#         Developed Markets - Equities 0.007821          730.496276            0.78
# Emerging Markets State - Obligations 0.006583          614.823723            0.66
#       High Yield Bonds - Obligations 0.008466          790.722850            0.85
# Investment Grade Bonds - Obligations 0.016227         1515.520662            1.62
#    Government ZC Bonds - Obligations 0.012336         1152.127965            1.23
#
# Utility:
# [0.10539919 0.06533375 0.04786044 ... 0.05021703 0.07676205 0.07119848]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1568
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = Y
# Row 13: Year = 2036, Status = Y
# Row 14: Year = 2037, Status = Y
# Row 15: Year = 2038, Status = Y
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2039
#
# --- Year 2039 Summary ---
# Income (Salary): 79531.92
# Previous Wealth Carried: 13865.25
# Post-Tax Wealth (New Final Wealth): 93397.17
# ------------------------------
#
# 2040 16 40 55
# Starting Year: 2025
# Current Year: 2040
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 35, 'GOAL B': -10, 'GOAL C': -5, 'GOAL D': 0}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2040
# [DEBUG] Gross Gains (Normal account): -1742.51
# [DEBUG] Tax Calculated (Normal account): -470.48
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.969066        99162.183883           96.91
#         Developed Markets - Equities 0.014206         1453.636007            1.42
# Emerging Markets State - Obligations 0.002868          293.472650            0.29
#       High Yield Bonds - Obligations 0.000837           85.697209            0.08
# Investment Grade Bonds - Obligations 0.000555           56.743224            0.06
#    Government ZC Bonds - Obligations 0.012468         1275.841042            1.25
#
# Utility:
# [0.06398425 0.13112549 0.07154229 ... 0.06782599 0.06782599 0.05588025]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.1569
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = Y
# Row 13: Year = 2036, Status = Y
# Row 14: Year = 2037, Status = Y
# Row 15: Year = 2038, Status = Y
# Row 16: Year = 2039, Status = Y
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2040
#
# --- Year 2040 Summary ---
# Income (Salary): 88280.43
# Previous Wealth Carried: 14047.15
# Post-Tax Wealth (New Final Wealth): 102327.57
# ------------------------------
#
# All loops completed
# 🧪 Running simulation for path 1
# 2025 1 25 40
# Starting Year: 2025
# Current Year: 2025
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 50, 'GOAL B': 5, 'GOAL C': 10, 'GOAL D': 15}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2025
# [DEBUG] Gross Gains (Normal account): 0.00
# [DEBUG] Tax Calculated (Normal account): 0.00
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            16.0
#    B            19.0
#    C            27.0
#    D            38.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.111992                 0.0           11.20
#         Developed Markets - Equities 0.232586                 0.0           23.26
# Emerging Markets State - Obligations 0.223236                 0.0           22.32
#       High Yield Bonds - Obligations 0.166812                 0.0           16.68
# Investment Grade Bonds - Obligations 0.258867                 0.0           25.89
#    Government ZC Bonds - Obligations 0.006506                 0.0            0.65
#
# Utility:
# [0. 0. 0. ... 0. 0. 0.]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2025
#
# --- Year 2025 Summary ---
# Income (Salary): 0.00
# Post-Tax Wealth (New Final Wealth): 0.00
# ------------------------------
#
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 49, 'GOAL B': 4, 'GOAL C': 9, 'GOAL D': 14}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2026
# [DEBUG] Gross Gains (Normal account): -500.45
# [DEBUG] Tax Calculated (Normal account): -135.12
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            95.0
#    B             1.0
#    C             3.0
#    D             1.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.952433        50141.000717           95.24
#         Developed Markets - Equities 0.016109          848.078819            1.61
# Emerging Markets State - Obligations 0.005538          291.538887            0.55
#       High Yield Bonds - Obligations 0.014504          763.546904            1.45
# Investment Grade Bonds - Obligations 0.004913          258.622753            0.49
#    Government ZC Bonds - Obligations 0.006504          342.411919            0.65
#
# Utility:
# [0.18960641 0.15410755 0.15423709 ... 0.16272269 0.22758279 0.23191128]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3122
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2026
#
# --- Year 2026 Summary ---
# Income (Salary): 52645.20
# Previous Wealth Carried: 0.00
# Post-Tax Wealth (New Final Wealth): 52645.20
# ------------------------------
#
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 48, 'GOAL B': 3, 'GOAL C': 8, 'GOAL D': 13}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2027
# [DEBUG] Gross Gains (Normal account): -24765.39
# [DEBUG] Tax Calculated (Normal account): -6686.65
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            95.0
#    B             1.0
#    C             2.0
#    D             2.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.956110       100694.083889           95.61
#         Developed Markets - Equities 0.002470          260.112363            0.25
# Emerging Markets State - Obligations 0.010760         1133.197950            1.08
#       High Yield Bonds - Obligations 0.015601         1643.039451            1.56
# Investment Grade Bonds - Obligations 0.002687          283.034872            0.27
#    Government ZC Bonds - Obligations 0.012372         1302.931264            1.24
#
# Utility:
# [0.17998794 0.23949531 0.17998799 ... 0.12056556 0.22214373 0.25169971]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3700
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2027
#
# --- Year 2027 Summary ---
# Income (Salary): 53171.65
# Previous Wealth Carried: 52144.75
# Post-Tax Wealth (New Final Wealth): 105316.40
# ------------------------------
#
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 47, 'GOAL B': 2, 'GOAL C': 7, 'GOAL D': 12}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2028
# [DEBUG] Gross Gains (Normal account): -4358.70
# [DEBUG] Tax Calculated (Normal account): -1176.85
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           94.06
#    B            0.99
#    C            0.99
#    D            3.96
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.952063       132880.859061           95.21
#         Developed Markets - Equities 0.013833         1930.732695            1.38
# Emerging Markets State - Obligations 0.005570          777.401737            0.56
#       High Yield Bonds - Obligations 0.011583         1616.668776            1.16
# Investment Grade Bonds - Obligations 0.008002         1116.796398            0.80
#    Government ZC Bonds - Obligations 0.008949         1249.082620            0.89
#
# Utility:
# [0.29334991 0.31688059 0.13617632 ... 0.08646686 0.29079571 0.34032055]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3899
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2028
#
# --- Year 2028 Summary ---
# Income (Salary): 59020.53
# Previous Wealth Carried: 80551.01
# Post-Tax Wealth (New Final Wealth): 139571.54
# ------------------------------
#
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 46, 'GOAL B': 1, 'GOAL C': 6, 'GOAL D': 11}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2029
# [DEBUG] Gross Gains (Normal account): -87495.18
# [DEBUG] Tax Calculated (Normal account): -23623.70
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            92.0
#    B             2.0
#    C             1.0
#    D             5.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.934127       181990.043292           93.41
#         Developed Markets - Equities 0.012176         2372.218808            1.22
# Emerging Markets State - Obligations 0.016747         3262.685793            1.67
#       High Yield Bonds - Obligations 0.005296         1031.750061            0.53
# Investment Grade Bonds - Obligations 0.016074         3131.633525            1.61
#    Government ZC Bonds - Obligations 0.015579         3035.248053            1.56
#
# Utility:
# [0.33118751 0.31295033 0.24259164 ... 0.36062782 0.31959617 0.31295033]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4129
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2029
#
# --- Year 2029 Summary ---
# Income (Salary): 59610.74
# Previous Wealth Carried: 135212.84
# Post-Tax Wealth (New Final Wealth): 194823.58
# ------------------------------
#
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 45, 'GOAL B': 0, 'GOAL C': 5, 'GOAL D': 10}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2030
# [DEBUG] Gross Gains (Normal account): -96846.24
# [DEBUG] Tax Calculated (Normal account): -26148.48
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           97.98
#    B            0.00
#    C            1.01
#    D            1.01
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.967787       160061.026403           96.78
#         Developed Markets - Equities 0.007682         1270.494887            0.77
# Emerging Markets State - Obligations 0.007585         1254.402902            0.76
#       High Yield Bonds - Obligations 0.002930          484.585231            0.29
# Investment Grade Bonds - Obligations 0.006033          997.764658            0.60
#    Government ZC Bonds - Obligations 0.007984         1320.403347            0.80
#
# Utility:
# [0.14578153 0.08842919 0.18397063 ... 0.2146815  0.15996657 0.26169782]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3922
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2030
#
# --- Year 2030 Summary ---
# Income (Salary): 60206.85
# Previous Wealth Carried: 105181.83
# Post-Tax Wealth (New Final Wealth): 165388.68
# ------------------------------
#
# 2031 7 31 46
# Starting Year: 2025
# Current Year: 2031
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 44, 'GOAL B': -1, 'GOAL C': 4, 'GOAL D': 9}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2031
# [DEBUG] Gross Gains (Normal account): -83046.67
# [DEBUG] Tax Calculated (Normal account): -22422.60
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            94.0
#    B             0.0
#    C             1.0
#    D             5.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.939809       121565.578112           93.98
#         Developed Markets - Equities 0.006265          810.391099            0.63
# Emerging Markets State - Obligations 0.005890          761.875933            0.59
#       High Yield Bonds - Obligations 0.015236         1970.752048            1.52
# Investment Grade Bonds - Obligations 0.017336         2242.443278            1.73
#    Government ZC Bonds - Obligations 0.015464         2000.310216            1.55
#
# Utility:
# [0.10439269 0.27657816 0.17317528 ... 0.2409292  0.23159679 0.22830663]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3528
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = N
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2031
#
# --- Year 2031 Summary ---
# Income (Salary): 60808.91
# Previous Wealth Carried: 68542.44
# Post-Tax Wealth (New Final Wealth): 129351.35
# ------------------------------
#
# 2032 8 32 47
# Starting Year: 2025
# Current Year: 2032
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 43, 'GOAL B': -2, 'GOAL C': 3, 'GOAL D': 8}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2032
# [DEBUG] Gross Gains (Normal account): -77781.74
# [DEBUG] Tax Calculated (Normal account): -21001.07
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           97.92
#    B            0.00
#    C            1.04
#    D            1.04
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.950941       108219.516666           95.09
#         Developed Markets - Equities 0.012119         1379.185531            1.21
# Emerging Markets State - Obligations 0.013483         1534.424660            1.35
#       High Yield Bonds - Obligations 0.008906         1013.494432            0.89
# Investment Grade Bonds - Obligations 0.010056         1144.420528            1.01
#    Government ZC Bonds - Obligations 0.004495          511.531564            0.45
#
# Utility:
# [0.22664855 0.25942543 0.21227274 ... 0.26145139 0.19221813 0.29303093]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3288
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2032
#
# --- Year 2032 Summary ---
# Income (Salary): 67497.90
# Previous Wealth Carried: 46304.68
# Post-Tax Wealth (New Final Wealth): 113802.57
# ------------------------------
#
# 2033 9 33 48
# Starting Year: 2025
# Current Year: 2033
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 42, 'GOAL B': -3, 'GOAL C': 2, 'GOAL D': 7}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2033
# [DEBUG] Gross Gains (Normal account): -70033.04
# [DEBUG] Tax Calculated (Normal account): -18908.92
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           94.95
#    B            0.00
#    C            1.01
#    D            4.04
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.941266        98074.033825           94.13
#         Developed Markets - Equities 0.022202         2313.265492            2.22
# Emerging Markets State - Obligations 0.004076          424.717189            0.41
#       High Yield Bonds - Obligations 0.018119         1887.837516            1.81
# Investment Grade Bonds - Obligations 0.010380         1081.553509            1.04
#    Government ZC Bonds - Obligations 0.003957          412.310752            0.40
#
# Utility:
# [0.25649809 0.21753561 0.04130775 ... 0.07617801 0.17742065 0.04130775]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.3086
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2033
#
# --- Year 2033 Summary ---
# Income (Salary): 68172.87
# Previous Wealth Carried: 36020.84
# Post-Tax Wealth (New Final Wealth): 104193.72
# ------------------------------
#
# 2034 10 34 49
# Starting Year: 2025
# Current Year: 2034
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 41, 'GOAL B': -4, 'GOAL C': 1, 'GOAL D': 6}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2034
# [DEBUG] Gross Gains (Normal account): -64698.08
# [DEBUG] Tax Calculated (Normal account): -17468.48
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            94.0
#    B             0.0
#    C             1.0
#    D             5.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.943785        97224.247607           94.38
#         Developed Markets - Equities 0.009184          946.057618            0.92
# Emerging Markets State - Obligations 0.015108         1556.368449            1.51
#       High Yield Bonds - Obligations 0.023143         2384.053826            2.31
# Investment Grade Bonds - Obligations 0.001757          180.950353            0.18
#    Government ZC Bonds - Obligations 0.007024          723.601423            0.70
#
# Utility:
# ...
#    Government ZC Bonds - Obligations 0.452921       305953.438748           45.29
#
# Utility:
# [0.42042362 0.39373424 0.43339196 ... 0.44120262 0.39076149 0.48734144]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.4648
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = N
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2032
#
# --- Year 2032 Summary ---
# Income (Salary): 67497.90
# Previous Wealth Carried: 608013.26
# Post-Tax Wealth (New Final Wealth): 675511.15
# ------------------------------
#
# 2033 9 33 48
# Starting Year: 2025
# Current Year: 2033
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 42, 'GOAL B': -3, 'GOAL C': 2, 'GOAL D': 7}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2033
# [DEBUG] Gross Gains (Normal account): 996991.91
# [DEBUG] Tax Calculated (Normal account): 408611.60
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           67.35
#    B            0.00
#    C            1.02
#    D           31.63
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.667248       647568.860250           66.72
#         Developed Markets - Equities 0.004157         4034.864329            0.42
# Emerging Markets State - Obligations 0.006198         6015.372567            0.62
#       High Yield Bonds - Obligations 0.000218          211.195890            0.02
# Investment Grade Bonds - Obligations 0.010540        10228.748278            1.05
#    Government ZC Bonds - Obligations 0.311639       302448.088524           31.16
#
# Utility:
# [0.44708733 0.38068858 0.51703546 ... 0.51303576 0.50572937 0.49632272]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5251
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = N
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2033
#
# --- Year 2033 Summary ---
# Income (Salary): 68172.87
# Previous Wealth Carried: 902334.26
# Post-Tax Wealth (New Final Wealth): 970507.13
# ------------------------------
#
# 2034 10 34 49
# Starting Year: 2025
# Current Year: 2034
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 41, 'GOAL B': -4, 'GOAL C': 1, 'GOAL D': 6}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2034
# [DEBUG] Gross Gains (Normal account): 2089777.12
# [DEBUG] Tax Calculated (Normal account): 867581.39
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           78.57
#    B            0.00
#    C            1.02
#    D           20.41
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.776877        1.264555e+06           77.69
#         Developed Markets - Equities 0.010042        1.634538e+04            1.00
# Emerging Markets State - Obligations 0.004579        7.453429e+03            0.46
#       High Yield Bonds - Obligations 0.000905        1.473236e+03            0.09
# Investment Grade Bonds - Obligations 0.007229        1.176630e+04            0.72
#    Government ZC Bonds - Obligations 0.200369        3.261490e+05           20.04
#
# Utility:
# [0.54497997 0.36977884 0.65158795 ... 0.46361375 0.55627347 0.59754641]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5972
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = N
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2034
#
# --- Year 2034 Summary ---
# Income (Salary): 68854.60
# Previous Wealth Carried: 1558887.43
# Post-Tax Wealth (New Final Wealth): 1627742.03
# ------------------------------
#
# 2035 11 35 50
# Starting Year: 2025
# Current Year: 2035
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 40, 'GOAL B': -5, 'GOAL C': 0, 'GOAL D': 5}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2035
# [DEBUG] Gross Gains (Normal account): 2556477.69
# [DEBUG] Tax Calculated (Normal account): 1063595.63
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           88.66
#    B            0.00
#    C            0.00
#    D           11.34
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.228635        6.674951e+05           22.86
#         Developed Markets - Equities 0.640948        1.871236e+06           64.09
# Emerging Markets State - Obligations 0.007807        2.279277e+04            0.78
#       High Yield Bonds - Obligations 0.010743        3.136310e+04            1.07
# Investment Grade Bonds - Obligations 0.000219        6.399533e+02            0.02
#    Government ZC Bonds - Obligations 0.111648        3.259545e+05           11.16
#
# Utility:
# [0.61487465 0.46631264 0.47761792 ... 0.60399912 0.33712898 0.6426163 ]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.5994
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = N
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2035
#
# --- Year 2035 Summary ---
# Income (Salary): 69543.15
# Previous Wealth Carried: 2849937.77
# Post-Tax Wealth (New Final Wealth): 2919480.92
# ------------------------------
#
# 2036 12 36 51
# Starting Year: 2025
# Current Year: 2036
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 39, 'GOAL B': -6, 'GOAL C': -1, 'GOAL D': 4}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2036
# [DEBUG] Gross Gains (Normal account): 2167926.37
# [DEBUG] Tax Calculated (Normal account): 900404.08
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           90.53
#    B            0.00
#    C            0.00
#    D            9.47
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.225419        1.012033e+06           22.54
#         Developed Markets - Equities 0.653130        2.932265e+06           65.31
# Emerging Markets State - Obligations 0.003688        1.655928e+04            0.37
#       High Yield Bonds - Obligations 0.009526        4.276850e+04            0.95
# Investment Grade Bonds - Obligations 0.007577        3.401673e+04            0.76
#    Government ZC Bonds - Obligations 0.100659        4.519125e+05           10.07
#
# Utility:
# [0.2780895  0.62057099 0.69200317 ... 0.61019252 0.57971369 0.57262702]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.6586
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = Y
# Row 13: Year = 2036, Status = N
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2036
#
# --- Year 2036 Summary ---
# Income (Salary): 77192.90
# Previous Wealth Carried: 4412362.97
# Post-Tax Wealth (New Final Wealth): 4489555.87
# ------------------------------
#
# 2037 13 37 52
# Starting Year: 2025
# Current Year: 2037
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 38, 'GOAL B': -7, 'GOAL C': -2, 'GOAL D': 3}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2037
# [DEBUG] Gross Gains (Normal account): 2964097.49
# [DEBUG] Tax Calculated (Normal account): 1234795.95
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           93.88
#    B            0.00
#    C            0.00
#    D            6.12
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.188815        1.101742e+06           18.88
#         Developed Markets - Equities 0.360722        2.104826e+06           36.07
# Emerging Markets State - Obligations 0.000707        4.127183e+03            0.07
#       High Yield Bonds - Obligations 0.004200        2.450924e+04            0.42
# Investment Grade Bonds - Obligations 0.006706        3.913114e+04            0.67
#    Government ZC Bonds - Obligations 0.438850        2.560708e+06           43.88
#
# Utility:
# [0.70308219 0.69847906 0.54351775 ... 0.50387183 0.64910189 0.63739277]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.7088
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = Y
# Row 13: Year = 2036, Status = Y
# Row 14: Year = 2037, Status = N
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2037
#
# --- Year 2037 Summary ---
# Income (Salary): 77964.82
# Previous Wealth Carried: 5757078.16
# Post-Tax Wealth (New Final Wealth): 5835042.99
# ------------------------------
#
# 2038 14 38 53
# Starting Year: 2025
# Current Year: 2038
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 37, 'GOAL B': -8, 'GOAL C': -3, 'GOAL D': 2}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2038
# [DEBUG] Gross Gains (Normal account): -746508.29
# [DEBUG] Tax Calculated (Normal account): -201557.24
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           95.92
#    B            0.00
#    C            0.00
#    D            4.08
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.002676        2.044921e+04            0.27
#         Developed Markets - Equities 0.003863        2.952872e+04            0.39
# Emerging Markets State - Obligations 0.003491        2.668239e+04            0.35
#       High Yield Bonds - Obligations 0.003568        2.726709e+04            0.36
# Investment Grade Bonds - Obligations 0.002268        1.733533e+04            0.23
#    Government ZC Bonds - Obligations 0.984134        7.521826e+06           98.41
#
# Utility:
# [0.65811436 0.78385456 0.6500164  ... 0.71111907 0.64202556 0.72189662]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 1.0000
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = Y
# Row 13: Year = 2036, Status = Y
# Row 14: Year = 2037, Status = Y
# Row 15: Year = 2038, Status = N
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2038
#
# --- Year 2038 Summary ---
# Income (Salary): 78744.47
# Previous Wealth Carried: 7564344.54
# Post-Tax Wealth (New Final Wealth): 7643089.01
# ------------------------------
#
# 2039 15 39 54
# Starting Year: 2025
# Current Year: 2039
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 36, 'GOAL B': -9, 'GOAL C': -4, 'GOAL D': 1}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2039
# [DEBUG] Gross Gains (Normal account): 1449233.09
# [DEBUG] Tax Calculated (Normal account): 598552.90
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           93.81
#    B            0.00
#    C            0.00
#    D            6.19
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.164651        1.148625e+06           16.47
#         Developed Markets - Equities 0.225635        1.574053e+06           22.56
# Emerging Markets State - Obligations 0.010251        7.151353e+04            1.03
#       High Yield Bonds - Obligations 0.010761        7.507051e+04            1.08
# Investment Grade Bonds - Obligations 0.015805        1.102576e+05            1.58
#    Government ZC Bonds - Obligations 0.572897        3.996593e+06           57.29
#
# Utility:
# [0.66547602 0.70870235 0.74796324 ... 0.65852627 0.34557332 0.58285338]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.7451
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 1.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = Y
# Row 13: Year = 2036, Status = Y
# Row 14: Year = 2037, Status = Y
# Row 15: Year = 2038, Status = Y
# Row 16: Year = 2039, Status = N
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2039
#
# --- Year 2039 Summary ---
# Income (Salary): 79531.92
# Previous Wealth Carried: 6896580.72
# Post-Tax Wealth (New Final Wealth): 6976112.64
# ------------------------------
#
# 2040 16 40 55
# Starting Year: 2025
# Current Year: 2040
# Goal Years: {'GOAL A': 2075, 'GOAL B': 2030, 'GOAL C': 2035, 'GOAL D': 2040}
# Adjusted Horizons: {'GOAL A': 35, 'GOAL B': -10, 'GOAL C': -5, 'GOAL D': 0}
# [DEBUG] Final weight sum: 1.0000000000
# [DEBUG] Year: 2040
# [DEBUG] Gross Gains (Normal account): 1843183.27
# [DEBUG] Tax Calculated (Normal account): 764011.97
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           100.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Invested Amt (DKK)  Allocation (%)
#          Emerging Markets - Equities 0.177479        1.351512e+06           17.75
#         Developed Markets - Equities 0.199242        1.517243e+06           19.92
# Emerging Markets State - Obligations 0.020305        1.546271e+05            2.03
#       High Yield Bonds - Obligations 0.013485        1.026892e+05            1.35
# Investment Grade Bonds - Obligations 0.044457        3.385439e+05            4.45
#    Government ZC Bonds - Obligations 0.545032        4.150458e+06           54.50
#
# Utility:
# [0.6296708  0.3827729  0.39710174 ... 0.60609187 0.32888422 0.66175843]
#
# Probability of Achieving Each Goal at Optimal Allocation:
# Goal A: 0.7641
# Goal B: 0.0000
# Goal C: 0.0000
# Goal D: 0.0000
# Starting loop status check (in-memory)...
# Row 8: Year = 2031, Status = Y
# Row 9: Year = 2032, Status = Y
# Row 10: Year = 2033, Status = Y
# Row 11: Year = 2034, Status = Y
# Row 12: Year = 2035, Status = Y
# Row 13: Year = 2036, Status = Y
# Row 14: Year = 2037, Status = Y
# Row 15: Year = 2038, Status = Y
# Row 16: Year = 2039, Status = Y
# Row 17: Year = 2040, Status = N
# ✅ LoopStatus updated to 'Y' for Year 2040
#
# --- Year 2040 Summary ---
# Income (Salary): 88280.43
# Previous Wealth Carried: 7526792.83
# Post-Tax Wealth (New Final Wealth): 7615073.26
# ------------------------------
#
# All loops completed

# %%
# V7C: Export new asset-level log for debugging
pd.DataFrame(asset_level_log).to_csv(os.path.join(output_folder, "asset_returns_log.csv"), index=False)

#V12 moved finalwealth to python
pd.DataFrame.from_dict(final_wealth_tracker, orient='index', columns=['Final Wealth']).to_csv(
    os.path.join(output_folder, "final_wealth_by_year.csv")
)

#V15
pd.DataFrame(goal_weights_tracker).to_csv(
    os.path.join(output_folder, "goal_weights_by_year.csv"), index=False
)

pd.DataFrame(aggregate_portfolio_tracker).to_csv(
    os.path.join(output_folder, "aggregate_portfolio_by_year.csv"), index=False
)

# V15: Save optimal_weights for Goals A–D
for goal_letter, matrix_dict in zip(
    ["A", "B", "C", "D"],
    [goal_optimal_weights_A, goal_optimal_weights_B, goal_optimal_weights_C, goal_optimal_weights_D]
):
    all_dfs = []
    for year, mat in matrix_dict.items():
        df = pd.DataFrame(mat)
        df.insert(0, "Year", year)
        df.insert(1, "Allocation Level", np.arange(0.01, 1.01, 0.01))
        all_dfs.append(df)

    df_all = pd.concat(all_dfs, ignore_index=True)
    df_all.to_csv(os.path.join(output_folder, f"optimal_weights_goal_{goal_letter}.csv"), index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[145], line 2
#       1 # V7C: Export new asset-level log for debugging
# ----> 2 pd.DataFrame(asset_level_log).to_csv(os.path.join(output_folder, "asset_returns_log.csv"), index=False)
#       4 #V12 moved finalwealth to python
#       5 pd.DataFrame.from_dict(final_wealth_tracker, orient='index', columns=['Final Wealth']).to_csv(
#       6     os.path.join(output_folder, "final_wealth_by_year.csv")
#       7 )
#
# File ~\anaconda3\envs\Thesis\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\Thesis\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\anaconda3\envs\Thesis\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\envs\Thesis\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\anaconda3\envs\Thesis\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'C:/Users/admin/Desktop/Thesis New/AEF_thesis_GBI\\GBI Optimisation\\asset_returns_log.csv'
