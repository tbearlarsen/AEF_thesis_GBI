# %% [markdown]
# # Visualising goal performance

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from codelib.Visuals.portfolio_probabilities import plot_percentage_distribution_for_goal

# %% [markdown]
# ## P1

# %%
data_path=r"/Users/osito/Library/CloudStorage/OneDrive-SharedLibraries-CBS-CopenhagenBusinessSchool/Thesis - General/Modelling/P1/P1_outputs_path_0_to_50/goal_redemption_details.csv"

# %%
plot_percentage_distribution_for_goal(data_path,"A")

# %%
plot_percentage_distribution_for_goal(data_path,"B")

# %%
plot_percentage_distribution_for_goal(data_path,"C")

# %%
plot_percentage_distribution_for_goal(data_path,"D")

# %% [markdown]
# ## P2

# %%
data_path=r"/Users/osito/Library/CloudStorage/OneDrive-SharedLibraries-CBS-CopenhagenBusinessSchool/Thesis - General/Modelling/P2/P2_outputs_path_0_to_50/goal_redemption_details.csv"

# %%
plot_percentage_distribution_for_goal(data_path,"A")

# %%
plot_percentage_distribution_for_goal(data_path,"B")

# %%
plot_percentage_distribution_for_goal(data_path,"C")

# %%
plot_percentage_distribution_for_goal(data_path,"D")
