# %% [markdown]
# V1 (02 11 2025): Translated from R to Python and added the visualizations for goals B to D
#
#
# V2 (04 01 2025): Loop system implemented
#
# V2.5 (04 02 2025): Loops system tweaks. Removed openpyxl as it was corrupting files and replaced it with xlwings
#
# V3 & V4 finalize the loop except for the tax and asset channel
#
# V5 & V6 Add the tax system and aktiesparekonto pools, aka true dynamic wealth in calculations
#
# V7 Incorporates two stage system for returns, sd and correlations based on the afkvastforventing

# %%
#!pip install numpy pandas scipy matplotlib xlwings

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import subprocess
import xlwings as xw
import time

# %%
# -- Variable Setup -- ##

#Monte Carlo Trials
n_trials = 10**5

#Case Study Profile Selection
Profile = "P1" #Either P1 or P2

#Excel worksheets
excel_returns = "Returns"
excel_volatilities = "Volatilities"
excel_correlation = "Correlation"
excel_gbi = "GBI Allocations P1" if Profile == "P1" else "GBI Allocations P2"
excel_gbi_goals = "GBI Goals P1" if Profile == "P1" else "GBI Goals P2"

# %% [markdown]
# # Define Functions
# This section defines the functions used for calculating portfolio volatility, expected return,
# goal achievement probability, and the objective (failure probability) to minimize.

# %%
def sd_f(weight_vector, covar_table):
    covar_vector = np.zeros(len(weight_vector))
    for z in range(len(weight_vector)):
        covar_vector[z] = np.sum(weight_vector * covar_table[:, z])
    return np.sqrt(np.sum(weight_vector * covar_vector))

# %%
def mean_f(weight_vector, return_vector):
    return np.sum(weight_vector * return_vector)

# %%
"""def phi_f(goal_vector, goal_allocation, pool, mean, sd):
    # goal_vector is [value ratio, funding requirement, time horizon]
    required_return = (goal_vector[1] / (pool * goal_allocation))**(1 / goal_vector[2]) - 1
    if goal_allocation * pool >= goal_vector[1]:
        return 1
    else:
        return 1 - norm.cdf(required_return, loc=mean, scale=sd)

""" #Made new version below that takes into account cases where the goal is too unreachable and writes down when that happens

def phi_f(goal_vector, goal_allocation, pool, mean, sd, year=None, goal_name=None):
    denominator = pool * goal_allocation
    if denominator <= 0:
        if year and goal_name:
            infeasible_goals_log.append((year, goal_name, "Zero allocation or pool"))
        return 0

    required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1

    if required_return > 1:
        if year and goal_name:
            infeasible_goals_log.append((year, goal_name, f"Required return > 100% ({required_return:.2%})"))
        return 0

    if denominator >= goal_vector[1]:
        return 1

    return 1 - norm.cdf(required_return, loc=mean, scale=sd)

# %%
def optim_function(weights):
    # Uses the current global variables: goal_vector, allocation, pool, return_vector, covar_table
    return 1 - phi_f(
        goal_vector,
        allocation,
        pool,
        mean_f(weights, return_vector),
        sd_f(weights, covar_table)
    )

# %%
def constraint_function(weights):
    # For SciPy equality constraints, we require constraint_function(weights) == 0.
    return np.sum(weights) - 1

# %%
def mvu_f(weights):
    # mvu_f is defined for mean-variance optimization (not used below).
    return -(mean_f(weights, return_vector) - 0.5 * gamma * sd_f(weights, covariances)**2)

# %%
def r_req_f(goal_vector, goal_allocation, pool):
    return (goal_vector[1] / (goal_allocation * pool))**(1 / goal_vector[2]) - 1

# %%
def get_goal_data(master_excel_path, plan=Profile):
    """
    Returns a DataFrame of the specified goal table (P1 or P2).
    P1 => B2:F5
    P2 => B7:F10
    """
    if plan == "P1":
        skip = 1  # start reading at row 2
    elif plan == "P2":
        skip = 6  # start reading at row 7
    else:
        raise ValueError("Plan not recognized. Use 'P1' or 'P2'.")

    df_goals = pd.read_excel(master_excel_path,sheet_name="Goals",skiprows=skip,nrows=4,usecols="B:F",header=0)
    # First column is "Goal Info", so make that the index
    df_goals.set_index(df_goals.columns[0], inplace=True)
    return df_goals

# %% [markdown]
# # Load & Parse Data

# %%
## -- Repo Root and Folders -- ##

# Get repo root and set folders
root = subprocess.run(["git", "rev-parse", "--show-toplevel"], capture_output=True, text=True).stdout.strip()
data_folder = os.path.join(root, "GBI Optimisation", "data")
output_folder = os.path.join(root, "GBI Optimisation")
# Get excel file and sheets

master_excel_path = os.path.join(data_folder, "Master.xlsx")

# %%
# - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #

# Initialize tracker for account allocations
all_account_allocations = []

# Aktiesparekonto cap
aktiesparekonto_cap = 166200
aktiesparekonto_used_total = 0

# %%
infeasible_goals_log = [] #Added for the new phi_f definition
tax_log = [] # - V6 - Added for following the tax stuff

while True:
    ## -- Loop Table -- ##
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop",usecols="B:F",skiprows=1,header=0)
    # Find Last looped year and select the next one
    # Filter only rows where LoopStatus is N
    pending_rows = table_loop_df[table_loop_df["LoopStatus"] == "N"]

    # If we find any rows, get the row with the lowest Year
    if pending_rows.empty:
        print("All loops completed")
        break


    chosen_row = pending_rows.loc[pending_rows["Year"].idxmin()]
    loop_year = chosen_row["Year"]
    loop_number = chosen_row["N"]
    loop_age1 = chosen_row["AgeP1"]
    loop_age2 = chosen_row["AgeP2"]

    print(loop_year, loop_number, loop_age1, loop_age2)

    # - Wealth - #

    # -- V7: Load correct data sheets based on current loop year -- #
    if loop_year <= 2034:
        excel_returns = "Returns"
        excel_volatilities = "Volatilities"
        excel_correlation = "Correlation"
    else:
        excel_returns = "Returns2"
        excel_volatilities = "Volatilities2"
        excel_correlation = "Correlation2"

    # Load capital market data
    df_returns = pd.read_excel(master_excel_path, sheet_name=excel_returns)
    df_vols = pd.read_excel(master_excel_path, sheet_name=excel_volatilities)
    df_corr = pd.read_excel(master_excel_path, sheet_name=excel_correlation)

    df_returns.set_index(df_returns.columns[0], inplace=True)
    df_vols.set_index(df_vols.columns[0], inplace=True)
    df_corr.set_index(df_corr.columns[0], inplace=True)

    # - End of V7 Addition - #

    # -- Load wealth info for the current loop year -- #
    df_wealth = pd.read_excel(master_excel_path, sheet_name="Salary")
    df_wealth.set_index(df_wealth.columns[0], inplace=True)
    # - V7 change so the income is added beginning of year - #
    income = df_wealth.loc[Profile, str(loop_year)] if str(loop_year) in df_wealth.columns else 0
    if loop_year == starting_year:
        pool = income  # Initialize pool in the first year
    else:
        pool += income  # Add income to existing pool
    # End of v7

    capital_market_expectations_raw = {}
    for asset in df_returns.index:
        expected_return = df_returns.loc[asset, str(loop_year)]
        volatility = df_vols.loc[asset, 'volatility']
        capital_market_expectations_raw[asset] = {
            'Return Forecast': expected_return,
            'Volatility Forecast': volatility
        }

    capital_market_expectations_raw = pd.DataFrame.from_dict(capital_market_expectations_raw, orient='index')

    capital_market_expectations_raw = capital_market_expectations_raw.reset_index()
    capital_market_expectations_raw.rename(columns={'index': 'Unnamed: 0'}, inplace=True)

    # Rearrange columns to match your old format (optional):
    capital_market_expectations_raw = capital_market_expectations_raw[['Unnamed: 0', 'Return Forecast', 'Volatility Forecast']]

    goal_data_raw = get_goal_data(master_excel_path, plan="P1")

    # - Dynamic time horizon based on current year - #

    # Step 1: Get Starting Year (minimum year in Loop sheet)
    starting_year = table_loop_df["Year"].min()

    # Step 2: Compute Goal Years = starting_year + time_horizon
    goal_horizons = goal_data_raw.loc["Time Horizon"].astype(int)
    goal_years = starting_year + goal_horizons

    # Step 3: Recalculate Time Horizons = goal_years - current loop_year
    adjusted_horizons = goal_years - loop_year

    # Step 4: Replace the "Time Horizon" row in goal_data_raw
    goal_data_raw.loc["Time Horizon"] = adjusted_horizons

    goals = ["A", "B", "C", "D"]
    active_goal_mask = np.array([adjusted_horizons[f"GOAL {g}"] > 0 for g in goals])

    # Optional: print to confirm
    print("Starting Year:", starting_year)
    print("Current Year:", loop_year)
    print("Goal Years:", goal_years.to_dict())
    print("Adjusted Horizons:", adjusted_horizons.to_dict())

    # - NEW V6 CONTENT REGARDING TAXATION # -
    # Track asset values and cost basis
    if loop_year == starting_year:
        portfolio_book = {}  # dict of form {(account_type, asset): [amount_invested, current_value]}
    else:
        # Carry forward previous year values (from last loop)
        portfolio_book = portfolio_book_last_year.copy()
    # - END OF V6 - #

    # Record number of potential investments and goals
    num_assets = capital_market_expectations_raw.shape[0]
    num_goals = goal_data_raw.shape[1]

    # Create vector of expected returns
    return_vector = capital_market_expectations_raw["Return Forecast"].to_numpy()

    # Get the correlations as a numeric DataFrame (just a num_assets × num_assets block)
    correlations = df_corr.iloc[:num_assets, :num_assets].astype(float)

    # Build the covariance matrix: stdev_i * stdev_j * correlation_ij
    stdevs = capital_market_expectations_raw["Volatility Forecast"].to_numpy()
    covariances = np.zeros((num_assets, num_assets))
    for i in range(num_assets):
        for j in range(num_assets):
            covariances[i, j] = stdevs[i] * stdevs[j] * correlations.iloc[i, j]

    goal_A = goal_data_raw["GOAL A"].values
    goal_B = goal_data_raw["GOAL B"].values
    goal_C = goal_data_raw["GOAL C"].values
    goal_D = goal_data_raw["GOAL D"].values

    # - Optimal Goal Allocation - #


    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    goal_allocation = np.arange(0.01, 1.01, 0.01)

    # Starting weights (random initialization normalized to sum to 1)
    starting_weights = np.random.uniform(0, 1, num_assets)
    starting_weights /= np.sum(starting_weights)

    # Initialize matrices to store the optimal weights for each goal
    optimal_weights_A = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_B = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_C = np.zeros((len(goal_allocation), num_assets))
    optimal_weights_D = np.zeros((len(goal_allocation), num_assets))

    # Set SLSQP options to be more stringent, mimicking solnp's behavior.
    slsqp_opts = {
        'ftol': 1e-12,     # function tolerance
        'eps': 1e-12,      # finite-difference step size for gradient estimation
        'maxiter': 10000,  # maximum iterations
        'disp': False     # do not display convergence messages
    }

    for i, alloc in enumerate(goal_allocation):
        allocation = alloc      # Global variable used in optim_function
        covar_table = covariances

        # Goal A Optimization
        goal_vector = goal_A   # Global variable used in optim_function
        if goal_A[1] <= pool * allocation:
            optimal_weights_A[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_A[i, :] = result.x

        # Goal B Optimization
        goal_vector = goal_B
        if goal_B[1] <= pool * allocation:
            optimal_weights_B[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_B[i, :] = result.x

        # Goal C Optimization
        goal_vector = goal_C
        if goal_C[1] <= pool * allocation:
            optimal_weights_C[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_C[i, :] = result.x

        # Goal D Optimization
        goal_vector = goal_D
        if goal_D[1] <= pool * allocation:
            optimal_weights_D[i, :] = [0]*(num_assets - 1) + [1]
        else:
            result = minimize(
                optim_function,
                starting_weights,
                constraints=[{'type': 'eq', 'fun': constraint_function}],
                bounds=[(0, 1)] * num_assets,
                method='SLSQP',
                options=slsqp_opts
            )
            optimal_weights_D[i, :] = result.x

    # Calculate the best probability (phi) for each allocation level for every goal
    phi_A = np.zeros(len(goal_allocation))
    phi_B = np.zeros(len(goal_allocation))
    phi_C = np.zeros(len(goal_allocation))
    phi_D = np.zeros(len(goal_allocation))

    for i, alloc in enumerate(goal_allocation):
        phi_A[i] = phi_f(goal_A, alloc, pool,
                         mean_f(optimal_weights_A[i, :], return_vector),
                         sd_f(optimal_weights_A[i, :], covariances), year=loop_year, goal_name="Goal A")
        phi_B[i] = phi_f(goal_B, alloc, pool,
                         mean_f(optimal_weights_B[i, :], return_vector),
                         sd_f(optimal_weights_B[i, :], covariances), year=loop_year, goal_name="Goal B")
        phi_C[i] = phi_f(goal_C, alloc, pool,
                         mean_f(optimal_weights_C[i, :], return_vector),
                         sd_f(optimal_weights_C[i, :], covariances), year=loop_year, goal_name="Goal C")
        phi_D[i] = phi_f(goal_D, alloc, pool,
                         mean_f(optimal_weights_D[i, :], return_vector),
                         sd_f(optimal_weights_D[i, :], covariances), year=loop_year, goal_name="Goal D")

    # Simulate goal weights: each row is a simulated allocation (in percentages)
    sim_goal_weights = np.random.multinomial(100, [1/num_goals]*num_goals, size=n_trials) #this one sums to 100 so its good
    for i in range(n_trials):
        rand_vector = np.random.uniform(0, 1, num_goals)
        normalizer = np.sum(rand_vector)
        percents = np.round((rand_vector / normalizer) * 100, 0)

        # Only enforce floor for active goals
        floor_applied = np.where(active_goal_mask, np.maximum(percents, 1), percents)
        sim_goal_weights[i, :] = floor_applied


    # Calculate utility for each simulated portfolio.
    # Note: subtract 1 from simulated weights for 0-indexing.
    utility = (
        goal_A[0] * phi_A[sim_goal_weights[:, 0] - 1] +
        goal_A[0] * goal_B[0] * phi_B[sim_goal_weights[:, 1] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * phi_C[sim_goal_weights[:, 2] - 1] +
        goal_A[0] * goal_B[0] * goal_C[0] * goal_D[0] * phi_D[sim_goal_weights[:, 3] - 1]
    )

    # Find the index of the portfolio with the highest utility
    index = np.argmax(utility)
    optimal_goal_weights = sim_goal_weights[index, :]

    # - Optimal Subportfolio Allocation - #

    # Retrieve optimal subportfolio allocations
    optimal_subportfolios = np.zeros((num_goals, num_assets))

    # For each goal, use the simulated percentage to select the corresponding row
    # from the optimal weights matrix (adjust for zero-indexing)
    for i in range(num_goals):
        optimal_subportfolios[i, :] = eval(f"optimal_weights_{goals[i]}")[optimal_goal_weights[i] - 1, :]

    # Compute the optimal aggregate investment portfolio.
    optimal_aggregate_portfolio = (optimal_goal_weights / 100) @ optimal_subportfolios

    #Define asset names
    asset_names = capital_market_expectations_raw.iloc[:, 0].astype(str).tolist()

    # - Storing and exporting results - #

    # Create a DataFrame for the aggregate portfolio.
    # First calculate unrounded percentages
    raw_alloc = optimal_aggregate_portfolio * 100

    # Normalize to force sum = 100 after rounding
    normalized_alloc = raw_alloc / raw_alloc.sum() * 100
    normalized_goal_alloc = np.zeros_like(optimal_goal_weights, dtype=float)
    active_sum = np.sum(optimal_goal_weights[active_goal_mask])
    normalized_goal_alloc[active_goal_mask] = (optimal_goal_weights[active_goal_mask] / active_sum) * 100

    # Create a DataFrame for the across-goal allocation.
    df_across_goal = pd.DataFrame({
        "Goal": goals,
        "Allocation (%)": np.round(normalized_goal_alloc, 2) # Keep raw percentages
    })

    # Round after normalization
    df_aggregate = pd.DataFrame({
        "Asset": asset_names,
        "Weight": optimal_aggregate_portfolio,
        "Allocation (%)": np.round(normalized_alloc, 2)
    })

    # - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #
    account_allocations = []

    for i, row in df_aggregate.iterrows():
        asset_name = row["Asset"]
        weight = row["Weight"]
        allocation_value = weight * pool  # actual money invested this year

        if "Equities" in asset_name:
            remaining_cap = aktiesparekonto_cap - aktiesparekonto_used_total
            if remaining_cap > 0:
                invested_in_ask = min(allocation_value, remaining_cap)
                invested_in_normal = allocation_value - invested_in_ask
                aktiesparekonto_used_total += invested_in_ask
            else:
                invested_in_ask = 0
                invested_in_normal = allocation_value
        else:
            invested_in_ask = 0
            invested_in_normal = allocation_value

        account_allocations.append({
            "Year": loop_year,
            "Asset": asset_name,
            "ASK (DKK)": invested_in_ask,
            "Normal (DKK)": invested_in_normal
        })

    df_accounts = pd.DataFrame(account_allocations)
    all_account_allocations.append(df_accounts)

    # - V5 END - #

    # - NEW V6 CONTENT REGARDING GAINS & TAXES - #

    total_gains_ask = 0
    total_gains_normal = 0
    share_income_normal = 0  # for progressive tax
    tax_ask = 0  # Track ASK tax separately

    # Update portfolio and compute gains
    if not account_allocations:
        account_allocations = [{
            "Year": loop_year,
            "Asset": asset,
            "ASK (DKK)": 0,
            "Normal (DKK)": 0
        } for asset in asset_names]

    for row in account_allocations:
        asset = row["Asset"]
        ask = row["ASK (DKK)"]
        normal = row["Normal (DKK)"]
        expected_return = capital_market_expectations_raw.loc[
            capital_market_expectations_raw["Unnamed: 0"] == asset,
            "Return Forecast"
        ].values[0]

        # Aktiesparekonto
        prev_amt, prev_val = portfolio_book.get(("ASK", asset), [0, 0])
        new_val = prev_val * (1 + expected_return) + ask
        gain = new_val - (prev_val + ask)
        tax = 0.17 * gain if gain > 0 else 0
        tax_ask += tax
        total_gains_ask += (gain - tax)
        portfolio_book[("NORMAL", asset)] = [prev_amt + normal, new_val]

        # Normal Account
        prev_amt, prev_val = portfolio_book.get(("NORMAL", asset), [0, 0])
        new_val = prev_val * (1 + expected_return) + normal
        gain = new_val - (prev_val + normal)
        share_income_normal += gain
        portfolio_book[("NORMAL", asset)] = [prev_amt + normal, new_val]

    # Tax on Normal Account (progressive)
    cap = 67500
    if share_income_normal <= cap:
        tax_normal = 0.27 * share_income_normal
    else:
        tax_normal = 0.27 * cap + 0.42 * (share_income_normal - cap)
    total_gains_normal = share_income_normal - tax_normal

    # Adjust wealth by net gains
    net_gains = total_gains_ask + total_gains_normal
    pool += net_gains

    # - V7: Improving tax log output - #
    # Calculate total account values
    total_ask = sum(val for (acct, _), (_, val) in portfolio_book.items() if acct == "ASK")
    total_normal = sum(val for (acct, _), (_, val) in portfolio_book.items() if acct == "NORMAL")
    investment_wealth = total_ask + total_normal

    # Get income from salary table if available
    try:
        income = df_wealth.loc[Profile, str(loop_year)]
    except KeyError:
        income = 0

    tax_log.append({
        "Year": loop_year,
        "Gains ASK (gross)": total_gains_ask + tax_ask,
        "Tax ASK": tax_ask,
        "Gains Normal (gross)": share_income_normal,
        "Tax Normal": tax_normal,
        "Net Gains": net_gains,
        "Post-Tax Wealth": pool,
        "Income": income,
        "Investment Wealth": investment_wealth,
        "ASK Value": total_ask,
        "Normal Value": total_normal
    })
    # - V7 End - #

    # - END OF V6 GAINS/TAX BLOCK - #

    print("Optimal Across-Goal Allocation:")
    print(df_across_goal.to_string(index=False))

    print("\nOptimal Aggregate Investment Allocation:")
    print(df_aggregate.to_string(index=False))

    # -- Safer Excel launch --
    app = xw.App(visible=False)
    app.display_alerts = False
    app.screen_updating = False

    time.sleep(1)

    # Open workbook
    wb = app.books.open(master_excel_path)
    ws = wb.sheets[excel_gbi]

    # Get header values from row 1 (columns B to AY ~= cols 2 to 51)
    header_values = [ws.cells(1, col).value for col in range(2, 53)]

    try:
        year_col = header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in worksheet headers.")

    # Write weights, modified in V7 to fix the export for the second stage to equities and obligations
    for i, asset in enumerate(asset_names):
        allocation = float(np.round(normalized_alloc[i], 2)) / 100
        cell_row = i + 2  # default row 2 onwards
        if set(asset_names) == {"Equities", "Obligations"}:
            cell_row = i + 8  # write to row 8/9 instead
        cell = ws.cells(cell_row, year_col)
        cell.value = allocation
        cell.number_format = '0.00%'


    # -- Export Goal Weights to Excel -- #

    # Re-access the sheet after workbook is open
    ws_goals = wb.sheets[excel_gbi_goals]

    # Read header values from row 1 (columns B to AY ≈ cols 2 to 52)
    goal_header_values = [ws_goals.cells(1, col).value for col in range(2, 53)]

    try:
        goal_year_col = goal_header_values.index(str(loop_year)) + 2
    except ValueError:
        raise ValueError(f"Year {loop_year} not found in goal worksheet headers.")

    # Write each across-goal allocation to the appropriate row
    for i, allocation in enumerate(df_across_goal["Allocation (%)"]):
        value = float(np.round(allocation / 100, 6))  # convert to decimal
        row = i + 2  # assuming goal names are in rows starting at 2
        cell = ws_goals.cells(row, goal_year_col)
        cell.value = value
        cell.number_format = '0.00%'  # display as percentage

    # -- Modify Loop Check -- #
    print("Starting loop status check...")

    ws_loop = wb.sheets["Loop"]
    print("Accessed 'Loop' worksheet.")

    # Read data range again (columns B to F)
    last_row = ws_loop.cells.last_cell.row
    print(f"Last cell row: {last_row}")

    loop_data = ws_loop.range("B2:F" + str(last_row)).value
    print(f"Loaded loop data. Total rows read: {len(loop_data)}")

    # Find and update the matching year with LoopStatus 'N'
    found = False
    for i, row in enumerate(loop_data):
        year = row[1]
        status = row[4]
        print(f"Row {i+2}: Year = {year}, Status = {status}")
        if year == loop_year and status == 'N':
            print(f"Match found at row {i+2}. Updating status to 'Y'.")
            ws_loop.cells(i + 2, 6).value = 'Y'  # Column F is column 6
            found = True
            break

    if not found:
        print(f"No matching row found for year {loop_year} with status 'N'.")
    else:
        print("Status updated successfully.")

    wb.save()
    wb.close()
    app.quit()
    time.sleep(1)
    portfolio_book_last_year = portfolio_book.copy() # - V6 - Save portfolio state for next iteration
    table_loop_df = pd.read_excel(master_excel_path, sheet_name="Loop", usecols="B:F", skiprows=1, header=0)
# Out:
# 2026 2 26 41
# Starting Year: 2025
# Current Year: 2026
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 9, 'GOAL B': 14, 'GOAL C': 19, 'GOAL D': 49}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             1.0
#    B            72.0
#    C            19.0
#    D             8.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.272485           27.25
#         Developed Markets - Equities 0.002557            0.26
# Emerging Markets State - Obligations 0.002444            0.24
#       High Yield Bonds - Obligations 0.000153            0.02
# Investment Grade Bonds - Obligations 0.001090            0.11
#    Government ZC Bonds - Obligations 0.721271           72.13
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = N
# Match found at row 4. Updating status to 'Y'.
# Status updated successfully.
# 2027 3 27 42
# Starting Year: 2025
# Current Year: 2027
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 8, 'GOAL B': 13, 'GOAL C': 18, 'GOAL D': 48}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           78.22
#    B           18.81
#    C            0.99
#    D            1.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 1.002710           99.28
#         Developed Markets - Equities 0.001586            0.16
# Emerging Markets State - Obligations 0.001796            0.18
#       High Yield Bonds - Obligations 0.002204            0.22
# Investment Grade Bonds - Obligations 0.001583            0.16
#    Government ZC Bonds - Obligations 0.000120            0.01
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = N
# Match found at row 5. Updating status to 'Y'.
# Status updated successfully.
# 2028 4 28 43
# Starting Year: 2025
# Current Year: 2028
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 7, 'GOAL B': 12, 'GOAL C': 17, 'GOAL D': 47}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           86.27
#    B           11.76
#    C            0.98
#    D            0.98
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 1.012036           99.22
#         Developed Markets - Equities 0.001986            0.19
# Emerging Markets State - Obligations 0.000752            0.07
#       High Yield Bonds - Obligations 0.001852            0.18
# Investment Grade Bonds - Obligations 0.001739            0.17
#    Government ZC Bonds - Obligations 0.001635            0.16
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = N
# Match found at row 6. Updating status to 'Y'.
# Status updated successfully.
# 2029 5 29 44
# Starting Year: 2025
# Current Year: 2029
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 6, 'GOAL B': 11, 'GOAL C': 16, 'GOAL D': 46}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           78.22
#    B           19.80
#    C            0.99
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.888663           87.99
#         Developed Markets - Equities 0.010626            1.05
# Emerging Markets State - Obligations 0.056162            5.56
#       High Yield Bonds - Obligations 0.002073            0.21
# Investment Grade Bonds - Obligations 0.050355            4.99
#    Government ZC Bonds - Obligations 0.002120            0.21
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = N
# Match found at row 7. Updating status to 'Y'.
# Status updated successfully.
# 2030 6 30 45
# Starting Year: 2025
# Current Year: 2030
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 5, 'GOAL B': 10, 'GOAL C': 15, 'GOAL D': 45}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           81.19
#    B           14.85
#    C            2.97
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Allocation (%)
#          Emerging Markets - Equities 9.573535e-01           94.79
#         Developed Markets - Equities 3.832138e-02            3.79
# Emerging Markets State - Obligations 1.432516e-02            1.42
#       High Yield Bonds - Obligations 6.648842e-16            0.00
# Investment Grade Bonds - Obligations 1.717168e-16            0.00
#    Government ZC Bonds - Obligations 1.273661e-16            0.00
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = N
# Match found at row 8. Updating status to 'Y'.
# Status updated successfully.
# 2031 7 31 46
# Starting Year: 2025
# Current Year: 2031
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 4, 'GOAL B': 9, 'GOAL C': 14, 'GOAL D': 44}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           88.12
#    B            7.92
#    C            0.99
#    D            2.97
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.497620           49.27
#         Developed Markets - Equities 0.038950            3.86
# Emerging Markets State - Obligations 0.244588           24.22
#       High Yield Bonds - Obligations 0.001763            0.17
# Investment Grade Bonds - Obligations 0.224017           22.18
#    Government ZC Bonds - Obligations 0.003061            0.30
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = N
# Match found at row 9. Updating status to 'Y'.
# Status updated successfully.
# 2032 8 32 47
# Starting Year: 2025
# Current Year: 2032
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 3, 'GOAL B': 8, 'GOAL C': 13, 'GOAL D': 43}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           83.17
#    B           12.87
#    C            0.99
#    D            2.97
#
# Optimal Aggregate Investment Allocation:
#                                Asset   Weight  Allocation (%)
#          Emerging Markets - Equities 0.287708           28.49
#         Developed Markets - Equities 0.015410            1.53
# Emerging Markets State - Obligations 0.064754            6.41
#       High Yield Bonds - Obligations 0.002408            0.24
# Investment Grade Bonds - Obligations 0.297428           29.45
#    Government ZC Bonds - Obligations 0.342293           33.89
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = N
# Match found at row 10. Updating status to 'Y'.
# Status updated successfully.
# 2033 9 33 48
# Starting Year: 2025
# Current Year: 2033
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 2, 'GOAL B': 7, 'GOAL C': 12, 'GOAL D': 42}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A           74.26
#    B           13.86
#    C           10.89
#    D            0.99
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Allocation (%)
#          Emerging Markets - Equities 1.200000e-01           11.88
#         Developed Markets - Equities 3.077378e-14            0.00
# Emerging Markets State - Obligations 0.000000e+00            0.00
#       High Yield Bonds - Obligations 4.779887e-18            0.00
# Investment Grade Bonds - Obligations 6.435378e-19            0.00
#    Government ZC Bonds - Obligations 8.900000e-01           88.12
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = N
# Match found at row 11. Updating status to 'Y'.
# Status updated successfully.
# 2034 10 34 49
# Starting Year: 2025
# Current Year: 2034
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 1, 'GOAL B': 6, 'GOAL C': 11, 'GOAL D': 41}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            66.0
#    B            13.0
#    C            17.0
#    D             4.0
#
# Optimal Aggregate Investment Allocation:
#                                Asset       Weight  Allocation (%)
#          Emerging Markets - Equities 2.100000e-01            21.0
#         Developed Markets - Equities 6.430265e-16             0.0
# Emerging Markets State - Obligations 0.000000e+00             0.0
#       High Yield Bonds - Obligations 0.000000e+00             0.0
# Investment Grade Bonds - Obligations 0.000000e+00             0.0
#    Government ZC Bonds - Obligations 7.900000e-01            79.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = N
# Match found at row 12. Updating status to 'Y'.
# Status updated successfully.
# 2035 11 35 50
# Starting Year: 2025
# Current Year: 2035
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': 0, 'GOAL B': 5, 'GOAL C': 10, 'GOAL D': 40}
# C:\Users\admin\AppData\Local\Temp\ipykernel_7232\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B            11.0
#    C            44.0
#    D            45.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.45            45.0
# Obligations    0.55            55.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = N
# Match found at row 13. Updating status to 'Y'.
# Status updated successfully.
# 2036 12 36 51
# Starting Year: 2025
# Current Year: 2036
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -1, 'GOAL B': 4, 'GOAL C': 9, 'GOAL D': 39}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B            10.0
#    C            40.0
#    D            50.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.505957           50.09
# Obligations 0.504043           49.91
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = N
# Match found at row 14. Updating status to 'Y'.
# Status updated successfully.
# 2037 13 37 52
# Starting Year: 2025
# Current Year: 2037
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -2, 'GOAL B': 3, 'GOAL C': 8, 'GOAL D': 38}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B            10.0
#    C            36.0
#    D            54.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.54            54.0
# Obligations    0.46            46.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = N
# Match found at row 15. Updating status to 'Y'.
# Status updated successfully.
# 2038 14 38 53
# Starting Year: 2025
# Current Year: 2038
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -3, 'GOAL B': 2, 'GOAL C': 7, 'GOAL D': 37}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             9.0
#    C            34.0
#    D            57.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.57            57.0
# Obligations    0.43            43.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = N
# Match found at row 16. Updating status to 'Y'.
# Status updated successfully.
# 2039 15 39 54
# Starting Year: 2025
# Current Year: 2039
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -4, 'GOAL B': 1, 'GOAL C': 6, 'GOAL D': 36}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            8.16
#    C           32.65
#    D           59.18
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.581292           58.72
# Obligations 0.408708           41.28
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = N
# Match found at row 17. Updating status to 'Y'.
# Status updated successfully.
# 2040 16 40 55
# Starting Year: 2025
# Current Year: 2040
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -5, 'GOAL B': 0, 'GOAL C': 5, 'GOAL D': 35}
# C:\Users\admin\AppData\Local\Temp\ipykernel_7232\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C            29.9
#    D            70.1
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.686573           68.66
# Obligations 0.313427           31.34
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = N
# Match found at row 18. Updating status to 'Y'.
# Status updated successfully.
# 2041 17 41 56
# Starting Year: 2025
# Current Year: 2041
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -6, 'GOAL B': -1, 'GOAL C': 4, 'GOAL D': 34}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C            26.8
#    D            73.2
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.722064           72.94
# Obligations 0.267936           27.06
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = N
# Match found at row 19. Updating status to 'Y'.
# Status updated successfully.
# 2042 18 42 57
# Starting Year: 2025
# Current Year: 2042
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -7, 'GOAL B': -2, 'GOAL C': 3, 'GOAL D': 33}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C           26.53
#    D           73.47
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.723329           72.33
# Obligations 0.276671           27.67
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = N
# Match found at row 20. Updating status to 'Y'.
# Status updated successfully.
# 2043 19 43 58
# Starting Year: 2025
# Current Year: 2043
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -8, 'GOAL B': -3, 'GOAL C': 2, 'GOAL D': 32}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C           25.26
#    D           74.74
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.71            70.3
# Obligations    0.30            29.7
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = N
# Match found at row 21. Updating status to 'Y'.
# Status updated successfully.
# 2044 20 44 59
# Starting Year: 2025
# Current Year: 2044
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -9, 'GOAL B': -4, 'GOAL C': 1, 'GOAL D': 31}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A            0.00
#    B            0.00
#    C           21.21
#    D           78.79
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.785325           77.75
# Obligations 0.224675           22.25
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = N
# Match found at row 22. Updating status to 'Y'.
# Status updated successfully.
# 2045 21 45 60
# Starting Year: 2025
# Current Year: 2045
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -10, 'GOAL B': -5, 'GOAL C': 0, 'GOAL D': 30}
# C:\Users\admin\AppData\Local\Temp\ipykernel_7232\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.957632           96.73
# Obligations 0.032368            3.27
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = N
# Match found at row 23. Updating status to 'Y'.
# Status updated successfully.
# 2046 22 46 61
# Starting Year: 2025
# Current Year: 2046
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -11, 'GOAL B': -6, 'GOAL C': -1, 'GOAL D': 29}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.861152           86.12
# Obligations 0.138848           13.88
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = N
# Match found at row 24. Updating status to 'Y'.
# Status updated successfully.
# 2047 23 47 62
# Starting Year: 2025
# Current Year: 2047
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -12, 'GOAL B': -7, 'GOAL C': -2, 'GOAL D': 28}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.919355           91.94
# Obligations 0.080645            8.06
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = N
# Match found at row 25. Updating status to 'Y'.
# Status updated successfully.
# 2048 24 48 63
# Starting Year: 2025
# Current Year: 2048
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -13, 'GOAL B': -8, 'GOAL C': -3, 'GOAL D': 27}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.870224            87.9
# Obligations 0.119776            12.1
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = N
# Match found at row 26. Updating status to 'Y'.
# Status updated successfully.
# 2049 25 49 64
# Starting Year: 2025
# Current Year: 2049
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -14, 'GOAL B': -9, 'GOAL C': -4, 'GOAL D': 26}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.877001            87.7
# Obligations 0.122999            12.3
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = N
# Match found at row 27. Updating status to 'Y'.
# Status updated successfully.
# 2050 26 50 65
# Starting Year: 2025
# Current Year: 2050
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -15, 'GOAL B': -10, 'GOAL C': -5, 'GOAL D': 25}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.945944           93.66
# Obligations 0.064056            6.34
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = N
# Match found at row 28. Updating status to 'Y'.
# Status updated successfully.
# 2051 27 51 66
# Starting Year: 2025
# Current Year: 2051
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -16, 'GOAL B': -11, 'GOAL C': -6, 'GOAL D': 24}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.893925           89.39
# Obligations 0.106075           10.61
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = N
# Match found at row 29. Updating status to 'Y'.
# Status updated successfully.
# 2052 28 52 67
# Starting Year: 2025
# Current Year: 2052
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -17, 'GOAL B': -12, 'GOAL C': -7, 'GOAL D': 23}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.82            82.0
# Obligations    0.18            18.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = N
# Match found at row 30. Updating status to 'Y'.
# Status updated successfully.
# 2053 29 53 68
# Starting Year: 2025
# Current Year: 2053
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -18, 'GOAL B': -13, 'GOAL C': -8, 'GOAL D': 22}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.92            92.0
# Obligations    0.08             8.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = N
# Match found at row 31. Updating status to 'Y'.
# Status updated successfully.
# 2054 30 54 69
# Starting Year: 2025
# Current Year: 2054
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -19, 'GOAL B': -14, 'GOAL C': -9, 'GOAL D': 21}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.913665           91.37
# Obligations 0.086335            8.63
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = N
# Match found at row 32. Updating status to 'Y'.
# Status updated successfully.
# 2055 31 55 70
# Starting Year: 2025
# Current Year: 2055
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -20, 'GOAL B': -15, 'GOAL C': -10, 'GOAL D': 20}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.78            78.0
# Obligations    0.22            22.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = N
# Match found at row 33. Updating status to 'Y'.
# Status updated successfully.
# 2056 32 56 71
# Starting Year: 2025
# Current Year: 2056
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -21, 'GOAL B': -16, 'GOAL C': -11, 'GOAL D': 19}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.873737           87.37
# Obligations 0.126263           12.63
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = N
# Match found at row 34. Updating status to 'Y'.
# Status updated successfully.
# 2057 33 57 72
# Starting Year: 2025
# Current Year: 2057
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -22, 'GOAL B': -17, 'GOAL C': -12, 'GOAL D': 18}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.81            81.0
# Obligations    0.19            19.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = N
# Match found at row 35. Updating status to 'Y'.
# Status updated successfully.
# 2058 34 58 73
# Starting Year: 2025
# Current Year: 2058
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -23, 'GOAL B': -18, 'GOAL C': -13, 'GOAL D': 17}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.921848           93.12
# Obligations 0.068152            6.88
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = N
# Match found at row 36. Updating status to 'Y'.
# Status updated successfully.
# 2059 35 59 74
# Starting Year: 2025
# Current Year: 2059
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# ...
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = N
# Match found at row 47. Updating status to 'Y'.
# Status updated successfully.
# 2070 46 70 85
# Starting Year: 2025
# Current Year: 2070
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -35, 'GOAL B': -30, 'GOAL C': -25, 'GOAL D': 5}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.83           83.84
# Obligations    0.16           16.16
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = N
# Match found at row 48. Updating status to 'Y'.
# Status updated successfully.
# 2071 47 71 86
# Starting Year: 2025
# Current Year: 2071
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -36, 'GOAL B': -31, 'GOAL C': -26, 'GOAL D': 4}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities     0.9            90.0
# Obligations     0.1            10.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = N
# Match found at row 49. Updating status to 'Y'.
# Status updated successfully.
# 2072 48 72 87
# Starting Year: 2025
# Current Year: 2072
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -37, 'GOAL B': -32, 'GOAL C': -27, 'GOAL D': 3}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.89            89.9
# Obligations    0.10            10.1
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = N
# Match found at row 50. Updating status to 'Y'.
# Status updated successfully.
# 2073 49 73 88
# Starting Year: 2025
# Current Year: 2073
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -38, 'GOAL B': -33, 'GOAL C': -28, 'GOAL D': 2}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset  Weight  Allocation (%)
#    Equities    0.87            87.0
# Obligations    0.13            13.0
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = N
# Match found at row 51. Updating status to 'Y'.
# Status updated successfully.
# 2074 50 74 89
# Starting Year: 2025
# Current Year: 2074
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -39, 'GOAL B': -34, 'GOAL C': -29, 'GOAL D': 1}
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D           100.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.468261           46.83
# Obligations 0.531739           53.17
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = Y
# Row 52: Year = 2074.0, Status = N
# Match found at row 52. Updating status to 'Y'.
# Status updated successfully.
# 2075 51 75 90
# Starting Year: 2025
# Current Year: 2075
# Goal Years: {'GOAL A': 2035, 'GOAL B': 2040, 'GOAL C': 2045, 'GOAL D': 2075}
# Adjusted Horizons: {'GOAL A': -40, 'GOAL B': -35, 'GOAL C': -30, 'GOAL D': 0}
# C:\Users\admin\AppData\Local\Temp\ipykernel_7232\411645512.py:18: RuntimeWarning: divide by zero encountered in scalar divide
#   required_return = (goal_vector[1] / denominator)**(1 / goal_vector[2]) - 1
# Optimal Across-Goal Allocation:
# Goal  Allocation (%)
#    A             0.0
#    B             0.0
#    C             0.0
#    D             0.0
#
# Optimal Aggregate Investment Allocation:
#       Asset   Weight  Allocation (%)
#    Equities 0.135799           13.58
# Obligations 0.864201           86.42
# Starting loop status check...
# Accessed 'Loop' worksheet.
# Last cell row: 1048576
# Loaded loop data. Total rows read: 1048575
# Row 2: Year = Year, Status = LoopStatus
# Row 3: Year = 2025.0, Status = Y
# Row 4: Year = 2026.0, Status = Y
# Row 5: Year = 2027.0, Status = Y
# Row 6: Year = 2028.0, Status = Y
# Row 7: Year = 2029.0, Status = Y
# Row 8: Year = 2030.0, Status = Y
# Row 9: Year = 2031.0, Status = Y
# Row 10: Year = 2032.0, Status = Y
# Row 11: Year = 2033.0, Status = Y
# Row 12: Year = 2034.0, Status = Y
# Row 13: Year = 2035.0, Status = Y
# Row 14: Year = 2036.0, Status = Y
# Row 15: Year = 2037.0, Status = Y
# Row 16: Year = 2038.0, Status = Y
# Row 17: Year = 2039.0, Status = Y
# Row 18: Year = 2040.0, Status = Y
# Row 19: Year = 2041.0, Status = Y
# Row 20: Year = 2042.0, Status = Y
# Row 21: Year = 2043.0, Status = Y
# Row 22: Year = 2044.0, Status = Y
# Row 23: Year = 2045.0, Status = Y
# Row 24: Year = 2046.0, Status = Y
# Row 25: Year = 2047.0, Status = Y
# Row 26: Year = 2048.0, Status = Y
# Row 27: Year = 2049.0, Status = Y
# Row 28: Year = 2050.0, Status = Y
# Row 29: Year = 2051.0, Status = Y
# Row 30: Year = 2052.0, Status = Y
# Row 31: Year = 2053.0, Status = Y
# Row 32: Year = 2054.0, Status = Y
# Row 33: Year = 2055.0, Status = Y
# Row 34: Year = 2056.0, Status = Y
# Row 35: Year = 2057.0, Status = Y
# Row 36: Year = 2058.0, Status = Y
# Row 37: Year = 2059.0, Status = Y
# Row 38: Year = 2060.0, Status = Y
# Row 39: Year = 2061.0, Status = Y
# Row 40: Year = 2062.0, Status = Y
# Row 41: Year = 2063.0, Status = Y
# Row 42: Year = 2064.0, Status = Y
# Row 43: Year = 2065.0, Status = Y
# Row 44: Year = 2066.0, Status = Y
# Row 45: Year = 2067.0, Status = Y
# Row 46: Year = 2068.0, Status = Y
# Row 47: Year = 2069.0, Status = Y
# Row 48: Year = 2070.0, Status = Y
# Row 49: Year = 2071.0, Status = Y
# Row 50: Year = 2072.0, Status = Y
# Row 51: Year = 2073.0, Status = Y
# Row 52: Year = 2074.0, Status = Y
# Row 53: Year = 2075.0, Status = N
# Match found at row 53. Updating status to 'Y'.
# Status updated successfully.
# All loops completed

# %%
# - NEW V5 CONTENT REGARDING AKTIESPAREKONTO ALLOCATION - #
final_accounts_df = pd.concat(all_account_allocations, ignore_index=True)
final_accounts_df.to_csv(os.path.join(output_folder, "account_allocations_log.csv"), index=False)

# %%
# V6 Export
pd.DataFrame(tax_log).to_csv(os.path.join(output_folder, "tax_log.csv"), index=False)

# %%
if infeasible_goals_log:
    print("\n⚠️ Infeasible goal scenarios encountered:")
    for year, goal, reason in infeasible_goals_log:
        print(f" - Year {year}, Goal {goal}: {reason}")

    # Optional: write to CSV
    pd.DataFrame(infeasible_goals_log, columns=["Year", "Goal", "Reason"]).to_csv(
        os.path.join(output_folder, "infeasible_goals_log.csv"), index=False)
else:
    print("\n✅ No infeasible goals encountered.")
# Out:
# ⚠️ Infeasible goal scenarios encountered:
#  - Year 2028, Goal Goal A: Required return > 100% (109.26%)
#  - Year 2029, Goal Goal A: Required return > 100% (127.66%)
#  - Year 2029, Goal Goal A: Required return > 100% (102.82%)
#  - Year 2030, Goal Goal A: Required return > 100% (158.36%)
#  - Year 2030, Goal Goal A: Required return > 100% (124.91%)
#  - Year 2030, Goal Goal A: Required return > 100% (107.40%)
#  - Year 2031, Goal Goal A: Required return > 100% (214.61%)
#  - Year 2031, Goal Goal A: Required return > 100% (164.55%)
#  - Year 2031, Goal Goal A: Required return > 100% (139.05%)
#  - Year 2031, Goal Goal A: Required return > 100% (122.46%)
#  - Year 2031, Goal Goal A: Required return > 100% (110.39%)
#  - Year 2031, Goal Goal A: Required return > 100% (101.02%)
#  - Year 2032, Goal Goal A: Required return > 100% (338.07%)
#  - Year 2032, Goal Goal A: Required return > 100% (247.70%)
#  - Year 2032, Goal Goal A: Required return > 100% (203.74%)
#  - Year 2032, Goal Goal A: Required return > 100% (175.97%)
#  - Year 2032, Goal Goal A: Required return > 100% (156.19%)
#  - Year 2032, Goal Goal A: Required return > 100% (141.08%)
#  - Year 2032, Goal Goal A: Required return > 100% (129.01%)
#  - Year 2032, Goal Goal A: Required return > 100% (119.04%)
#  - Year 2032, Goal Goal A: Required return > 100% (110.60%)
#  - Year 2032, Goal Goal A: Required return > 100% (103.34%)
#  - Year 2033, Goal Goal A: Required return > 100% (757.52%)
#  - Year 2033, Goal Goal A: Required return > 100% (506.36%)
#  - Year 2033, Goal Goal A: Required return > 100% (395.09%)
#  - Year 2033, Goal Goal A: Required return > 100% (328.76%)
#  - Year 2033, Goal Goal A: Required return > 100% (283.49%)
#  - Year 2033, Goal Goal A: Required return > 100% (250.08%)
#  - Year 2033, Goal Goal A: Required return > 100% (224.11%)
#  - Year 2033, Goal Goal A: Required return > 100% (203.18%)
#  - Year 2033, Goal Goal A: Required return > 100% (185.84%)
#  - Year 2033, Goal Goal A: Required return > 100% (171.17%)
#  - Year 2033, Goal Goal A: Required return > 100% (158.55%)
#  - Year 2033, Goal Goal A: Required return > 100% (147.54%)
#  - Year 2033, Goal Goal A: Required return > 100% (137.83%)
#  - Year 2033, Goal Goal A: Required return > 100% (129.18%)
#  - Year 2033, Goal Goal A: Required return > 100% (121.41%)
#  - Year 2033, Goal Goal A: Required return > 100% (114.38%)
#  - Year 2033, Goal Goal A: Required return > 100% (107.98%)
#  - Year 2033, Goal Goal A: Required return > 100% (102.12%)
#  - Year 2034, Goal Goal A: Required return > 100% (6427.17%)
#  - Year 2034, Goal Goal A: Required return > 100% (3163.59%)
#  - Year 2034, Goal Goal A: Required return > 100% (2075.72%)
#  - Year 2034, Goal Goal A: Required return > 100% (1531.79%)
#  - Year 2034, Goal Goal A: Required return > 100% (1205.43%)
#  - Year 2034, Goal Goal A: Required return > 100% (987.86%)
#  - Year 2034, Goal Goal A: Required return > 100% (832.45%)
#  - Year 2034, Goal Goal A: Required return > 100% (715.90%)
#  - Year 2034, Goal Goal A: Required return > 100% (625.24%)
#  - Year 2034, Goal Goal A: Required return > 100% (552.72%)
#  - Year 2034, Goal Goal A: Required return > 100% (493.38%)
#  - Year 2034, Goal Goal A: Required return > 100% (443.93%)
#  - Year 2034, Goal Goal A: Required return > 100% (402.09%)
#  - Year 2034, Goal Goal A: Required return > 100% (366.23%)
#  - Year 2034, Goal Goal A: Required return > 100% (335.14%)
#  - Year 2034, Goal Goal A: Required return > 100% (307.95%)
#  - Year 2034, Goal Goal A: Required return > 100% (283.95%)
#  - Year 2034, Goal Goal A: Required return > 100% (262.62%)
#  - Year 2034, Goal Goal A: Required return > 100% (243.54%)
#  - Year 2034, Goal Goal A: Required return > 100% (226.36%)
#  - Year 2034, Goal Goal A: Required return > 100% (210.82%)
#  - Year 2034, Goal Goal A: Required return > 100% (196.69%)
#  - Year 2034, Goal Goal A: Required return > 100% (183.79%)
#  - Year 2034, Goal Goal A: Required return > 100% (171.97%)
#  - Year 2034, Goal Goal A: Required return > 100% (161.09%)
#  - Year 2034, Goal Goal A: Required return > 100% (151.05%)
#  - Year 2034, Goal Goal A: Required return > 100% (141.75%)
#  - Year 2034, Goal Goal A: Required return > 100% (133.11%)
#  - Year 2034, Goal Goal A: Required return > 100% (125.07%)
#  - Year 2034, Goal Goal A: Required return > 100% (117.57%)
#  - Year 2034, Goal Goal A: Required return > 100% (110.55%)
#  - Year 2034, Goal Goal A: Required return > 100% (103.97%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2035, Goal Goal A: Required return > 100% (inf%)
#  - Year 2037, Goal Goal B: Required return > 100% (107.66%)
#  - Year 2038, Goal Goal B: Required return > 100% (186.10%)
#  - Year 2038, Goal Goal B: Required return > 100% (102.30%)
#  - Year 2039, Goal Goal B: Required return > 100% (653.16%)
#  - Year 2039, Goal Goal B: Required return > 100% (276.58%)
#  - Year 2039, Goal Goal B: Required return > 100% (151.05%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2040, Goal Goal B: Required return > 100% (inf%)
#  - Year 2041, Goal Goal C: Required return > 100% (124.87%)
#  - Year 2041, Goal Goal B: Required return > 100% (103.36%)
#  - Year 2041, Goal Goal B: Required return > 100% (119.01%)
#  - Year 2041, Goal Goal B: Required return > 100% (134.65%)
#  - Year 2041, Goal Goal B: Required return > 100% (150.29%)
#  - Year 2041, Goal Goal B: Required return > 100% (165.94%)
#  - Year 2041, Goal Goal B: Required return > 100% (181.58%)
#  - Year 2041, Goal Goal B: Required return > 100% (197.22%)
#  - Year 2041, Goal Goal B: Required return > 100% (212.86%)
#  - Year 2041, Goal Goal B: Required return > 100% (228.51%)
#  - Year 2041, Goal Goal B: Required return > 100% (244.15%)
#  - Year 2041, Goal Goal B: Required return > 100% (259.79%)
#  - Year 2041, Goal Goal B: Required return > 100% (275.44%)
#  - Year 2041, Goal Goal B: Required return > 100% (291.08%)
#  - Year 2041, Goal Goal B: Required return > 100% (306.72%)
#  - Year 2041, Goal Goal B: Required return > 100% (322.37%)
#  - Year 2041, Goal Goal B: Required return > 100% (338.01%)
#  - Year 2041, Goal Goal B: Required return > 100% (353.65%)
#  - Year 2041, Goal Goal B: Required return > 100% (369.30%)
#  - Year 2041, Goal Goal B: Required return > 100% (384.94%)
#  - Year 2041, Goal Goal B: Required return > 100% (400.58%)
#  - Year 2041, Goal Goal B: Required return > 100% (416.23%)
#  - Year 2041, Goal Goal B: Required return > 100% (431.87%)
#  - Year 2041, Goal Goal B: Required return > 100% (447.51%)
#  - Year 2041, Goal Goal B: Required return > 100% (463.16%)
#  - Year 2041, Goal Goal B: Required return > 100% (478.80%)
#  - Year 2041, Goal Goal B: Required return > 100% (494.44%)
#  - Year 2041, Goal Goal B: Required return > 100% (510.09%)
#  - Year 2041, Goal Goal B: Required return > 100% (525.73%)
#  - Year 2041, Goal Goal B: Required return > 100% (541.37%)
#  - Year 2041, Goal Goal B: Required return > 100% (557.02%)
#  - Year 2041, Goal Goal B: Required return > 100% (572.66%)
#  - Year 2041, Goal Goal B: Required return > 100% (588.30%)
#  - Year 2041, Goal Goal B: Required return > 100% (603.95%)
#  - Year 2041, Goal Goal B: Required return > 100% (619.59%)
#  - Year 2041, Goal Goal B: Required return > 100% (635.23%)
#  - Year 2041, Goal Goal B: Required return > 100% (650.88%)
#  - Year 2041, Goal Goal B: Required return > 100% (666.52%)
#  - Year 2041, Goal Goal B: Required return > 100% (682.16%)
#  - Year 2041, Goal Goal B: Required return > 100% (697.81%)
#  - Year 2041, Goal Goal B: Required return > 100% (713.45%)
#  - Year 2041, Goal Goal B: Required return > 100% (729.09%)
#  - Year 2041, Goal Goal B: Required return > 100% (744.74%)
#  - Year 2041, Goal Goal B: Required return > 100% (760.38%)
#  - Year 2041, Goal Goal B: Required return > 100% (776.02%)
#  - Year 2041, Goal Goal B: Required return > 100% (791.67%)
#  - Year 2041, Goal Goal B: Required return > 100% (807.31%)
#  - Year 2041, Goal Goal B: Required return > 100% (822.95%)
#  - Year 2041, Goal Goal B: Required return > 100% (838.59%)
#  - Year 2041, Goal Goal B: Required return > 100% (854.24%)
#  - Year 2041, Goal Goal B: Required return > 100% (869.88%)
#  - Year 2041, Goal Goal B: Required return > 100% (885.52%)
#  - Year 2041, Goal Goal B: Required return > 100% (901.17%)
#  - Year 2041, Goal Goal B: Required return > 100% (916.81%)
#  - Year 2041, Goal Goal B: Required return > 100% (932.45%)
#  - Year 2041, Goal Goal B: Required return > 100% (948.10%)
#  - Year 2041, Goal Goal B: Required return > 100% (963.74%)
#  - Year 2041, Goal Goal B: Required return > 100% (979.38%)
#  - Year 2041, Goal Goal B: Required return > 100% (995.03%)
#  - Year 2041, Goal Goal B: Required return > 100% (1010.67%)
#  - Year 2041, Goal Goal B: Required return > 100% (1026.31%)
#  - Year 2041, Goal Goal B: Required return > 100% (1041.96%)
#  - Year 2041, Goal Goal B: Required return > 100% (1057.60%)
#  - Year 2041, Goal Goal B: Required return > 100% (1073.24%)
#  - Year 2041, Goal Goal B: Required return > 100% (1088.89%)
#  - Year 2041, Goal Goal B: Required return > 100% (1104.53%)
#  - Year 2041, Goal Goal B: Required return > 100% (1120.17%)
#  - Year 2041, Goal Goal B: Required return > 100% (1135.82%)
#  - Year 2041, Goal Goal B: Required return > 100% (1151.46%)
#  - Year 2041, Goal Goal B: Required return > 100% (1167.10%)
#  - Year 2041, Goal Goal B: Required return > 100% (1182.75%)
#  - Year 2041, Goal Goal B: Required return > 100% (1198.39%)
#  - Year 2041, Goal Goal B: Required return > 100% (1214.03%)
#  - Year 2041, Goal Goal B: Required return > 100% (1229.68%)
#  - Year 2041, Goal Goal B: Required return > 100% (1245.32%)
#  - Year 2041, Goal Goal B: Required return > 100% (1260.96%)
#  - Year 2041, Goal Goal B: Required return > 100% (1276.61%)
#  - Year 2041, Goal Goal B: Required return > 100% (1292.25%)
#  - Year 2041, Goal Goal B: Required return > 100% (1307.89%)
#  - Year 2041, Goal Goal B: Required return > 100% (1323.54%)
#  - Year 2041, Goal Goal B: Required return > 100% (1339.18%)
#  - Year 2041, Goal Goal B: Required return > 100% (1354.82%)
#  - Year 2041, Goal Goal B: Required return > 100% (1370.47%)
#  - Year 2041, Goal Goal B: Required return > 100% (1386.11%)
#  - Year 2041, Goal Goal B: Required return > 100% (1401.75%)
#  - Year 2041, Goal Goal B: Required return > 100% (1417.40%)
#  - Year 2041, Goal Goal B: Required return > 100% (1433.04%)
#  - Year 2041, Goal Goal B: Required return > 100% (1448.68%)
#  - Year 2041, Goal Goal B: Required return > 100% (1464.32%)
#  - Year 2042, Goal Goal C: Required return > 100% (187.43%)
#  - Year 2042, Goal Goal C: Required return > 100% (128.14%)
#  - Year 2042, Goal Goal B: Required return > 100% (101.06%)
#  - Year 2042, Goal Goal B: Required return > 100% (105.21%)
#  - Year 2042, Goal Goal B: Required return > 100% (109.27%)
#  - Year 2042, Goal Goal B: Required return > 100% (113.26%)
#  - Year 2042, Goal Goal B: Required return > 100% (117.17%)
#  - Year 2042, Goal Goal B: Required return > 100% (121.01%)
#  - Year 2042, Goal Goal B: Required return > 100% (124.79%)
#  - Year 2042, Goal Goal B: Required return > 100% (128.51%)
#  - Year 2042, Goal Goal B: Required return > 100% (132.17%)
#  - Year 2042, Goal Goal B: Required return > 100% (135.76%)
#  - Year 2042, Goal Goal B: Required return > 100% (139.31%)
#  - Year 2042, Goal Goal B: Required return > 100% (142.80%)
#  - Year 2042, Goal Goal B: Required return > 100% (146.25%)
#  - Year 2042, Goal Goal B: Required return > 100% (149.65%)
#  - Year 2042, Goal Goal B: Required return > 100% (153.00%)
#  - Year 2042, Goal Goal B: Required return > 100% (156.30%)
#  - Year 2042, Goal Goal B: Required return > 100% (159.57%)
#  - Year 2042, Goal Goal B: Required return > 100% (162.79%)
#  - Year 2042, Goal Goal B: Required return > 100% (165.98%)
#  - Year 2042, Goal Goal B: Required return > 100% (169.13%)
#  - Year 2042, Goal Goal B: Required return > 100% (172.24%)
#  - Year 2042, Goal Goal B: Required return > 100% (175.31%)
#  - Year 2042, Goal Goal B: Required return > 100% (178.36%)
#  - Year 2042, Goal Goal B: Required return > 100% (181.37%)
#  - Year 2042, Goal Goal B: Required return > 100% (184.34%)
#  - Year 2042, Goal Goal B: Required return > 100% (187.29%)
#  - Year 2042, Goal Goal B: Required return > 100% (190.21%)
#  - Year 2042, Goal Goal B: Required return > 100% (193.09%)
#  - Year 2042, Goal Goal B: Required return > 100% (195.95%)
#  - Year 2042, Goal Goal B: Required return > 100% (198.79%)
#  - Year 2042, Goal Goal B: Required return > 100% (201.59%)
#  - Year 2042, Goal Goal B: Required return > 100% (204.37%)
#  - Year 2042, Goal Goal B: Required return > 100% (207.13%)
#  - Year 2042, Goal Goal B: Required return > 100% (209.86%)
#  - Year 2042, Goal Goal B: Required return > 100% (212.56%)
#  - Year 2042, Goal Goal B: Required return > 100% (215.25%)
#  - Year 2042, Goal Goal B: Required return > 100% (217.91%)
#  - Year 2042, Goal Goal B: Required return > 100% (220.54%)
#  - Year 2042, Goal Goal B: Required return > 100% (223.16%)
#  - Year 2042, Goal Goal B: Required return > 100% (225.76%)
#  - Year 2042, Goal Goal B: Required return > 100% (228.33%)
#  - Year 2042, Goal Goal B: Required return > 100% (230.89%)
#  - Year 2042, Goal Goal B: Required return > 100% (233.42%)
#  - Year 2042, Goal Goal B: Required return > 100% (235.94%)
#  - Year 2042, Goal Goal B: Required return > 100% (238.44%)
#  - Year 2042, Goal Goal B: Required return > 100% (240.92%)
#  - Year 2042, Goal Goal B: Required return > 100% (243.38%)
#  - Year 2042, Goal Goal B: Required return > 100% (245.82%)
#  - Year 2042, Goal Goal B: Required return > 100% (248.25%)
#  - Year 2042, Goal Goal B: Required return > 100% (250.66%)
#  - Year 2042, Goal Goal B: Required return > 100% (253.05%)
#  - Year 2042, Goal Goal B: Required return > 100% (255.43%)
#  - Year 2042, Goal Goal B: Required return > 100% (257.79%)
#  - Year 2042, Goal Goal B: Required return > 100% (260.14%)
#  - Year 2042, Goal Goal B: Required return > 100% (262.47%)
#  - Year 2042, Goal Goal B: Required return > 100% (264.78%)
#  - Year 2042, Goal Goal B: Required return > 100% (267.09%)
#  - Year 2042, Goal Goal B: Required return > 100% (269.37%)
#  - Year 2042, Goal Goal B: Required return > 100% (271.65%)
#  - Year 2042, Goal Goal B: Required return > 100% (273.91%)
#  - Year 2042, Goal Goal B: Required return > 100% (276.15%)
#  - Year 2042, Goal Goal B: Required return > 100% (278.38%)
#  - Year 2042, Goal Goal B: Required return > 100% (280.60%)
#  - Year 2042, Goal Goal B: Required return > 100% (282.81%)
#  - Year 2042, Goal Goal B: Required return > 100% (285.00%)
#  - Year 2042, Goal Goal B: Required return > 100% (287.18%)
#  - Year 2042, Goal Goal B: Required return > 100% (289.35%)
#  - Year 2042, Goal Goal B: Required return > 100% (291.51%)
#  - Year 2042, Goal Goal B: Required return > 100% (293.66%)
#  - Year 2042, Goal Goal B: Required return > 100% (295.79%)
#  - Year 2042, Goal Goal B: Required return > 100% (297.91%)
#  - Year 2042, Goal Goal B: Required return > 100% (300.02%)
#  - Year 2042, Goal Goal B: Required return > 100% (302.12%)
#  - Year 2042, Goal Goal B: Required return > 100% (304.21%)
#  - Year 2042, Goal Goal B: Required return > 100% (306.29%)
#  - Year 2042, Goal Goal B: Required return > 100% (308.36%)
#  - Year 2042, Goal Goal B: Required return > 100% (310.41%)
#  - Year 2043, Goal Goal C: Required return > 100% (370.66%)
#  - Year 2043, Goal Goal C: Required return > 100% (232.81%)
#  - Year 2043, Goal Goal C: Required return > 100% (171.74%)
#  - Year 2043, Goal Goal C: Required return > 100% (135.33%)
#  - Year 2043, Goal Goal C: Required return > 100% (110.49%)
#  - Year 2043, Goal Goal B: Required return > 100% (101.04%)
#  - Year 2043, Goal Goal B: Required return > 100% (102.52%)
#  - Year 2043, Goal Goal B: Required return > 100% (103.98%)
#  - Year 2043, Goal Goal B: Required return > 100% (105.41%)
#  - Year 2043, Goal Goal B: Required return > 100% (106.83%)
#  - Year 2043, Goal Goal B: Required return > 100% (108.23%)
#  - Year 2043, Goal Goal B: Required return > 100% (109.61%)
#  - Year 2043, Goal Goal B: Required return > 100% (110.97%)
#  - Year 2043, Goal Goal B: Required return > 100% (112.31%)
#  - Year 2043, Goal Goal B: Required return > 100% (113.64%)
#  - Year 2043, Goal Goal B: Required return > 100% (114.95%)
#  - Year 2043, Goal Goal B: Required return > 100% (116.24%)
#  - Year 2043, Goal Goal B: Required return > 100% (117.52%)
#  - Year 2043, Goal Goal B: Required return > 100% (118.79%)
#  - Year 2043, Goal Goal B: Required return > 100% (120.04%)
#  - Year 2043, Goal Goal B: Required return > 100% (121.27%)
#  - Year 2043, Goal Goal B: Required return > 100% (122.50%)
#  - Year 2043, Goal Goal B: Required return > 100% (123.71%)
#  - Year 2043, Goal Goal B: Required return > 100% (124.90%)
#  - Year 2043, Goal Goal B: Required return > 100% (126.09%)
#  - Year 2043, Goal Goal B: Required return > 100% (127.26%)
#  - Year 2043, Goal Goal B: Required return > 100% (128.42%)
#  - Year 2043, Goal Goal B: Required return > 100% (129.56%)
#  - Year 2043, Goal Goal B: Required return > 100% (130.70%)
#  - Year 2043, Goal Goal B: Required return > 100% (131.83%)
#  - Year 2043, Goal Goal B: Required return > 100% (132.94%)
#  - Year 2043, Goal Goal B: Required return > 100% (134.04%)
#  - Year 2043, Goal Goal B: Required return > 100% (135.14%)
#  - Year 2043, Goal Goal B: Required return > 100% (136.22%)
#  - Year 2043, Goal Goal B: Required return > 100% (137.30%)
#  - Year 2043, Goal Goal B: Required return > 100% (138.36%)
#  - Year 2043, Goal Goal B: Required return > 100% (139.41%)
#  - Year 2043, Goal Goal B: Required return > 100% (140.46%)
#  - Year 2043, Goal Goal B: Required return > 100% (141.50%)
#  - Year 2043, Goal Goal B: Required return > 100% (142.52%)
#  - Year 2043, Goal Goal B: Required return > 100% (143.54%)
#  - Year 2043, Goal Goal B: Required return > 100% (144.55%)
#  - Year 2043, Goal Goal B: Required return > 100% (145.56%)
#  - Year 2043, Goal Goal B: Required return > 100% (146.55%)
#  - Year 2043, Goal Goal B: Required return > 100% (147.54%)
#  - Year 2043, Goal Goal B: Required return > 100% (148.51%)
#  - Year 2043, Goal Goal B: Required return > 100% (149.49%)
#  - Year 2043, Goal Goal B: Required return > 100% (150.45%)
#  - Year 2043, Goal Goal B: Required return > 100% (151.40%)
#  - Year 2043, Goal Goal B: Required return > 100% (152.35%)
#  - Year 2043, Goal Goal B: Required return > 100% (153.30%)
#  - Year 2043, Goal Goal B: Required return > 100% (154.23%)
#  - Year 2043, Goal Goal B: Required return > 100% (155.16%)
#  - Year 2043, Goal Goal B: Required return > 100% (156.08%)
#  - Year 2043, Goal Goal B: Required return > 100% (156.99%)
#  - Year 2043, Goal Goal B: Required return > 100% (157.90%)
#  - Year 2043, Goal Goal B: Required return > 100% (158.80%)
#  - Year 2043, Goal Goal B: Required return > 100% (159.70%)
#  - Year 2043, Goal Goal B: Required return > 100% (160.59%)
#  - Year 2043, Goal Goal B: Required return > 100% (161.47%)
#  - Year 2043, Goal Goal B: Required return > 100% (162.35%)
#  - Year 2044, Goal Goal C: Required return > 100% (1961.55%)
#  - Year 2044, Goal Goal C: Required return > 100% (930.78%)
#  - Year 2044, Goal Goal C: Required return > 100% (587.18%)
#  - Year 2044, Goal Goal C: Required return > 100% (415.39%)
#  - Year 2044, Goal Goal C: Required return > 100% (312.31%)
#  - Year 2044, Goal Goal C: Required return > 100% (243.59%)
#  - Year 2044, Goal Goal C: Required return > 100% (194.51%)
#  - Year 2044, Goal Goal C: Required return > 100% (157.69%)
#  - Year 2044, Goal Goal C: Required return > 100% (129.06%)
#  - Year 2044, Goal Goal C: Required return > 100% (106.16%)
#  - Year 2044, Goal Goal B: Required return > 100% (100.33%)
#  - Year 2044, Goal Goal B: Required return > 100% (100.93%)
#  - Year 2044, Goal Goal B: Required return > 100% (101.52%)
#  - Year 2044, Goal Goal B: Required return > 100% (102.11%)
#  - Year 2044, Goal Goal B: Required return > 100% (102.70%)
#  - Year 2044, Goal Goal B: Required return > 100% (103.28%)
#  - Year 2044, Goal Goal B: Required return > 100% (103.85%)
#  - Year 2044, Goal Goal B: Required return > 100% (104.42%)
#  - Year 2044, Goal Goal B: Required return > 100% (104.99%)
#  - Year 2044, Goal Goal B: Required return > 100% (105.55%)
#  - Year 2044, Goal Goal B: Required return > 100% (106.10%)
#  - Year 2044, Goal Goal B: Required return > 100% (106.66%)
#  - Year 2044, Goal Goal B: Required return > 100% (107.20%)
#  - Year 2044, Goal Goal B: Required return > 100% (107.75%)
#  - Year 2044, Goal Goal B: Required return > 100% (108.29%)
#  - Year 2044, Goal Goal B: Required return > 100% (108.82%)
#  - Year 2044, Goal Goal B: Required return > 100% (109.35%)
#  - Year 2044, Goal Goal B: Required return > 100% (109.88%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2045, Goal Goal C: Required return > 100% (inf%)
#  - Year 2046, Goal Goal C: Required return > 100% (104.75%)
#  - Year 2046, Goal Goal C: Required return > 100% (110.29%)
#  - Year 2046, Goal Goal C: Required return > 100% (115.82%)
#  - Year 2046, Goal Goal C: Required return > 100% (121.36%)
#  - Year 2046, Goal Goal C: Required return > 100% (126.89%)
#  - Year 2046, Goal Goal C: Required return > 100% (132.42%)
#  - Year 2046, Goal Goal C: Required return > 100% (137.96%)
#  - Year 2046, Goal Goal C: Required return > 100% (143.49%)
#  - Year 2046, Goal Goal C: Required return > 100% (149.03%)
#  - Year 2046, Goal Goal C: Required return > 100% (154.56%)
#  - Year 2046, Goal Goal C: Required return > 100% (160.09%)
#  - Year 2046, Goal Goal C: Required return > 100% (165.63%)
#  - Year 2046, Goal Goal C: Required return > 100% (171.16%)
#  - Year 2046, Goal Goal C: Required return > 100% (176.70%)
#  - Year 2046, Goal Goal C: Required return > 100% (182.23%)
#  - Year 2046, Goal Goal C: Required return > 100% (187.76%)
#  - Year 2046, Goal Goal C: Required return > 100% (193.30%)
#  - Year 2046, Goal Goal C: Required return > 100% (198.83%)
#  - Year 2046, Goal Goal C: Required return > 100% (204.37%)
#  - Year 2046, Goal Goal C: Required return > 100% (209.90%)
#  - Year 2046, Goal Goal C: Required return > 100% (215.43%)
#  - Year 2046, Goal Goal C: Required return > 100% (220.97%)
#  - Year 2046, Goal Goal C: Required return > 100% (226.50%)
#  - Year 2046, Goal Goal C: Required return > 100% (232.03%)
#  - Year 2046, Goal Goal C: Required return > 100% (237.57%)
#  - Year 2046, Goal Goal C: Required return > 100% (243.10%)
#  - Year 2046, Goal Goal C: Required return > 100% (248.64%)
#  - Year 2046, Goal Goal C: Required return > 100% (254.17%)
#  - Year 2046, Goal Goal C: Required return > 100% (259.70%)
#  - Year 2046, Goal Goal C: Required return > 100% (265.24%)
#  - Year 2046, Goal Goal C: Required return > 100% (270.77%)
#  - Year 2046, Goal Goal C: Required return > 100% (276.31%)
#  - Year 2046, Goal Goal C: Required return > 100% (281.84%)
#  - Year 2046, Goal Goal C: Required return > 100% (287.37%)
#  - Year 2046, Goal Goal C: Required return > 100% (292.91%)
#  - Year 2046, Goal Goal C: Required return > 100% (298.44%)
#  - Year 2046, Goal Goal C: Required return > 100% (303.98%)
#  - Year 2046, Goal Goal C: Required return > 100% (309.51%)
#  - Year 2046, Goal Goal C: Required return > 100% (315.04%)
#  - Year 2046, Goal Goal C: Required return > 100% (320.58%)
#  - Year 2046, Goal Goal C: Required return > 100% (326.11%)
#  - Year 2046, Goal Goal C: Required return > 100% (331.65%)
#  - Year 2046, Goal Goal C: Required return > 100% (337.18%)
#  - Year 2046, Goal Goal C: Required return > 100% (342.71%)
#  - Year 2046, Goal Goal C: Required return > 100% (348.25%)
#  - Year 2046, Goal Goal C: Required return > 100% (353.78%)
#  - Year 2046, Goal Goal C: Required return > 100% (359.31%)
#  - Year 2046, Goal Goal C: Required return > 100% (364.85%)
#  - Year 2046, Goal Goal C: Required return > 100% (370.38%)
#  - Year 2046, Goal Goal C: Required return > 100% (375.92%)
#  - Year 2046, Goal Goal C: Required return > 100% (381.45%)
#  - Year 2046, Goal Goal C: Required return > 100% (386.98%)
#  - Year 2046, Goal Goal C: Required return > 100% (392.52%)
#  - Year 2046, Goal Goal C: Required return > 100% (398.05%)
#  - Year 2046, Goal Goal C: Required return > 100% (403.59%)
#  - Year 2046, Goal Goal C: Required return > 100% (409.12%)
#  - Year 2046, Goal Goal C: Required return > 100% (414.65%)
#  - Year 2046, Goal Goal C: Required return > 100% (420.19%)
#  - Year 2046, Goal Goal C: Required return > 100% (425.72%)
#  - Year 2046, Goal Goal C: Required return > 100% (431.26%)
#  - Year 2046, Goal Goal C: Required return > 100% (436.79%)
#  - Year 2046, Goal Goal C: Required return > 100% (442.32%)
#  - Year 2046, Goal Goal C: Required return > 100% (447.86%)
#  - Year 2046, Goal Goal C: Required return > 100% (453.39%)
#  - Year 2047, Goal Goal C: Required return > 100% (101.44%)
#  - Year 2047, Goal Goal C: Required return > 100% (102.89%)
#  - Year 2047, Goal Goal C: Required return > 100% (104.33%)
#  - Year 2047, Goal Goal C: Required return > 100% (105.77%)
#  - Year 2047, Goal Goal C: Required return > 100% (107.19%)
#  - Year 2047, Goal Goal C: Required return > 100% (108.61%)
#  - Year 2047, Goal Goal C: Required return > 100% (110.01%)
#  - Year 2047, Goal Goal C: Required return > 100% (111.41%)
#  - Year 2047, Goal Goal C: Required return > 100% (112.79%)
#  - Year 2047, Goal Goal C: Required return > 100% (114.17%)
#  - Year 2047, Goal Goal C: Required return > 100% (115.54%)
#  - Year 2047, Goal Goal C: Required return > 100% (116.90%)
#  - Year 2047, Goal Goal C: Required return > 100% (118.25%)
#  - Year 2047, Goal Goal C: Required return > 100% (119.59%)
#  - Year 2047, Goal Goal C: Required return > 100% (120.93%)
#  - Year 2047, Goal Goal C: Required return > 100% (122.26%)
#  - Year 2047, Goal Goal C: Required return > 100% (123.57%)
#  - Year 2047, Goal Goal C: Required return > 100% (124.89%)
#  - Year 2047, Goal Goal C: Required return > 100% (126.19%)
#  - Year 2047, Goal Goal C: Required return > 100% (127.49%)
#  - Year 2047, Goal Goal C: Required return > 100% (128.77%)
#  - Year 2047, Goal Goal C: Required return > 100% (130.06%)
#  - Year 2047, Goal Goal C: Required return > 100% (131.33%)
#  - Year 2047, Goal Goal C: Required return > 100% (132.60%)
#  - Year 2047, Goal Goal C: Required return > 100% (133.86%)
#  - Year 2047, Goal Goal C: Required return > 100% (135.11%)
#  - Year 2047, Goal Goal C: Required return > 100% (136.36%)
#  - Year 2047, Goal Goal C: Required return > 100% (137.60%)
#  - Year 2047, Goal Goal C: Required return > 100% (138.84%)
#  - Year 2047, Goal Goal C: Required return > 100% (140.06%)
#  - Year 2047, Goal Goal C: Required return > 100% (141.28%)
#  - Year 2047, Goal Goal C: Required return > 100% (142.50%)
#  - Year 2068, Goal Goal D: Required return > 100% (107.32%)
#  - Year 2069, Goal Goal D: Required return > 100% (132.80%)
#  - Year 2069, Goal Goal D: Required return > 100% (107.40%)
#  - Year 2070, Goal Goal D: Required return > 100% (173.85%)
#  - Year 2070, Goal Goal D: Required return > 100% (138.40%)
#  - Year 2070, Goal Goal D: Required return > 100% (119.83%)
#  - Year 2070, Goal Goal D: Required return > 100% (107.54%)
#  - Year 2071, Goal Goal D: Required return > 100% (252.28%)
#  - Year 2071, Goal Goal D: Required return > 100% (196.23%)
#  - Year 2071, Goal Goal D: Required return > 100% (167.68%)
#  - Year 2071, Goal Goal D: Required return > 100% (149.10%)
#  - Year 2071, Goal Goal D: Required return > 100% (135.59%)
#  - Year 2071, Goal Goal D: Required return > 100% (125.09%)
#  - Year 2071, Goal Goal D: Required return > 100% (116.58%)
#  - Year 2071, Goal Goal D: Required return > 100% (109.47%)
#  - Year 2071, Goal Goal D: Required return > 100% (103.39%)
#  - Year 2072, Goal Goal D: Required return > 100% (436.03%)
#  - Year 2072, Goal Goal D: Required return > 100% (325.45%)
#  - Year 2072, Goal Goal D: Required return > 100% (271.66%)
#  - Year 2072, Goal Goal D: Required return > 100% (237.68%)
#  - Year 2072, Goal Goal D: Required return > 100% (213.47%)
#  - Year 2072, Goal Goal D: Required return > 100% (194.99%)
#  - Year 2072, Goal Goal D: Required return > 100% (180.21%)
#  - Year 2072, Goal Goal D: Required return > 100% (168.02%)
#  - Year 2072, Goal Goal D: Required return > 100% (157.70%)
#  - Year 2072, Goal Goal D: Required return > 100% (148.80%)
#  - Year 2072, Goal Goal D: Required return > 100% (141.02%)
#  - Year 2072, Goal Goal D: Required return > 100% (134.13%)
#  - Year 2072, Goal Goal D: Required return > 100% (127.97%)
#  - Year 2072, Goal Goal D: Required return > 100% (122.41%)
#  - Year 2072, Goal Goal D: Required return > 100% (117.35%)
#  - Year 2072, Goal Goal D: Required return > 100% (112.72%)
#  - Year 2072, Goal Goal D: Required return > 100% (108.47%)
#  - Year 2072, Goal Goal D: Required return > 100% (104.53%)
#  - Year 2072, Goal Goal D: Required return > 100% (100.88%)
#  - Year 2073, Goal Goal D: Required return > 100% (1141.04%)
#  - Year 2073, Goal Goal D: Required return > 100% (777.55%)
#  - Year 2073, Goal Goal D: Required return > 100% (616.51%)
#  - Year 2073, Goal Goal D: Required return > 100% (520.52%)
#  - Year 2073, Goal Goal D: Required return > 100% (455.01%)
#  - Year 2073, Goal Goal D: Required return > 100% (406.65%)
#  - Year 2073, Goal Goal D: Required return > 100% (369.07%)
#  - Year 2073, Goal Goal D: Required return > 100% (338.77%)
#  - Year 2073, Goal Goal D: Required return > 100% (313.68%)
#  - Year 2073, Goal Goal D: Required return > 100% (292.45%)
#  - Year 2073, Goal Goal D: Required return > 100% (274.19%)
#  - Year 2073, Goal Goal D: Required return > 100% (258.26%)
#  - Year 2073, Goal Goal D: Required return > 100% (244.20%)
#  - Year 2073, Goal Goal D: Required return > 100% (231.68%)
#  - Year 2073, Goal Goal D: Required return > 100% (220.43%)
#  - Year 2073, Goal Goal D: Required return > 100% (210.26%)
#  - Year 2073, Goal Goal D: Required return > 100% (201.00%)
#  - Year 2073, Goal Goal D: Required return > 100% (192.52%)
#  - Year 2073, Goal Goal D: Required return > 100% (184.71%)
#  - Year 2073, Goal Goal D: Required return > 100% (177.50%)
#  - Year 2073, Goal Goal D: Required return > 100% (170.82%)
#  - Year 2073, Goal Goal D: Required return > 100% (164.59%)
#  - Year 2073, Goal Goal D: Required return > 100% (158.77%)
#  - Year 2073, Goal Goal D: Required return > 100% (153.33%)
#  - Year 2073, Goal Goal D: Required return > 100% (148.21%)
#  - Year 2073, Goal Goal D: Required return > 100% (143.39%)
#  - Year 2073, Goal Goal D: Required return > 100% (138.84%)
#  - Year 2073, Goal Goal D: Required return > 100% (134.53%)
#  - Year 2073, Goal Goal D: Required return > 100% (130.46%)
#  - Year 2073, Goal Goal D: Required return > 100% (126.58%)
#  - Year 2073, Goal Goal D: Required return > 100% (122.90%)
#  - Year 2073, Goal Goal D: Required return > 100% (119.39%)
#  - Year 2073, Goal Goal D: Required return > 100% (116.04%)
#  - Year 2073, Goal Goal D: Required return > 100% (112.84%)
#  - Year 2073, Goal Goal D: Required return > 100% (109.77%)
#  - Year 2073, Goal Goal D: Required return > 100% (106.84%)
#  - Year 2073, Goal Goal D: Required return > 100% (104.03%)
#  - Year 2073, Goal Goal D: Required return > 100% (101.32%)
#  - Year 2074, Goal Goal D: Required return > 100% (15301.78%)
#  - Year 2074, Goal Goal D: Required return > 100% (7600.89%)
#  - Year 2074, Goal Goal D: Required return > 100% (5033.93%)
#  - Year 2074, Goal Goal D: Required return > 100% (3750.45%)
#  - Year 2074, Goal Goal D: Required return > 100% (2980.36%)
#  - Year 2074, Goal Goal D: Required return > 100% (2466.96%)
#  - Year 2074, Goal Goal D: Required return > 100% (2100.25%)
#  - Year 2074, Goal Goal D: Required return > 100% (1825.22%)
#  - Year 2074, Goal Goal D: Required return > 100% (1611.31%)
#  - Year 2074, Goal Goal D: Required return > 100% (1440.18%)
#  - Year 2074, Goal Goal D: Required return > 100% (1300.16%)
#  - Year 2074, Goal Goal D: Required return > 100% (1183.48%)
#  - Year 2074, Goal Goal D: Required return > 100% (1084.75%)
#  - Year 2074, Goal Goal D: Required return > 100% (1000.13%)
#  - Year 2074, Goal Goal D: Required return > 100% (926.79%)
#  - Year 2074, Goal Goal D: Required return > 100% (862.61%)
#  - Year 2074, Goal Goal D: Required return > 100% (805.99%)
#  - Year 2074, Goal Goal D: Required return > 100% (755.65%)
#  - Year 2074, Goal Goal D: Required return > 100% (710.62%)
#  - Year 2074, Goal Goal D: Required return > 100% (670.09%)
#  - Year 2074, Goal Goal D: Required return > 100% (633.42%)
#  - Year 2074, Goal Goal D: Required return > 100% (600.08%)
#  - Year 2074, Goal Goal D: Required return > 100% (569.64%)
#  - Year 2074, Goal Goal D: Required return > 100% (541.74%)
#  - Year 2074, Goal Goal D: Required return > 100% (516.07%)
#  - Year 2074, Goal Goal D: Required return > 100% (492.38%)
#  - Year 2074, Goal Goal D: Required return > 100% (470.44%)
#  - Year 2074, Goal Goal D: Required return > 100% (450.06%)
#  - Year 2074, Goal Goal D: Required return > 100% (431.10%)
#  - Year 2074, Goal Goal D: Required return > 100% (413.39%)
#  - Year 2074, Goal Goal D: Required return > 100% (396.83%)
#  - Year 2074, Goal Goal D: Required return > 100% (381.31%)
#  - Year 2074, Goal Goal D: Required return > 100% (366.72%)
#  - Year 2074, Goal Goal D: Required return > 100% (352.99%)
#  - Year 2074, Goal Goal D: Required return > 100% (340.05%)
#  - Year 2074, Goal Goal D: Required return > 100% (327.83%)
#  - Year 2074, Goal Goal D: Required return > 100% (316.26%)
#  - Year 2074, Goal Goal D: Required return > 100% (305.31%)
#  - Year 2074, Goal Goal D: Required return > 100% (294.92%)
#  - Year 2074, Goal Goal D: Required return > 100% (285.04%)
#  - Year 2074, Goal Goal D: Required return > 100% (275.65%)
#  - Year 2074, Goal Goal D: Required return > 100% (266.71%)
#  - Year 2074, Goal Goal D: Required return > 100% (258.18%)
#  - Year 2074, Goal Goal D: Required return > 100% (250.04%)
#  - Year 2074, Goal Goal D: Required return > 100% (242.26%)
#  - Year 2074, Goal Goal D: Required return > 100% (234.82%)
#  - Year 2074, Goal Goal D: Required return > 100% (227.70%)
#  - Year 2074, Goal Goal D: Required return > 100% (220.87%)
#  - Year 2074, Goal Goal D: Required return > 100% (214.32%)
#  - Year 2074, Goal Goal D: Required return > 100% (208.04%)
#  - Year 2074, Goal Goal D: Required return > 100% (202.00%)
#  - Year 2074, Goal Goal D: Required return > 100% (196.19%)
#  - Year 2074, Goal Goal D: Required return > 100% (190.60%)
#  - Year 2074, Goal Goal D: Required return > 100% (185.22%)
#  - Year 2074, Goal Goal D: Required return > 100% (180.03%)
#  - Year 2074, Goal Goal D: Required return > 100% (175.03%)
#  - Year 2074, Goal Goal D: Required return > 100% (170.21%)
#  - Year 2074, Goal Goal D: Required return > 100% (165.55%)
#  - Year 2074, Goal Goal D: Required return > 100% (161.05%)
#  - Year 2074, Goal Goal D: Required return > 100% (156.70%)
#  - Year 2074, Goal Goal D: Required return > 100% (152.49%)
#  - Year 2074, Goal Goal D: Required return > 100% (148.42%)
#  - Year 2074, Goal Goal D: Required return > 100% (144.47%)
#  - Year 2074, Goal Goal D: Required return > 100% (140.65%)
#  - Year 2074, Goal Goal D: Required return > 100% (136.95%)
#  - Year 2074, Goal Goal D: Required return > 100% (133.36%)
#  - Year 2074, Goal Goal D: Required return > 100% (129.88%)
#  - Year 2074, Goal Goal D: Required return > 100% (126.50%)
#  - Year 2074, Goal Goal D: Required return > 100% (123.21%)
#  - Year 2074, Goal Goal D: Required return > 100% (120.03%)
#  - Year 2074, Goal Goal D: Required return > 100% (116.93%)
#  - Year 2074, Goal Goal D: Required return > 100% (113.91%)
#  - Year 2074, Goal Goal D: Required return > 100% (110.98%)
#  - Year 2074, Goal Goal D: Required return > 100% (108.13%)
#  - Year 2074, Goal Goal D: Required return > 100% (105.36%)
#  - Year 2074, Goal Goal D: Required return > 100% (102.66%)
#  - Year 2074, Goal Goal D: Required return > 100% (100.02%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
#  - Year 2075, Goal Goal D: Required return > 100% (inf%)
