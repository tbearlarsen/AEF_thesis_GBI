# %% [markdown]
# # Estimating vasicek parameters and approximate risk premium

# %% [markdown]
# ## Load packages

# %%
import os
from codelib.file_management.dynamic_file_pathing import get_root
import pandas as pd
import numpy as np
from codelib.Models.vasicek_model import VasicekRiskNeutralEstimator
from codelib.Models.vasicek_model import VasicekModel

# %% [markdown]
# ## Load data

# %%
root = get_root()
data_folder = os.path.join(root, 'Simulation', 'Bonds', 'Data')
data = os.path.join(data_folder, 'monthly_rate_and_yields.xlsx')
#data = pd.read_excel(os.path.join(data_folder, 'monthly_rate_and_yields.xlsx'), index_col=0)

# %% [markdown]
# ## Initialising the model

# %%
risk_premium = -0.02
model = VasicekRiskNeutralEstimator(data,12)

# %% [markdown]
# ### Estimate parameters

# %%
model.estimate_params(rates)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.estimate_params(rates)
#
# File ~/Repositories/AEF_thesis_GBI/codelib/Models/vasicek_model.py:334, in VasicekRiskNeutralEstimator.estimate_params(self, rates)
#     332 # Perform OLS regression: r_{t+1} = theta + phi * r_t + error
#     333 X = sm.add_constant(r_t)
# --> 334 model = sm.OLS(r_t1, X).fit()
#     335 print(model.summary())
#     337 phi_hat = model.params[1]
#
# File /opt/anaconda3/envs/PyFin/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:921, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     918     msg = ("Weights are not supported in OLS and will be ignored"
#     919            "An exception will be raised in the next version.")
#     920     warnings.warn(msg, ValueWarning)
# --> 921 super().__init__(endog, exog, missing=missing,
# ...

# %% [markdown]
# ### Compute risk neutral parameter

# %%
model.compute_risk_neutral()

# %% [markdown]
# ### Price ZCBs and compute model-implied yields.

# %%
# Use the last observed short rate as the current rate.
r_current = rates.iloc[-1]
# Define the maturities (in years) for the ZCBs.
maturities = [1, 5, 10, 20, 30]
model_yields = {}

print("\nModel-Implied Yields:")
for T in maturities:
    price = model.price_zcb(r_current, T)
    yield_cc = model.yield_from_price(price, T)
    model_yields[T] = yield_cc
    print(f"  {T}Y yield: {yield_cc:.4%}")
